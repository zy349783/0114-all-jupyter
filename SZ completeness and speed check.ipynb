# %%
import pandas as pd
import numpy as np

# data1 = pd.read_csv(r'\\192.168.10.28\DataTeamShared\20200723\zs_52_08\mdLog_SZ_20200723_1225.csv',
#                     encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
#                                               "exchange", "time", "cum_volume", "cum_amount", "close",
#                                               "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
#                                               "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
#                                               "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
#                                               "ask4q", "ask5q", "openPrice"]]
# data2 = pd.read_csv(r'\\192.168.10.28\DataTeamShared\20200723\zs_52_08\mdLog_SZ_20200723_1306.csv',
#                     encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
#                                               "exchange", "time", "cum_volume", "cum_amount", "close",
#                                               "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
#                                               "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
#                                               "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
#                                               "ask4q", "ask5q", "openPrice"]]
# data3 = pd.read_csv(r'F:\data\20200723\preMDGW\mdLog_SZ_20200723_0911.csv').loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
#                                               "exchange", "time", "cum_volume", "cum_amount", "close",
#                                               "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
#                                               "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
#                                               "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
#                                               "ask4q", "ask5q", "openPrice"]]
# logSZ = pd.concat([data3, data1, data2])
# del data1
# del data2
# del data3
logSZ = pd.read_csv(r'F:\data\20200820\full_20200820_zs_66_01_day_mdtest\mdLog_SZ_20200820_0843.csv').loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
                                              "exchange", "time", "cum_volume", "cum_amount", "close",
                                              "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
                                              "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
                                              "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
                                              "ask4q", "ask5q", "openPrice"]]
logSZ1 = pd.read_csv(r'F:\data\20200820\full_20200820_zs_66_01_day_6678\mdLog_SZ_20200820_0847.csv').loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
                                              "exchange", "time", "cum_volume", "cum_amount", "close",
                                              "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
                                              "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
                                              "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
                                              "ask4q", "ask5q", "openPrice"]]
print("original data source type: ")
print(logSZ["source"].unique())
print("new data source type: ")
print(logSZ1["source"].unique())
print(logSZ["time"].unique())
print(logSZ1["time"].unique())
# Out:
# original data source type:
# [4 3]
# new data source type:
# [24]
# ['08:44:09.000' '08:45:09.000' '08:46:09.000' ... '15:32:03.000'
#  '15:33:03.000' '15:34:03.000']
# ['08:48:09.000' '08:49:09.000' '08:50:09.000' ... '15:28:03.000'
#  '15:29:03.000' '15:30:03.000']

# %%
logSZ[logSZ['time'] <= 114203000].groupby('StockID')['time'].max().min()
# Out:
# 114200000

# %%
logSZ1[logSZ1['time'] <= 114203000].groupby('StockID')['time'].max().min()
# Out:
# 114200000

# %%
logSZ1["time"] = logSZ1["time"].apply(lambda x: int((x.replace(':', "")).replace(".", "")))
logSZ["time"] = logSZ["time"].apply(lambda x: int((x.replace(':', "")).replace(".", "")))

display(logSZ[(logSZ["StockID"] == 1) & (logSZ["time"] >= 93000000) & (logSZ["time"] <= 93500000)])
display(logSZ1[(logSZ1["StockID"] == 1) & (logSZ1["time"] >= 93000000) & (logSZ1["time"] <= 93500000)])
# Out:
#           clockAtArrival  sequenceNo  source  StockID exchange      time  \
# 317048  1597887004380294     2244101       4        1       SZ  93000000
# 317150  1597887004429409     2251170       3        1       SZ  93000000
# 319870  1597887007523874     2694965       4        1       SZ  93003000
# 320495  1597887007783258     2728948       3        1       SZ  93003000
# 324345  1597887010501358     3112547       4        1       SZ  93006000
# ...                  ...         ...     ...      ...      ...       ...
# 739276  1597887298787393    12594383       3        1       SZ  93454000
# 742739  1597887301457215    12654920       4        1       SZ  93457000
# 742836  1597887301489713    12656018       3        1       SZ  93457000
# 746970  1597887304415018    12722996       4        1       SZ  93500000
# 747278  1597887304598977    12728323       3        1       SZ  93500000
#
#         cum_volume    cum_amount  close  bid1p  ...  ask2p  ask3p  ask4p  \
# 351998     7412400  1.115226e+08  15.05  15.05  ...  15.07  15.08  15.09
# 354142     7418400  1.116129e+08  15.05  15.05  ...  15.08  15.09  15.10
#
#         ask5p  ask1q  ask2q  ask3q  ask4q  ask5q  openPrice
# 137644  15.09  15100  10200   1500   3800  28200      15.01
# 139055  15.07    100  64700  22800  21100   2000      15.01
# 141290  15.07  24200  46500  21700  10000   2000      15.01
# 143539  15.06  23200    500  40700  13900  10600      15.01
# 145754  15.05  42786   4900   1400  28300  18600      15.01
# ...       ...    ...    ...    ...    ...    ...        ...
# 345559  15.11  13500  44700  80200  65300  29990      15.01
# 347716  15.11  13500  42700  78900  65300  29990      15.01
# 349870  15.11  10300  42700  68600  68300  29990      15.01
# 351998  15.10   2000  11600  41700  68600  68500      15.01
# 354142  15.11  13100  41700  68700  69200  28890      15.01
#
# [101 rows x 30 columns]

# %%
logSZ = pd.read_csv(r'F:\data\20200817\logs_20200817_zs_96_03_day_96data\mdLog_SZ_20200817_0839.csv').loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
                                              "exchange", "time", "cum_volume", "cum_amount", "close",
                                              "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
                                              "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
                                              "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
                                              "ask4q", "ask5q", "openPrice"]]
display(logSZ['source'].unique())
logSZ["time"] = logSZ["time"].apply(lambda x: int((x.replace(':', "")).replace(".", "")))
# Out:
# array([24], dtype=int64)

# %%
data1 = logSZ[(logSZ["cum_volume"] > 0) & (logSZ["time"] < 145700000) & (logSZ["source"] == 4)]
data2 = logSZ1[(logSZ1["cum_volume"] > 0) & (logSZ1["time"] < 145700000) & (logSZ1["source"] == 24)]
columns = ["StockID", "cum_volume", "cum_amount", "close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q", "bid2q",
           "bid3q", "bid4q", "bid5q", "ask1p", "ask2p", "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
           "ask4q", "ask5q", "openPrice"]
data1_1 = data1.drop_duplicates(subset=columns, keep="first").reset_index()
data2_1 = data2.drop_duplicates(subset=columns, keep="first").reset_index()
n1 = len(data1_1["StockID"].unique())
n2 = len(data2_1["StockID"].unique())
print(n1)
print(n2)
if n1 != n2:
    sl = list(set(data1_1["StockID"].unique()) & (set(data2_1["StockID"].unique())))
    data1_1 = data1_1[data1_1["StockID"].isin(sl)]
    data2_1 = data2_1[data2_1["StockID"].isin(sl)]
test = pd.merge(data1_1, data2_1, left_on=columns, right_on=columns, how="outer")
n1 = test["sequenceNo_x"].count()
n2 = test["sequenceNo_y"].count()
len1 = len(test)
print(n1)
print(n2)
print(len1)
print("-----------------------------------------------")
if n2 < len1:
    display("test is not complete:")
    display(test[np.isnan(test["sequenceNo_y"])])
    print(len(test[np.isnan(test["sequenceNo_y"])])/n1)
if (len1 == n2) & (n1 < len1):
    display("baseline is not complete:")
    display(test[np.isnan(test["sequenceNo_x"])])
    display(n2-n1)
# Out:
# 2233
# 2233
# 7630618
# 7771174
# 7771174
# -----------------------------------------------
# 'baseline is not complete:'
#          index_x  clockAtArrival_x  sequenceNo_x  source_x  StockID  \
# 7630618      NaN               NaN           NaN       NaN      536
# 7630619      NaN               NaN           NaN       NaN      537
# 7630620      NaN               NaN           NaN       NaN      538
# 7630621      NaN               NaN           NaN       NaN      553
# 7630622      NaN               NaN           NaN       NaN      555
# ...          ...               ...           ...       ...      ...
# 7771169      NaN               NaN           NaN       NaN   300796
# 7771170      NaN               NaN           NaN       NaN   300772
# 7771171      NaN               NaN           NaN       NaN   300783
# 7771172      NaN               NaN           NaN       NaN   300840
# 7771173      NaN               NaN           NaN       NaN   300849
#
#         exchange_x  time_x  cum_volume    cum_amount   close  ...   ask3q  \
# 7630618        NaN     NaN     8070300  1.766729e+07    2.19  ...  908843
# 7630619        NaN     NaN      549600  4.166092e+06    7.57  ...   20000
# 7630620        NaN     NaN      532920  5.406586e+07  101.30  ...     600
# 7630621        NaN     NaN     1229400  1.162026e+07    9.50  ...   21710
# 7630622        NaN     NaN     1970700  3.428637e+07   17.45  ...    9400
# ...            ...     ...         ...           ...     ...  ...     ...
# 7771169        NaN     NaN      654392  1.349524e+07   20.55  ...     300
# 7771170        NaN     NaN     2314951  3.367381e+07   14.46  ...    8100
# 7771171        NaN     NaN     1780637  1.173836e+08   65.88  ...     200
# 7771172        NaN     NaN     4924992  9.475866e+07   19.07  ...    4400
# 7771173        NaN     NaN      969782  2.646611e+07   27.31  ...    1600
#
#           ask4q   ask5q  openPrice  index_y  clockAtArrival_y  sequenceNo_y  \
# 7630618  546900  377000       2.16   484264  1597887487503706      29956264
# 7630619    6200   10000       7.60   484265  1597887487503708      29956265
# 7630620     100     100     101.71   484266  1597887487503711      29956266
# 7630621   14200   31800       9.42   484267  1597887487503717      29956267
# 7630622    3700   19200      17.22   484268  1597887487503721      29956268
# ...         ...     ...        ...      ...               ...           ...
# 7771169    5700     500      20.68  8354431  1597906274343989     225826130
# 7771170    1600    2700      14.75  8354432  1597906274344025     225826131
# 7771171     300    1000      66.98  8354441  1597906274347220     225826161
# 7771172    2300    2900      19.92  8354470  1597906274358341     225826256
# 7771173    2500    4300      27.20  8354484  1597906274367153     225826325
#
#          source_y  exchange_y     time_y
# 7630618        24          SZ   93803000
# 7630619        24          SZ   93803000
# 7630620        24          SZ   93803000
# 7630621        24          SZ   93803000
# 7630622        24          SZ   93803000
# ...           ...         ...        ...
# 7771169        24          SZ  145109000
# 7771170        24          SZ  145109000
# 7771171        24          SZ  145109000
# 7771172        24          SZ  145109000
# 7771173        24          SZ  145109000
#
# [140556 rows x 37 columns]
# 140556

# %%
# speed check
test1 = test[~np.isnan(test["sequenceNo_x"])]
test1 = test1[~np.isnan(test1["sequenceNo_y"])]
diff = test1["clockAtArrival_y"] - test1["clockAtArrival_x"]
print(np.quantile(abs(diff[diff < 0]), 0.25))
print(np.median(abs(diff[diff < 0])))
print(np.quantile(abs(diff[diff < 0]), 0.75))
print(np.quantile(diff[diff > 0], 0.25))
print(np.median(diff[diff > 0]))
print(np.quantile(diff[diff > 0], 0.75))
print(sum(diff < 0)/len(diff))
print(sum(diff > 0)/len(diff))
# Out:
# 1522.0
# 6767.0
# 13569.0
# 2893.0
# 3311.5
# 3669.25
# 0.9999944958586579
# 5.504141342156035e-06

# %%
import pandas as pd
import random
import numpy as np
import pickle

TradeLog = pd.read_csv(r'F:\data\20200820\full_20200820_zs_66_01_day_mdtest\mdTradeLog_20200820_0843.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
                                                 "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
                                                 "OfferApplSeqNum"]]
TradeLog1 = pd.read_csv(r'F:\data\20200820\full_20200820_zs_66_01_day_6678\mdTradeLog_20200820_0847.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
                                                 "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
                                                 "OfferApplSeqNum"]]

OrderLog = pd.read_csv(r'F:\data\20200820\full_20200820_zs_66_01_day_mdtest\mdOrderLog_20200820_0843.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
                                                 "OrderQty"]]

OrderLog1 = pd.read_csv(r'F:\data\20200820\full_20200820_zs_66_01_day_6678\mdOrderLog_20200820_0847.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
                                                 "OrderQty"]]

stocks = OrderLog1["SecurityID"].unique()
l1 = stocks[:1000]
l2 = stocks[1000:]
OrderLogSZ = OrderLog[OrderLog["SecurityID"].isin(l1)]
OrderLogSZ1 = OrderLog1[OrderLog1["SecurityID"].isin(l1)]
print(len(OrderLogSZ["SecurityID"].unique()))
print(len(OrderLogSZ1["SecurityID"].unique()))
OrderLogSZZ = OrderLog[OrderLog["SecurityID"].isin(l2)]
OrderLogSZZ1 = OrderLog1[OrderLog1["SecurityID"].isin(l2)]
print(len(OrderLogSZZ["SecurityID"].unique()))
print(len(OrderLogSZZ1["SecurityID"].unique()))
del OrderLog
del OrderLog1
TradeLogSZ = TradeLog[TradeLog["SecurityID"].isin(l1)]
TradeLogSZ1 = TradeLog1[TradeLog1["SecurityID"].isin(l1)]
print(len(TradeLogSZ["SecurityID"].unique()))
print(len(TradeLogSZ1["SecurityID"].unique()))
TradeLogSZZ = TradeLog[TradeLog["SecurityID"].isin(l2)]
TradeLogSZZ1 = TradeLog1[TradeLog1["SecurityID"].isin(l2)]
print(len(TradeLogSZZ["SecurityID"].unique()))
print(len(TradeLogSZZ1["SecurityID"].unique()))
# TradeLogSH = TradeLog[TradeLog["exchId"] == 1]
# TradeLogSH1 = TradeLog1[TradeLog1["exchId"] == 1]
# print(len(TradeLogSH["SecurityID"].unique()))
# print(len(TradeLogSH1["SecurityID"].unique()))
del TradeLog
del TradeLog1

OrderLogSZ.to_pickle(r'F:\\data\\20200820\\baseline\\order1.pkl')
OrderLogSZZ.to_pickle(r'F:\\data\\20200820\\baseline\\order2.pkl')
TradeLogSZ.to_pickle(r'F:\\data\\20200820\\baseline\\trade1.pkl')
TradeLogSZZ.to_pickle(r'F:\\data\\20200820\\baseline\\trade2.pkl')
# TradeLogSH.to_pickle(r'F:\\data\\20200324\\zt_88_02\\SH.pkl')
OrderLogSZ1.to_pickle(r'F:\\data\\20200820\\test\\order1.pkl')
OrderLogSZZ1.to_pickle(r'F:\\data\\20200820\\test\\order2.pkl')
TradeLogSZ1.to_pickle(r'F:\\data\\20200820\\test\\trade1.pkl')
TradeLogSZZ1.to_pickle(r'F:\\data\\20200820\\test\\trade2.pkl')
# TradeLogSH1.to_pickle(r'F:\\data\\20200324\\zt_88_03\\SH.pkl')
# Out:
# C:\Users\win\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\win\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 1000
# 1000
# 1233
# 1233
# 1000
# 1000
# 1233
# 1233

# %%
import pandas as pd
import random
import numpy as np
import pickle

F1 = open("F:\\data\\20200903\\baseline\\order1.pkl", 'rb')
OrderLogSZ = pickle.load(F1)
F2 = open("F:\\data\\20200903\\test\\order1.pkl", 'rb')
OrderLogSZ1 = pickle.load(F2)

OrderLogSZ["OrderType"] = OrderLogSZ["OrderType"].apply(lambda x: str(x))
OrderLogSZ1["OrderType"] = OrderLogSZ1["OrderType"].apply(lambda x: str(x))
sl = list(set(OrderLogSZ["SecurityID"].unique()) & set(OrderLogSZ1['SecurityID'].unique()))
OrderLogSZ = OrderLogSZ[OrderLogSZ["SecurityID"].isin(sl)]
OrderLogSZ1 = OrderLogSZ1[OrderLogSZ1["SecurityID"].isin(sl)]
print(len(OrderLogSZ["SecurityID"].unique()))
print(len(OrderLogSZ1["SecurityID"].unique()))

F1 = open("F:\\data\\20200903\\baseline\\order2.pkl", 'rb')
o = pickle.load(F1)
F2 = open("F:\\data\\20200903\\test\\order2.pkl", 'rb')
o1 = pickle.load(F2)
o["OrderType"] = o["OrderType"].apply(lambda x: str(x))
o["OrderType"] = o["OrderType"].apply(lambda x: str(x))
sl = list(set(o["SecurityID"].unique()) & set(o1['SecurityID'].unique()))
o = o[o["SecurityID"].isin(sl)]
o1 = o1[o1["SecurityID"].isin(sl)]
print(len(o["SecurityID"].unique()))
print(len(o1["SecurityID"].unique()))

OrderLogSZ = pd.concat([OrderLogSZ, o])
OrderLogSZ1 = pd.concat([OrderLogSZ1, o1])
del o
del o1
# Out:
# 1000
# 1000
# 1232
# 1232

# %%
import pandas as pd
import random
import numpy as np
import pickle

F3 = open("F:\\data\\20200903\\baseline\\trade1.pkl", 'rb')
TradeLogSZ = pickle.load(F3)
F4 = open("F:\\data\\20200903\\test\\trade1.pkl", 'rb')
TradeLogSZ1 = pickle.load(F4)
sl = list(set(TradeLogSZ["SecurityID"].unique()) & set(TradeLogSZ1['SecurityID'].unique()))
TradeLogSZ = TradeLogSZ[TradeLogSZ["SecurityID"].isin(sl)]
TradeLogSZ1 = TradeLogSZ1[TradeLogSZ1["SecurityID"].isin(sl)]
print(len(TradeLogSZ["SecurityID"].unique()))
print(len(TradeLogSZ1["SecurityID"].unique()))


F3 = open("F:\\data\\20200903\\baseline\\trade2.pkl", 'rb')
t = pickle.load(F3)
F4 = open("F:\\data\\20200903\\test\\trade2.pkl", 'rb')
t1 = pickle.load(F4)
sl = list(set(t["SecurityID"].unique()) & set(t1['SecurityID'].unique()))
t = t[t["SecurityID"].isin(sl)]
t1 = t1[t1["SecurityID"].isin(sl)]
print(len(t["SecurityID"].unique()))
print(len(t1["SecurityID"].unique()))

TradeLogSZ = pd.concat([TradeLogSZ, t])
TradeLogSZ1 = pd.concat([TradeLogSZ1, t1])
del t
del t1
# Out:
# 1000
# 1000
# 1232
# 1232

# %%
import pandas as pd
import numpy as np

TradeLog = pd.read_csv(r'F:\data\20200817\logs_20200817_zs_96_03_day_96data\mdTradeLog_20200817_0839.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
                                                 "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
                                                 "OfferApplSeqNum"]]
TradeLog1 = pd.read_csv(r'F:\data\20200817\full_20200817_zs_66_01_day_test\mdTradeLog_20200817_0859.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
                                                 "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
                                                 "OfferApplSeqNum"]]

OrderLog = pd.read_csv(r'F:\data\20200817\logs_20200817_zs_96_03_day_96data\mdOrderLog_20200817_0839.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
                                                 "OrderQty"]]

OrderLog1 = pd.read_csv(r'F:\data\20200817\full_20200817_zs_66_01_day_test\mdOrderLog_20200817_0859.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
                                                 "OrderQty"]]

stocks = list(set(OrderLog1["SecurityID"].unique()) & set(OrderLog["SecurityID"].unique()))
display(len(stocks))
OrderLogSZ = OrderLog[OrderLog["SecurityID"].isin(stocks)]
OrderLogSZ1 = OrderLog1[OrderLog1["SecurityID"].isin(stocks)]
del OrderLog
del OrderLog1
TradeLogSZ = TradeLog[TradeLog["SecurityID"].isin(stocks)]
TradeLogSZ1 = TradeLog1[TradeLog1["SecurityID"].isin(stocks)]
del TradeLog
del TradeLog1
OrderLogSZ["OrderType"] = OrderLogSZ["OrderType"].apply(lambda x: str(x))
OrderLogSZ1["OrderType"] = OrderLogSZ1["OrderType"].apply(lambda x: str(x))
print(len(OrderLogSZ["SecurityID"].unique()))
print(len(OrderLogSZ1["SecurityID"].unique()))
print(len(TradeLogSZ["SecurityID"].unique()))
print(len(TradeLogSZ1["SecurityID"].unique()))

# %%
TradeLogSZ1[(TradeLogSZ1['TransactTime'] >= 103248080) & (TradeLogSZ1['TransactTime'] <= 112959990)].groupby('SecurityID')['TransactTime'].max().min()
# Out:
# 112457430

# %%
TradeLogSZ[(TradeLogSZ['TransactTime'] >= 103248080) & (TradeLogSZ['TransactTime'] <= 112959990)].groupby('SecurityID')['TransactTime'].max().min()
# Out:
# 112457430

# %%
TradeLogSZ["ExecType"] = TradeLogSZ["ExecType"].apply(lambda x: str(x))
TradeLogSZ1["ExecType"] = TradeLogSZ1["ExecType"].apply(lambda x: str(x))

# TradeLogSZ1 = TradeLogSZ1[(TradeLogSZ1['TransactTime'] > 103248080) & (TradeLogSZ1['TransactTime'] <= 112959990)]
# TradeLogSZ = TradeLogSZ[(TradeLogSZ['TransactTime'] > 103248080) & (TradeLogSZ['TransactTime'] <= 112959990)]

columns = ["TransactTime","ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag","TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum","OfferApplSeqNum"]
# columns = ["TransactTime","ApplSeqNum", "SecurityID", "ExecType", "TradePrice", "TradeQty", "BidApplSeqNum","OfferApplSeqNum"]
TradeLogSZ = TradeLogSZ.sort_values(by=["sequenceNo"])
TradeLogSZ = TradeLogSZ.drop_duplicates(columns, keep='first')

re = pd.merge(TradeLogSZ, TradeLogSZ1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
n1 = re["sequenceNo_x"].count()
n2 = re["sequenceNo_y"].count()
len1 = len(re)
print(n1)
print(n2)
print(len1)
print("-----------------------------------------------")
if n2 < len1:
    display("test is not complete:")
    display(re[np.isnan(re["sequenceNo_y"])])
    print(len(re[np.isnan(re["sequenceNo_y"])]))
    print(np.sort(re[np.isnan(re["sequenceNo_y"])]["TransactTime"].unique()))
    print(len(re[np.isnan(re["sequenceNo_y"])]["SecurityID"].unique()))
    print(re[np.isnan(re["sequenceNo_y"])]["SecurityID"].unique())
if (len1 == n2) & (n1 < len1):
    display("baseline is not complete:")
    display(re[np.isnan(re["sequenceNo_x"])])
    print(np.sort(re[np.isnan(re["sequenceNo_x"])]["TransactTime"].unique()))
    print(len(re[np.isnan(re["sequenceNo_x"])]["SecurityID"].unique()))
    print(re[np.isnan(re["sequenceNo_x"])]["SecurityID"].unique())
    display(n2-n1)
# Out:
# 46701118
# 46666243
# 46701118
# -----------------------------------------------
# 'test is not complete:'

# %%
TradeLogSZ[(TradeLogSZ['SecurityID'] == 300853) & (TradeLogSZ['ApplSeqNum'] == 25711469)]
# Out:
#             clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 65419699  1599116401643331   146837436       2     150000000    25711469
#
#           SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 65419699      300853        F           B      666500       400   266600000
#
#           BidApplSeqNum  OfferApplSeqNum
# 65419699       25624589         25592197

# %%
TradeLogSZ1[(TradeLogSZ1['SecurityID'] == 300853) & (TradeLogSZ1['ApplSeqNum'] == 25711469)]
# Out:
#             clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 18089612  1599116401559207    47709105       2     150000000    25711469
#
#           SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 18089612      300853        F           N      666500       400   266600000
#
#           BidApplSeqNum  OfferApplSeqNum
# 18089612       25624589         25592197

# %%
TradeLogSZ1[TradeLogSZ1['TransactTime'] < 130000000].groupby('SecurityID')['TransactTime'].max().min()
# Out:
# 112457430

# %%
TradeLogSZ[(TradeLogSZ['SecurityID'] == 2277) & (TradeLogSZ['TransactTime'] >= 112956000)].head(50)
# Out:
#             clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
#
ecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 32429498        2277        F           N       45900      3000   137700000
# 8436            2277        4           N           0      2000           0
# 13654           2277        F           N       45900      1500    68850000
# 18872           2277        4           N           0      2000           0
# 24339           2277        F           N       46000      4000   184000000
# 25039           2277        4           N           0       200           0
# 28184           2277        F           N       46000       100     4600000
# 28817           2277        4           N           0     10000           0
# 29070           2277        4           N           0     10000           0
# 36926           2277        4           N           0      1000           0
# 40568           2277        4           N           0       300           0
# 41223           2277        4           N           0       700           0
# 43586           2277        4           N           0       200           0
# 45399           2277        F           N       46000     42000  1932000000
# 49298           2277        F           N       46000      5600   257600000
# 51690           2277        F           N       45900      2000    91800000
# 52149           2277        4           N           0      4000           0
# 52150           2277        4           N           0      3000           0
# 52151           2277        4           N           0      2000           0
# 56544           2277        F           N       45900       100     4590000
# 58087           2277        4           N           0      2000           0
# 58214           2277        F           N       46000      3000   138000000
# 58215           2277        F           N       46000     37000  1702000000
# 62230           2277        4           N           0       600           0
# 65833           2277        4           N           0      3000           0
# 67209           2277        4           N           0      5000           0
# 68239           2277        F           N       46000     10700   492200000
# 68714           2277        4           N           0     59700           0
# 72020           2277        F           N       46000      7400   340400000
# 73071           2277        F           N       45900       200     9180000
# 76409           2277        4           N           0      5000           0
# 76451           2277        4           N           0      5800           0
# 81388           2277        4           N           0       800           0
# 82004           2277        4           N           0      1000           0
# 82496           2277        4           N           0       800           0
# 83688           2277        4           N           0      1100           0
# 84686           2277        4           N           0      3300           0
# 86773           2277        4           N           0      4700           0
# 91081           2277        F           N       46000     16900   777400000
# 91409           2277        4           N           0      1200           0
# 91415           2277        4           N           0       400           0
# 93416           2277        F           N       46000       100     4600000
# 95082           2277        F           N       45900       200     9180000
# 95274           2277        4           N           0       400           0
# 97314           2277        4           N           0      1000           0
# 99348           2277        4           N           0      4800           0
# 99349           2277        4           N           0      8000           0
# 102747          2277        F           N       46000       500    23000000
# 104730          2277        4           N           0     10000           0
# 105701          2277        4           N           0      2200           0
#
#           BidApplSeqNum  OfferApplSeqNum
# 32429498       17575387         17721797
# 8436                  0          6181465
# 13654          17582202         17730256
# 18872                 0          8001343
# 24339          17735599         17554221
# 25039           8017250                0
# 28184          17737574         17554221
# 28817            495998                0
# 29070           4721796                0
# 36926                 0          6304780
# 40568           4010413                0
# 41223                 0         16679329
# 43586          11801033                0
# 45399          17747388         17554221
# 49298          17749545         17554221
# 51690          17582202         17750876
# 52149                 0         17036442
# 52150                 0         17010378
# 52151                 0         16958348
# 56544          17582202         17753567
# 58087                 0         13788769
# 58214          17754763         17554221
# 58215          17754763         17595373
# 62230          17743289                0
# 65833          17667948                0
# 67209          17615555                0
# 68239          17760621         17595373
# 68714                 0          6556902
# 72020          17763015         17595373
# 73071          17582202         17763596
# 76409           3020301                0
# 76451           6046932                0
# 81388          17690361                0
# 82004           2853205                0
# 82496          17618705                0
# 83688          15524634                0
# 84686           1411635                0
# 86773          17730388                0
# 91081          17774904         17595373
# 91409                 0         17618335
# 91415                 0          9714149
# 93416          17776320         17595373
# 95082          17582202         17777431
# 95274          15165970                0
# 97314                 0         10841339
# 99348                 0         12504167
# 99349                 0          7701066
# 102747         17782232         17595373
# 104730                0         14258701
# 105701         17760888                0

# %%
# speed test
re = re[~re["sequenceNo_x"].isnull()]
re = re[~re["sequenceNo_y"].isnull()]
diff = re["clockAtArrival_y"] - re["clockAtArrival_x"]
re["diff"] = re["clockAtArrival_y"] - re["clockAtArrival_x"]
print(np.quantile(abs(diff[diff < 0]), 0.25))
print(np.median(abs(diff[diff < 0])))
print(np.quantile(abs(diff[diff < 0]), 0.75))
# print(np.quantile(diff[diff > 0], 0.25))
# print(np.median(diff[diff > 0]))
# print(np.quantile(diff[diff > 0], 0.75))
print(sum(diff < 0)/len(diff))
print(sum(diff > 0)/len(diff))
print(sum(diff == 0)/len(diff))
# Out:
# 6800.0
# 10922.0
# 14961.0
# 1.0
# 0.0
# 0.0

# %%
OrderLogSZ[(OrderLogSZ['TransactTime'] >= 103430010) & (OrderLogSZ['TransactTime'] <= 112457430)].groupby('SecurityID')['TransactTime'].max().min()
# Out:
# 112246420

# %%
OrderLogSZ1[(OrderLogSZ1['TransactTime'] >= 103430010) & (OrderLogSZ1['TransactTime'] <= 112457430)].groupby('SecurityID')['TransactTime'].max().min()
# Out:
# 112246420

# %%
columns = ["TransactTime", "ApplSeqNum","Side",'OrderType', 'Price', 'OrderQty', "SecurityID"]
OrderLogSZ1['OrderType'] = OrderLogSZ1['OrderType'].astype(str)
OrderLogSZ = OrderLogSZ.drop_duplicates(columns, keep='first')
# OrderLogSZ = OrderLogSZ[(OrderLogSZ['TransactTime'] >= 103430010) & (OrderLogSZ['TransactTime'] <= 112457430)]
# OrderLogSZ1 = OrderLogSZ1[(OrderLogSZ1['TransactTime'] >= 103430010) & (OrderLogSZ1['TransactTime'] <= 112457430)]
ree = pd.merge(OrderLogSZ, OrderLogSZ1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
n1 = ree["sequenceNo_x"].count()
n2 = ree["sequenceNo_y"].count()
len1 = len(ree)
print(n1)
print(n2)
print(len1)
print("-----------------------------------------------")
if n2 < len1:
    display("test is not complete:")
    display(ree[np.isnan(ree["sequenceNo_y"])])
    print(len(ree[np.isnan(ree["sequenceNo_y"])]))
    print(np.sort(ree[np.isnan(ree["sequenceNo_y"])]["TransactTime"].unique()))
    print(len(ree[np.isnan(ree["sequenceNo_y"])]["SecurityID"].unique()))
    print(ree[np.isnan(ree["sequenceNo_y"])]["SecurityID"].unique())
if (len1 == n2) & (n1 < len1):
    display("test is complete, baseline is not complete:")
    display(ree[np.isnan(ree["sequenceNo_x"])])
    print(np.sort(ree[np.isnan(ree["sequenceNo_x"])]["TransactTime"].unique()))
    print(len(ree[np.isnan(ree["sequenceNo_x"])]["SecurityID"].unique()))
    print(ree[np.isnan(ree["sequenceNo_x"])]["SecurityID"].unique())
    display(n2-n1)
# Out:
# 52280691
# 51297917
# 52280691
# -----------------------------------------------
# 'test is not complete:'
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 0         1599095699570760         14061         2      91500000           1
# 1         1599095699570767         14062         2      91500000           2
# 2         1599095699570776         14064         2      91500000           4
# 3         1599095699570784         14065         2      91500000           5
# 4         1599095699570784         14066         2      91500000           6
# ...                    ...           ...       ...           ...         ...
# 35018066  1599096038250270       1172075         2      92038790      253208
# 35018067  1599096038250289       1172078         2      92038790      253211
# 35018068  1599096038250331       1172084         2      92038800      278804
# 35018069  1599096038265871       1172085         2      92038800      278805
# 35018070  1599096038265883       1172087         2      92038800      253215
#
#           SecurityID  Side OrderType   Price  OrderQty  clockAtArrival_y  \
# 0                709     1         2   22000     60000               NaN
# 1               2630     1         2   27800    970800               NaN
# 2             300301     1         2   48100    293400               NaN
# 3               2315     1         2  283100     70400               NaN
# 4               2315     1         2  283100    529700               NaN
# ...              ...   ...       ...     ...       ...               ...
# 35018066        2863     2         2   80000      1000               NaN
# 35018067      300032     1         2   54900       200               NaN
# 35018068        2040     2         2   70800      2500               NaN
# 35018069          70     1         2  112300       100               NaN
# 35018070      300177     2         2  121000      1000               NaN
#
#           sequenceNo_y  exchId_y
# 0                  NaN       NaN
# 1                  NaN       NaN
# 2                  NaN       NaN
# 3                  NaN       NaN
# 4                  NaN       NaN
# ...                ...       ...
# 35018066           NaN       NaN
# 35018067           NaN       NaN
# 35018068           NaN       NaN
# 35018069           NaN       NaN
# 35018070           NaN       NaN
#
# [982774 rows x 13 columns]
# 982774
# [91500000 91500010 91500020 ... 92038790 92038800 92038810]
# 2232
# [   709   2630 300301 ... 300530   2569    803]

# %%
OrderLogSZ[(OrderLogSZ['SecurityID'] == 2241) & (OrderLogSZ['TransactTime'] >= 112958000)].head(100)
# Out:
#             clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 37112707  1595474998203444    74260736       2     112958200    17390901
# 37112915  1595474998333556    74261136       2     112958330    17390984
# 37112963  1595474998372673    74261238       2     112958370    17391003
# 37113023  1595474998420442    74261354       2     112958420    17391034
# 37113433  1595474998712697    74262122       2     112958710    17391204
# 37113796  1595474999008491    74262942       2     112959010    17391406
# 37114113  1595474999259454    74263702       2     112959260    17391588
# 37114270  1595474999394549    74264009       2     112959390    17391658
# 37114732  1595474999785847    74264930       2     112959780    17391876
# 23        1595480400026037       75813       2     130000000    17392371
# 107       1595480400027180       76264       2     130000000    17392767
# 326       1595480400028736       76960       2     130000020    17393238
# 363       1595480400029018       77041       2     130000020    17393268
# 390       1595480400029064       77094       2     130000020    17393321
# 439       1595480400029442       77271       2     130000020    17393382
# 539       1595480400029866       77506       2     130000030    17393563
# 820       1595480400041592       78575       2     130000030    17394037
# 884       1595480400041728       78723       2     130000030    17394185
# 953       1595480400041946       78858       2     130000030    17394322
# 1019      1595480400042180       78993       2     130000030    17394457
# 1034      1595480400042205       79025       2     130000030    17394489
# 1035      1595480400042205       79026       2     130000030    17394490
# 1055      1595480400042232       79061       2     130000030    17394527
# 1280      1595480400052760       80012       2     130000030    17394792
# 1363      1595480400052915       80151       2     130000030    17394932
# 1998      1595480400063988       81423       2     130000040    17395602
# 2462      1595480400076117       82741       2     130000040    17395834
# 2913      1595480400087261       84001       2     130000040    17396034
# 2941      1595480400087297       84052       2     130000040    17396085
# 2957      1595480400087316       84077       2     130000040    17396110
# 3432      1595480400089857       85052       2     130000040    17396244
# 3434      1595480400089859       85056       2     130000040    17396248
# 3632      1595480400098834       85592       2     130000050    17396307
# 3653      1595480400098853       85622       2     130000050    17396337
# 4879      1595480400113191       88054       2     130000050    17396575
# 6363      1595480400134035       90652       2     130000050    17396768
# 7341      1595480400145402       92370       2     130000060    17396983
# 7366      1595480400147278       92416       2     130000060    17397029
# 15626           2241     2         2  370000       200
# 15654           2241     1         2  333800      2000
# 16008           2241     2         2  342000      2000
# 16880           2241     1         2  342600      1000
# 17516           2241     2         2  346800       400
# 17674           2241     1         2  342400       100
# 18467           2241     1         2  342600       500
# 18848           2241     1         2  333000       300
# 18970           2241     1         2  331500       100
# 19219           2241     1         2  335000       200
# 19574           2241     1         2  329600       200
# 19772           2241     1         2  342200      1700
# 20489           2241     2         2  343000       100
# 20536           2241     1         2  330100       100
# 21022           2241     2         2  350000       400
# 21030           2241     2         2  342400       200
# 21304           2241     1         2  342400       500

# %%
OrderLogSZ[(OrderLogSZ['SecurityID'] == 300139) & (OrderLogSZ['TransactTime'] >= 103900000)].head(100)
# Out:
#             clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 27916557  1595471940842143    54547642       2     103900840    12416520
# 27917770  1595471941137887    54550522       2     103901130    12417036
# 27919355  1595471941563444    54554016       2     103901560    12417797
# 27929351  1595471944797325    54575561       2     103904790    12422463
# 27929719  1595471944934472    54576247       2     103904930    12422638
# 27933240  1595471946178019    54582799       2     103906170    12424102
# 27933669  1595471946337663    54583698       2     103906330    12424360
# 27936811  1595471947210877    54591496       2     103907210    12425812
# 27941302  1595471948799634    54600469       2     103908800    12427894
# 27944057  1595471949775090    54606212       2     103909770    12429181
# 27946243  1595471950354400    54611477       2     103910350    12430174
# 27950101  1595471951680241    54618737       2     103911680    12431912
# 27950165  1595471951702189    54618827       2     103911700    12431934
# 27951147  1595471952070093    54620699       2     103912070    12432453
# 27970537  1595471958159906    54661412       2     103918160    12441679
# 27981298  1595471961814677    54684376       2     103921810    12446815
# 27984713  1595471962882222    54692230       2     103922880    12448463
# 27989561  1595471964647506    54701683       2     103924640    12450781
# 27993447  1595471965783458    54710572       2     103925780    12452602
# 28001663  1595471968485365    54727717       2     103928480    12456375
# 28004335  1595471969498572    54732604       2     103929490    12457561
# 28006406  1595471970243899    54736611       2     103930240    12458581
# 28006936  1595471970435957    54737638       2     103930430    12458791
# 28007729  1595471970701461    54739496       2     103930700    12459169
# 28009602  1595471971193116    54744048       2     103931190    12460077
# 28010697  1595471971528279    54746416       2     103931520    12460587
# 28011171  1595471971690979    54747327       2     103931690    12460784
# 28014017  1595471972761910    54753242       2     103932760    12461945
# 28014994  1595471973154516    54755043       2     103933150    12462338
# 28015429  1595471973308935    54755861       2     103933310    12462514
# 28017184  1595471973862173    54759913       2     103933860    12463340
# 28029273  1595471977824156    54785739       2     103937820    12469093
# 28036374  1595471980163596    54800522       2     103940160    12472360
# 28058916  1595471987735484    54848183       2     103947730    12483385
# 28059160  1595471987838325    54848623       2     103947830    12483498
# 28061224  1595471988621812    54852967       2     103948620    12484436
# 28070019  1595471991641196    54872033       2     103951640    12488650
# 28072059  1595471992198698    54877661       2     103952190    12489565
# 28081703  1595471995481970    54898449       2     103955480    12494105
# 28083963  1595471996218677    54903020       2     103956220    12495162
# 28087899  1595471997481049    54910643       2     103957480    12497171
# 28088449  1595471997634483    54911944       2     103957630    12497452
# 28369436  1595472066361104    55542908       2     104106360    12640739
# 28377976  1595472068206747    55563516       2     104108200    12644941
#
#           SecurityID  Side OrderType  Price  OrderQty
# 27916557      300139     2         2  83800      3600
# 27917770      300139     1         2  83200      3000
# 27919355      300139     1         2  83700       400
# 27929351      300139     1         2  83900      1100
# 27929719      300139     1         2  83900      2000
# 27933240      300139     1         2  82100       600
# 27933669      300139     1         2  83900      2000
# 27936811      300139     2         2  83800      2000
# 27941302      300139     1         2  83900       200
# 27944057      300139     1         2  81800      2000
# 27946243      300139     1         2  83900      1000
# 27950101      300139     1         2  83900       400
# 27950165      300139     1         2  83900      1000
# 27951147      300139     2         2  83800     10000
# 27970537      300139     1         2  83300      4000
# 27981298      300139     1         2  78800      3300
# 27984713      300139     2         2  83900      2000
# 27989561      300139     1         2  83900      1000
# 27993447      300139     1         2  83900       200
# 28001663      300139     2         2  89600      1000
# 28004335      300139     1         2  83700       500
# 28006406      300139     1         2  83900      3700
# 28006936      300139     1         2  83000       300
# 28007729      300139     1         2  83900     12300
# 28009602      300139     2         2  90000       100
# 28010697      300139     2         2  83900      4000
# 28011171      300139     2         2  83800       100
# 28014017      300139     2         2  84000      3000
# 28014994      300139     1         2  83900      2000
# 28015429      300139     1         2  83400       300
# 28017184      300139     2         2  83800     24000
# 28029273      300139     1         2  83800      6000
# 28036374      300139     2         2  84100      2000
# 28058916      300139     1         2  84000      1000
# 28059160      300139     1         2  83000      2000
# 28061224      300139     1         2  83200       200
# 28070019      300139     1         2  83700       700
# 28072059      300139     2         2  83800      3000
# 28081703      300139     1         2  83800      1000
# 28083963      300139     1         2  83300      3000
# 28087899      300139     2         2  83800       900
# 28088449      300139     2         2  83800     46700
# 28091903      300139     1         2  83800       300
# 28093727      300139     1         2  83800      2900
# 28104248      300139     1         2  83100       300
# 28104669      300139     1         2  83800       300
# 28117429      300139     1         2  83800      3000
# 28120247      300139     1         2  83700      3600
# 28121231      300139     1         2  83800      3900
# 28124917      300139     1         2  83700      6000
# 28128476      300139     1         2  83500       500
# 28129429      300139     1         2  84000       100
# 28129891      300139     1         2  83800       800
# 28133302      300139     2         2  84200      5000
# 28135237      300139     2         2  90000      1000
# 28139624      300139     1         2  83600      2000
# 28159259      300139     1         2  83700      6000
# 28161688      300139     1         2  81900       500
# 28162396      300139     1         2  83800       200
# 28163326      300139     1         2  83700      2000
# 28168523      300139     1         2  83100      1000
# 28169398      300139     2         2  83700      3400
# 28172609      300139     2         2  83700       200
# 28178818      300139     1         2  81000      1100
# 28189833      300139     1         2  80000       400
# 28192592      300139     2         2  83700      3400
# 28202578      300139     1         2  83400       500
# 28203127      300139     1         2  83800       200
# 28205041      300139     2         2  84300      3000
# 28211847      300139     2         2  83700      1500
# 28216899      300139     1         2  83600      1000
# 28217396      300139     1         2  83100      4000
# 28219285      300139     2         2  84000      3700
# 28223461      300139     2         2  83800       100
# 28231524      300139     2         2  91800      2800
# 28232600      300139     2         2  83700      1300
# 28236073      300139     1         2  83800       200
# 28251907      300139     1         2  82900       600
# 28256793      300139     2         2  83700       600
# 28260419      300139     2         2  94000      1000
# 28260943      300139     2         2  83700       900
# 28268164      300139     1         2  83500       500
# 28275987      300139     2         2  83400      5000
# 28280844      300139     2         2  95200      3800
# 28298081      300139     1         2  83700      1000
# 28306649      300139     1         2  81800       900
# 28310316      300139     2         2  83800      3000
# 28311048      300139     1         2  83900      2000
# 28311757      300139     2         2  83700      7500
# 28318628      300139     1         2  83700       600
# 28320344      300139     2         2  86800      2000
# 28322408      300139     1         2  83000      1000
# 28325694      300139     1         2  83100      1200
# 28344522      300139     1         2  83700       300
# 28347485      300139     1         2  83500       400
# 28352494      300139     2         2  83700      5000
# 28356267      300139     2         2  83600      1000
# 28357838      300139     1         2  83800     22700
# 28369436      300139     1         2  83800       100
# 28377976      300139     2         2  83700      3000

# %%
# speed test
ree = ree[~ree["sequenceNo_x"].isnull()]
ree = ree[~ree["sequenceNo_y"].isnull()]
ree["diff"] = ree["clockAtArrival_y"] - ree["clockAtArrival_x"]
diff = ree["clockAtArrival_y"] - ree["clockAtArrival_x"]
print(np.quantile(abs(diff[diff < 0]), 0.25))
print(np.median(abs(diff[diff < 0])))
print(np.quantile(abs(diff[diff < 0]), 0.75))
print(np.quantile(diff[diff > 0], 0.25))
print(np.median(diff[diff > 0]))
print(np.quantile(diff[diff > 0], 0.75))
print(sum(diff < 0)/len(diff))
print(sum(diff > 0)/len(diff))
# Out:
# 6729.0
# 10858.0
# 14907.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-d714fe0e57d2> in <module>
#       7 print(np.median(abs(diff[diff < 0])))
#       8 print(np.quantile(abs(diff[diff < 0]), 0.75))
# ----> 9 print(np.quantile(diff[diff > 0], 0.25))
#      10 print(np.median(diff[diff > 0]))
#      11 print(np.quantile(diff[diff > 0], 0.75))
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in quantile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3816         raise ValueError("Quantiles must be in the range [0, 1]")
#    3817     return _quantile_unchecked(
# -> 3818         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3819
#    3820
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3824     r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,
#    3825                     overwrite_input=overwrite_input,
# -> 3826                     interpolation=interpolation)
#    3827     if keepdims:
#    3828         return r.reshape(q.shape + k)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3403         keepdim = (1,) * a.ndim
#    3404
# -> 3405     r = func(a, **kwargs)
#    3406     return r, keepdim
#    3407
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in _quantile_ureduce_func(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3939             n = np.isnan(ap[-1:, ...])
#    3940
# -> 3941         x1 = take(ap, indices_below, axis=axis) * weights_below
#    3942         x2 = take(ap, indices_above, axis=axis) * weights_above
#    3943
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in take(a, indices, axis, out, mode)
#     187            [5, 7]])
#     188     """
# --> 189     return _wrapfunc(a, 'take', indices, axis=axis, out=out, mode=mode)
#     190
#     191
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      54 def _wrapfunc(obj, method, *args, **kwds):
#      55     try:
# ---> 56         return getattr(obj, method)(*args, **kwds)
#      57
#      58     # An AttributeError occurs if the object does not have
#
# IndexError: cannot do a non-empty take from an empty axes.
