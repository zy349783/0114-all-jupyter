# %% [markdown]
# # 1. snapshot data check

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import pickle
from matplotlib import pyplot as plt
import statsmodels.api as sm
from matplotlib.ticker import Formatter
import collections
import glob
import os
# pd.set_option("max_columns", 200)

# readPath = r'\\192.168.10.30\Kevin_zhenyu\temp\wind\20200513\Tick\SH\20200513\***'
# dataPathLs = np.array(glob.glob(readPath))
# dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
# dataPathLs = dataPathLs[((dateLs >= 600000) & (dateLs <= 700000))| (dateLs == 16) | (dateLs == 300)
#                        | (dateLs == 852) | (dateLs == 905)]
# logSH1 = []
# for i in dataPathLs:
#     df = pd.read_csv(i, compression='gzip')[["code", "time", "accvolume", "price", "volume", "open", 
#                                             "bid1", "bid2", "bid3", "bid4", "bid5", "bsize1", "bsize2",
#                                             "bsize3", "bsize4", "bsize5", "ask1", "ask2", "ask3", "ask4", 
#                                             "ask5", "asize1", "asize2", "asize3", "asize4", "asize5"]]
#     logSH1 += [df]
# logSH1 = pd.concat(logSH1).reset_index(drop=True)
# logSH1 = logSH1.rename(columns={"code":"StockID", "accvolume":"cum_volume", "price":"close", "open":"openPrice",
#                                "bid1":"bid1p", "bid2":"bid2p", "bid3":"bid3p", "bid4":"bid4p", "bid5":"bid5p",
#                                "bsize1":"bid1q", "bsize2":"bid2q", "bsize3":"bid3q", "bsize4":"bid4q", "bsize5":"bid5q",
#                                "ask1":"ask1p", "ask2":"ask2p", "ask3":"ask3p", "ask4":"ask4p", "ask5":"ask5p","asize1":"ask1q", 
#                                 "asize2":"ask2q", "asize3":"ask3q", "asize4":"ask4q", "asize5":"ask5q"})

readPath = r'\\192.168.10.30\Kevin_zhenyu\temp\wind\20200515_Tick\20200515_Tick\SZ\20200515\***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs < 4000) | (dateLs > 300000)]
logSZ1 = []
for i in dataPathLs:
    df = pd.read_csv(i, encoding='GBK')[["code", "time", "accvolume", "price", "volume", "open", 
                                            "bid1", "bid2", "bid3", "bid4", "bid5", "bsize1", "bsize2",
                                            "bsize3", "bsize4", "bsize5", "ask1", "ask2", "ask3", "ask4", 
                                            "ask5", "asize1", "asize2", "asize3", "asize4", "asize5"]]
    logSZ1 += [df]
logSZ1 = pd.concat(logSZ1).reset_index(drop=True)
logSZ1 = logSZ1.rename(columns={"code":"StockID", "accvolume":"cum_volume", "price":"close", "open":"openPrice",
                               "bid1":"bid1p", "bid2":"bid2p", "bid3":"bid3p", "bid4":"bid4p", "bid5":"bid5p",
                               "bsize1":"bid1q", "bsize2":"bid2q", "bsize3":"bid3q", "bsize4":"bid4q", "bsize5":"bid5q",
                               "ask1":"ask1p", "ask2":"ask2p", "ask3":"ask3p", "ask4":"ask4p", "ask5":"ask5p","asize1":"ask1q", 
                                "asize2":"ask2q", "asize3":"ask3q", "asize4":"ask4q", "asize5":"ask5q"})
for col in ["close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "ask1p", "ask2p","ask3p", "ask4p", "ask5p","openPrice"]:
    logSZ1[col] = logSZ1[col]/10000
#     logSH1[col] = logSH1[col]/10000

    
# logSH = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\rawData\logs_20200513_zs_92_01_day_data\mdLog_SH_20200513_0831.csv',
#                     encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
#                                               "exchange", "time", "cum_volume", "cum_amount", "close",
#                                               "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
#                                               "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
#                                               "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
#                                               "ask4q", "ask5q", "openPrice"]]
# logSH2 = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\rawData\logs_20200513_zt_96_04_day_96data\mdLog_SH_20200513_0832.csv',
#                     encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
#                                               "exchange", "time", "cum_volume", "cum_amount", "close",
#                                               "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
#                                               "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
#                                               "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
#                                               "ask4q", "ask5q", "openPrice"]]
logSZ = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\rawData\logs_20200515_zs_92_01_day_data\mdLog_SZ_20200515_0834.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
                                              "exchange", "time", "cum_volume", "cum_amount", "close",
                                              "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
                                              "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
                                              "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
                                              "ask4q", "ask5q", "openPrice"]]
# logSH["time"] = logSH["time"].apply(lambda x: int((x.replace(':', "")).replace(".", "")))
# logSH2["time"] = logSH2["time"].apply(lambda x: int((x.replace(':', "")).replace(".", "")))
logSZ["time"] = logSZ["time"].apply(lambda x: int((x.replace(':', "")).replace(".", "")))  
# display(logSH2["source"].unique())

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import pickle
from matplotlib import pyplot as plt
import statsmodels.api as sm
from matplotlib.ticker import Formatter
import collections
import glob
import os

readPath = r'\\192.168.10.30\Kevin_zhenyu\temp\wind\20200527\20200527_Tick\SZ\20200527\***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs < 4000) | (dateLs > 300000)]
logSZ11 = []
for i in dataPathLs:
    df = pd.read_csv(i, encoding='GBK')[["code", "time", "accvolume", "price", "volume", "open", 
                                            "bid1", "bid2", "bid3", "bid4", "bid5", "bsize1", "bsize2",
                                            "bsize3", "bsize4", "bsize5", "ask1", "ask2", "ask3", "ask4", 
                                            "ask5", "asize1", "asize2", "asize3", "asize4", "asize5"]]
    logSZ11 += [df]
logSZ11 = pd.concat(logSZ11).reset_index(drop=True)
logSZ11 = logSZ11.rename(columns={"code":"StockID", "accvolume":"cum_volume", "price":"close", "open":"openPrice",
                               "bid1":"bid1p", "bid2":"bid2p", "bid3":"bid3p", "bid4":"bid4p", "bid5":"bid5p",
                               "bsize1":"bid1q", "bsize2":"bid2q", "bsize3":"bid3q", "bsize4":"bid4q", "bsize5":"bid5q",
                               "ask1":"ask1p", "ask2":"ask2p", "ask3":"ask3p", "ask4":"ask4p", "ask5":"ask5p","asize1":"ask1q", 
                                "asize2":"ask2q", "asize3":"ask3q", "asize4":"ask4q", "asize5":"ask5q"})
for col in ["close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "ask1p", "ask2p","ask3p", "ask4p", "ask5p","openPrice"]:
    logSZ11[col] = logSZ11[col]/10000

readPath = r'\\192.168.10.30\Kevin_zhenyu\temp\wind\20200527\20200527_Tick_2\20200527_Tick\SZ\20200527\***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs < 4000) | (dateLs > 300000)]
logSZ12 = []
for i in dataPathLs:
    df = pd.read_csv(i, encoding='GBK')[["code", "time", "accvolume", "price", "volume", "open", 
                                            "bid1", "bid2", "bid3", "bid4", "bid5", "bsize1", "bsize2",
                                            "bsize3", "bsize4", "bsize5", "ask1", "ask2", "ask3", "ask4", 
                                            "ask5", "asize1", "asize2", "asize3", "asize4", "asize5"]]
    logSZ12 += [df]
logSZ12 = pd.concat(logSZ12).reset_index(drop=True)
logSZ12 = logSZ12.rename(columns={"code":"StockID", "accvolume":"cum_volume", "price":"close", "open":"openPrice",
                               "bid1":"bid1p", "bid2":"bid2p", "bid3":"bid3p", "bid4":"bid4p", "bid5":"bid5p",
                               "bsize1":"bid1q", "bsize2":"bid2q", "bsize3":"bid3q", "bsize4":"bid4q", "bsize5":"bid5q",
                               "ask1":"ask1p", "ask2":"ask2p", "ask3":"ask3p", "ask4":"ask4p", "ask5":"ask5p","asize1":"ask1q", 
                                "asize2":"ask2q", "asize3":"ask3q", "asize4":"ask4q", "asize5":"ask5q"})
for col in ["close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "ask1p", "ask2p","ask3p", "ask4p", "ask5p","openPrice"]:
    logSZ12[col] = logSZ12[col]/10000

display(logSZ11.shape[0])
display(logSZ12.shape[0])
logSZ1 = pd.concat([logSZ11, logSZ12]).drop_duplicates()
display(logSZ1.shape[0])

    

logSZ = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\rawData\logs_20200527_zs_92_01_day_data\mdLog_SZ_20200527_0838.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
                                              "exchange", "time", "cum_volume", "cum_amount", "close",
                                              "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
                                              "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
                                              "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
                                              "ask4q", "ask5q", "openPrice"]]
logSZ["time"] = logSZ["time"].apply(lambda x: int((x.replace(':', "")).replace(".", "")))

# %% [markdown]
# ## 1.1 SH lv2 comparison

# %%
in_dex = [16, 300, 852, 905]
data1 = logSH2[~logSH2["StockID"].isin(in_dex) & (logSH2["cum_volume"] > 0) & (logSH2["time"] <= 145700000)
              & (logSH2["source"] == 13)]
data2 = logSH1[~logSH1["StockID"].isin(in_dex) & (logSH1["cum_volume"] > 0) & (logSH1["time"] <= 145700000)]
columns = ["StockID", "cum_volume", "close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q", "bid2q",
           "bid3q", "bid4q", "bid5q", "ask1p", "ask2p", "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
           "ask4q", "ask5q", "openPrice"]
data1_1 = data1.drop_duplicates(subset=columns, keep="first").reset_index()
data2_1 = data2.drop_duplicates(subset=columns, keep="first").reset_index()

n1 = len(data1_1["StockID"].unique())
n2 = len(data2_1["StockID"].unique())
print(n1)
print(n2)
if n1 > n2:
    data1_1 = data1_1[data1_1["StockID"].isin(data2_1["StockID"].unique())]
if n2 > n1:
    data2_1 = data2_1[data2_1["StockID"].isin(data1_1["StockID"].unique())]

test = pd.merge(data1_1, data2_1, left_on=columns, right_on=columns, how="outer")
n1 = test["time_x"].count()
n2 = test["time_y"].count()
len1 = len(test)
print(n1)
print(n2)
print(len1)
print("-----------------------------------------------")
if n2 < len1:
    display("test is not complete:")
    display(test[np.isnan(test["time_y"])])
    display(len(test[np.isnan(test["time_y"])])/n1)
if (len1 == n2) & (n1 < len1):
    display("baseline is not complete:")
    display(test[np.isnan(test["time_x"])])
    display(n2-n1)
    print((n2-n1)/n1)
# Out:
# 1600
# 1602
# 5116051
# 5116051
# 5116051
# -----------------------------------------------

# %%
display(data1_1[(data1_1["StockID"] == 688169) & (data1_1["cum_volume"] == 1011)])
display(data2_1[(data2_1["StockID"] == 688169) & (data2_1["cum_volume"] == 1011)])

# %% [markdown]
# ## 1.2 SH index comparison

# %%
in_dex = list(set(in_dex) & set(logSH1["StockID"].unique()))
print(in_dex)
data1 = logSH[(logSH["StockID"].isin(in_dex)) & (logSH["cum_volume"] > 0) & (logSH["time"] <= 145700000)]
data2 = logSH1[(logSH1["StockID"].isin(in_dex)) & (logSH1["cum_volume"] > 0) & (logSH1["time"] <= 145700000)]

data2["cum_volume"] = data2["cum_volume"]/100

# data2 = data2[data2["openPrice"] != 0]
columns = ["StockID", "cum_volume", "close", "openPrice"]
data1_1 = data1.drop_duplicates(subset=columns, keep="first").reset_index()
data2_1 = data2.drop_duplicates(subset=columns, keep="first").reset_index()
columns = ["StockID", "cum_volume", "close", "openPrice"]
test = pd.merge(data1_1, data2_1, left_on=columns, right_on=columns, how="outer")
n1 = test["time_x"].count()
n2 = test["time_y"].count()
len1 = len(test)
print(n1)
print(n2)
print(len1)
if n2 < len1:
    display("test is not complete:")
    display(test[np.isnan(test["time_y"])])
# Out:
# [300]
# C:\Users\win\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2847
# 2847
# 2847

# %% [markdown]
# ## 1.3 SZ lv2 comparison

# %%
data1 = logSZ[(logSZ["cum_volume"] > 0) & (logSZ["time"] < 145700000) ]
data2 = logSZ1[(logSZ1["cum_volume"] > 0) & (logSZ1["time"] < 145700000)]

columns = ["StockID", "cum_volume", "close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q", "bid2q",
           "bid3q", "bid4q", "bid5q", "ask1p", "ask2p", "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
           "ask4q", "ask5q", "openPrice"]
data1_1 = data1.drop_duplicates(subset=columns, keep="first").reset_index()
data2_1 = data2.drop_duplicates(subset=columns, keep="first").reset_index()
n1 = len(data1_1["StockID"].unique())
n2 = len(data2_1["StockID"].unique())
print(n1)
print(n2)
if n1 > n2:
    data1_1 = data1_1[data1_1["StockID"].isin(data2_1["StockID"].unique())]
if n2 > n1:
    data2_1 = data2_1[data2_1["StockID"].isin(data1_1["StockID"].unique())]
test = pd.merge(data1_1, data2_1, left_on=columns, right_on=columns, how="outer")
n1 = test["time_x"].count()
n2 = test["time_y"].count()
len1 = len(test)
print(n1)
print(n2)
print(len1)
print("-----------------------------------------------")
if n2 < len1:
    display("test is not complete:")
    display(test[np.isnan(test["time_y"])])
    print(len(test[np.isnan(test["time_y"])])/n1)
    print(np.sort(test[np.isnan(test["time_y"])]["time_x"].unique()))
    print(len(np.sort(test[np.isnan(test["time_y"])]["StockID"].unique())))
    print(np.sort(test[np.isnan(test["time_y"])]["StockID"].unique()))
if (len1 == n2) & (n1 < len1):
    display("baseline is not complete:")
    display(test[np.isnan(test["time_x"])])
    display(n2-n1)
# Out:
# 2203
# 2567
# 6813370
# 6813370
# 6813370
# -----------------------------------------------

# %%
pd.set_option("max_columns", 200)
data2[(data2["StockID"] == 1)]
# Out:
#          StockID       time  cum_volume  close  volume  openPrice  bid1p  \
# 6695300        1   92500000      291800  13.05  291800      13.05  13.05
# 6695301        1   93000000      370800  13.06   79000      13.05  13.05
# 6695302        1   93003000      813000  13.07  442200      13.05  13.06
# 6695303        1   93006000      925100  13.07  112100      13.05  13.06
# 6695304        1   93009000      978500  13.07   53400      13.05  13.07
# ...          ...        ...         ...    ...     ...        ...    ...
# 6700003        1  145648000    47823194  13.00    4108      13.05  12.99
# 6700004        1  145651000    47827994  13.00    4800      13.05  12.99
# 6700005        1  145654000    47829994  13.00    2000      13.05  12.99
# 6700006        1  145657000    47851594  13.01   21600      13.05  13.00
# 6697160        1  104412000    26062889  13.03   11800      13.05  13.02
#
#          bid2p  bid3p  bid4p  bid5p   bid1q   bid2q   bid3q   bid4q   bid5q  \
# ...

# %%
data1[(data1["StockID"] == 1) & (data1["cum_volume"] == 794409)]
# Out:
#           clockAtArrival  sequenceNo  source  StockID exchange      time  \
# 322018  1589505917302915     1846306       4        1       SZ  92500000
# 322028  1589505917303893     1846316       3        1       SZ  92500000
# 327782  1589505977307026     2019591       4        1       SZ  92600000
# 327813  1589505977310015     2019622       3        1       SZ  92600000
# 332182  1589506037303812     2028819       4        1       SZ  92700000
# 332237  1589506037309860     2028876       3        1       SZ  92700000
# 336612  1589506097303953     2038068       4        1       SZ  92800000
# 336661  1589506097310331     2038135       3        1       SZ  92800000
# 341043  1589506157304219     2047324       4        1       SZ  92900000
# 341096  1589506157314523     2047377       3        1       SZ  92900000
#
#         cum_volume   cum_amount  close  bid1p  ...  ask2p  ask3p  ask4p  \
# 322018      794409  10637136.51  13.39  13.39  ...  13.41  13.42  13.43
# ...

# %% [markdown]
# # 2. Order data check

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import pickle
from matplotlib import pyplot as plt
import statsmodels.api as sm
from matplotlib.ticker import Formatter
import collections
import glob
import os
pd.set_option("max_columns", 200)

readPath = r'\\192.168.10.30\Kevin_zhenyu\temp\wind\20200513\Order\SZ\20200513\***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs < 4000) | (dateLs > 300000)]
OrderLogSZ1 = []
for i in dataPathLs:
    df = pd.read_csv(i, compression='gzip')
    OrderLogSZ1 += [df]
OrderLogSZ1 = pd.concat(OrderLogSZ1).reset_index(drop=True)
OrderLogSZ1 = OrderLogSZ1.rename(columns={"code":"SecurityID", "time":"TransactTime", "function_code":"Side", "order_kind":"OrderType",
                             "order_price":"Price", "order_volume":"OrderQty", "order":"ApplSeqNum"})
OrderLogSZ1["Side"] = np.where(OrderLogSZ1["Side"] == 66, 1, 2)
OrderLogSZ1["OrderType"] = np.where(OrderLogSZ1["OrderType"] == 48, '2', np.where(
OrderLogSZ1["OrderType"] == 49, '1', 'U'))
OrderLogSZ = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\rawData\logs_20200513_zs_92_01_day_data\mdOrderLog_20200513_0831.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
                                                 "OrderQty"]]
OrderLogSZ["OrderType"] = OrderLogSZ["OrderType"].apply(lambda x: str(x))
OrderLogSZ1["OrderType"] = OrderLogSZ1["OrderType"].apply(lambda x: str(x))
sl = list(set(OrderLogSZ["SecurityID"].unique()) & set(OrderLogSZ1['SecurityID'].unique()))
OrderLogSZ = OrderLogSZ[OrderLogSZ["SecurityID"].isin(sl)]
OrderLogSZ1 = OrderLogSZ1[OrderLogSZ1["SecurityID"].isin(sl)]
print(len(OrderLogSZ["SecurityID"].unique()))
print(len(OrderLogSZ1["SecurityID"].unique()))

print(OrderLogSZ1.columns)
# Out:
# C:\Users\win\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 2207
# 2207
# Index(['SecurityID', 'wind_code', 'name', 'date', 'TransactTime', 'ApplSeqNum',
#        'OrderType', 'Side', 'Price', 'OrderQty'],
#       dtype='object')

# %%
columns = ["ApplSeqNum", "TransactTime","Side",'OrderType', 'Price', 'OrderQty', "SecurityID"]
ree = pd.merge(OrderLogSZ, OrderLogSZ1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
n1 = ree["sequenceNo"].count()
n2 = ree["date"].count()
len1 = len(ree)
print(n1)
print(n2)
print(len1)
print("-----------------------------------------------")
if n2 < len1:
    display("test is not complete:")
    display(ree[np.isnan(ree["date"])])
    print(len(ree[np.isnan(ree["date"])]))
    print(np.sort(ree[np.isnan(ree["date"])]["TransactTime"].unique()))
    print(len(ree[np.isnan(ree["date"])]["SecurityID"].unique()))
    print(ree[np.isnan(ree["date"])]["SecurityID"].unique())
if (len1 == n2) & (n1 < len1):
    display("test is complete, baseline is not complete:")
    display(ree[np.isnan(ree["sequenceNo"])])
    print(np.sort(ree[np.isnan(ree["sequenceNo"])]["TransactTime"].unique()))
    print(len(ree[np.isnan(ree["sequenceNo"])]["SecurityID"].unique()))
    print(ree[np.isnan(ree["sequenceNo"])]["SecurityID"].unique())
    display(n2-n1)
# Out:
# 35944783
# 35944828
# 35944828
# -----------------------------------------------
# 'test is complete, baseline is not complete:'
#           clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 35944783             NaN         NaN     NaN     145959990    16242217
# 35944784             NaN         NaN     NaN     145959980    16242209
# 35944785             NaN         NaN     NaN     145959990    17033962
# 35944786             NaN         NaN     NaN     145959960    16702867
# 35944787             NaN         NaN     NaN     145959960    17419914
# 35944788             NaN         NaN     NaN     145959970    17419915
# 35944789             NaN         NaN     NaN     145959980    17033959
# 35944790             NaN         NaN     NaN     145959980    16702873
# 35944791             NaN         NaN     NaN     145959960    16242207
# 35944792             NaN         NaN     NaN     145959950    17033953
# ...

# %% [markdown]
# # 3. Trade data check

# %% [markdown]
# ## 3.1 SH trade data check

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import pickle
from matplotlib import pyplot as plt
import statsmodels.api as sm
from matplotlib.ticker import Formatter
import collections
import glob
import os
pd.set_option("max_columns", 200)

readPath = r'\\192.168.10.30\Kevin_zhenyu\temp\wind\20200513\Transaction\SH\20200513\***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs >= 600000) & (dateLs <= 700000)]
SH1 = []
for i in dataPathLs:
    df = pd.read_csv(i, compression='gzip')
    SH1 += [df]
SH1 = pd.concat(SH1).reset_index(drop=True)

SH1 = SH1.rename(columns={"code":"SecurityID", "time":"TransactTime", "bs_flag":"TradeBSFlag", "function_code":"ExecType",
                             "trade_price":"TradePrice", "trade_volume":"TradeQty", "ask_order":"OfferApplSeqNum", 
                              "bid_order":"BidApplSeqNum"})
SH1["ExecType"] = np.where(SH1["ExecType"] == 67, '4', 'F')
SH1["TradeMoney"] = SH1["TradePrice"] * SH1["TradeQty"]
SH1["TradeBSFlag"] = np.where(SH1["TradeBSFlag"] == 83, 'S', np.where(
SH1["TradeBSFlag"] == 66, 'B', 'N'))


SH = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\rawData\logs_20200513_zs_92_01_day_data\mdTradeLog_20200513_0831.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
                                                 "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
                                                 "OfferApplSeqNum"]]
sl = list(set(SH["SecurityID"].unique()) & set(SH1['SecurityID'].unique()))
SH = SH[SH["SecurityID"].isin(sl)]
SH1 = SH1[SH1["SecurityID"].isin(sl)]
print(len(SH["SecurityID"].unique()))
print(len(SH1["SecurityID"].unique()))

print(SH1.columns)
# Out:
# 1600
# 1600
# Index(['SecurityID', 'wind_code', 'name', 'date', 'TransactTime', 'ExecType',
#        'order_kind', 'TradeBSFlag', 'TradePrice', 'TradeQty',
#        'OfferApplSeqNum', 'BidApplSeqNum', 'TradeMoney'],
#       dtype='object')

# %%
# Wind少ApplSeqNum 
SH["ExecType"] = SH["ExecType"].apply(lambda x: str(x))
SH1["ExecType"] = SH1["ExecType"].apply(lambda x: str(x))
columns = ["TransactTime", "SecurityID", "TradePrice", "TradeQty", "TradeMoney", "TradeBSFlag","ExecType",
           "BidApplSeqNum", "OfferApplSeqNum"]
n1 = len(SH["SecurityID"].unique())
n2 = len(SH1["SecurityID"].unique())
print(n1)
print(n2)
if n1 > n2:
    SH = SH[SH["SecurityID"].isin(SH1["SecurityID"].unique())]
if n2 > n1:
    SH1 = SH1[SH1["SecurityID"].isin(SH["SecurityID"].unique())]
re = pd.merge(SH, SH1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
n1 = re["sequenceNo"].count()
n2 = re["name"].count()
len1 = len(re)
print(n1)
print(n2)
print(len1)
print("-----------------------------------------------")
if n2 < len1:
    display("test is not complete:")
    display(re[np.isnan(re["name"])])
    print(len(re[np.isnan(re["name"])]))
    print(np.sort(re[np.isnan(re["name"])]["TransactTime"].unique()))
    print(len(re[np.isnan(re["name"])]["SecurityID"].unique()))
    print(re[np.isnan(re["name"])]["SecurityID"].unique())
if (len1 == n2) & (n1 < len1):
    display("baseline is not complete:")
    display(re[np.isnan(re["sequenceNo"])])
    print(np.sort(re[np.isnan(re["sequenceNo"])]["TransactTime"].unique()))
    print(len(re[np.isnan(re["sequenceNo"])]["SecurityID"].unique()))
    print(re[np.isnan(re["sequenceNo"])]["SecurityID"].unique())
    display(n2-n1)
# Out:
# 1600
# 1600
# 13877616
# 13877810
# 13877810
# -----------------------------------------------
# 'baseline is not complete:'
#           clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 13877616             NaN         NaN     NaN     150500080         NaN
# 13877617             NaN         NaN     NaN     150500080         NaN
# 13877618             NaN         NaN     NaN     150500080         NaN
# 13877619             NaN         NaN     NaN     150500080         NaN
# 13877620             NaN         NaN     NaN     150500080         NaN
# ...                  ...         ...     ...           ...         ...
# 13877805             NaN         NaN     NaN     151858000         NaN
# 13877806             NaN         NaN     NaN     151456360         NaN
# 13877807             NaN         NaN     NaN     150829600         NaN
# 13877808             NaN         NaN     NaN     151931680         NaN
# ...

# %% [markdown]
# ## 3.2 SZ trade data check

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import pickle
from matplotlib import pyplot as plt
import statsmodels.api as sm
from matplotlib.ticker import Formatter
import collections
import glob
import os
pd.set_option("max_columns", 200)

readPath = r'\\192.168.10.30\Kevin_zhenyu\temp\wind\20200513\Transaction\SZ\20200513\***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs < 4000) | (dateLs > 300000)]
TradeLogSZ1 = []
for i in dataPathLs:
    df = pd.read_csv(i, compression='gzip')
    TradeLogSZ1 += [df]
TradeLogSZ1 = pd.concat(TradeLogSZ1).reset_index(drop=True)

TradeLogSZ1 = TradeLogSZ1.rename(columns={"code":"SecurityID", "time":"TransactTime", "bs_flag":"TradeBSFlag", "function_code":"ExecType",
                             "trade_price":"TradePrice", "trade_volume":"TradeQty", "ask_order":"OfferApplSeqNum", 
                              "bid_order":"BidApplSeqNum"})
TradeLogSZ1["ExecType"] = np.where(TradeLogSZ1["ExecType"] == 67, '4', 'F')
TradeLogSZ1["TradeMoney"] = TradeLogSZ1["TradePrice"] * TradeLogSZ1["TradeQty"]
TradeLogSZ1["TradeBSFlag"] = np.where(TradeLogSZ1["TradeBSFlag"] == 83, 'S', np.where(
TradeLogSZ1["TradeBSFlag"] == 66, 'B', 'N'))


TradeLogSZ = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\rawData\logs_20200513_zs_92_01_day_data\mdTradeLog_20200513_0831.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
                                                 "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
                                                 "OfferApplSeqNum"]]
sl = list(set(TradeLogSZ["SecurityID"].unique()) & set(TradeLogSZ1['SecurityID'].unique()))
TradeLogSZ = TradeLogSZ[TradeLogSZ["SecurityID"].isin(sl)]
TradeLogSZ1 = TradeLogSZ1[TradeLogSZ1["SecurityID"].isin(sl)]
print(len(TradeLogSZ["SecurityID"].unique()))
print(len(TradeLogSZ1["SecurityID"].unique()))

print(TradeLogSZ1.columns)
# Out:
# 2207
# 2207
# Index(['SecurityID', 'wind_code', 'name', 'date', 'TransactTime', 'ExecType',
#        'order_kind', 'TradeBSFlag', 'TradePrice', 'TradeQty',
#        'OfferApplSeqNum', 'BidApplSeqNum', 'TradeMoney'],
#       dtype='object')

# %%
TradeLogSZ["ExecType"] = TradeLogSZ["ExecType"].apply(lambda x: str(x))
TradeLogSZ1["ExecType"] = TradeLogSZ1["ExecType"].apply(lambda x: str(x))

TradeLogSZ1["TradeBSFlag"] = 'N'

columns = ["TransactTime","SecurityID", "ExecType", "TradeBSFlag","TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum","OfferApplSeqNum"]
re = pd.merge(TradeLogSZ, TradeLogSZ1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
n1 = re["sequenceNo"].count()
n2 = re["name"].count()
len1 = len(re)
print(n1)
print(n2)
print(len1)
print("-----------------------------------------------")
if n2 < len1:
    display("test is not complete:")
    display(re[np.isnan(re["name"])])
    print(len(re[np.isnan(re["name"])]))
    print(np.sort(re[np.isnan(re["name"])]["TransactTime"].unique()))
    print(len(re[np.isnan(re["name"])]["SecurityID"].unique()))
    print(re[np.isnan(re["name"])]["SecurityID"].unique())
if (len1 == n2) & (n1 < len1):
    display("baseline is not complete:")
    display(re[np.isnan(re["sequenceNo"])])
    print(np.sort(re[np.isnan(re["sequenceNo"])]["TransactTime"].unique()))
    print(len(re[np.isnan(re["sequenceNo"])]["SecurityID"].unique()))
    print(re[np.isnan(re["sequenceNo"])]["SecurityID"].unique())
    display(n2-n1)
# Out:
# 31625685
# 31625685
# 31625685
# -----------------------------------------------
