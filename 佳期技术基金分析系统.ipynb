# %%
import os
import glob
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_finance import candlestick2_ohlc
import matplotlib.dates as mdates
# %matplotlib inline

pd.set_option('max_rows', 300)
pd.set_option('max_columns', 150)
plt.rcParams['font.sans-serif']=['Microsoft YaHei']
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# ### Login

# %%
import tkinter as tk
import ttk

window = tk.Tk()
window.title("佳期技术基金分析系统")
# menu_widget.entryconfig(0, bg='#a1dbcd')

# the main window is divided into left and right sections,
# and the sidebar is divided into a top and bottom section.
pw = tk.PanedWindow(orient="vertical", background="#4f4f4f")
sidebar = tk.PanedWindow(pw, orient="horizontal", background="#4f4f4f")
main = tk.Frame(pw, width=400, height=400, background="#4f4f4f", borderwidth=2)
sidebar_frame = tk.Frame(sidebar, width=200, height=120, background="#4f4f4f", borderwidth=1)

# add the paned window to the window
pw.pack(fill="both", expand=True)

# add the sidebar and main area to the main paned window
pw.add(sidebar)
pw.add(main)

# add the top and bottom to the sidebar
sidebar.add(sidebar_frame)
title = tk.Label(sidebar_frame, text='佳期技术基金分析系统', fg='#e2d397', bg='#4f4f4f', height=2)
title.pack(fill='x')
title.config(font=('System', 25))

startX = 110
startY = 30
label = tk.Label(main, text='账户： ', fg='#e2d397', bg='#4f4f4f')
label.place(x=startX, y=startY)
entry = tk.Entry(main)
entry.place(x=startX+40, y=startY)
label = tk.Label(main, text='密码： ', fg='#e2d397', bg='#4f4f4f')
label.place(x=startX, y=startY+40)
entry = tk.Entry(main, show='*')
entry.place(x=startX+40, y=startY+40)
button = tk.Button(main, text='登陆', fg='#e2d397', bg='#4f4f4f')
button.place(x=startX, y = startY+80)
button = tk.Button(main, text='退出', fg='#e2d397', bg='#4f4f4f')
button.place(x=startX+130, y = startY+80)

window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-263b5e6be1ce> in <module>
#       1 import tkinter as tk
# ----> 2 import ttk
#       3
#       4 window = tk.Tk()
#       5 window.title("佳期技术基金分析系统")
#
# ModuleNotFoundError: No module named 'ttk'

# %% [markdown]
# #### main UI

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
import ttk

window= Tk()
window.title("佳期技术基金分析系统")
# width = 300*2
# height = 369

# screen_width = window.winfo_screenwidth()
# screen_height = window.winfo_screenheight()
# x = (screen_width/2) - (width/2)
# y = (screen_height/2) - (height/2)
# window.geometry("%dx%d+%d+%d" % (width, height, x, y))
# window.resizable(0, 0)

menu_widget = Menu(window)
menu_widget.add_command(label="信息速览")
menu_widget.add_command(label="财经新闻")
menu_widget.add_command(label="业绩排行")
menu_widget.add_command(label="多维数据")
menu_widget.add_command(label="财务数据")
menu_widget.add_command(label="市场表现")
menu_widget.add_command(label="投资组合")
menu_widget.add_command(label="基金评估")
menu_widget.add_command(label="其他理财")
window.config(menu=menu_widget)


pw = ttk.PanedWindow(orient="vertical")
sidebar1 = ttk.PanedWindow(pw, orient="horizontal")
sidebar2 = ttk.PanedWindow(pw, orient="horizontal")
sidebar3 = ttk.PanedWindow(pw, orient="horizontal")

pw.pack(fill="both", expand=True)
pw.add(sidebar1)
pw.add(sidebar2)
pw.add(sidebar3)

sidebar1_left = Frame(sidebar1, width=200, height=120, background="#4f4f4f")
sidebar1_mid = Frame(sidebar1, width=200, height=120, background="#4f4f4f")
sidebar1_right = Frame(sidebar1, width=200, height=120, background="#4f4f4f")
sidebar1.add(sidebar1_left)
sidebar1.add(sidebar1_mid)
sidebar1.add(sidebar1_right)

title = Label(sidebar1_left, text='信息速览', fg='#e2d397', bg='#4f4f4f', height=4, width=15)
title.config(font=("System", 25))
title.pack(fill='x')
title = Label(sidebar1_mid, text='财经新闻', fg='#e2d397', bg='#4f4f4f', height=4, width=15)
title.config(font=("System", 25))
title.pack(fill='x')
title = Label(sidebar1_right, text='业绩排行', fg='#e2d397', bg='#4f4f4f', height=4, width=15)
title.config(font=("System", 25))
title.pack(fill='x')

sidebar2_left = Frame(sidebar2, width=200, height=120, background="#4f4f4f")
sidebar2_mid = Frame(sidebar2, width=200, height=120, background="#4f4f4f")
sidebar2_right = Frame(sidebar2, width=200, height=120, background="#4f4f4f")
sidebar2.add(sidebar2_left)
sidebar2.add(sidebar2_mid)
sidebar2.add(sidebar2_right)

title = Label(sidebar2_left, text='多维数据', fg='#e2d397', bg='#4f4f4f', height=4, width=15)
title.config(font=("System", 25))
title.pack(fill='x')
title = Label(sidebar2_mid, text='财务数据', fg='#e2d397', bg='#4f4f4f', height=4, width=15)
title.config(font=("System", 25))
title.pack(fill='x')
title = Label(sidebar2_right, text='市场表现', fg='#e2d397', bg='#4f4f4f', height=4, width=15)
title.config(font=("System", 25))
title.pack(fill='x')

sidebar3_left = Frame(sidebar3, width=200, height=120, background="#4f4f4f")
sidebar3_mid = Frame(sidebar3, width=200, height=120, background="#4f4f4f")
sidebar3_right = Frame(sidebar3, width=200, height=120, background="#4f4f4f")
sidebar3.add(sidebar3_left)
sidebar3.add(sidebar3_mid)
sidebar3.add(sidebar3_right)

title = Label(sidebar3_left, text='投资组合', fg='#e2d397', bg='#4f4f4f', height=4, width=15)
title.config(font=("System", 25))
title.pack(fill='x')
title = Label(sidebar3_mid, text='基金评估', fg='#e2d397', bg='#4f4f4f', height=4, width=15)
title.config(font=("System", 25))
title.pack(fill='x')
title = Label(sidebar3_right, text='其他理财', fg='#e2d397', bg='#4f4f4f', height=4, width=15)
title.config(font=("System", 25))
title.pack(fill='x')

window.mainloop()

# %% [markdown]
# #### 基金季报

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
import ttk

window= Tk()
window.title("佳期技术基金分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="信息速览")
menu_widget.add_command(label="财经新闻")
menu_widget.add_command(label="业绩排行")
menu_widget.add_command(label="多维数据")
menu_widget.add_command(label="财务数据")
menu_widget.add_command(label="市场表现")
menu_widget.add_command(label="投资组合")
menu_widget.add_command(label="基金评估")
menu_widget.add_command(label="其他理财")
window.config(menu=menu_widget)

pw = PanedWindow(orient="horizontal")
sidebar1 = PanedWindow(pw, orient="vertical")
sidebar2 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')

pw.pack(fill="both", expand=True)
pw.add(sidebar1)
pw.add(sidebar2)

sidebar = Frame(sidebar1, bg='#4f4f4f', borderwidth=2)
sidebar.pack(expand=True, fill='both')

sidebar1.add(sidebar)

title = Button(sidebar, text="基金定期报告", fg='#e2d397', bg='#4f4f4f')
title.pack(fill='x')
label1 = Label(sidebar, text='基金季报', fg='#e2d397', bg='#4f4f4f')
label1.pack(fill='x')
label1 = Label(sidebar, text='基金半年报', fg='#cccccc', bg='#4f4f4f')
label1.pack(fill='x')
label1 = Label(sidebar, text='基金年报', fg='#cccccc', bg='#4f4f4f')
label1.pack(fill='x')
button1 = Button(sidebar, text = "基金招募", fg='#e2d397', bg='#4f4f4f')
button1.pack(fill='x')
button2 = Button(sidebar, text = "重要事项", fg='#e2d397', bg='#4f4f4f')
button2.pack(fill='x')
button3 = Button(sidebar, text = "基金其他情况", fg='#e2d397', bg='#4f4f4f')
button3.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='公告日期', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-04-22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-04-22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-04-22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-04-22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-04-22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-04-22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-04-22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-04-22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-04-22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-04-22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-04-22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-04-22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-04-22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-04-22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='证券代码', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='004225.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='004226.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='005683.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='004279.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='004280.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='001241.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='002720.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='001931.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='000931.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='001826.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='006773.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='004942.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='006184.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='006185.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='公告标题', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='国寿安保稳诚A:混合型证券投资基金2019年第1季度报告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='国寿安保稳诚C:混合型证券投资基金2019年第1季度报告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='国寿安保华兴灵活配置混合型证券投资基金2019年第1季度报告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='国寿安保稳荣A混合型证券投资基金2019年第1季度报告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='国寿安保稳荣C混合型证券投资基金2019年第1季度报告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='国寿安保中证500ETF联接:2019年第1季度报告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='国寿安保尊利增强回报A:2019年第1季度报告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='国寿安保鑫钱包货币市场基金:2019年第1季度报告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='国寿安保尊利增强回报C:2019年第1季度报告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='国寿安保尊益信用纯债:2019年第1季度报告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='国寿安保增金宝:2019年第1季度报告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='格林伯元灵活配置混合型证券投资基金2019年第1季度报告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='格林泓鑫纯债债券型证券投资基金2019年第1季度报告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='格林泓鑫纯债债券型证券投资基金2019年第1季度报告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='发布时间', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='04-23 13:54', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='04-23 13:54', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='04-23 13:54', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='04-23 13:23', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='04-23 13:23', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='04-23 09:54', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='04-23 09:54', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='04-23 09:54', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='04-23 09:54', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='04-23 09:54', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='04-23 09:54', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='04-22 20:14', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='04-22 20:14', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='04-22 20:14', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')



window.mainloop()

# %% [markdown]
# #### 收益分配

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
import ttk

window= Tk()
window.title("佳期技术基金分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="信息速览")
menu_widget.add_command(label="财经新闻")
menu_widget.add_command(label="业绩排行")
menu_widget.add_command(label="多维数据")
menu_widget.add_command(label="财务数据")
menu_widget.add_command(label="市场表现")
menu_widget.add_command(label="投资组合")
menu_widget.add_command(label="基金评估")
menu_widget.add_command(label="其他理财")
window.config(menu=menu_widget)

pw = PanedWindow(orient="horizontal")
sidebar1 = PanedWindow(pw, orient="vertical")
sidebar2 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')

pw.pack(fill="both", expand=True)
pw.add(sidebar1)
pw.add(sidebar2)

sidebar = Frame(sidebar1, bg='#4f4f4f', borderwidth=2)
sidebar.pack(expand=True, fill='both')

sidebar1.add(sidebar)

title = Button(sidebar, text="基金定期报告", fg='#e2d397', bg='#4f4f4f')
title.pack(fill='x')
button1 = Button(sidebar, text = "基金招募", fg='#e2d397', bg='#4f4f4f')
button1.pack(fill='x')
button2 = Button(sidebar, text = "重要事项", fg='#e2d397', bg='#4f4f4f')
button2.pack(fill='x')
label1 = Label(sidebar, text='收益分配', fg='#e2d397', bg='#4f4f4f')
label1.pack(fill='x')
label1 = Label(sidebar, text='申购赎回', fg='#cccccc', bg='#4f4f4f')
label1.pack(fill='x')
label1 = Label(sidebar, text='基金经理变更', fg='#cccccc', bg='#4f4f4f')
label1.pack(fill='x')
label1 = Label(sidebar, text='管理公司信息', fg='#cccccc', bg='#4f4f4f')
label1.pack(fill='x')
label1 = Label(sidebar, text='参与增发', fg='#cccccc', bg='#4f4f4f')
label1.pack(fill='x')
label1 = Label(sidebar, text='清算报告', fg='#cccccc', bg='#4f4f4f')
label1.pack(fill='x')
label1 = Label(sidebar, text='持有人大会', fg='#cccccc', bg='#4f4f4f')
label1.pack(fill='x')
label1 = Label(sidebar, text='募集期调整', fg='#cccccc', bg='#4f4f4f')
label1.pack(fill='x')
button3 = Button(sidebar, text = "基金其他情况", fg='#e2d397', bg='#4f4f4f')
button3.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='公告日期', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-05-17', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-05-17', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-05-17', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-05-16', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-05-16', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-05-16', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-05-16', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-05-16', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-05-16', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-05-16', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-05-16', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-05-16', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-05-15', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2019-05-15', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='证券代码', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='006222.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='001991.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='001992.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='519128.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='519129.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='519322.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='519323.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='003673.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='003651.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='000183.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='673030.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='519185.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='392002.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='392001.OF', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='公告标题', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='平安惠兴:平安惠兴纯债债券型证券投资基金分红公告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='农银汇理天天利A:关于农银天天利货币基金调整收益支付方式并修改基金合同的公告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='农银汇理天天利B:关于农银天天利货币基金调整收益支付方式并修改基金合同的公告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='浦银安盛月月盈A:浦银安盛月月盈定期支付债券型证券投资基金2019年定期支付表(5月)', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='浦银安盛月月盈C:浦银安盛月月盈定期支付债券型证券投资基金2019年定期支付表(5月)', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='浦银安盛盛元定开A:浦银安盛盛元定期开放债券型发起式证券投资基金2019年度第一次分红公告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='浦银安盛盛元定开C:浦银安盛盛元定期开放债券型发起式证券投资基金2019年度第一次分红公告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='中加丰裕纯债:中加丰裕纯债债券型证券投资基金分红公告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='博时丰达纯债6个月:博时丰达纯债6个月定期开放债券型发起式证券投资基金分红公告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='嘉实丰益策略:嘉实丰益策略定期开放债券型证券投资基金2019年第二次收益分配公告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='西部利得多策略优选:西部利得多策略优选灵活配置混合型证券投资基金2019年临时公告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='万家精选:万家精选混合型证券投资基金分红公告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='中海货币A:中海货币市场证券投资基金收益支付公告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='中海货币A:中海货币市场证券投资基金收益支付公告', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='发布时间', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='05-17 09:01', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='05-17 01:01', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='05-17 01:01', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='05-16 15:29', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='05-16 15:29', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='05-16 15:29', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='05-16 15:29', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='05-16 11:06', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='05-16 09:00', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='05-16 07:35', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='05-16 01:02', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='05-16 00:34', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='05-15 14:46', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='05-15 14:46', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')



window.mainloop()

# %% [markdown]
# #### 财经新闻

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window= Tk()
window.title("佳期技术基金分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="信息速览")
menu_widget.add_command(label="财经新闻")
menu_widget.add_command(label="业绩排行")
menu_widget.add_command(label="多维数据")
menu_widget.add_command(label="财务数据")
menu_widget.add_command(label="市场表现")
menu_widget.add_command(label="投资组合")
menu_widget.add_command(label="基金评估")
menu_widget.add_command(label="其他理财")
window.config(menu=menu_widget)

pw = PanedWindow(orient="horizontal")
main1 = PanedWindow(pw, orient="vertical")
sidebar1 = PanedWindow(pw, orient="vertical")
sidebar2 = PanedWindow(pw, orient="horizontal", bg='#3a3a3a')
main1.pack(fill="both", expand=True)
main1.add(sidebar1)
main1.add(sidebar2)

main2 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
sidebar3 = PanedWindow(pw, orient="horizontal")
sidebar4 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')
sidebar5 = PanedWindow(pw, orient="horizontal")
sidebar6 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')
main2.pack(fill="both", expand=True)
main2.add(sidebar3)
main2.add(sidebar4)
main2.add(sidebar5)
main2.add(sidebar6)

pw.pack(fill="both", expand=True)
pw.add(main1)
pw.add(main2)

mainCol1 = Frame(sidebar1, bg='#4f4f4f', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
entry1 = Entry(mainCol1, show='')
entry1Start = 170
entry1.place(x=entry1Start, y=5)
button1 = Button(mainCol1, text='搜索', fg='#f4f4f4', bg='#4f4f4f')
button1.place(x=entry1Start + 140, y=2)


mainCol1 = Frame(sidebar2, bg='#4f4f4f', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='11:33', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='11:22', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='11:05', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='10:07', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='09:48', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='09:21', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='09:09', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='09:08', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='09:00', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='08:58', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='08:49', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='08:45', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='08:38', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='08:23', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='MSCI扩容引入增量“活水”新华基金前瞻布局相关主题投资', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='天广中茂收年报问询函：要求说明中茂园林相关工程项目停工的原因', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='港股通资金可用时点提前，您的资金使用效率将更高！(国金证券)', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='仅差2000亿！建信等基金公司的专户规模赶上公募啦？ (维基揭秘)', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='*ST龙力收年报问询函：要求说明业务毛利率变动的原因及合理性', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='重回配置区间？可转债基金后市如何演绎', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='追踪ETF“抄底盘”：半月吸金145亿 保险、个人或是主力', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='A股融资融券日报：两融余额增加0.24亿元', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='*ST毅昌收年报问询函：要求补充说明收购乐融致新2.22%股权的原因', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='浔兴股份收年报问询函：要求说明价之链未完成业绩承诺的原因', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='美邦服饰收年报问询函：说明是否存在利用加盟商压货协助提前确认收入', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='智通港股通占比异动统计(智通财经)', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='非银｜蚂蚁金服：新用户价值开始体现，全年增长展望乐观 (中信证券研究)', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='大股东减持新套路：股票换购ETF (阿尔法工场)', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar3, bg='#4f4f4f', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='阅读排行', fg='#e2d397', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#4f4f4f', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='1', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='4', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='5', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')


mainCol1 = Frame(sidebar4, bg='#4f4f4f', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='今年最惨新股诞生！上市次日即开板，首日一签仅赚不足5000元 (中证报)', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='陆家嘴财经早餐2019年5月17日星期五', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='重组并购雷区频现，至少24家券商公开致歉！', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='发改委新闻发布会 (全文)', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='发改委等要求做好2019年降成本重点工作：扩大直接融资规模', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#4f4f4f', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='财经日历 2019-05-17', fg='#e2d397', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')

mainCol1 = Frame(sidebar6, bg='#4f4f4f', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='时间', fg='#cccccc', bg='#666666', height=1)
label1.config(font=("System", 5))
label1.pack(fill='x')
label1 = Label(mainCol1, text='08:30', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='12:30', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='16:30', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='17:00', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='17:00', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='22:00', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='22:00', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar6, bg='#4f4f4f', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='地区', fg='#cccccc', bg='#666666', height=1)
label1.config(font=("System", 5))
label1.pack(fill='x')
label1 = Label(mainCol1, text='新加坡', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='日本', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='中国香港', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='欧盟', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='欧盟', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='俄罗斯', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='俄罗斯', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')


mainCol1 = Frame(sidebar6, bg='#4f4f4f', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='事件', fg='#cccccc', bg='#666666', height=1)
label1.config(font=("System", 5))
label1.pack(fill='x')
label1 = Label(mainCol1, text='出口金额', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='第三产业活动指数', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='GDP:同比(%)', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='欧元区:营建产出:环比(%)', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='欧盟:CPI:同比(%)', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='货物进口:同比(%)', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='货物出口:同比(%)', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')


window.mainloop()

# %% [markdown]
# #### 业绩排行

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
import ttk

window= Tk()
window.title("佳期技术基金分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="信息速览")
menu_widget.add_command(label="财经新闻")
menu_widget.add_command(label="业绩排行")
menu_widget.add_command(label="多维数据")
menu_widget.add_command(label="财务数据")
menu_widget.add_command(label="市场表现")
menu_widget.add_command(label="投资组合")
menu_widget.add_command(label="基金评估")
menu_widget.add_command(label="其他理财")
window.config(menu=menu_widget)

pw = PanedWindow(orient="horizontal")
sidebar1 = PanedWindow(pw, orient="vertical")
sidebar2 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')

pw.pack(fill="both", expand=True)
pw.add(sidebar1)
pw.add(sidebar2)

sidebar = Frame(sidebar1, bg='#4f4f4f', borderwidth=2)
sidebar.pack(expand=True, fill='both')

sidebar1.add(sidebar)

title = Button(sidebar, text="ETF基金", fg='#cccccc', bg='#4f4f4f')
title.pack(fill='x')
label1 = Button(sidebar, text='分级基金', fg='#e2d397', bg='#4f4f4f')
label1.pack(fill='x')
label1 = Button(sidebar, text='开放式基金', fg='#e2d397', bg='#4f4f4f')
label1.pack(fill='x')
label1 = Button(sidebar, text='QDII基金', fg='#e2d397', bg='#4f4f4f')
label1.pack(fill='x')
button1 = Button(sidebar, text = "RQFII基金", fg='#e2d397', bg='#4f4f4f')
button1.pack(fill='x')
button2 = Button(sidebar, text = "阳光私募", fg='#e2d397', bg='#4f4f4f')
button2.pack(fill='x')
button3 = Button(sidebar, text = "全部上市基金", fg='#e2d397', bg='#4f4f4f')
button3.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='序号', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='4', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='5', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='6', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='8', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='9', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='10', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='11', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='12', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='13', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='14', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='代码', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='159901', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='159902', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='159903', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='159905', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='159906', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='159907', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='159908', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='159909', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='159910', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='159911', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='159912', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='159913', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='159915', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='159916', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='名称', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深100ETF', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='中小板', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深成ETF', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深红利', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='中小300', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='博时创业', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深TMT', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深F120', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='民营ETF', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深300ETF', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深价值', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='创业板', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深F60', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='现价', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='4.278', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.711', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.999', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.759', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.757', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.133', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.272', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3.892', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.757', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3.427', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.189', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.780', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.416', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3.869', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='涨跌幅', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-2.99%', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-2.76%', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-1.48%', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-2.44%', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-1.56%', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-2.66%', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-3.49%', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-3.35%', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-2.50%', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-3.08%', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-1.41%', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-1.93%', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-3.54%', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-2.59%', fg='#26ed1f', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='溢折率', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.06%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.11%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.74%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.12%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.87%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-1.00%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-0.02%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.04%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.67%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-0.33%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.48%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-0.17%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-0.01%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-0.04%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='换手率', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='4.17%', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3.44%', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.28%', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.48%', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.10%', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.15%', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.55%', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.66%', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.14%', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.82%', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.54%', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.46%', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='4.38%', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.15%', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='成交金额', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.29亿', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='6976.47万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='112.71万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1675.98万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='11.60万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='28.96万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='258.64万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='306.72万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='148.82万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='35.49万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='63.27万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='35.35万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='9.10亿', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='71.20万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='5日涨跌幅', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-2.48%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-3.18%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-0.99%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-1.01%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-2.57%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-2.75%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-3.71%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-5.99%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-1.51%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-3.79%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-2.70%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-1.11%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-3.34%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-2.54%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='60日涨跌幅', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.41%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.07%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='8.59%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='13.56%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3.70%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.71%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='5.21%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-1.84%', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='10.64%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3.66%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='8.09%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='9.88%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='4.35%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='12.31%', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='基金份额', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='12.65亿', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='8.40亿', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='4.06亿', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='6.39亿', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.46亿', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.72亿', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7772.90万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='4627.14万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='6.17亿', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1247.25万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='9754.90万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='4332.97万', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='144.13亿', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.23亿', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='跟踪指数', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深证100', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='中小板指', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深证成指', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深证红利', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='成长40', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='中小300', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='创业板指', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='TMT50', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深证F120', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深证民营', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深证300', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深证价值', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='创业板指', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='深证F60', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')


window.mainloop()

# %% [markdown]
# #### 历史业绩

# %%
readPath = r'\\192.168.10.217\shareWithBenny\indexInfo\IC'
data = pd.read_pickle(os.path.join(readPath, 'Day_Index_IC.pkl'))
data['date'] = data['intdate'].apply(lambda x: datetime.datetime(1899,12,30) + datetime.timedelta(int(x)))
data['close'] = data['d_index_close']/data[data['date'] == datetime.date(2018, 12, 17)]['d_index_close'].values[0]


induData = data[['date', 'close']].reset_index(drop=True)
induData = induData.set_index('date')
induData['MA10'] = induData["close"].rolling(10, min_periods = 1).mean()
induData['MA20'] = induData["close"].rolling(20, min_periods = 1).mean()
induData['MA60'] = induData["close"].rolling(60, min_periods = 1).mean()
induData = induData.iloc[400:]

fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)

xticks = [i for i in range(0, len(induData.index)+1, 20)]
ax.set_xticks(xticks)
xlabels = [i.date() for i in induData.index[0::20]]
ax.set_xticklabels(xlabels)
ax.set_xlim(0)

ax.plot(induData['close'].values, label='收盘价')
ax.plot(induData.MA10.values, label='10天均线', alpha=0.7)
ax.plot(induData.MA20.values, label='20天均线', alpha=0.7)
ax.plot(induData.MA60.values, label='60天均线', alpha=0.7)
# Out:
# C:\Users\win\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and 'the values will not compare equal to the
# 'datetime.date'. To retain the current behavior, convert the
# 'datetime.date' to a datetime with 'pd.Timestamp'.
#   after removing the cwd from sys.path.

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
import ttk

window= Tk()
window.title("佳期技术基金分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="信息速览")
menu_widget.add_command(label="财经新闻")
menu_widget.add_command(label="业绩排行")
menu_widget.add_command(label="多维数据")
menu_widget.add_command(label="财务数据")
menu_widget.add_command(label="市场表现")
menu_widget.add_command(label="投资组合")
menu_widget.add_command(label="基金评估")
menu_widget.add_command(label="其他理财")
window.config(menu=menu_widget)

pw = PanedWindow(orient="horizontal")
sidebar1 = PanedWindow(pw, orient="vertical")
sidebar2 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')

pw.pack(fill="both", expand=True)
pw.add(sidebar1)
pw.add(sidebar2)

sidebar = Frame(sidebar1, bg='#4f4f4f', borderwidth=2)
sidebar.pack(expand=True, fill='both')

sidebar1.add(sidebar)

title = Button(sidebar, text="ETF基金", fg='#e2d397', bg='#4f4f4f')
title.pack(fill='x')
label1 = Label(sidebar, text='深300ETF', fg='#e2d397', bg='#4f4f4f')
label1.pack(fill='x')
label1 = Button(sidebar, text='分级基金', fg='#e2d397', bg='#4f4f4f')
label1.pack(fill='x')
label1 = Button(sidebar, text='开放式基金', fg='#e2d397', bg='#4f4f4f')
label1.pack(fill='x')
label1 = Button(sidebar, text='QDII基金', fg='#e2d397', bg='#4f4f4f')
label1.pack(fill='x')
button1 = Button(sidebar, text = "RQFII基金", fg='#e2d397', bg='#4f4f4f')
button1.pack(fill='x')
button2 = Button(sidebar, text = "阳光私募", fg='#e2d397', bg='#4f4f4f')
button2.pack(fill='x')
button3 = Button(sidebar, text = "全部上市基金", fg='#e2d397', bg='#4f4f4f')
button3.pack(fill='x')

mainarea = Frame(sidebar2, bg='#CCC')
mainarea.pack(expand=True, fill='both', side='right')

induData = data[['date', 'close']].reset_index(drop=True)
induData = induData.set_index('date')
induData['MA10'] = induData["close"].rolling(10, min_periods = 1).mean()
induData['MA20'] = induData["close"].rolling(20, min_periods = 1).mean()
induData['MA60'] = induData["close"].rolling(60, min_periods = 1).mean()
induData = induData.iloc[400:]

fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)

xticks = [i for i in range(0, len(induData.index)+1, 20)]
ax.set_xticks(xticks)
xlabels = [i.date() for i in induData.index[0::20]]
ax.set_xticklabels(xlabels)
ax.set_xlim(0)

ax.plot(induData['close'].values, label='收盘价', linewidth=2, color='#649fed')
ax.plot(induData.MA10.values, label='10天均线', alpha=0.5, color='#ed8037')
ax.plot(induData.MA20.values, label='20天均线', alpha=0.5, color='#80ed92')
ax.plot(induData.MA60.values, label='60天均线', alpha=0.5, color='#ed8eda')
ax.set_title('深300ETF日线')
ax.set_ylabel('ETF净值')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_facecolor('#4f4f4f')
fig.patch.set_facecolor('#4f4f4f')

# axisColor = '#b2d9ed'
axisColor = '#e2d397'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)

legend = plt.legend(frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('#4f4f4f')
frame.set_edgecolor('#4f4f4f')
plt.setp(legend.get_texts(), color=axisColor)

canvas = FigureCanvasTkAgg(fig, master=mainarea)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()

# sidebar2


window.mainloop()

# %% [markdown]
# #### 基金比较

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
import ttk

window= Tk()
window.title("佳期技术基金分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="信息速览")
menu_widget.add_command(label="财经新闻")
menu_widget.add_command(label="业绩排行")
menu_widget.add_command(label="多维数据")
menu_widget.add_command(label="财务数据")
menu_widget.add_command(label="市场表现")
menu_widget.add_command(label="投资组合")
menu_widget.add_command(label="基金评估")
menu_widget.add_command(label="其他理财")
window.config(menu=menu_widget)

pw = PanedWindow(orient="horizontal")
mainbar1 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar2 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar3 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar4 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')
mainbar5 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar6 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')

mainbar2.pack(fill='both', expand=True)
mainbar2.add(mainbar3)
mainbar2.add(mainbar4)
mainbar2.add(mainbar5)
mainbar2.add(mainbar6)

pw.pack(fill="both", expand=True)
pw.add(mainbar1)
pw.add(mainbar2)


sidebar1 = Frame(mainbar1, bg='#4f4f4f', borderwidth=2)
sidebar1.pack(expand=True, fill='both')
mainbar1.add(sidebar1)
title = Button(sidebar1, text="基金数据浏览", fg='#e2d397', bg='#4f4f4f', anchor='w')
title.pack(fill='x')
label1 = Button(sidebar1, text='基金筛选', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Button(sidebar1, text='基金比较', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='今年业绩表现', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='本月业绩表现', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='一年业绩表现', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='今年相关系数矩阵', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='本月相关系数矩阵', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='近五年净值走势', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='近五年收益回报', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='行业配置对比', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='重仓持股对比', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='持有人结构', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Button(sidebar1, text='基金经理比较', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
button1 = Button(sidebar1, text = "基金定投计算器", fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')

sidebar1 = Frame(mainbar1, bg='#4f4f4f', borderwidth=2)
sidebar1.pack(expand=True, fill='both')
mainbar1.add(sidebar1)

entry1XStart = 1
entry1YStart = 25
button1 = Label(sidebar1, text='选择基准', fg='#e2d397', bg='#4f4f4f')
button1.place(x=entry1Start, y=0)
entry1 = Entry(sidebar1, show='')
entry1.place(x=entry1Start+60, y=2, width=80)

button1 = Label(sidebar1, text='截至日期', fg='#e2d397', bg='#4f4f4f')
button1.place(x=entry1Start, y=entry1YStart)
entry1 = Entry(sidebar1, show='')
entry1.place(x=entry1Start+60, y=entry1YStart+2, width=80)

button1 = Label(sidebar1, text='选择基金', fg='#e2d397', bg='#4f4f4f')
button1.place(x=entry1Start, y=entry1YStart*2)
entry1 = Entry(sidebar1, show='')
entry1.place(x=entry1Start+60, y=entry1YStart*2+2, width=80)


sidebar1 = Frame(mainbar3, bg='#4f4f4f')
sidebar1.pack(expand=True, fill='both')
mainbar3.add(sidebar1)
label1 = Label(sidebar1, text='已添加基金', fg='#e2d397', bg='#4f4f4f', height=1)
label1.config(font=("System", 6))
label1.place(x=0)

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金名称', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='华安创新', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='博时价值成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='易方达策略成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='华夏成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金成立日', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2001-09-21', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2002-10-09', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2003-12-09', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2001-12-18', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金类型', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='平衡混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='平衡混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='偏股混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='偏股混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金规模(亿元)', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='19.29', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='38.59', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='12.16', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='49.91', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='最新单位净值', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.6770', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.7670', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.8660', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.1020', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='申购赎回状态', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

sidebar1 = Frame(mainbar5, bg='#4f4f4f')
sidebar1.pack(expand=True, fill='both')
mainbar5.add(sidebar1)
label1 = Label(sidebar1, text='今年业绩表现', fg='#e2d397', bg='#4f4f4f', height=1)
label1.config(font=("System", 6))
label1.place(x=0)

mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='基金名称', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='华安创新', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='博时价值成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='易方达策略成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='华夏成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='沪深300', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='回报(%)', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='21.76', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='22.13', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20.66', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20.04', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='21.19', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='超额回报(%)', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.57', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.94', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-0.53', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-1.15', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='Sharpe', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.69', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.66', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.97', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.30', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='标准差', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='21.07', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='21.70', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='28.34', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='23.25', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='26.72', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='Alpha', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='8.68', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='11.36', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-4.67', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.08', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='Beta', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.76', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.73', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.95', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.82', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='R平方', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.90', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.79', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.78', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.87', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='下行风险', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='13.50', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='13.29', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='17.91', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='14.28', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='Sortino', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='4.22', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='4.37', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3.14', fg='#26ed1f', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3.76', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-', fg='#f4f4f4', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')

window.mainloop()

# %% [markdown]
# #### 基金相关性矩阵

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
import ttk

window= Tk()
window.title("佳期技术基金分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="信息速览")
menu_widget.add_command(label="财经新闻")
menu_widget.add_command(label="业绩排行")
menu_widget.add_command(label="多维数据")
menu_widget.add_command(label="财务数据")
menu_widget.add_command(label="市场表现")
menu_widget.add_command(label="投资组合")
menu_widget.add_command(label="基金评估")
menu_widget.add_command(label="其他理财")
window.config(menu=menu_widget)

pw = PanedWindow(orient="horizontal")
mainbar1 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar2 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar3 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar4 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')
mainbar5 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar6 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')

mainbar2.pack(fill='both', expand=True)
mainbar2.add(mainbar3)
mainbar2.add(mainbar4)
mainbar2.add(mainbar5)
mainbar2.add(mainbar6)

pw.pack(fill="both", expand=True)
pw.add(mainbar1)
pw.add(mainbar2)


sidebar1 = Frame(mainbar1, bg='#4f4f4f', borderwidth=2)
sidebar1.pack(expand=True, fill='both')
mainbar1.add(sidebar1)
title = Button(sidebar1, text="基金数据浏览", fg='#e2d397', bg='#4f4f4f', anchor='w')
title.pack(fill='x')
label1 = Button(sidebar1, text='基金筛选', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Button(sidebar1, text='基金比较', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='今年业绩表现', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='本月业绩表现', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='一年业绩表现', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='今年相关系数矩阵', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='本月相关系数矩阵', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='近五年净值走势', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='近五年收益回报', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='行业配置对比', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='重仓持股对比', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='持有人结构', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Button(sidebar1, text='基金经理比较', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
button1 = Button(sidebar1, text = "基金定投计算器", fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')

sidebar1 = Frame(mainbar1, bg='#4f4f4f', borderwidth=2)
sidebar1.pack(expand=True, fill='both')
mainbar1.add(sidebar1)

entry1XStart = 1
entry1YStart = 25
button1 = Label(sidebar1, text='选择基准', fg='#e2d397', bg='#4f4f4f')
button1.place(x=entry1Start, y=0)
entry1 = Entry(sidebar1, show='')
entry1.place(x=entry1Start+60, y=2, width=80)

button1 = Label(sidebar1, text='截至日期', fg='#e2d397', bg='#4f4f4f')
button1.place(x=entry1Start, y=entry1YStart)
entry1 = Entry(sidebar1, show='')
entry1.place(x=entry1Start+60, y=entry1YStart+2, width=80)

button1 = Label(sidebar1, text='选择基金', fg='#e2d397', bg='#4f4f4f')
button1.place(x=entry1Start, y=entry1YStart*2)
entry1 = Entry(sidebar1, show='')
entry1.place(x=entry1Start+60, y=entry1YStart*2+2, width=80)


sidebar1 = Frame(mainbar3, bg='#4f4f4f')
sidebar1.pack(expand=True, fill='both')
mainbar3.add(sidebar1)
label1 = Label(sidebar1, text='已添加基金', fg='#e2d397', bg='#4f4f4f', height=1)
label1.config(font=("System", 6))
label1.place(x=0)

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金名称', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='华安创新', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='博时价值成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='易方达策略成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='华夏成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金成立日', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2001-09-21', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2002-10-09', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2003-12-09', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2001-12-18', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金类型', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='平衡混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='平衡混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='偏股混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='偏股混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金规模(亿元)', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='19.29', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='38.59', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='12.16', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='49.91', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='最新单位净值', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.6770', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.7670', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.8660', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.1020', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='申购赎回状态', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

sidebar1 = Frame(mainbar5, bg='#4f4f4f')
sidebar1.pack(expand=True, fill='both')
mainbar5.add(sidebar1)
label1 = Label(sidebar1, text='今年以来相关系数矩阵', fg='#e2d397', bg='#4f4f4f', height=1)
label1.config(font=("System", 6))
label1.place(x=0)

mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#f4f4f4', bg='#4f4f4f', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in ['华安创新', '博时价值增长', '易方达策略成长', '华夏成长', '沪深300']:
    label1 = Label(mainCol1, text=value, fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='华安创新', fg='#f4f4f4', bg='#4f4f4f', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in ['1.00', '0.84', '0.86', '0.89', '0.95']:
    if value == '0.89':
        label1 = Label(mainCol1, text=value, fg='#ed6b51', bg='#4f4f4f', anchor='w')
    elif value == '0.84':
        label1 = Label(mainCol1, text=value, fg='#8eed9b', bg='#4f4f4f', anchor='w')
    else:
        label1 = Label(mainCol1, text=value, fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='博时价值增长', fg='#f4f4f4', bg='#4f4f4f', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in ['0.84', '1.00', '0.94', '0.92', '0.89']:
    if value == '0.94':
        label1 = Label(mainCol1, text=value, fg='#ed6b51', bg='#4f4f4f', anchor='w')
    elif value == '0.84':
        label1 = Label(mainCol1, text=value, fg='#8eed9b', bg='#4f4f4f', anchor='w')
    else:
        label1 = Label(mainCol1, text=value, fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='易方达策略成长', fg='#f4f4f4', bg='#4f4f4f', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in ['0.86', '0.94', '1.00', '0.93', '0.88']:
    if value == '0.94':
        label1 = Label(mainCol1, text=value, fg='#ed6b51', bg='#4f4f4f', anchor='w')
    elif value == '0.86':
        label1 = Label(mainCol1, text=value, fg='#8eed9b', bg='#4f4f4f', anchor='w')
    else:
        label1 = Label(mainCol1, text=value, fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='华夏成长', fg='#f4f4f4', bg='#4f4f4f', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in ['0.89', '0.92', '0.93', '1.00', '0.94']:
    if value == '0.93':
        label1 = Label(mainCol1, text=value, fg='#ed6b51', bg='#4f4f4f', anchor='w')
    elif value == '0.89':
        label1 = Label(mainCol1, text=value, fg='#8eed9b', bg='#4f4f4f', anchor='w')
    else:
        label1 = Label(mainCol1, text=value, fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='沪深300', fg='#f4f4f4', bg='#4f4f4f', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in ['0.95', '0.89', '0.88', '0.94', '1.00']:
    if value == '0.95':
        label1 = Label(mainCol1, text=value, fg='#ed6b51', bg='#4f4f4f', anchor='w')
    elif value == '0.88':
        label1 = Label(mainCol1, text=value, fg='#8eed9b', bg='#4f4f4f', anchor='w')
    else:
        label1 = Label(mainCol1, text=value, fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')

window.mainloop()

# %%
label1 = Label(mainCol1, text='11.36', fg='#ed330e', bg='#4f4f4f', anchor='e')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='-4.67', fg='#26ed1f', bg='#4f4f4f', anchor='e')

# %% [markdown]
# #### 近五年年度收益回报

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
import ttk

window= Tk()
window.title("佳期技术基金分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="信息速览")
menu_widget.add_command(label="财经新闻")
menu_widget.add_command(label="业绩排行")
menu_widget.add_command(label="多维数据")
menu_widget.add_command(label="财务数据")
menu_widget.add_command(label="市场表现")
menu_widget.add_command(label="投资组合")
menu_widget.add_command(label="基金评估")
menu_widget.add_command(label="其他理财")
window.config(menu=menu_widget)

pw = PanedWindow(orient="horizontal")
mainbar1 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar2 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar3 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar4 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')
mainbar5 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar6 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')

mainbar2.pack(fill='both', expand=True)
mainbar2.add(mainbar3)
mainbar2.add(mainbar4)
mainbar2.add(mainbar5)
mainbar2.add(mainbar6)

pw.pack(fill="both", expand=True)
pw.add(mainbar1)
pw.add(mainbar2)


sidebar1 = Frame(mainbar1, bg='#4f4f4f', borderwidth=2)
sidebar1.pack(expand=True, fill='both')
mainbar1.add(sidebar1)
title = Button(sidebar1, text="基金数据浏览", fg='#e2d397', bg='#4f4f4f', anchor='w')
title.pack(fill='x')
label1 = Button(sidebar1, text='基金筛选', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Button(sidebar1, text='基金比较', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='今年业绩表现', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='本月业绩表现', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='一年业绩表现', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='今年相关系数矩阵', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='本月相关系数矩阵', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='近五年净值走势', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='近五年收益回报', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='行业配置对比', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='重仓持股对比', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='持有人结构', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Button(sidebar1, text='基金经理比较', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
button1 = Button(sidebar1, text = "基金定投计算器", fg='#e2d397', bg='#4f4f4f', anchor='w')
button1.pack(fill='x')

sidebar1 = Frame(mainbar1, bg='#4f4f4f', borderwidth=2)
sidebar1.pack(expand=True, fill='both')
mainbar1.add(sidebar1)

entry1XStart = 1
entry1YStart = 25
button1 = Label(sidebar1, text='选择基准', fg='#e2d397', bg='#4f4f4f')
button1.place(x=entry1Start, y=0)
entry1 = Entry(sidebar1, show='')
entry1.place(x=entry1Start+60, y=2, width=80)

button1 = Label(sidebar1, text='截至日期', fg='#e2d397', bg='#4f4f4f')
button1.place(x=entry1Start, y=entry1YStart)
entry1 = Entry(sidebar1, show='')
entry1.place(x=entry1Start+60, y=entry1YStart+2, width=80)

button1 = Label(sidebar1, text='选择基金', fg='#e2d397', bg='#4f4f4f')
button1.place(x=entry1Start, y=entry1YStart*2)
entry1 = Entry(sidebar1, show='')
entry1.place(x=entry1Start+60, y=entry1YStart*2+2, width=80)


sidebar1 = Frame(mainbar3, bg='#4f4f4f')
sidebar1.pack(expand=True, fill='both')
mainbar3.add(sidebar1)
label1 = Label(sidebar1, text='已添加基金', fg='#e2d397', bg='#4f4f4f', height=1)
label1.config(font=("System", 6))
label1.place(x=0)

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金名称', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='华安创新', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='博时价值成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='易方达策略成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='华夏成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金成立日', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2001-09-21', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2002-10-09', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2003-12-09', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2001-12-18', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金类型', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='平衡混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='平衡混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='偏股混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='偏股混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金规模(亿元)', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='19.29', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='38.59', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='12.16', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='49.91', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='最新单位净值', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.6770', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.7670', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.8660', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.1020', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='申购赎回状态', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

sidebar1 = Frame(mainbar5, bg='#4f4f4f')
sidebar1.pack(expand=True, fill='both')
mainbar5.add(sidebar1)
label1 = Label(sidebar1, text='近五年收益回报', fg='#e2d397', bg='#4f4f4f', height=1)
label1.config(font=("System", 6))
label1.place(x=0)

mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)

data1 = np.array([14.62, 27.74, -18.89, 4.48, -25.47, 21.76])/100
data2 = np.array([23.24, 6.32, -9.32, -3.47, -19.49, 22.13])/100
data3 = np.array([13.79, 24.24, -35.12, 17.42, -32.18, 20.66])/100
data4 = np.array([15.27, 25.86, -22.72, 17.11, -19.05, 20.04])/100
data5 = np.array([51.66, 5.58, -11.28, 21.78, -25.31, 21.19])/100
index = np.arange(0, 1.5*6, 1.5)

fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)
bar_width = 0.2
ax.bar(index, data1, bar_width, color='#5f9ced', label='华安创新')
ax.bar(index+bar_width, data2, bar_width, color='#ed927b', label='博时价值成长')
ax.bar(index+bar_width*2, data3, bar_width, color='#77eda6', label='易方达策略成长')
ax.bar(index+bar_width*3, data4, bar_width, color='#bf82ed', label='华夏成长')
ax.bar(index+bar_width*4, data5, bar_width, color='#ed9f39', label='沪深300')
ax.set_ylim(-0.5, 0.75)
xindexReset = [0.4, 1.9, 3.4, 4.9, 6.4, 7.9]
ax.set_xticks(xindexReset)
xlabelReset = [2014, 2015, 2016, 2017, 2018, 'YTD']
ax.set_xticklabels(xlabelReset)
yindexReset = [-0.5, -0.25, 0, 0.25, 0.5, 0.75]
ax.set_yticks(yindexReset)
ylabelReset = ['-50%', '-25%', '0%', '25%', '50%', '75%']
ax.set_yticklabels(ylabelReset)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_facecolor('#4f4f4f')
fig.patch.set_facecolor('#4f4f4f')
axisColor = '#e2d397'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)

legend = plt.legend(frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('#4f4f4f')
frame.set_edgecolor('#4f4f4f')
plt.setp(legend.get_texts(), color=axisColor)

canvas = FigureCanvasTkAgg(fig, master=mainCol1)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()

window.mainloop()

# %% [markdown]
# #### 重仓持股结构

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
import ttk

window= Tk()
window.title("佳期技术基金分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="信息速览")
menu_widget.add_command(label="财经新闻")
menu_widget.add_command(label="业绩排行")
menu_widget.add_command(label="多维数据")
menu_widget.add_command(label="财务数据")
menu_widget.add_command(label="市场表现")
menu_widget.add_command(label="投资组合")
menu_widget.add_command(label="基金评估")
menu_widget.add_command(label="其他理财")
window.config(menu=menu_widget)

pw = PanedWindow(orient="horizontal")
mainbar1 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar2 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar3 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar4 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')
mainbar5 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar6 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')
mainbar7 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')

mainbar2.pack(fill='both', expand=True)
mainbar2.add(mainbar3)
mainbar2.add(mainbar4)
mainbar2.add(mainbar5)
mainbar2.add(mainbar6)
mainbar2.add(mainbar7)

pw.pack(fill="both", expand=True)
pw.add(mainbar1)
pw.add(mainbar2)


sidebar1 = Frame(mainbar1, bg='#4f4f4f', borderwidth=2)
sidebar1.pack(expand=True, fill='both')
mainbar1.add(sidebar1)
title = Button(sidebar1, text="基金数据浏览", fg='#e2d397', bg='#4f4f4f', anchor='w')
title.pack(fill='x')
label1 = Button(sidebar1, text='基金筛选', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Button(sidebar1, text='基金比较', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='今年业绩表现', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='本月业绩表现', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='一年业绩表现', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='今年相关系数矩阵', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='本月相关系数矩阵', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='近五年净值走势', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='近五年收益回报', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='行业配置对比', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='重仓持股对比', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='持有人结构', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Button(sidebar1, text='基金经理比较', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
button1 = Button(sidebar1, text = "基金定投计算器", fg='#e2d397', bg='#4f4f4f', anchor='w')
button1.pack(fill='x')

sidebar1 = Frame(mainbar1, bg='#4f4f4f', borderwidth=2)
sidebar1.pack(expand=True, fill='both')
mainbar1.add(sidebar1)

entry1XStart = 1
entry1YStart = 25
button1 = Label(sidebar1, text='选择基准', fg='#e2d397', bg='#4f4f4f')
button1.place(x=entry1Start, y=0)
entry1 = Entry(sidebar1, show='')
entry1.place(x=entry1Start+60, y=2, width=80)

button1 = Label(sidebar1, text='截至日期', fg='#e2d397', bg='#4f4f4f')
button1.place(x=entry1Start, y=entry1YStart)
entry1 = Entry(sidebar1, show='')
entry1.place(x=entry1Start+60, y=entry1YStart+2, width=80)

button1 = Label(sidebar1, text='选择基金', fg='#e2d397', bg='#4f4f4f')
button1.place(x=entry1Start, y=entry1YStart*2)
entry1 = Entry(sidebar1, show='')
entry1.place(x=entry1Start+60, y=entry1YStart*2+2, width=80)


sidebar1 = Frame(mainbar3, bg='#4f4f4f')
sidebar1.pack(expand=True, fill='both')
mainbar3.add(sidebar1)
label1 = Label(sidebar1, text='已添加基金', fg='#e2d397', bg='#4f4f4f', height=1)
label1.config(font=("System", 6))
label1.place(x=0)

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金名称', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='华安创新', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='博时价值成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='易方达策略成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='华夏成长', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金成立日', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2001-09-21', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2002-10-09', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2003-12-09', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2001-12-18', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金类型', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='平衡混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='平衡混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='偏股混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='偏股混合型', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='基金规模(亿元)', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='19.29', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='38.59', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='12.16', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='49.91', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='最新单位净值', fg='#f4f4f4', bg='#666666', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.6770', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.7670', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.8660', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.1020', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
label1 = Label(mainCol1, text='申购赎回状态', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#f4f4f4', bg='#4f4f4f')
label1.config(font=("System", 4))
label1.pack(fill='x')

sidebar1 = Frame(mainbar5, bg='#4f4f4f')
sidebar1.pack(expand=True, fill='both')
mainbar5.add(sidebar1)
label1 = Label(sidebar1, text='重仓持股结构', fg='#e2d397', bg='#4f4f4f', height=1)
label1.config(font=("System", 6))
label1.place(x=0)

mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='华安创新', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='博时价值成长', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='易方达策略成长', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
mainCol1 = Frame(mainbar6, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar6.add(mainCol1)
label1 = Label(mainCol1, text='华夏成长', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')

mainCol1 = Frame(mainbar7, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar7.add(mainCol1)
label1 = Label(mainCol1, text='股票名称', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in ['中国平安','招商银行','宁波银行','华夏幸福','桐昆股份','万科A','万华化学','潍柴动力','贵州茅台','温氏股份']:
    label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar7, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar7.add(mainCol1)
label1 = Label(mainCol1, text='占净值比', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in [9.86, '5.80', 5.35, '4.90', 4.17, 3.96, 3.38, 3.32, 3.24, 3.15]:
    if value == 9.86:
        label1 = Label(mainCol1, text=str(value), fg='#ed330e', bg='#4f4f4f')
    elif value == 3.15:
        label1 = Label(mainCol1, text=str(value), fg='#26ed1f', bg='#4f4f4f')
    else:
        label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar7, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar7.add(mainCol1)
label1 = Label(mainCol1, text='近三月涨幅', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in [25.06, 14.27, 27.43, 6.52, 17.63, 3.05, 9.19, 27.37, 25.11, '13.10']:
    if value == 27.43:
        label1 = Label(mainCol1, text=str(value), fg='#ed330e', bg='#4f4f4f')
    elif value == 3.05:
        label1 = Label(mainCol1, text=str(value), fg='#26ed1f', bg='#4f4f4f')
    else:
        label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(mainbar7, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar7.add(mainCol1)
label1 = Label(mainCol1, text='股票名称', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in ['同花顺','完美世界','海通证券','华夏幸福','温氏股份','中兴通讯','宝信软件','太阳纸业','通威股份','格力电器']:
    label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar7, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar7.add(mainCol1)
label1 = Label(mainCol1, text='占净值比', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in [4.94, 3.98, 3.53, 3.32, '2.70' , 2.55, 2.54, 2.41 , '2.20' , 2.06]:
    if value == 4.94:
        label1 = Label(mainCol1, text=str(value), fg='#ed330e', bg='#4f4f4f')
    elif value == 2.06:
        label1 = Label(mainCol1, text=str(value), fg='#26ed1f', bg='#4f4f4f')
    else:
        label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar7, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar7.add(mainCol1)
label1 = Label(mainCol1, text='近三月涨幅', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in [54.41, -2.19, 11.74,  6.52, '13.10' , 23.91, 15.89,  3.94, 36.21, 29.92]:
    if value == 54.41:
        label1 = Label(mainCol1, text=str(value), fg='#ed330e', bg='#4f4f4f')
    elif value == -2.19:
        label1 = Label(mainCol1, text=str(value), fg='#26ed1f', bg='#4f4f4f')
    else:
        label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f')
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(mainbar7, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar7.add(mainCol1)
label1 = Label(mainCol1, text='股票名称', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in ['同花顺', '金雷股份', '泸州老窖', '国电南瑞', '温氏股份', '华东医药', '荣盛发展', '中科曙光', '隆基股份', '长春高新']:
    label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar7, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar7.add(mainCol1)
label1 = Label(mainCol1, text='占净值比', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in [4.66, 4.59, 3.55, 3.39, 3.38, '3.30' , 3.21 , 3.03, 3.01, 2.98]:
    if value == 4.66:
        label1 = Label(mainCol1, text=str(value), fg='#ed330e', bg='#4f4f4f')
    elif value == 2.98:
        label1 = Label(mainCol1, text=str(value), fg='#26ed1f', bg='#4f4f4f')
    else:
        label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar7, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar7.add(mainCol1)
label1 = Label(mainCol1, text='近三月涨幅', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in [54.41,  5.74, 62.16, -3.14, '13.10', 15.99,  6.41, 32.47, 26.26, 48.18]:
    if value == 62.16:
        label1 = Label(mainCol1, text=str(value), fg='#ed330e', bg='#4f4f4f')
    elif value == -3.14:
        label1 = Label(mainCol1, text=str(value), fg='#26ed1f', bg='#4f4f4f')
    else:
        label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f')
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(mainbar7, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar7.add(mainCol1)
label1 = Label(mainCol1, text='股票名称', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in ['南极电商', '中国平安', '洲明科技', '新华保险', '五粮液', '吉艾科技', '光环新网', '同花顺', '润和软件', '上海钢联']:
    label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar7, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar7.add(mainCol1)
label1 = Label(mainCol1, text='占净值比', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in ['7.10', 6.13, 6.08, 4.24, '3.70' , 3.69, 3.38, 3.06, 2.71, 2.44]:
    if value == '7.10':
        label1 = Label(mainCol1, text=str(value), fg='#ed330e', bg='#4f4f4f')
    elif value == 2.44:
        label1 = Label(mainCol1, text=str(value), fg='#26ed1f', bg='#4f4f4f')
    else:
        label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar7, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar7.add(mainCol1)
label1 = Label(mainCol1, text='近三月涨幅', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in [28.53, 25.06, -0.91, 16.22, 60.33,  8.53,  4.79, 54.41, 24.61 , 12.65]:
    if value == -0.91:
        label1 = Label(mainCol1, text=str(value), fg='#ed330e', bg='#4f4f4f')
    elif value == 60.33:
        label1 = Label(mainCol1, text=str(value), fg='#26ed1f', bg='#4f4f4f')
    else:
        label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
window.mainloop()

# %%
readPath = r'D:\Dropbox (study-int)\Personal - Kevin\Python Scripts\Study\Study28 - Data Analysis Software'
data = pd.read_excel(os.path.join(readPath, 'Book1.xlsx'), header=None)

# %%
data[11].values
# Out:
# array([28.53, 25.06, -0.91, 16.22, 60.33,  8.53,  4.79, 54.41, 24.6 ,
#        12.65])

# %% [markdown]
# #### 私募基金榜

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
import ttk

window= Tk()
window.title("佳期技术基金分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="信息速览")
menu_widget.add_command(label="财经新闻")
menu_widget.add_command(label="业绩排行")
menu_widget.add_command(label="多维数据")
menu_widget.add_command(label="财务数据")
menu_widget.add_command(label="市场表现")
menu_widget.add_command(label="投资组合")
menu_widget.add_command(label="基金评估")
menu_widget.add_command(label="其他理财")
window.config(menu=menu_widget)

pw = PanedWindow(orient="horizontal")
mainbar1 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar2 = PanedWindow(pw, orient="vertical", bg='#4f4f4f')
mainbar3 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')
mainbar4 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')
mainbar5 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')
mainbar6 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')
mainbar7 = PanedWindow(pw, orient="horizontal", bg='#4f4f4f')

mainbar2.pack(fill='both', expand=True)
mainbar2.add(mainbar3)
mainbar2.add(mainbar4)
mainbar2.add(mainbar5)
mainbar2.add(mainbar6)
mainbar2.add(mainbar7)

pw.pack(fill="both", expand=True)
pw.add(mainbar1)
pw.add(mainbar2)


sidebar1 = Frame(mainbar1, bg='#4f4f4f', borderwidth=2)
sidebar1.pack(expand=True, fill='both')
mainbar1.add(sidebar1)
title = Button(sidebar1, text="私募基金", fg='#e2d397', bg='#4f4f4f', anchor='w')
title.pack(fill='x')
label1 = Label(sidebar1, text='产品发行统计', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='投资顾问统计', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='机构持股汇总', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='私募基金排行榜', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='私募证券投资经理TOP50', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='基金备案信息', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='管理人备案信息', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Label(sidebar1, text='外包服务机构', fg='#f4f4f4', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Button(sidebar1, text='券商资管', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
label1 = Button(sidebar1, text='银行理财', fg='#e2d397', bg='#4f4f4f', anchor='w')
label1.pack(fill='x')
button1 = Button(sidebar1, text = "信托产品", fg='#e2d397', bg='#4f4f4f', anchor='w')
button1.pack(fill='x')
button1 = Button(sidebar1, text = "保险产品", fg='#e2d397', bg='#4f4f4f', anchor='w')
button1.pack(fill='x')


mainCol1 = Frame(mainbar3, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar3.add(mainCol1)
label1 = Label(mainCol1, text='策略类型', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in ['股票多头策略', '股票多头策略', '股票多头策略', '股票多头策略', '股票多头策略', '股票多头策略']:
    label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar3, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar3.add(mainCol1)
label1 = Label(mainCol1, text='基金名称', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in ['潮金产融1号', '大禾投资-掘金1号', '固禾钻石', '红亨稳赢2期', '幻方中证500指数增强1号', '简一天行成长3号']:
    label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar3, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar3.add(mainCol1)
label1 = Label(mainCol1, text='所属公司', fg='#f4f4f4', bg='#666666', height=1)
label1.config(font=("System", 6))
label1.pack(fill='x')
for value in ['广东潮金投资基金管理有限公司', '深圳大禾投资管理有限公司', '深圳前海固禾资产管理有限公司',
              '成都红亨投资管理有限公司', '浙江九章资产管理有限公司', '广州市简一投资管理有限公司']:
    label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)

for value in ['股票多空策略', '股票多空策略', '股票多空策略', '股票多空策略', '股票多空策略', '股票多空策略']:
    label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
for value in ['国道念空稳进4号', '禾昇1号', '金舆灵活配置1期', '锦和5号', '盘古1号', '浦来德天天开心对冲1号']:
    label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar4, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar4.add(mainCol1)
for value in ['上海念空数据科技中心(有限合伙)', '上海禾升投资管理有限公司', '上海金舆资产管理有限公司',
              '浙江锦和投资管理有限公司', '宁波宁聚资产管理中心(有限合伙)', '北京浦来德资产管理有限责任公司']:
    label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(mainbar5, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar5.add(mainCol1)
for value in ['宏观策略', '宏观策略', '宏观策略', '宏观策略', '宏观策略', '宏观策略']:
    label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar5, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar5.add(mainCol1)
for value in ['半夏宏观对冲', '华溢启明星1号', '季胜全球套利量化2号', '经易宏观对冲1号', '久期宏观对冲1号', '钱缘量化全天候进取2期']:
    label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(mainbar5, bg='#4f4f4f')
mainCol1.pack(expand=True, fill='both')
mainbar5.add(mainCol1)
for value in ['上海半夏投资管理中心(有限合伙)', '华溢之星资产管理(北京)有限公司', '上海季胜投资管理有限公司',
              '经易金业有限责任公司', '上海久期投资有限公司', '广东钱缘基金管理有限公司']:
    label1 = Label(mainCol1, text=str(value), fg='#f4f4f4', bg='#4f4f4f', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
window.mainloop()

# %%
readPath = r'D:\Dropbox (study-int)\Personal - Kevin\Python Scripts\Study\Study28 - Data Analysis Software'
data = pd.read_excel(os.path.join(readPath, 'Book2.xlsx'), header=None)

# %%
data[0].values[1:7]
# Out:
# array(['股票多头策略', '股票多头策略', '股票多头策略', '股票多头策略', '股票多头策略', '股票多头策略'],
#       dtype=object)

# %%
data[1].values[1:7]
# Out:
# array(['潮金产融1号', '大禾投资-掘金1号', '固禾钻石', '红亨稳赢2期', '幻方中证500指数增强1号',
#        '简一天行成长3号'], dtype=object)

# %%
data[2].values[1:7]
# Out:
# array(['广东潮金投资基金管理有限公司', '深圳大禾投资管理有限公司', '深圳前海固禾资产管理有限公司', '成都红亨投资管理有限公司',
#        '浙江九章资产管理有限公司', '广州市简一投资管理有限公司'], dtype=object)

# %%
data[0].values[-14:-8]
# Out:
# array(['宏观策略', '宏观策略', '宏观策略', '宏观策略', '宏观策略', '宏观策略'], dtype=object)

# %%
data[1].values[-14:-8]
# Out:
# array(['半夏宏观对冲', '华溢启明星1号', '季胜全球套利量化2号', '经易宏观对冲1号', '久期宏观对冲1号',
#        '钱缘量化全天候进取2期'], dtype=object)

# %%
data[2].values[-14:-8]
# Out:
# array(['上海半夏投资管理中心(有限合伙)', '华溢之星资产管理(北京)有限公司', '上海季胜投资管理有限公司',
#        '经易金业有限责任公司', '上海久期投资有限公司', '广东钱缘基金管理有限公司'], dtype=object)

# %%
data5
# Out:
# array([ 0.5166,  0.0558, -0.1128,  0.2178, -0.2531,  0.2119])

# %%
data1 = np.array([14.62, 27.74, -18.89, 4.48, -25.47, 21.76])/100
data2 = np.array([23.24, 6.32, -9.32, -3.47, -19.49, 22.13])/100
data3 = np.array([13.79, 24.24, -35.12, 17.42, -32.18, 20.66])/100
data4 = np.array([15.27, 25.86, -22.72, 17.11, -19.05, 20.04])/100
data5 = np.array([51.66, 5.58, -11.28, 21.78, -25.31, 21.19])/100
index = np.arange(0, 1.5*6, 1.5)

fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)
bar_width = 0.2
ax.bar(index, data1, bar_width, color='#5f9ced', label='华安创新')
ax.bar(index+bar_width, data2, bar_width, color='#ed927b', label='博时价值成长')
ax.bar(index+bar_width*2, data3, bar_width, color='#77eda6', label='易方达策略成长')
ax.bar(index+bar_width*3, data4, bar_width, color='#bf82ed', label='华夏成长')
ax.bar(index+bar_width*4, data5, bar_width, color='#ed9f39', label='沪深300')
ax.set_ylim(-0.5, 0.75)
xindexReset = [0.4, 1.9, 3.4, 4.9, 6.4, 7.9]
ax.set_xticks(xindexReset)
xlabelReset = [2014, 2015, 2016, 2017, 2018, 'YTD']
ax.set_xticklabels(xlabelReset)
yindexReset = [-0.5, -0.25, 0, 0.25, 0.5, 0.75]
ax.set_yticks(yindexReset)
ylabelReset = ['-50%', '-25%', '0%', '25%', '50%', '75%']
ax.set_yticklabels(ylabelReset)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_facecolor('#4f4f4f')
fig.patch.set_facecolor('#4f4f4f')
axisColor = '#e2d397'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)

legend = plt.legend(frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('#4f4f4f')
frame.set_edgecolor('#4f4f4f')
plt.setp(legend.get_texts(), color=axisColor)
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
n_groups = 4
means_frank = (90, 55, 40, 65)
means_guido = (85, 62, 54, 20)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Frank')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='Guido')

plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')
plt.xticks(index + bar_width, ('A', 'B', 'C', 'D'))
plt.legend()

plt.tight_layout()
plt.show()

# %%
mainarea = Frame(sidebar2, bg='#CCC')
mainarea.pack(expand=True, fill='both', side='right')

induData = data[['date', 'close']].reset_index(drop=True)
induData = induData.set_index('date')
induData['MA10'] = induData["close"].rolling(10, min_periods = 1).mean()
induData['MA20'] = induData["close"].rolling(20, min_periods = 1).mean()
induData['MA60'] = induData["close"].rolling(60, min_periods = 1).mean()
induData = induData.iloc[400:]

fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111)

xticks = [i for i in range(0, len(induData.index)+1, 20)]
ax.set_xticks(xticks)
xlabels = [i.date() for i in induData.index[0::20]]
ax.set_xticklabels(xlabels)
ax.set_xlim(0)

ax.plot(induData['close'].values, label='收盘价', linewidth=2)
ax.plot(induData.MA10.values, label='10天均线', alpha=0.3)
ax.plot(induData.MA20.values, label='20天均线', alpha=0.3)
ax.plot(induData.MA60.values, label='60天均线', alpha=0.3)
ax.set_title('深300ETF日线')
ax.set_ylabel('ETF净值')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_facecolor('#4f4f4f')
fig.patch.set_facecolor('#4f4f4f')

# axisColor = '#b2d9ed'
axisColor = '#e2d397'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)

legend = plt.legend(frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('#4f4f4f')
frame.set_edgecolor('#4f4f4f')
plt.setp(legend.get_texts(), color=axisColor)

canvas = FigureCanvasTkAgg(fig, master=mainarea)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()

# %%
from tkinter import *
from tkinter import ttk

root = Tk()
root.geometry("500x200")

data = [ ["val1", "val2", "val3"],
         ["asd1", "asd2", "asd3"],
         ["bbb1", "bbb3", "bbb4"],
         ["ccc1", "ccc3", "ccc4"],
         ["ddd1", "ddd3", "ddd4"],
         ["eee1", "eee3", "eee4"] ]


frame = Frame(root)
frame.pack()

tree = tkk.Treeview(frame, columns = (1,2,3), height = 5, show = "headings",  bg='#4f4f4f')
tree.pack(side = 'left')

tree.heading(1, text="Column 1")
tree.heading(2, text="Column 2")
tree.heading(3, text="Column 3")

tree.column(1, width = 100)
tree.column(2, width = 100)
tree.column(3, width = 100)

scroll = ttk.Scrollbar(frame, orient="vertical", command=tree.yview)
scroll.pack(side = 'right', fill = 'y')

tree.configure(yscrollcommand=scroll.set)

for val in data:
    tree.insert('', 'end', values = (val[0], val[1], val[2]) )

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-ffe1d4166dd7> in <module>()
#      17 frame.pack()
#      18
# ---> 19 tree = Treeview(frame, columns = (1,2,3), height = 5, show = "headings",  bg='#4f4f4f')
#      20 tree.pack(side = 'left')
#      21
#
# NameError: name 'Treeview' is not defined

# %%
import tkinter
window = tkinter.Tk()

window.configure(background='#a1dbcd')
window.title("佳期技术交易监控系统")
width = 400
height = 200
screen_width = window.winfo_screenwidth()
screen_height = window.winfo_screenheight()
x = (screen_width/2) - (width/2)
y = (screen_height/2) - (height/2)
window.geometry("%dx%d+%d+%d" % (width, height, x, y))
window.resizable(0, 0)
# window.wm_iconbitmap('Icon.ico')

# photo = tkinter.PhotoImage(file='title.gif')
# w = tkinter.Label(window, image=photo)
# w.pack()

lblInst = tkinter.Label(window, text='佳期技术交易监控系统', fg='#383a39', bg='#a1dbcd', font=('Arial', 16))
lblInst.pack()

lblUsername = tkinter.Label(window, text='用户名:', fg='#383a39', bg='#a1dbcd')
entUsername = tkinter.Entry(window)
lblUsername.pack()
entUsername.pack()

lblPassword = tkinter.Label(window, text='密码:', fg='#383a39', bg='#a1dbcd')
entPassword = tkinter.Entry(window)
lblPassword.pack()
entPassword.pack()

btn = tkinter.Button(window, text='登陆', fg='#a1dbcd', bg='#383a39')
btn.pack()

window.mainloop()
