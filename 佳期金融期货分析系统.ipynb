# %%
import os
import glob
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from mpl_finance import candlestick2_ohlc
import matplotlib.dates as mdates
# %matplotlib inline

pd.set_option('max_rows', 300)
pd.set_option('max_columns', 150)
plt.rcParams['font.sans-serif']=['KaiTi']
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# #### Login

# %%
import tkinter as tk
from tkinter import ttk
import tkinter.font as tkFont



window = tk.Tk()
window.title("佳期金融期货分析系统")
# menu_widget.entryconfig(0, bg='#a1dbcd')

# the main window is divided into left and right sections,
# and the sidebar is divided into a top and bottom section.
pw = tk.PanedWindow(orient="vertical", background="#fbeeac")
sidebar = tk.PanedWindow(pw, orient="horizontal", background="#f9bc08")
main = tk.Frame(pw, width=400, height=400, borderwidth=2, background="#fbeeac")
sidebar_frame = tk.Frame(sidebar, width=400, height=120, background="#f9bc08", borderwidth=1)

# add the paned window to the window
pw.pack(fill="both", expand=True)

# add the sidebar and main area to the main paned window
pw.add(sidebar)
pw.add(main)

# add the top and bottom to the sidebar

startX = 40
startY = 0

sidebar.add(sidebar_frame)
title = tk.Label(sidebar_frame, text='用户登录', fg='#f7fafc', bg='#f9bc08')
title.place(x=startX-5, y=startY)
title.config(font=('System', 18))

label = tk.Label(main, text='账户', fg='#3d4240', bg="#fbeeac")
label.place(x=startX-2, y=startY)
entry = tk.Entry(main)
entry.place(x=startX, y=startY+20, width=240)
entry.config(fg='#d1d1d1')
entry.insert(0, '填写您的佳期技术账号')
label = tk.Label(main, text='密码', fg='#3d4240', bg="#fbeeac")
label.place(x=startX-2, y=startY+50)
entry = tk.Entry(main)
entry.place(x=startX, y=startY+70, width=240)
entry.config(fg='#d1d1d1')
entry.insert(0, '您的密码')
button = tk.Button(main, text='登录', fg='#3d4240', relief=tk.GROOVE)
button.place(x=startX+260, y = startY+15)
button = tk.Button(main, text='退出', fg='#3d4240', relief=tk.GROOVE)
button.place(x=startX+260, y = startY+65)
check = tk.Checkbutton(main, text="记住密码", fg='#3d4240', relief=tk.GROOVE)
check.place(x=startX+165, y = startY+100)

window.mainloop()

# %% [markdown]
# #### 主界面

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window= Tk()
window.title("佳期金融期货分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="行情报价")
menu_widget.add_command(label="期货数据")
menu_widget.add_command(label="期货资讯")
menu_widget.add_command(label="深度分析")
window.config(menu=menu_widget)

main = PanedWindow(orient="vertical", bg='#fbeeac')
sidebar1 = PanedWindow(main, orient="horizontal", bg='#f9bc08', relief=RAISED)
sidebar2 = PanedWindow(main, orient="horizontal", bg='#f9bc08')
sidebar3 = PanedWindow(main, orient="horizontal", bg='#f9bc08', relief=RAISED)
sidebar4 = PanedWindow(main, orient="horizontal", bg='#f9bc08')
sidebar5 = PanedWindow(main, orient="horizontal", bg='#f9bc08', relief=RAISED)
sidebar6 = PanedWindow(main, orient="horizontal", bg='#f9bc08')
sidebar7 = PanedWindow(main, orient="horizontal", bg='#f9bc08', relief=RAISED)
sidebar8 = PanedWindow(main, orient="horizontal", bg='#f9bc08')
main.add(sidebar1)
main.add(sidebar2)
main.add(sidebar3)
main.add(sidebar4)
main.add(sidebar5)
main.add(sidebar6)
main.add(sidebar7)
main.add(sidebar8)


main.pack(fill='both', expand=True)

mainCol = Frame(sidebar1, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
sidebar1.add(mainCol)
label = Label(mainCol, text='行情报价', fg='#f7fafc', bg='#f9bc08', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar2, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar2.add(mainCol)
label = Label(mainCol, text='期货综合屏', fg='#3d596b', bg='#fbeeac', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar2, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar2.add(mainCol)
label = Label(mainCol, text='中金所', fg='#3d596b', bg='#fbeeac', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar2, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar2.add(mainCol)
label = Label(mainCol, text='股指期货', fg='#3d596b', bg='#fbeeac', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar2, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar2.add(mainCol)
label = Label(mainCol, text='国债期货', fg='#3d596b', bg='#fbeeac', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')


mainCol = Frame(sidebar3, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
sidebar3.add(mainCol)
label = Label(mainCol, text='期货数据', fg='#f7fafc', bg='#f9bc08', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar4, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar4.add(mainCol)
label = Label(mainCol, text='期货数据浏览器', fg='#3d596b', bg='#fbeeac', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar4, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar4.add(mainCol)
label = Label(mainCol, text='行情序列', fg='#3d596b', bg='#fbeeac', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar4, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar4.add(mainCol)
label = Label(mainCol, text='股指期货统计', fg='#3d596b', bg='#fbeeac', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar4, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar4.add(mainCol)
label = Label(mainCol, text='期货公司资料', fg='#3d596b', bg='#fbeeac', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar5, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
sidebar5.add(mainCol)
label = Label(mainCol, text='期货资讯', fg='#f7fafc', bg='#f9bc08', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar6, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar6.add(mainCol)
label = Label(mainCol, text='股指期货资讯', fg='#3d596b', bg='#fbeeac', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar6, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar6.add(mainCol)
label = Label(mainCol, text='国债期货研究', fg='#3d596b', bg='#fbeeac', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar6, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar6.add(mainCol)
label = Label(mainCol, text='股指期货研究', fg='#3d596b', bg='#fbeeac', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')


mainCol = Frame(sidebar7, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
sidebar7.add(mainCol)
label = Label(mainCol, text='深度分析', fg='#f7fafc', bg='#f9bc08', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar8, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar8.add(mainCol)
label = Label(mainCol, text='期现基差', fg='#3d596b', bg='#fbeeac', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

window.mainloop()

# %% [markdown]
# #### 商品期货

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk
import pandas as pd

window= Tk()
window.title("佳期金融期货分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="行情报价")
menu_widget.add_command(label="期货数据")
menu_widget.add_command(label="期货资讯")
menu_widget.add_command(label="深度分析")
window.config(menu=menu_widget)

main = PanedWindow(orient="vertical", bg='#fbeeac')
sidebar1 = PanedWindow(main, orient="horizontal", bg='#fbeeac')
sidebar2 = PanedWindow(main, orient="horizontal", bg='#fbeeac')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)

mainCol = Frame(sidebar1, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
sidebar1.add(mainCol)
label = Label(mainCol, text='国债期货', fg='#585570', bg='#f9bc08')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar1, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
sidebar1.add(mainCol)
label = Label(mainCol, text='股指期货', fg='#f7fafc', bg='#f9bc08')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar2, bg='#fbeeac', borderwidth=2)
mainCol.pack(expand=True, fill='both')
sidebar2.add(mainCol)
title = Button(mainCol, text="首页", fg='#585570', bg='#f9bc08')
title.pack(fill='x')
button3 = Button(mainCol, text = "中金所", fg='#585570', bg='#f9bc08')
button3.pack(fill='x')
button3 = Button(mainCol, text = "股指期货", fg='#f7fafc', bg='#f9bc08')
button3.pack(fill='x')
button3 = Button(mainCol, text = "国债期货", fg='#585570', bg='#f9bc08')
button3.pack(fill='x')


mainCol1 = Frame(sidebar2, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='代码', fg='#585570', bg='#fbeeac', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
df1 = pd.read_csv("C:\\Users\\win\\Desktop\\CFFEX 股指期货-行情报价.csv", encoding="GBK")
for col in df1["代码"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar2, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='名称', fg='#585570', bg='#fbeeac', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["名称"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='最新', fg='#585570', bg='#fbeeac', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col, color in zip(df1['最新'].values,
                      ['red', 'green', 'red', 'green', 'red','red','green','red','red','green','green','red','red','red','red','red','red','red'
                       ,'red','red','red','red','red','red','red','red','red',]):
    label1 = Label(mainCol1, text=col, fg=color, bg='#fbeeac', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar2, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='涨幅%', fg='#585570', bg='#fbeeac', height=1, anchor='e')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col, color in zip(df1['涨幅%'].values,
                      ['red', 'green', 'red', 'green', 'red','red','green','red','red','green','green','red','red','red','red','red','red','red'
                       ,'red','red','red','red','red','red','red','red','red',]):
    label1 = Label(mainCol1, text=col, fg=color, bg='#fbeeac', anchor='e')
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='涨跌', fg='#585570', bg='#fbeeac', height=1, anchor='e')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col, color in zip(df1['涨跌'].values,
                      ['red', 'green', 'red', 'green', 'red','red','green','red','red','green','green','red','red','red','red','red','red','red'
                       ,'red','red','red','red','red','red','red','red','red',]):
    label1 = Label(mainCol1, text=col, fg=color, bg='#fbeeac', anchor='e')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar2, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='成交量', fg='#585570', bg='#fbeeac', height=1, anchor='e')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["成交量"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='e')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar2, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='成交额', fg='#585570', bg='#fbeeac', height=1, anchor='e')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["成交额"].values:
    label1 = Label(mainCol1, text=col, fg="#0d75f8", bg='#fbeeac', anchor='e')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar2, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='持仓', fg='#585570', bg='#fbeeac', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["成交额"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
window.mainloop()

# %% [markdown]
# #### 期货数据浏览器

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window= Tk()
window.title("佳期金融期货分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="行情报价")
menu_widget.add_command(label="期货数据")
menu_widget.add_command(label="期货资讯")
menu_widget.add_command(label="深度分析")
window.config(menu=menu_widget)

pw = PanedWindow(orient="vertical")
pw1 = PanedWindow(pw, orient="horizontal")
pw2 = PanedWindow(pw, orient="horizontal")
pw.pack(fill="both", expand=True)
pw.add(pw1)
pw.add(pw2)

main1 = PanedWindow(pw2, orient="vertical")
sidebar1 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
sidebar2 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
main1.pack(fill="both", expand=True)
main1.add(sidebar1)
main1.add(sidebar2)

main2 = PanedWindow(pw2, orient="vertical", bg='#fbeeac')
sidebar3 = PanedWindow(pw2, orient="horizontal",bg='#fbeeac')
main2.pack(fill="both", expand=True)
main2.add(sidebar3)

pw1.pack(fill="both", expand=True)
pw2.pack(fill="both", expand=True)
pw2.add(main1)
pw2.add(main2)


mainCol = Frame(pw1, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
label = Label(mainCol, text='待选指标', fg='#f7fafc', bg='#f9bc08')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(pw1, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
label = Label(mainCol, text='我的指标', fg='#585570', bg='#f9bc08')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(pw1, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
button1 = Button(mainCol, text = "提取数据", fg='#585570', bg='#fbeeac')
button1.pack(fill='x')
mainCol = Frame(pw1, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
button1 = Button(mainCol, text = "指标计算", fg='#585570', bg='#fbeeac')
button1.pack(fill='x')
mainCol = Frame(pw1, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
button1 = Button(mainCol, text = "显示图形", fg='#585570', bg='#fbeeac')
button1.pack(fill='x')   
mainCol = Frame(pw1, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
button1 = Button(mainCol, text = "数据统计", fg='#585570', bg='#fbeeac')
button1.pack(fill='x')  
mainCol = Frame(pw1, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
label = Label(mainCol, text='', fg='#f7fafc', bg='#fbeeac')
label.config(font=("System", 4))
label.pack(fill='x') 



mainCol1 = Frame(sidebar1, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="基本资料", fg='#585570', bg='#f9bc08')
title.pack(fill='x')
button1 = Button(mainCol1, text = "标准合约资料", fg='#585570', bg='#f9bc08')
button1.pack(fill='x')
button2 = Button(mainCol1, text = "行情指标", fg='#585570', bg='#f9bc08')
button2.pack(fill='x')
button3 = Button(mainCol1, text = "会员持仓", fg='#585570', bg='#f9bc08')
button3.pack(fill='x')
button3 = Button(mainCol1, text = "期货仓单", fg='#585570', bg='#f9bc08')
button3.pack(fill='x')
button3 = Button(mainCol1, text = "风险分析", fg='#f7fafc', bg='#f9bc08')
button3.pack(fill='x')
label1 = Label(mainCol1, text='平均收益率', fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='年化收益率', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='波动率', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='beta', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='alpha', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
button3 = Button(mainCol1, text = "技术形态", fg='#585570', bg='#f9bc08')
button3.pack(fill='x')


mainCol1 = Frame(sidebar2, bg='#f9bc08', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
title = Button(mainCol1, text="中金所", fg='#f7fafc', bg='#f9bc08')
title.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 沪深300', fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 上证50', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 中证500', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 2年期国债期货', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 5年期国债期货', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 10年期国债期货', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')

    
mainCol1 = Frame(sidebar3, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='证券代码', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['IF00C1.CFE', 'IF00C2.CFE', 'IF00C3.CFE', 'IF00C4.CFE', 'IF2002.CFE', 'IF2003.CFE', 'IF2006.CFE', 'IF2009.CFE', 'IFM.CFE']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar3, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='证券名称', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['IF当月连续', 'IF下月连续', 'IF下季连续', 'IF隔季连续', 'IF2002', 'IF2003',
            'IF2006', 'IF2009', '沪深300股指期货主力连续']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar3, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='平均收益率(%)', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['0.3269', '0.2751', '0.2850', '0.2622', '-0.1899', '0.1847', '0.1811', '-1.4685', '0.2853']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar3, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='年化收益率(%)', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['20.4316', '20.4522', '19.9775', '19.3702', '16.2353','17.4158', '23.0938', '-26.5310', '20.5815']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar3, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='波动率', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['0.0248', '0.0257', '0.0261', '0.0263', '0.0241','0.0221', '0.0200', '0.0300', '0.0249']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar3, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='Beta', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['1.0000', '1.0350', '1.0528', '1.0553', '1.1347', '1.1298', '1.1462', '1.2096', '1.0062']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar3, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='Alpha(%)', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['0.2210', '0.1655', '0.1736', '0.1505', '0.2090','0.1743', '0.2145', '0.0948', '0.1789']:
    label1 = Label(mainCol1, text=col, fg="#585570", bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

    
window.mainloop()

# %% [markdown]
# #### 显示图形

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk
import matplotlib.pyplot as plt
import numpy as np

window= Tk()
window.title("佳期金融期货分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="行情报价")
menu_widget.add_command(label="期货数据")
menu_widget.add_command(label="期货资讯")
menu_widget.add_command(label="深度分析")
window.config(menu=menu_widget)

pw = PanedWindow(orient="vertical")
pw1 = PanedWindow(pw, orient="horizontal")
pw2 = PanedWindow(pw, orient="horizontal")
pw.pack(fill="both", expand=True)
pw.add(pw1)
pw.add(pw2)

main1 = PanedWindow(pw2, orient="vertical")
sidebar1 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
sidebar2 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
main1.pack(fill="both", expand=True)
main1.add(sidebar1)
main1.add(sidebar2)

main2 = PanedWindow(pw2, orient="vertical", bg='#fbeeac')
sidebar3 = PanedWindow(pw2, orient="horizontal",bg='#fbeeac')
sidebar4 = PanedWindow(pw2, orient="horizontal",bg='#fbeeac')
main2.pack(fill="both", expand=True)
main2.add(sidebar3)
main2.add(sidebar4)

pw1.pack(fill="both", expand=True)
pw2.pack(fill="both", expand=True)
pw2.add(main1)
pw2.add(main2)


mainCol = Frame(pw1, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
label = Label(mainCol, text='待选指标', fg='#f7fafc', bg='#f9bc08')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(pw1, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
label = Label(mainCol, text='我的指标', fg='#585570', bg='#f9bc08')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(pw1, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
button1 = Button(mainCol, text = "提取数据", fg='#585570', bg='#fbeeac')
button1.pack(fill='x')
mainCol = Frame(pw1, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
button1 = Button(mainCol, text = "指标计算", fg='#585570', bg='#fbeeac')
button1.pack(fill='x')
mainCol = Frame(pw1, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
button1 = Button(mainCol, text = "显示图形", fg='#585570', bg='#fbeeac')
button1.pack(fill='x')   
mainCol = Frame(pw1, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
button1 = Button(mainCol, text = "数据统计", fg='#585570', bg='#fbeeac')
button1.pack(fill='x')  
mainCol = Frame(pw1, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
label = Label(mainCol, text='', fg='#f7fafc', bg='#fbeeac')
label.config(font=("System", 4))
label.pack(fill='x') 



mainCol1 = Frame(sidebar1, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="基本资料", fg='#585570', bg='#f9bc08')
title.pack(fill='x')
button1 = Button(mainCol1, text = "标准合约资料", fg='#585570', bg='#f9bc08')
button1.pack(fill='x')
button2 = Button(mainCol1, text = "行情指标", fg='#f7fafc', bg='#f9bc08')
button2.pack(fill='x')
label1 = Label(mainCol1, text='收盘价', fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='开盘价', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='成交均价', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='涨跌幅', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='成交额', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
button3 = Button(mainCol1, text = "技术形态", fg='#585570', bg='#f9bc08')
button3.pack(fill='x')
button3 = Button(mainCol1, text = "会员持仓", fg='#585570', bg='#f9bc08')
button3.pack(fill='x')
button3 = Button(mainCol1, text = "期货仓单", fg='#585570', bg='#f9bc08')
button3.pack(fill='x')
button3 = Button(mainCol1, text = "风险分析", fg='#585570', bg='#f9bc08')
button3.pack(fill='x')



mainCol1 = Frame(sidebar2, bg='#f9bc08', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
title = Button(mainCol1, text="中金所", fg='#f7fafc', bg='#f9bc08')
title.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 沪深300', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 上证50', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 中证500', fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 2年期国债期货', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 5年期国债期货', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 10年期国债期货', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')

df1 = pd.read_csv("C:\\Users\\win\\Desktop\\CFFEX 中证500.csv", encoding="GBK")
    
mainCol1 = Frame(sidebar3, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='证券代码', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1['证券代码'].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar3, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='证券名称', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1['证券名称'].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar3, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='收盘价（最新）', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1['收盘价\r\n[交易日期]最新(2020-02-20)\r\n[单位]元'].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar3, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='收盘价（一月前）', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1['收盘价\r\n[交易日期]1月前\r\n[单位]元'].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol = Frame(sidebar4, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar4.add(mainCol)

fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(111)
data1 = np.array([5704.8, 5667.8, 5567, 5477.6, 5704.8, 5667.8, 5567, 5477.6, 5667.8])
data2 = np.array([5516.6, 5495, 5424.4, 5358.6, 5516.6, 5495, 5424.4, 5358.6, 5516.6])
index1 = np.arange(0, 9, 1)
bar_width = 0.4
ax1.bar(index1, data1, bar_width, color='#5f9ced', label='收盘价（最新）')
ax1.bar(index1+bar_width, data2, bar_width, color='#ed927b', label='收盘价（一月前）')


# ax1.set_title('持仓图')
xindexReset = np.arange(0, 9, 1)
ax1.set_xticks(xindexReset)
xlabelReset = df1['证券代码'].values
ax1.set_xticklabels(xlabelReset)

ax1.set_facecolor('#fbeeac')
fig.patch.set_facecolor('#fbeeac')
ax1isColor = '#585570'
axisColor = '#585570'
ax1.spines['bottom'].set_color(axisColor)
ax1.spines['left'].set_color(axisColor)
ax1.tick_params(axis='x', colors=axisColor)
ax1.tick_params(axis='y', colors=axisColor)
ax1.yaxis.label.set_color(axisColor)
ax1.xaxis.label.set_color(axisColor)
ax1.title.set_color(axisColor)

legend = plt.legend(frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('#fbeeac')
frame.set_edgecolor('#4f4f4f')
plt.setp(legend.get_texts(), color=axisColor)

canvas = FigureCanvasTkAgg(fig, master=mainCol)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()


window.mainloop()

# %% [markdown]
# #### 行情序列

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window = Tk()
window.title("佳期金融期货分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="行情报价")
menu_widget.add_command(label="期货数据")
menu_widget.add_command(label="期货资讯")
menu_widget.add_command(label="深度分析")
window.config(menu=menu_widget)

pw = PanedWindow(orient="vertical")
pw1 = PanedWindow(pw, orient="horizontal")
pw2 = PanedWindow(pw, orient="horizontal")
pw.pack(fill="both", expand=True)
pw.add(pw1)
pw.add(pw2)

main1 = PanedWindow(pw2, orient="vertical")
sidebar1 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
sidebar2 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
sidebar3 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
sidebar8 = PanedWindow(sidebar3, orient="vertical", bg='#fbeeac')
sidebar9 = PanedWindow(sidebar3, orient="vertical", bg='#fbeeac')
sidebar10 = PanedWindow(sidebar3, orient="vertical", bg='#fbeeac')
main1.pack(fill="both", expand=True)
main1.add(sidebar1)
main1.add(sidebar2)
main1.add(sidebar3)
sidebar3.add(sidebar8)
sidebar3.add(sidebar9)
sidebar3.add(sidebar10)

main2 = PanedWindow(pw2, orient="vertical", bg='#fbeeac')
sidebar4 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
sidebar5 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
sidebar6 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
sidebar11 = PanedWindow(sidebar6, orient="vertical", bg='#fbeeac')
sidebar12 = PanedWindow(sidebar6, orient="vertical", bg='#fbeeac')
sidebar13 = PanedWindow(sidebar6, orient="vertical", bg='#fbeeac')
sidebar14 = PanedWindow(sidebar6, orient="vertical", bg='#fbeeac')
main2.pack(fill="both", expand=True)
main2.add(sidebar4)
main2.add(sidebar5)
main2.add(sidebar6)
sidebar6.add(sidebar11)
sidebar6.add(sidebar12)
sidebar6.add(sidebar13)
sidebar6.add(sidebar14)



main3 = PanedWindow(pw2, orient="vertical", bg='#fbeeac')
sidebar7 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
main3.pack(fill="both", expand=True)
main3.add(sidebar7)

main4 = PanedWindow(pw2, orient="vertical", bg='#fbeeac')
sidebar15 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
sidebar16 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
main4.pack(fill="both", expand=True)
main4.add(sidebar15)
main4.add(sidebar16)

pw1.pack(fill="both", expand=True)
pw2.pack(fill="both", expand=True)
pw2.add(main1)
pw2.add(main2)
pw2.add(main3)
pw2.add(main4)

mainCol = Frame(pw1, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
label = Label(mainCol, text='待选产品分类', fg='#585570', bg='#f9bc08')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(pw1, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
label = Label(mainCol, text='待选产品列表', fg='#585570', bg='#f9bc08')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(pw1, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
label = Label(mainCol, text='', fg='#585570', bg='#f9bc08')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(pw1, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
pw1.add(mainCol)
label = Label(mainCol, text='已选产品列表', fg='#585570', bg='#f9bc08')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol1 = Frame(sidebar1, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="中金所", fg='#f7fafc', bg='#f9bc08')
title.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 沪深300', fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 上证50', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 中证500', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 2年期国债期货', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 5年期国债期货', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='CFFEX 10年期国债期货', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')

mainCol = Frame(sidebar2, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
sidebar2.add(mainCol)
label = Label(mainCol, text='选择指标', fg='#585570', bg='#f9bc08')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol1 = Frame(sidebar8, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
c1 = tk.Checkbutton(sidebar8, text="全选", bg='#fbeeac')
c1.pack(fill='x')

mainCol1 = Frame(sidebar9, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
c1 = tk.Checkbutton(sidebar9, text="开盘价", bg='#fbeeac')
c1.pack(fill='x')
c1 = tk.Checkbutton(sidebar9, text="最高价", bg='#fbeeac')
c1.pack(fill='x')
c1 = tk.Checkbutton(sidebar9, text="结算价", bg='#fbeeac')
c1.pack(fill='x')
c1 = tk.Checkbutton(sidebar9, text="成交均价", bg='#fbeeac')
c1.pack(fill='x')
c1 = tk.Checkbutton(sidebar9, text="涨跌", bg='#fbeeac')
c1.pack(fill='x')
c1 = tk.Checkbutton(sidebar9, text="涨跌幅", bg='#fbeeac')
c1.pack(fill='x')
c1 = tk.Checkbutton(sidebar9, text="成交量", bg='#fbeeac')
c1.pack(fill='x')

mainCol1 = Frame(sidebar10, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
c1 = tk.Checkbutton(sidebar10, text="收盘价", bg='#fbeeac')
c1.pack(fill='x')
c1 = tk.Checkbutton(sidebar10, text="最低价", bg='#fbeeac')
c1.pack(fill='x')
c1 = tk.Checkbutton(sidebar10, text="振幅", bg='#fbeeac')
c1.pack(fill='x')
c1 = tk.Checkbutton(sidebar10, text="成交额", bg='#fbeeac')
c1.pack(fill='x')
c1 = tk.Checkbutton(sidebar10, text="持仓量", bg='#fbeeac')
c1.pack(fill='x')
c1 = tk.Checkbutton(sidebar10, text="价差", bg='#fbeeac')
c1.pack(fill='x')
c1 = tk.Checkbutton(sidebar10, text="持仓量变化", bg='#fbeeac')
c1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='证券代码', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['IF00C1.CFE', 'IF00C2.CFE', 'IF00C3.CFE', 'IF00C4.CFE', 'IF2002.CFE', 'IF2003.CFE', 'IF2006.CFE', 'IF2009.CFE', 'IFM.CFE']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='证券名称', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['IF当月连续', 'IF下月连续', 'IF下季连续', 'IF隔季连续', 'IF2002', 'IF2003',
            'IF2006', 'IF2009', '沪深300股指期货主力连续']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

    
mainCol = Frame(sidebar5, borderwidth=2, bg='#f9bc08')
mainCol.pack(expand=True, fill='both')
sidebar5.add(mainCol)
label = Label(mainCol, text='选择时间', fg='#585570', bg='#f9bc08')
label.config(font=("System", 4))
label.pack(fill='x') 

v = tk.IntVar()
v.set(1)
mainCol = Frame(sidebar11, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar11.add(mainCol)
r1 = tk.Radiobutton(mainCol, text='近一周', bg='#fbeeac',value=2)
r1.pack(fill='x')    
r1 = tk.Radiobutton(mainCol, text='近三年', bg='#fbeeac',value=1)
r1.pack(fill='x')
mainCol = Frame(sidebar12, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar12.add(mainCol)
r1 = tk.Radiobutton(mainCol, text='近一月', bg='#fbeeac',value=1)
r1.pack(fill='x')          
r1 = tk.Radiobutton(mainCol, text='近五年', bg='#fbeeac',value=1)
r1.pack(fill='x')   
mainCol = Frame(sidebar13, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar13.add(mainCol)
r1 = tk.Radiobutton(mainCol, text='近三月', bg='#fbeeac',value=1)
r1.pack(fill='x')          
r1 = tk.Radiobutton(mainCol, text='近十年', bg='#fbeeac',value=1)
r1.pack(fill='x') 
mainCol = Frame(sidebar14, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar14.add(mainCol)
r1 = tk.Radiobutton(mainCol, text='近一年', bg='#fbeeac',value=1)
r1.pack(fill='x')    
r1 = tk.Radiobutton(mainCol, text='上市以来', bg='#fbeeac',value=1)
r1.pack(fill='x')

print(v.get())


mainCol1 = Frame(sidebar7, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
title = Button(mainCol1, text=">>", fg='#585570', bg='#fbeeac')
title.pack(fill='x')
title = Button(mainCol1, text="<", fg='#585570', bg='#fbeeac')
title.pack(fill='x')
label1 = Label(mainCol1, text='', fg='#f7fafc', bg='#fbeeac')
label1.pack(fill='x')
label1 = Label(mainCol1, text='', fg='#f7fafc', bg='#fbeeac')
label1.pack(fill='x')
title = Button(mainCol1, text="<<", fg='#585570', bg='#fbeeac')
title.pack(fill='x')
title = Button(mainCol1, text="<", fg='#585570', bg='#fbeeac')
title.pack(fill='x')


mainCol1 = Frame(sidebar16, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar16.add(mainCol1)
title = Button(mainCol1, text="导出数据", fg='#585570', bg='#fbeeac')
title.pack(fill='x')

mainCol1 = Frame(sidebar16, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar16.add(mainCol1)
title = Button(mainCol1, text="停止导出", fg='#585570', bg='#fbeeac')
title.pack(fill='x')




window.mainloop()
# Out:
# 1

# %% [markdown]
# #### 股指期货统计

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window= Tk()
window.title("佳期金融期货分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="行情报价")
menu_widget.add_command(label="期货数据")
menu_widget.add_command(label="期货资讯")
menu_widget.add_command(label="深度分析")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#fbeeac')
sidebar1 = PanedWindow(main, orient="vertical", bg='#fbeeac')
sidebar2 = PanedWindow(main, orient="vertical", bg='#fbeeac')
sidebar3 = PanedWindow(sidebar2, orient="horizontal", bg='#fbeeac')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#fbeeac')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#fbeeac')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)
sidebar2.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)

mainCol1 = Frame(sidebar1, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="基本资料", fg='#585570', bg='#f9bc08')
title.pack(fill='x')
title = Button(mainCol1, text="合约市场表现", fg='#585570', bg='#f9bc08')
title.pack(fill='x')
title = Button(mainCol1, text="持仓分析", fg='#f7fafc', bg='#f9bc08')
title.pack(fill='x')
label1 = Label(mainCol1, text='持仓排名', fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='区间持仓排名', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='区间持仓合计', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='持仓查询', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='净持仓', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
title = Button(mainCol1, text="沪深300指数成分股", fg='#585570', bg='#f9bc08')
title.pack(fill='x')
title = Button(mainCol1, text="沪深300行业", fg='#585570', bg='#f9bc08')
title.pack(fill='x')


mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='区间起始时间', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '2020/2/10')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='区间截止时间', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '2020/2/20')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='期货品种', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '沪深300股指期货(IF)')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='期货合约', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, 'IF2002')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="提取数据", fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#fbeeac')
label1.pack(fill='x')



mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='区间成交量', fg='#585570', bg='#fbeeac',height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='区间多头持仓', fg='#585570', bg='#fbeeac',height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='区间空头持仓', fg='#585570', bg='#fbeeac',height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')


mainCol1 = Frame(sidebar5, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='会员简称', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['中信期货','国泰君安','海通期货','兴证期货','上海东证','银河期货','方正中期','华泰期货','五矿经易','申银万国','广发期货','东兴期货',
'国信期货','西部期货','光大期货','国投安信','德盛期货','永安期货','招商期货','中金期货','中信建投','中融汇信','华西期货','国富期货','海证期货',
'南华期货']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar5, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='成交量', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in [101048.0000,69839.0000,61596.0000,43553.0000,36461.0000,34794.0000,31970.0000,31864.0000,30079.0000,29424.0000,27848.0000,27596.0000,
24199.0000,22707.0000,22576.0000,21767.0000,21289.0000,15003.0000,14276.0000,6863.0000,6674.0000,6362.0000,5785.0000,2786.0000,2262.0000,
1145.0000]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='会员简称', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['中信期货','中金期货','国泰君安','海通期货','华泰期货','上海东证','永安期货','兴证期货','申银万国','银河期货','方正中期','五矿经易',
'国投安信','广发期货','国信期货','东兴期货','光大期货','中信建投','南华期货','西部期货','德盛期货','国富期货','华西期货','乾坤期货','瑞银期货',
'招商期货']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar5, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='多单量', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in [47936.0000,46962.0000,25102.0000,20920.0000,16365.0000,13793.0000,12424.0000,12328.0000,11539.0000,10616.0000,9726.0000,9584.0000,8278.0000,
8067.0000,7481.0000,7060.0000,5370.0000,5325.0000,5262.0000,5220.0000,2470.0000,1186.0000,1077.0000,932.0000,871.0000,664.0000]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='会员简称', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['中信期货','海通期货','申银万国','国泰君安','上海东证','华泰期货','兴证期货','广发期货','银河期货','招商期货','方正中期','中金期货',
'五矿经易','中信建投','国信期货','光大期货','平安期货','东兴期货','东吴期货','西部期货','永安期货','国投安信','南华期货','华西期货','德盛期货',
'上海中期']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar5, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='空单量', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in [38197.0000,27651.0000,26023.0000,25301.0000,20365.0000,15600.0000,15324.0000,11948.0000,10571.0000,10475.0000,9416.0000,
9131.0000,8653.0000,7812.0000,7518.0000,7379.0000,6948.0000,6792.0000,5249.0000,4692.0000,3462.0000,1425.0000,1117.0000,1100.0000,
557.0000,244.0000]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
    


window.mainloop()

# %% [markdown]
# #### 商品期货统计

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window= Tk()
window.title("佳期金融期货分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="行情报价")
menu_widget.add_command(label="期货数据")
menu_widget.add_command(label="期货资讯")
menu_widget.add_command(label="深度分析")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#fbeeac')
sidebar1 = PanedWindow(main, orient="vertical", bg='#fbeeac')
sidebar2 = PanedWindow(main, orient="vertical", bg='#fbeeac')
sidebar3 = PanedWindow(sidebar2, orient="horizontal", bg='#fbeeac')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#fbeeac')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#fbeeac')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)
sidebar2.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)


mainCol1 = Frame(sidebar1, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="市场表现", fg='#585570', bg='#f9bc08')
title.pack(fill='x')
title = Button(mainCol1, text="主力合约", fg='#585570', bg='#f9bc08')
title.pack(fill='x')
title = Button(mainCol1, text="库存状态", fg='#585570', bg='#f9bc08')
title.pack(fill='x')
title = Button(mainCol1, text="成交统计", fg='#585570', bg='#f9bc08')
title.pack(fill='x')
title = Button(mainCol1, text="持仓分析", fg='#f7fafc', bg='#f9bc08')
title.pack(fill='x')
label1 = Label(mainCol1, text='持仓排名', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='区间持仓合计', fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
title = Button(mainCol1, text="CFTC持仓", fg='#585570', bg='#f9bc08')
title.pack(fill='x')


mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='区间起始时间', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '2020/1/20')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='区间截止时间', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '2020/2/20')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='期货品种', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, 'PTA(TA)')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='期货合约', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, 'TA2003')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="提取数据", fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="显示图形", fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#fbeeac')
label1.pack(fill='x')



mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='日期', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['2020-02-19','2020-02-18','2020-02-17','2020-02-14','2020-02-13','2020-02-12','2020-02-11','2020-02-10','2020-02-07','2020-02-06',
'2020-02-05','2020-02-04','2020-02-03','2020-01-23','2020-01-22','2020-01-21','2020-01-20']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='区间成交合计', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in [8944.0000,9369.0000,21044.0000,21750.0000,14180.0000,25975.0000,35020.0000,14398.0000,9621.0000,25777.0000,76399.0000,58673.0000,
3256.0000,61814.0000,77066.0000,94050.0000,100287.0000]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='区间多头持仓合计', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in [66272.0000,66485.0000,64109.0000,65046.0000,66950.0000,68825.0000,68809.0000,65277.0000,63553.0000,62923.0000,63625.0000,69737.0000,
70074.0000,70250.0000,70428.0000,74195.0000,77158.0000]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='区间空头持仓合计', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in [66953.0000,67447.0000,66089.0000,67720.0000,72375.0000,75538.0000,76702.0000,72002.0000,69164.0000,68879.0000,69258.0000,75024.0000,
76829.0000,76321.0000,78018.0000,79962.0000,83236.0000]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

    
mainCol = Frame(sidebar5, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar5.add(mainCol)

fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(111)
data1 = np.array([8944.0000,9369.0000,21044.0000,21750.0000,14180.0000,25975.0000,35020.0000,14398.0000,9621.0000,25777.0000,76399.0000,58673.0000,
3256.0000,61814.0000,77066.0000,94050.0000,100287.0000])
data2 = np.array([66272.0000,66485.0000,64109.0000,65046.0000,66950.0000,68825.0000,68809.0000,65277.0000,63553.0000,62923.0000,63625.0000,69737.0000,
70074.0000,70250.0000,70428.0000,74195.0000,77158.0000])
data3 = np.array([66953.0000,67447.0000,66089.0000,67720.0000,72375.0000,75538.0000,76702.0000,72002.0000,69164.0000,68879.0000,69258.0000,75024.0000,
76829.0000,76321.0000,78018.0000,79962.0000,83236.0000])

ax1.plot(data1[::-1], color='#5f9ced', label='区间成交合计')
ax1.plot(data2[::-1], color='#ed927b', label='区间多头持仓合计')
ax1.plot(data3[::-1], color='#77eda6', label='区间空头持仓合计')
ax1.set_title('持仓图')
xindexReset = np.arange(0, 17, 1)
ax1.set_xticks(xindexReset)
xlabelReset = ['2020-02-19','2020-02-18','2020-02-17','2020-02-14','2020-02-13','2020-02-12','2020-02-11','2020-02-10','2020-02-07','2020-02-06',
'2020-02-05','2020-02-04','2020-02-03','2020-01-23','2020-01-22','2020-01-21','2020-01-20']
xlabelReset = xlabelReset[::-1]
ax1.set_xticklabels(xlabelReset)

ax1.set_facecolor('#fbeeac')
fig.patch.set_facecolor('#fbeeac')
ax1isColor = '#fbeeac'
ax1.spines['bottom'].set_color(axisColor)
ax1.spines['left'].set_color(axisColor)
ax1.tick_params(axis='x', colors=axisColor)
ax1.tick_params(axis='y', colors=axisColor)
ax1.yaxis.label.set_color(axisColor)
ax1.xaxis.label.set_color(axisColor)
ax1.title.set_color(axisColor)    

legend = plt.legend(frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('#fbeeac')
frame.set_edgecolor('#fbeeac')
plt.setp(legend.get_texts(), color=axisColor)

canvas = FigureCanvasTkAgg(fig, master=mainCol)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()  

window.mainloop()

# %% [markdown]
# #### 期货公司资料

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window= Tk()
window.title("佳期金融期货分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="行情报价")
menu_widget.add_command(label="期货数据")
menu_widget.add_command(label="期货资讯")
menu_widget.add_command(label="深度分析")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#fbeeac')
sidebar1 = PanedWindow(main, orient="vertical", bg='#fbeeac')
sidebar2 = PanedWindow(main, orient="vertical", bg='#fbeeac')
sidebar3 = PanedWindow(sidebar2, orient="horizontal", bg='#fbeeac')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#fbeeac')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)
sidebar2.add(sidebar3)
sidebar2.add(sidebar4)

mainCol1 = Frame(sidebar1, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="期货公司基本资料", fg='#f7fafc', bg='#f9bc08')
title.pack(fill='x')
label1 = Label(mainCol1, text='基本资料', fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
title = Button(mainCol1, text="期货公司财务数据", fg='#585570', bg='#f9bc08')
title.pack(fill='x')

mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="提取数据", fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="导出到Excel", fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#fbeeac')
label1.pack(fill='x')


mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='公司名称', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['安粮期货股份有限公司','混沌天成期货股份有限公司','中金期货有限公司','上海东方期货经纪有限责任公司','第一创业期货有限责任公司',
'天风期货股份有限公司','鲁证期货股份有限公司','华龙期货股份有限公司','永商期货有限公司','锦泰期货有限公司','瑞达期货股份有限公司',
'永安期货股份有限公司','河北恒银期货经纪有限公司','金鹏期货经纪有限公司','华安期货有限责任公司','中电投先融期货股份有限公司',
'道通期货经纪有限公司','格林大华期货有限公司','中天期货有限责任公司','东方汇金期货有限公司','深圳金汇期货经纪有限公司','华融期货有限责任公司',
'西南期货有限公司','乾坤期货有限公司','徽商期货有限责任公司','北京首创期货有限责任公司','华鑫期货有限公司','九州期货有限公司',
'创元期货股份有限公司','浙商期货有限公司']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='是否上市', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['否','是','否','否','否','是','是','是','否','否','是','是','否','否','否','是','否','否','否','否','否','否','否','否','否',
'否','否','否','是','否']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='省份', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['安徽省','广东省','青海省','上海市','北京市','上海市','山东省','甘肃省','黑龙江省','江苏省','福建省','浙江省','河北省','北京市',
'安徽省','重庆市','江苏省','北京市','北京市','吉林省','广东省','海南省','重庆市','广东省','安徽省','北京市','上海市','北京市','江苏省','浙江省']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='注册资本（亿元）', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in [5.0000,8.1000,3.5000,0.3000,1.7000,3.1440,10.0190,5.0000,0.5000,5.0715,4.4500,13.1000,0.7600,1.0090,2.7000,10.1000,0.5000,8.0000,
1.8600,1.3000,3.6000,1.2000,5.0000,1.5000,0.5200,2.0000,2.0000,5.1800,5.0000,5.0000]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='主页', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['www.alqh.com','www.chaosqh.com','www.cfqh.com','www.shdfqh.com','www.fcfco.cn','www.thanf.com','www.luzhengqh.com','www.hlqhgs.com',
'www.ysfutures.com','www.jtqh.cn','www.rdqh.com','www.yafco.com','www.hyfutures.com','www.jifco.com.cn','www.haqh.com','www.xrqh.com',
'www.doto-futures.com','www.gldhqh.com.cn','www.ztyjqh.com','www.jlfe.com','www.szjhqh.com','www.hrfutu.com.cn','www.swfutures.com',
'www.qkfutures.com','www.hsqh.net','www.scqh.com.cn','www.shhxqh.com','www.hhqh.net','www.cyqh.com.cn','www.cnzsqh.com']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='成立日期', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in ['1996-07-09','1995-01-03','2004-07-22','1993-04-14','1993-03-31','1996-03-29','2012-12-10','1992-11-12','1996-01-26','1995-09-28',
'1993-03-24','1992-09-07','1995-09-21','1991-05-15','1995-05-15','1995-08-23','1995-09-10','1993-02-28','1997-01-16','2004-12-12','1993-03-19',
'1993-09-22','1995-06-26','1993-11-05','1996-02-14','1996-01-12','1992-12-23','1993-04-18','1995-02-25','1995-09-07']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

window.mainloop()

# %% [markdown]
# #### 研报

# %%
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window= tk.Tk()
window.title("佳期金融期货分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="行情报价")
menu_widget.add_command(label="期货数据")
menu_widget.add_command(label="期货资讯")
menu_widget.add_command(label="深度分析")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#fbeeac')
sidebar1 = PanedWindow(main, orient="vertical", bg='#fbeeac')
sidebar2 = PanedWindow(main, orient="vertical", bg='#fbeeac')
sidebar3 = PanedWindow(sidebar2, orient="horizontal", bg='#fbeeac')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#fbeeac')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#fbeeac')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)
sidebar2.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)

mainCol1 = Frame(sidebar1, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="股指期货研究", fg='#f7fafc', bg='#f9bc08')
title.pack(fill='x')
title = Button(mainCol1, text="国债期货研究", fg='#585570', bg='#f9bc08')
title.pack(fill='x')

mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='标题检索', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '请输入关键字')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='证券', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '请输入证券')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='机构', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '请输入机构')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='作者', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '请输入作者')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="搜索", fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="重置", fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#fbeeac')
label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='研报类型', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '请选择研报类型')
e1.pack()
mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='行业', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '请输入行业')
e1.pack()
mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='页数', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '页数不限')
e1.pack()
mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='日期', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '输入起始日期')
e1.pack()
mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='至', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '输入结束日期')
e1.pack()

df1 = pd.read_csv("C:\\Users\\win\\Desktop\\股指期货研究_研究报告.csv", encoding="GBK")

mainCol1 = Frame(sidebar5, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='日期', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["日期"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
        
mainCol1 = Frame(sidebar5, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='标题', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["标题"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='机构', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["机构"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='作者', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["作者"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='页数', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["页数"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar5, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='大小', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["大小"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
    
window.mainloop()

# %% [markdown]
# #### 股指期货资讯

# %%
window= tk.Tk()
window.title("佳期金融期货分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="行情报价")
menu_widget.add_command(label="期货数据")
menu_widget.add_command(label="期货资讯")
menu_widget.add_command(label="深度分析")
window.config(menu=menu_widget)

pw = PanedWindow(orient="vertical")
pw2 = PanedWindow(pw, orient="horizontal")
pw.pack(fill="both", expand=True)
pw.add(pw2)

main1 = PanedWindow(pw2, orient="vertical")
sidebar1 = PanedWindow(pw2, orient="horizontal")
sidebar2 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
main1.pack(fill="both", expand=True)
main1.add(sidebar1)
main1.add(sidebar2)

main2 = PanedWindow(pw2, orient="vertical", bg='#fbeeac')
sidebar3 = PanedWindow(pw2, orient="vertical")
sidebar4 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
sidebar5 = PanedWindow(pw2, orient="horizontal")
sidebar6 = PanedWindow(pw2, orient="horizontal", bg='#fbeeac')
main2.pack(fill="both", expand=True)
main2.add(sidebar3)
main2.add(sidebar4)
main2.add(sidebar5)
main2.add(sidebar6)

pw2.pack(fill="both", expand=True)
pw2.add(main1)
pw2.add(main2)


mainCol1 = Frame(sidebar1, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
entry1 = Entry(mainCol1, show='')
entry1Start = 100
entry1.place(x=entry1Start, y=5, width=250)
entry1.config(fg='#d1d1d1')
entry1.insert(0, '请输入关键字')
button1 = Button(mainCol1, text='搜索', fg='#585570', bg='#fbeeac')
button1.place(x=entry1Start + 260, y=2)

mainCol1 = Frame(sidebar2, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
for col in ['08:54', '08:36', '08:02', '07:28', '06:35', '03:58', '03:58',
            '02:49', '02:05', '2020-02-20', '2020-02-20', '2020-02-20', '2020-02-20', '2020-02-20',
            '2020-02-20', '2020-02-20']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac')
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
for col in ['政策密集出台 股指继续看涨', '万亿成交再助大盘攻克3000点 103只股票获主力资金大手笔增持',
            '广州万隆：牛市风向标券商板块迎来热炒 市场变盘窗口将至？', '3000点轻松拿下！这是第46次 还是最后一次？',
            '罕见！沪指“带量”站上3000点', '“边打边看” 机构顺势优化持仓',
            '外资机构长线看好中国投资前景', '寻找3000点后的价值洼地 大金融板块重回机构视线',
            '牛市“带头大哥”发力 沪指重上3000点', '2月20日股指期货成交持仓龙虎榜',
            '“二八分化”显著 期指把握结构性行情', '百位险资大佬调查！最看好A股、愿意继续加仓、呼吁提升投资上限',
            '进入变盘节点 A股全线收跌', '四路增量资金携手进场 两市成交额突破万亿元',
            'A股放量震荡 机构关注结构性机会', '资金稳步入市 投出A股“信任票”']:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar3, bg='#f9bc08', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='头条资讯', fg='#585570', bg='#f9bc08', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
for col in [1,2,3,4,5,6]:
    label1 = Label(mainCol1, text=str(col), fg='#585570', bg='#fbeeac')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar4, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
for col in ['创业板指大涨近2%站上2200点 两市成交额连续三天突破万亿', '甘肃新冠肺炎疫情防控应急响应级别由一级调整为三级',
            '美元接近一个可能引发购买狂潮的关键水平', '中汽协：确实递交“推迟实施国六排放标准”建议 是否采纳暂未可知',
            '高盛：美股 回调修正可能性极高', '科技行业有序复工：疫情短期扰动难阻5G进程 激光产业链恢复正在进行']:
    label1 = Label(mainCol1, text=str(col), fg='#585570', bg='#fbeeac', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar5, bg='#f9bc08', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='财经要闻', fg='#585570', bg='#f9bc08', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')

mainCol1 = Frame(sidebar6, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
for col in ['司法部监狱管理局：目前没有发生监狱在押罪犯感染新冠肺炎死亡病例', '温彬等：信贷社融超预期 融资结构有改善',
            '两融余额四连升 387.60亿增量杠杆资金进场', '成都一治愈者出院后复检出核酸阳性 当地卫健委：属实',
            '中国石油化工集团公司由全民所有制企业改制为国有独资公司', '国家卫健委：2月20日全国单日新增治愈出院病例首次超过2000例']:
    label1 = Label(mainCol1, text=str(col), fg='#585570', bg='#fbeeac', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
window.mainloop()

# %% [markdown]
# #### 上月基差占比

# %%
import pickle
readPath = r'E:\OI\minOIData_IC'
dataPathLs = glob.glob(os.path.join(readPath, 'IC***.csv.gz'))
oiData = []
for path in dataPathLs:
    data = pd.read_csv(path, compression='gzip')
    oiData += [data]
oiData = pd.concat(oiData).reset_index(drop=True)
oiData.columns = ['time', 'oi', 'contract']
oiData['time'] = oiData['time'].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
oiData['date'] = oiData.time.dt.date
oiData = oiData.groupby(['contract', 'date'])['oi'].mean().reset_index()
oiData
oiData['totalOI'] = oiData.groupby(['date'])['oi'].transform('sum')
oiData
expiryData = pd.read_csv('E:\\OI\\expiryTable.csv',encoding='utf-8')
expiryData['contract'] = 'IC' + expiryData['contr_name'].str.slice(5)
expiryData['expDate'] = expiryData['expDate'].apply(lambda x: datetime.datetime.strptime(str(x), '%Y%m%d').date())
expiryData = expiryData[(expiryData['expDate'] <= datetime.date(2019, 10, 18))]
consData = pd.DataFrame({'date': sorted(oiData['date'].unique())})
consData['consDay'] = consData.index.values
consData = dict(zip(consData['date'], consData['consDay']))
expiryData['expConsDay'] = expiryData['expDate'].apply(lambda x: consData[x])
expiryData = expiryData[['contract', 'expDate', 'expConsDay']]
oiData['consDay'] = oiData['date'].apply(lambda x: consData[x])
oiData = pd.merge(oiData, expiryData, how='left', on=['contract'], validate='many_to_one')
oiData['remainDays'] = oiData['consDay'] - oiData['expConsDay']
oiData = oiData[oiData['contract'] <= 'IC1910'].reset_index(drop=True)
oiData = oiData[oiData['remainDays'] >= -20]

oiData['frontOI'] = oiData['oi'] / oiData['totalOI']
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)

for contract in oiData['contract'].unique()[16:24]:
    ax.plot(oiData[oiData['contract'] == contract]['remainDays'], oiData[oiData['contract'] == contract]['frontOI'], label=contract)

ax.set_xticks(np.arange(-20, 2, 2))
ax.set_xlabel('days to expiry')
ax.set_title('front month OI percentage')
ax.legend();

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)

for contract in oiData['contract'].unique()[-8:]:
    ax.plot(oiData[oiData['contract'] == contract]['remainDays'], oiData[oiData['contract'] == contract]['totalOI'], label=contract)

ax.set_xticks(np.arange(-20, 2, 2))
ax.set_xlabel('days to expiry')
ax.set_title('total OI')
ax.legend(loc='upper right');

# %%
oiData[(oiData["date"]> oiData["date"].iloc[0]) & (oiData["date"]< oiData["date"].iloc[16])]
# Out:
#    contract        date            oi       totalOI  consDay     expDate  \
# 1    IC1709  2017-09-04  22560.933333  30464.020833        1  2017-09-15
# 2    IC1709  2017-09-05  21675.341667  30164.520833        2  2017-09-15
# 3    IC1709  2017-09-06  21384.054167  30423.483333        3  2017-09-15
# 4    IC1709  2017-09-07  20789.054167  30433.595833        4  2017-09-15
# 5    IC1709  2017-09-08  20361.908333  30829.504167        5  2017-09-15
# 6    IC1709  2017-09-11  18479.650000  30537.920833        6  2017-09-15
# 7    IC1709  2017-09-12  16011.875000  30448.220833        7  2017-09-15
# 8    IC1709  2017-09-13  12613.566667  29827.508333        8  2017-09-15
# 9    IC1709  2017-09-14   8207.391667  29535.433333        9  2017-09-15
# 10   IC1709  2017-09-15   3719.437500  29578.066667       10  2017-09-15
# 21   IC1710  2017-09-15  17166.629167  29578.066667       10  2017-10-20
# 22   IC1710  2017-09-18  19173.354167  28079.266667       11  2017-10-20
# ...

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window= Tk()
window.title("佳期金融期货分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="行情报价")
menu_widget.add_command(label="期货数据")
menu_widget.add_command(label="期货资讯")
menu_widget.add_command(label="深度分析")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#fbeeac')
sidebar1 = PanedWindow(main, orient="vertical", bg='#fbeeac')
sidebar2 = PanedWindow(main, orient="vertical", bg='#fbeeac')
sidebar3 = PanedWindow(sidebar2, orient="horizontal", bg='#fbeeac')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#fbeeac')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#fbeeac')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)
sidebar2.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)


mainCol1 = Frame(sidebar1, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="期现基差", fg='#f7fafc', bg='#f9bc08')
title.pack(fill='x')
label1 = Label(mainCol1, text='基差占比', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
label1 = Label(mainCol1, text='总基差', fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')



mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='区间起始时间', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '2017/9/4')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='区间截止时间', fg='#585570', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '2017/9/21')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="提取数据", fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="显示图形", fg='#f7fafc', bg='#f9bc08')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#fbeeac', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#fbeeac')
label1.pack(fill='x')


df1 = oiData[(oiData["date"]> oiData["date"].iloc[0]) & (oiData["date"]< oiData["date"].iloc[16])]

mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='日期', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["date"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='当期基差', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["oi"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='当期总基差', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["totalOI"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar4, bg='#fbeeac')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='当期基差占比', fg='#585570', bg='#fbeeac', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["frontOI"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#fbeeac', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

    
mainCol = Frame(sidebar5, borderwidth=2, bg='#fbeeac')
mainCol.pack(expand=True, fill='both')
sidebar5.add(mainCol)

fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(111)
for contract in oiData['contract'].unique()[-8:]:
    ax1.plot(oiData[oiData['contract'] == contract]['remainDays'], oiData[oiData['contract'] == contract]['totalOI'], label=contract)

ax1.set_xlabel('days to expiry')
ax1.set_title('总基差')

xindexReset = np.arange(-20, 2, 2)
ax1.set_xticks(xindexReset)

ax1.set_facecolor('#fbeeac')
fig.patch.set_facecolor('#fbeeac')
ax1isColor = '#fbeeac'
ax1.spines['bottom'].set_color(axisColor)
ax1.spines['left'].set_color(axisColor)
ax1.tick_params(axis='x', colors=axisColor)
ax1.tick_params(axis='y', colors=axisColor)
ax1.yaxis.label.set_color(axisColor)
ax1.xaxis.label.set_color(axisColor)
ax1.title.set_color(axisColor)    

legend = plt.legend(frameon = 1)
frame = legend.get_frame()
frame.set_facecolor('#fbeeac')
frame.set_edgecolor('#fbeeac')
plt.setp(legend.get_texts(), color=axisColor)

canvas = FigureCanvasTkAgg(fig, master=mainCol)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()  

window.mainloop()
