# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import pickle
from matplotlib import pyplot as plt
import statsmodels.api as sm
from matplotlib.ticker import Formatter
import collections
import glob
import os
pd.set_option("max_columns", 200)

for y in ['20200520']:
    print('----------------------------------------------------------------')
    print(y)
    
#     readPath = '\\\\192.168.10.30\\Kevin_zhenyu\\temp\\wind\\Dayupdate\\' + y + '_Tick\\SH\\' + y + '\\***'
#     dataPathLs = np.array(glob.glob(readPath))
#     dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
#     dataPathLs = dataPathLs[((dateLs >= 600000) & (dateLs <= 700000))| (dateLs == 16) | (dateLs == 300)
#                        | (dateLs == 852) | (dateLs == 905)]
#     logSH1 = []
#     for i in dataPathLs:
#         df = pd.read_csv(i, encoding='GBK')[["code", "time", "accvolume", "accturover", "price", "volume", "open", 
#                                             "bid1", "bid2", "bid3", "bid4", "bid5", "bsize1", "bsize2",
#                                             "bsize3", "bsize4", "bsize5", "ask1", "ask2", "ask3", "ask4", 
#                                             "ask5", "asize1", "asize2", "asize3", "asize4", "asize5"]]
#         logSH1 += [df]
#     del df
#     logSH1 = pd.concat(logSH1).reset_index(drop=True)
#     logSH1 = logSH1.rename(columns={"code":"StockID", "accvolume":"cum_volume", "accturover":"cum_amount", "price":"close", "open":"openPrice",
#                                "bid1":"bid1p", "bid2":"bid2p", "bid3":"bid3p", "bid4":"bid4p", "bid5":"bid5p",
#                                "bsize1":"bid1q", "bsize2":"bid2q", "bsize3":"bid3q", "bsize4":"bid4q", "bsize5":"bid5q",
#                                "ask1":"ask1p", "ask2":"ask2p", "ask3":"ask3p", "ask4":"ask4p", "ask5":"ask5p","asize1":"ask1q", 
#                                 "asize2":"ask2q", "asize3":"ask3q", "asize4":"ask4q", "asize5":"ask5q"})


#     for col in ["close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "ask1p", "ask2p","ask3p", "ask4p", "ask5p","openPrice"]:
#         logSH1[col] = logSH1[col]/10000

#     path1 = np.array(glob.glob('\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_' + y + '_zs_92_01_day_data\\mdLog_SH_*'))[0]
    path2 = np.array(glob.glob('\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_' + y + '_zs_92_01_day_data\\mdLog_SZ_*'))[0]
#     path3 = np.array(glob.glob('\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_' + y + '_zt_96_04_day_96data\\mdLog_SH_*'))[0]
    
#     logSH2 = pd.read_csv(path3,
#                     encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
#                                               "exchange", "time", "cum_volume", "cum_amount", "close",
#                                               "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
#                                               "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
#                                               "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
#                                               "ask4q", "ask5q", "openPrice"]]
#     logSH2["time"] = logSH2["time"].apply(lambda x: int((x.replace(':', "")).replace(".", "")))
#     display(logSH2["source"].unique())
    
    
    
    
    
    
#     print('----------------------------------------------------------------')
#     print('SH lv2 data:')
    
#     in_dex = [16, 300, 852, 905]
#     data1 = logSH2[~logSH2["StockID"].isin(in_dex) & (logSH2["time"] >= 91500000) & (logSH2["time"] <= 145700000)
#               & (logSH2["source"] == 13)]
#     data2 = logSH1[~logSH1["StockID"].isin(in_dex) & (logSH1["time"] >= 91500000) & (logSH1["time"] <= 145700000)]
#     columns = ["StockID", "cum_volume", "close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q", "bid2q",
#            "bid3q", "bid4q", "bid5q", "ask1p", "ask2p", "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
#            "ask4q", "ask5q", "openPrice"]
#     data1_1 = data1.drop_duplicates(subset=columns, keep="first").reset_index()
#     data2_1 = data2.drop_duplicates(subset=columns, keep="first").reset_index()
    
#     data1_1 = data1_1[(data1_1["bid1p"] != 0) & (data1_1["ask1p"] != 0)]
#     data2_1 = data2_1[(data2_1["bid1p"] != 0) & (data2_1["ask1p"] != 0)]

#     n1 = len(data1_1["StockID"].unique())
#     n2 = len(data2_1["StockID"].unique())
#     print(n1)
#     print(n2)
#     if n1 != n2:
#         sl = list(set(data1_1["StockID"].unique()) & set(data2_1["StockID"].unique()))
#         data1_1 = data1_1[data1_1["StockID"].isin(sl)]
#         data2_1 = data2_1[data2_1["StockID"].isin(sl)]

#     test = pd.merge(data1_1, data2_1, left_on=columns, right_on=columns, how="outer")
#     n1 = test["time_x"].count()
#     n2 = test["time_y"].count()
#     len1 = len(test)
#     print(n1)
#     print(n2)
#     print(len1)
#     print("-----------------------------------------------")
#     if n2 < len1:
#         display("test is not complete:")
#         display(test[np.isnan(test["time_y"])])
#         display(len(test[np.isnan(test["time_y"])])/n1)
#         display(np.sort(test[np.isnan(test["time_y"])]["time_x"].unique()))
#         display(len(np.sort(test[np.isnan(test["time_y"])]["StockID"].unique())))
#         display(np.sort(test[np.isnan(test["time_y"])]["StockID"].unique()))
        
#     if (len1 == n2) & (n1 < len1):
#         display("baseline is not complete:")
#         display(test[np.isnan(test["time_x"])])
#         display(n2-n1)
#         print((n2-n1)/n1)
#     del data1
#     del data2
#     del logSH2
#     del data1_1
#     del data2_1
#     del test
    
    
    
    
    
    
#     print('----------------------------------------------------------------')
#     print('SH index data:')
    
#     logSH = pd.read_csv(path1,
#                     encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
#                                               "exchange", "time", "cum_volume", "cum_amount", "close",
#                                               "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
#                                               "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
#                                               "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
#                                               "ask4q", "ask5q", "openPrice"]]
#     logSH["time"] = logSH["time"].apply(lambda x: int((x.replace(':', "")).replace(".", "")))
    
#     in_dex = list(set(in_dex) & set(logSH1["StockID"].unique()))
#     print(in_dex)
#     data1 = logSH[(logSH["StockID"].isin(in_dex)) & (logSH["time"] >= 91500000) & (logSH["time"] <= 145700000)]
#     data2 = logSH1[(logSH1["StockID"].isin(in_dex)) & (logSH1["time"] >= 91500000) & (logSH1["time"] <= 145700000)]

#     data2["cum_volume"] = data2["cum_volume"]/100

#     # data2 = data2[data2["openPrice"] != 0]
#     columns = ["StockID", "cum_volume", "close", "openPrice"]
#     data1_1 = data1.drop_duplicates(subset=columns, keep="first").reset_index()
#     data2_1 = data2.drop_duplicates(subset=columns, keep="first").reset_index()
#     columns = ["StockID", "cum_volume", "close", "openPrice"]
#     test = pd.merge(data1_1, data2_1, left_on=columns, right_on=columns, how="outer")
#     n1 = test["time_x"].count()
#     n2 = test["time_y"].count()
#     len1 = len(test)
#     print(n1)
#     print(n2)
#     print(len1)
#     if n2 < len1:
#         display("test is not complete:")
#         display(test[np.isnan(test["time_y"])])
#         display(np.sort(test[np.isnan(test["time_y"])]["time_x"].unique()))
#         display(len(np.sort(test[np.isnan(test["time_y"])]["StockID"].unique())))
#         display(np.sort(test[np.isnan(test["time_y"])]["StockID"].unique()))
#     del data1
#     del data2
#     del logSH
#     del logSH1
#     del data1_1
#     del data2_1
#     del test
    
    
    
    
    
    
    
    
    print('----------------------------------------------------------------')
    print('SZ lv2 data:')
    
    readPath = '\\\\192.168.10.30\\Kevin_zhenyu\\temp\\wind\\Dayupdate\\' + y + '_Tick\\SZ\\' + y + '\\***'
    dataPathLs = np.array(glob.glob(readPath))
    dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
    dataPathLs = dataPathLs[(dateLs < 4000) | (dateLs > 300000)]
    logSZ1 = []
    for i in dataPathLs:
        df = pd.read_csv(i, encoding="GBK")[["code", "time", "accvolume", "accturover", "price", "volume", "open", 
                                            "bid1", "bid2", "bid3", "bid4", "bid5", "bsize1", "bsize2",
                                            "bsize3", "bsize4", "bsize5", "ask1", "ask2", "ask3", "ask4", 
                                            "ask5", "asize1", "asize2", "asize3", "asize4", "asize5"]]
        logSZ1 += [df]
    logSZ1 = pd.concat(logSZ1).reset_index(drop=True)
    logSZ1 = logSZ1.rename(columns={"code":"StockID", "accvolume":"cum_volume", "accturover":"cum_amount", "price":"close", "open":"openPrice",
                               "bid1":"bid1p", "bid2":"bid2p", "bid3":"bid3p", "bid4":"bid4p", "bid5":"bid5p",
                               "bsize1":"bid1q", "bsize2":"bid2q", "bsize3":"bid3q", "bsize4":"bid4q", "bsize5":"bid5q",
                               "ask1":"ask1p", "ask2":"ask2p", "ask3":"ask3p", "ask4":"ask4p", "ask5":"ask5p","asize1":"ask1q", 
                                "asize2":"ask2q", "asize3":"ask3q", "asize4":"ask4q", "asize5":"ask5q"})
    for col in ["close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "ask1p", "ask2p","ask3p", "ask4p", "ask5p","openPrice"]:
        logSZ1[col] = logSZ1[col]/10000
    
    logSZ = pd.read_csv(path2,
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
                                              "exchange", "time", "cum_volume", "cum_amount", "close",
                                              "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
                                              "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
                                              "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
                                              "ask4q", "ask5q", "openPrice"]]
    logSZ["time"] = logSZ["time"].apply(lambda x: int((x.replace(':', "")).replace(".", "")))  
    
    
    
    data1 = logSZ[(logSZ["time"] >= 91500000) & (logSZ["time"] < 145700000) ]
    data2 = logSZ1[(logSZ1["time"] >= 91500000) & (logSZ1["time"] < 145700000)]

    columns = ["StockID", "cum_volume", "close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q", "bid2q",
           "bid3q", "bid4q", "bid5q", "ask1p", "ask2p", "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
           "ask4q", "ask5q", "openPrice"]
    data1_1 = data1.drop_duplicates(subset=columns, keep="first").reset_index()
    data2_1 = data2.drop_duplicates(subset=columns, keep="first").reset_index()
    data1_1 = data1_1[(data1_1["bid1p"] != 0) & (data1_1["ask1p"] != 0)]
    data2_1 = data2_1[(data2_1["bid1p"] != 0) & (data2_1["ask1p"] != 0)]
    n1 = len(data1_1["StockID"].unique())
    n2 = len(data2_1["StockID"].unique())
    print(n1)
    print(n2)
    if n1 != n2:
        sl = list(set(data1_1["StockID"].unique()) & set(data2_1["StockID"].unique()))
        data1_1 = data1_1[data1_1["StockID"].isin(sl)]
        data2_1 = data2_1[data2_1["StockID"].isin(sl)]
    test = pd.merge(data1_1, data2_1, left_on=columns, right_on=columns, how="outer")
    n1 = test["time_x"].count()
    n2 = test["time_y"].count()
    len1 = len(test)
    print(n1)
    print(n2)
    print(len1)
    print("-----------------------------------------------")
    if n2 < len1:
        display("test is not complete:")
        display(test[np.isnan(test["time_y"])])
        print(len(test[np.isnan(test["time_y"])])/n1)
        print(np.sort(test[np.isnan(test["time_y"])]["time_x"].unique()))
        print(len(np.sort(test[np.isnan(test["time_y"])]["StockID"].unique())))
        print(np.sort(test[np.isnan(test["time_y"])]["StockID"].unique()))
    if (len1 == n2) & (n1 < len1):
        display("baseline is not complete:")
        display(test[np.isnan(test["time_x"])])
        display(n2-n1)
    del data1
    del data2
    del logSZ
    del logSZ1
    del data1_1
    del data2_1
    del test
    
    
    
    
    
    
    
    
    
    
    
#     readPath = '\\\\192.168.10.30\\Kevin_zhenyu\\temp\\wind\\Dayupdate\\' + y + '_Order\\SZ\\' + y + '\\***'
#     dataPathLs = np.array(glob.glob(readPath))
#     dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
#     dataPathLs = dataPathLs[(dateLs < 4000) | (dateLs > 300000)]
#     OrderLogSZ1 = []
#     for i in dataPathLs:
#         df = pd.read_csv(i, encoding='GBK')
#         OrderLogSZ1 += [df]
#     del df
#     OrderLogSZ1 = pd.concat(OrderLogSZ1).reset_index(drop=True)
#     OrderLogSZ1 = OrderLogSZ1.rename(columns={"code":"SecurityID", "time":"TransactTime", "function_code":"Side", "order_kind":"OrderType",
#                              "order_price":"Price", "order_volume":"OrderQty", "order":"ApplSeqNum"})
#     OrderLogSZ1["Side"] = np.where(OrderLogSZ1["Side"] == 66, 1, 2)
#     OrderLogSZ1["OrderType"] = np.where(OrderLogSZ1["OrderType"] == 48, '2', np.where(
#     OrderLogSZ1["OrderType"] == 49, '1', 'U'))
#     path1 = np.array(glob.glob('\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_' + y + '_zs_92_01_day_data\\mdOrderLog_*'))[0]
#     OrderLogSZ = pd.read_csv(path1,
#                     encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
#                                                  "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
#                                                  "OrderQty"]]
#     OrderLogSZ["OrderType"] = OrderLogSZ["OrderType"].apply(lambda x: str(x))
#     OrderLogSZ1["OrderType"] = OrderLogSZ1["OrderType"].apply(lambda x: str(x))
#     sl = list(set(OrderLogSZ["SecurityID"].unique()) & set(OrderLogSZ1['SecurityID'].unique()))
#     OrderLogSZ = OrderLogSZ[OrderLogSZ["SecurityID"].isin(sl)]
#     OrderLogSZ1 = OrderLogSZ1[OrderLogSZ1["SecurityID"].isin(sl)]
#     print(len(OrderLogSZ["SecurityID"].unique()))
#     print(len(OrderLogSZ1["SecurityID"].unique()))

#     print(OrderLogSZ1.columns)
    
#     print('----------------------------------------------------------------')
#     print('SZ order data:')
    
#     columns = ["ApplSeqNum", "TransactTime","Side",'OrderType', 'Price', 'OrderQty', "SecurityID"]
#     ree = pd.merge(OrderLogSZ, OrderLogSZ1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
#     n1 = ree["sequenceNo"].count()
#     n2 = ree["date"].count()
#     len1 = len(ree)
#     print(n1)
#     print(n2)
#     print(len1)
#     print("-----------------------------------------------")
#     if n2 < len1:
#         display("test is not complete:")
#         display(ree[np.isnan(ree["date"])])
#         print(len(ree[np.isnan(ree["date"])]))
#         print(np.sort(ree[np.isnan(ree["date"])]["TransactTime"].unique()))
#         print(len(ree[np.isnan(ree["date"])]["SecurityID"].unique()))
#         print(ree[np.isnan(ree["date"])]["SecurityID"].unique())
#     if (len1 == n2) & (n1 < len1):
#         display("test is complete, baseline is not complete:")
#         display(ree[np.isnan(ree["sequenceNo"])])
#         print(np.sort(ree[np.isnan(ree["sequenceNo"])]["TransactTime"].unique()))
#         print(len(ree[np.isnan(ree["sequenceNo"])]["SecurityID"].unique()))
#         print(ree[np.isnan(ree["sequenceNo"])]["SecurityID"].unique())
#         display(n2-n1)
#     del OrderLogSZ
#     del OrderLogSZ1
#     del ree
    
    
    
    
    
    
    
    
    
    
#     readPath = '\\\\192.168.10.30\\Kevin_zhenyu\\temp\\wind\\Dayupdate\\' + y + '_Transaction\\SH\\' + y + '\\***'
#     dataPathLs = np.array(glob.glob(readPath))
#     dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
#     dataPathLs = dataPathLs[(dateLs >= 600000) & (dateLs <= 700000)]
#     SH1 = []
#     for i in dataPathLs:
#         df = pd.read_csv(i, encoding="GBK")
#         SH1 += [df]
#     del df
#     SH1 = pd.concat(SH1).reset_index(drop=True)

#     SH1 = SH1.rename(columns={"code":"SecurityID", "time":"TransactTime", "bs_flag":"TradeBSFlag", "function_code":"ExecType",
#                              "trade_price":"TradePrice", "trade_volume":"TradeQty", "ask_order":"OfferApplSeqNum", 
#                               "bid_order":"BidApplSeqNum", "Index":"ApplSeqNum"})
#     SH1["ExecType"] = 'F'
#     SH1["TradeMoney"] = SH1["TradePrice"] * SH1["TradeQty"]
#     SH1["TradeBSFlag"] = np.where(SH1["TradeBSFlag"] == 83, 'S', np.where(
#     SH1["TradeBSFlag"] == 66, 'B', 'N'))
#     path1 = np.array(glob.glob('\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_' + y + '_zs_92_01_day_data\\mdTradeLog*'))[0]
#     SH = pd.read_csv(path1,
#                     encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
#                                                  "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
#                                                  "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
#                                                  "OfferApplSeqNum"]]
#     sl = list(set(SH["SecurityID"].unique()) & set(SH1['SecurityID'].unique()))
#     SH = SH[SH["SecurityID"].isin(sl)]
#     SH1 = SH1[SH1["SecurityID"].isin(sl)]
#     print(len(SH["SecurityID"].unique()))
#     print(len(SH1["SecurityID"].unique()))

#     print(SH1.columns)
    
#     print('----------------------------------------------------------------')
#     print('SH trade data:')
    
#     SH["ExecType"] = SH["ExecType"].apply(lambda x: str(x))
#     SH1["ExecType"] = SH1["ExecType"].apply(lambda x: str(x))
#     columns = ["TransactTime", "ApplSeqNum", "SecurityID", "TradePrice", "TradeQty", "TradeMoney", "TradeBSFlag","ExecType",
#            "BidApplSeqNum", "OfferApplSeqNum"]
#     n1 = len(SH["SecurityID"].unique())
#     n2 = len(SH1["SecurityID"].unique())
#     print(n1)
#     print(n2)
#     if n1 != n2:
#         sl = list(set(SH1["SecurityID"].unique()) & set(SH["SecurityID"].unique()))
#         SH = SH[SH["SecurityID"].isin(sl)]
#         SH1 = SH1[SH1["SecurityID"].isin(sl)]
#     re = pd.merge(SH, SH1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
#     n1 = re["sequenceNo"].count()
#     n2 = re["name"].count()
#     len1 = len(re)
#     print(n1)
#     print(n2)
#     print(len1)
#     print("-----------------------------------------------")
#     if n2 < len1:
#         display("test is not complete:")
#         display(re[np.isnan(re["name"])])
#         print(len(re[np.isnan(re["name"])]))
#         print(np.sort(re[np.isnan(re["name"])]["TransactTime"].unique()))
#         print(len(re[np.isnan(re["name"])]["SecurityID"].unique()))
#         print(re[np.isnan(re["name"])]["SecurityID"].unique())
#     if (len1 == n2) & (n1 < len1):
#         display("baseline is not complete:")
#         display(re[np.isnan(re["sequenceNo"])])
#         print(np.sort(re[np.isnan(re["sequenceNo"])]["TransactTime"].unique()))
#         print(len(re[np.isnan(re["sequenceNo"])]["SecurityID"].unique()))
#         print(re[np.isnan(re["sequenceNo"])]["SecurityID"].unique())
#         display(n2-n1)
#     del SH
#     del SH1
#     del re
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
#     readPath = '\\\\192.168.10.30\\Kevin_zhenyu\\temp\\wind\\Dayupdate\\' + y  + '_Transaction\\SZ\\' + y + '\\***'
#     dataPathLs = np.array(glob.glob(readPath))
#     dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
#     dataPathLs = dataPathLs[(dateLs < 4000) | (dateLs > 300000)]
#     TradeLogSZ1 = []
#     for i in dataPathLs:
#         df = pd.read_csv(i, encoding="GBK")
#         TradeLogSZ1 += [df]
#     del df
#     TradeLogSZ1 = pd.concat(TradeLogSZ1).reset_index(drop=True)

#     TradeLogSZ1 = TradeLogSZ1.rename(columns={"code":"SecurityID", "time":"TransactTime", "bs_flag":"TradeBSFlag", "function_code":"ExecType",
#                              "trade_price":"TradePrice", "trade_volume":"TradeQty", "ask_order":"OfferApplSeqNum", 
#                               "bid_order":"BidApplSeqNum", "Index":"ApplSeqNum"})
#     TradeLogSZ1["ExecType"] = np.where(TradeLogSZ1["ExecType"] == 67, '4', 'F')
#     TradeLogSZ1["TradeMoney"] = TradeLogSZ1["TradePrice"] * TradeLogSZ1["TradeQty"]
#     TradeLogSZ1["TradeBSFlag"] = np.where(TradeLogSZ1["TradeBSFlag"] == 83, 'S', np.where(
#     TradeLogSZ1["TradeBSFlag"] == 66, 'B', 'N'))

#     path1 = np.array(glob.glob('\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_' + y + '_zs_92_01_day_data\\mdTradeLog*'))[0]
#     TradeLogSZ = pd.read_csv(path1,
#                     encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
#                                                  "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
#                                                  "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
#                                                  "OfferApplSeqNum"]]
#     sl = list(set(TradeLogSZ["SecurityID"].unique()) & set(TradeLogSZ1['SecurityID'].unique()))
#     TradeLogSZ = TradeLogSZ[TradeLogSZ["SecurityID"].isin(sl)]
#     TradeLogSZ1 = TradeLogSZ1[TradeLogSZ1["SecurityID"].isin(sl)]
#     print(len(TradeLogSZ["SecurityID"].unique()))
#     print(len(TradeLogSZ1["SecurityID"].unique()))

#     print(TradeLogSZ1.columns)
    
#     print('----------------------------------------------------------------')
#     print('SZ trade data:')
    
#     TradeLogSZ["ExecType"] = TradeLogSZ["ExecType"].apply(lambda x: str(x))
#     TradeLogSZ1["ExecType"] = TradeLogSZ1["ExecType"].apply(lambda x: str(x))

#     TradeLogSZ1["TradeBSFlag"] = 'N'

#     columns = ["TransactTime", "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag","TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum","OfferApplSeqNum"]
#     re = pd.merge(TradeLogSZ, TradeLogSZ1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
#     n1 = re["sequenceNo"].count()
#     n2 = re["name"].count()
#     len1 = len(re)
#     print(n1)
#     print(n2)
#     print(len1)
#     print("-----------------------------------------------")
#     if n2 < len1:
#         display("test is not complete:")
#         display(re[np.isnan(re["name"])])
#         print(len(re[np.isnan(re["name"])]))
#         print(np.sort(re[np.isnan(re["name"])]["TransactTime"].unique()))
#         print(len(re[np.isnan(re["name"])]["SecurityID"].unique()))
#         print(re[np.isnan(re["name"])]["SecurityID"].unique())
#     if (len1 == n2) & (n1 < len1):
#         display("baseline is not complete:")
#         display(re[np.isnan(re["sequenceNo"])])
#         print(np.sort(re[np.isnan(re["sequenceNo"])]["TransactTime"].unique()))
#         print(len(re[np.isnan(re["sequenceNo"])]["SecurityID"].unique()))
#         print(re[np.isnan(re["sequenceNo"])]["SecurityID"].unique())
#         display(n2-n1)
#     del TradeLogSZ
#     del TradeLogSZ1
#     del re
# Out:
# ----------------------------------------------------------------
# 20200520
# ----------------------------------------------------------------
# SZ lv2 data:
# 2207
# 2210
# 6950829
# 6950441
# 6950829
# -----------------------------------------------
# 'test is not complete:'
#           index_x    clockAtArrival  sequenceNo  source  StockID exchange  \
# 123704     363130  1589938312122747     5802325       3     2690       SZ
# 123705     363131  1589938312122750     5802326       3     2693       SZ
# 123706     363132  1589938312122753     5802327       3     2694       SZ
# 123707     363133  1589938312122756     5802328       3     2696       SZ
# 123708     363134  1589938312122767     5802329       3     2699       SZ
# ...           ...               ...         ...     ...      ...      ...
# 6450911  14052438  1589956933018011   109818934       3     2413       SZ
# 6450912  14052439  1589956933018015   109818935       3     2416       SZ
# 6450913  14052440  1589956933018019   109818936       3     2422       SZ
# 6450923  14052479  1589956933030029   109819383       3     2417       SZ
# 6450924  14052480  1589956933030037   109819384       3     2430       SZ
#
#             time_x  cum_volume  cum_amount_x  close  bid1p  bid2p  bid3p  \
# 123704    93133000       54700  2.496088e+06  45.38  45.38  45.35  45.34
# 123705    93133000       28800  1.432180e+05   4.98   4.96   4.95   4.94
# 123706    93133000      143100  4.043210e+05   2.81   2.81   2.80   2.79
# 123707    93133000      199780  1.303311e+06   6.53   6.52   6.51   6.50
# 123708    93133000       96980  4.922318e+05   5.06   5.06   5.05   5.04
# ...            ...         ...           ...    ...    ...    ...    ...
# 6450911  144154000   134353347  1.138282e+09   8.27   8.26   0.00   0.00
# 6450912  144154000    25746991  1.887832e+08   7.22   7.22   7.21   7.20
# 6450913  144154000     7690626  1.552108e+08  20.09  20.09  20.08  20.07
# 6450923  144154000    10374976  7.160709e+07   6.84   6.84   6.83   6.82
# 6450924  144154000    12106358  1.505354e+08  12.36  12.36  12.35  12.34
#
#          bid4p  bid5p    bid1q   bid2q   bid3q   bid4q   bid5q  ask1p  ask2p  \
# 123704   45.33  45.32      100    3000     500    1400    2600  45.60  45.61
# 123705    4.93   4.92     9000    2700     900    9700    3100   4.98   4.99
# 123706    2.78   2.77    41100   71900  143700  144100     300   2.82   2.83
# 123707    6.49   6.48     8000   24100   47020   12600   34400   6.59   6.60
# 123708    5.03   5.02    48420   74000   43400    7600    1400   5.07   5.08
# ...        ...    ...      ...     ...     ...     ...     ...    ...    ...
# 6450911   0.00   0.00  2990611       0       0       0       0   8.27   8.28
# 6450912   7.19   7.18    41183  173200  256600   29000   83400   7.23   7.24
# 6450913  20.06  20.05    31400    3500   49800   16800   85000  20.10  20.11
# 6450923   6.81   6.80    18800   52100  122100  120100  336300   6.85   6.86
# 6450924  12.33  12.32    34200   30200   22400   17100   24300  12.38  12.39
#
#          ask3p  ask4p  ask5p   ask1q   ask2q  ask3q   ask4q   ask5q  \
# 123704   45.62  45.63  45.65     100    1500   1900     100     200
# 123705    5.00   5.01   5.02     900    8300   4800    2900   11500
# 123706    2.84   2.85   2.86   25000   25500  32400   56300  103000
# 123707    6.61   6.62   6.64    5000   22000   5900   13100    2000
# 123708    5.09   5.10   5.11    5100   48500  52800   23300   14000
# ...        ...    ...    ...     ...     ...    ...     ...     ...
# 6450911   8.29   8.30   8.31  104000  325592  85608  250700   22300
# 6450912   7.25   7.26   7.27   19000   41500  22800   47400   17200
# 6450913  20.12  20.13  20.14   26000   12400  12800    2200   26700
# 6450923   6.87   6.88   6.89   57313   18400  15400   18900   31600
# 6450924  12.40  12.42  12.43   23600    9300  22400    3000    5100
#
#          openPrice  index_y  time_y  cum_amount_y  volume
# 123704       46.00      NaN     NaN           NaN     NaN
# 123705        4.99      NaN     NaN           NaN     NaN
# 123706        2.83      NaN     NaN           NaN     NaN
# 123707        6.55      NaN     NaN           NaN     NaN
# 123708        5.08      NaN     NaN           NaN     NaN
# ...            ...      ...     ...           ...     ...
# 6450911       8.90      NaN     NaN           NaN     NaN
# 6450912       7.52      NaN     NaN           NaN     NaN
# 6450913      20.25      NaN     NaN           NaN     NaN
# 6450923       7.05      NaN     NaN           NaN     NaN
# 6450924      12.39      NaN     NaN           NaN     NaN
#
# [388 rows x 35 columns]
# 5.5820679806682054e-05
# [ 93133000 100009000 100609000 101709000 144154000]
# 310
# [ 721  725  728  729  731  732  735  739  750  751  758  759  760  767
#   768  776  778  779  782  783  785  788  789  795  797  802  813  815
#   816  819  826 2286 2301 2308 2310 2311 2312 2315 2316 2317 2318 2319
#  2321 2322 2324 2326 2327 2328 2329 2330 2331 2332 2333 2334 2335 2337
#  2338 2340 2341 2342 2343 2344 2345 2347 2348 2349 2350 2351 2352 2353
#  2354 2356 2357 2358 2359 2362 2363 2364 2365 2367 2368 2369 2370 2371
#  2372 2373 2375 2376 2377 2378 2380 2381 2382 2383 2384 2385 2386 2387
#  2388 2389 2390 2391 2392 2393 2394 2395 2396 2398 2399 2400 2401 2402
#  2404 2405 2406 2407 2408 2409 2410 2411 2412 2413 2414 2415 2416 2417
#  2418 2419 2420 2421 2422 2423 2424 2425 2428 2429 2430 2431 2432 2434
#  2435 2436 2437 2439 2442 2443 2444 2445 2446 2447 2449 2451 2452 2453
#  2454 2456 2457 2458 2459 2460 2461 2462 2463 2464 2465 2466 2467 2468
#  2470 2471 2475 2476 2479 2480 2481 2483 2484 2485 2486 2487 2488 2489
#  2491 2492 2493 2494 2495 2496 2499 2500 2504 2505 2506 2507 2510 2515
#  2690 2693 2694 2696 2699 2701 2703 2706 2707 2714 2716 2723 2724 2725
#  2726 2727 2728 2730 2731 2732 2733 2734 2735 2736 2737 2738 2739 2740
#  2741 2742 2745 2746 2747 2748 2749 2750 2751 2752 2755 2756 2757 2758
#  2759 2760 2761 2762 2765 2767 2768 2769 2770 2771 2772 2773 2776 2777
#  2780 2782 2783 2785 2786 2787 2788 2789 2790 2791 2792 2795 2796 2797
#  2798 2799 2800 2801 2802 2803 2805 2806 2807 2808 2809 2810 2812 2813
#  2815 2816 2817 2818 2819 2820 2821 2822 2824 2825 2827 2828 2829 2830
#  2833 2836 2837 2838 2839 2840 2841 2842 2849 2850 2852 2853 2858 2861
#  2862 2873]
