# %%
import os
import glob
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from mpl_finance import candlestick2_ohlc
import matplotlib.dates as mdates
import tkinter as tk
# %matplotlib inline

pd.set_option('max_rows', 300)
pd.set_option('max_columns', 150)
plt.rcParams['font.sans-serif']=['KaiTi']
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# ###  Login

# %%
import tkinter as tk
from tkinter import ttk
import tkinter.font as tkFont



window = tk.Tk()
window.title("佳期技术大数据库管理系统")
# menu_widget.entryconfig(0, bg='#a1dbcd')

# the main window is divided into left and right sections,
# and the sidebar is divided into a top and bottom section.
pw = tk.PanedWindow(orient="vertical", background="#FFFFE1")
sidebar = tk.PanedWindow(pw, orient="horizontal", background="green")
main = tk.Frame(pw, width=400, height=400, borderwidth=2, background="#FFFFE1")
sidebar_frame = tk.Frame(sidebar, width=400, height=120, background="green", borderwidth=1)

# add the paned window to the window
pw.pack(fill="both", expand=True)

# add the sidebar and main area to the main paned window
pw.add(sidebar)
pw.add(main)

# add the top and bottom to the sidebar

startX = 40
startY = 0

sidebar.add(sidebar_frame)
title = tk.Label(sidebar_frame, text='用户登录', fg='#f7fafc', bg='green')
title.place(x=startX-5, y=startY)
title.config(font=('System', 18))

label = tk.Label(main, text='账户', fg='#3d4240', bg="#FFFFE1")
label.place(x=startX-2, y=startY)
entry = tk.Entry(main)
entry.place(x=startX, y=startY+20, width=240)
entry.config(fg='#d1d1d1')
entry.insert(0, '请填写您的账号')
label = tk.Label(main, text='密码', fg='#3d4240', bg="#FFFFE1")
label.place(x=startX-2, y=startY+50)
entry = tk.Entry(main)
entry.place(x=startX, y=startY+70, width=240)
entry.config(fg='#d1d1d1')
entry.insert(0, '请输入您的密码')
button = tk.Button(main, text='登录', fg='#3d4240', relief=tk.GROOVE)
button.place(x=startX+260, y = startY+15)
button = tk.Button(main, text='找回密码', fg='#3d4240', relief=tk.GROOVE)
button.place(x=startX+260, y = startY+65)
check = tk.Checkbutton(main, text="记住密码", fg='#3d4240', relief=tk.GROOVE)
check.place(x=startX, y = startY+100)

window.mainloop()

# %% [markdown]
# ### 主界面

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window= Tk()
window.title("佳期技术大数据库管理系统")

menu_widget = Menu(window)
menu_widget.add_command(label="条件筛选")
menu_widget.add_command(label="数据浏览器")
menu_widget.add_command(label="行情序列")
menu_widget.add_command(label="纵向比较")
window.config(menu=menu_widget)

main = PanedWindow(orient="vertical", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="horizontal", bg='#FFFFE1', relief=RAISED)
sidebar2 = PanedWindow(main, orient="horizontal", bg='#FFFFE1')
sidebar3 = PanedWindow(main, orient="horizontal", bg='#FFFFE1', relief=RAISED)
sidebar4 = PanedWindow(main, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(main, orient="horizontal", bg='#FFFFE1', relief=RAISED)
sidebar6 = PanedWindow(main, orient="horizontal", bg='#FFFFE1')
sidebar7 = PanedWindow(main, orient="horizontal", bg='#FFFFE1', relief=RAISED)
sidebar8 = PanedWindow(main, orient="horizontal", bg='#FFFFE1')

main.add(sidebar1)
main.add(sidebar2)
main.add(sidebar3)
main.add(sidebar4)
main.add(sidebar5)
main.add(sidebar6)
main.add(sidebar7)
main.add(sidebar8)

main.pack(fill='both', expand=True)

mainCol = Frame(sidebar1, borderwidth=2, bg='green')
mainCol.pack(expand=True, fill='both')
sidebar1.add(mainCol)
label = Label(mainCol, text='条件筛选', fg='#f7fafc', bg='green', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar2, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar2.add(mainCol)
label = Label(mainCol, text='条件选股', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar2, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar2.add(mainCol)
label = Label(mainCol, text='债券筛选', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar2, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar2.add(mainCol)
label = Label(mainCol, text='基金筛选', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar3, borderwidth=2, bg='green')
mainCol.pack(expand=True, fill='both')
sidebar3.add(mainCol)
label = Label(mainCol, text='数据浏览器', fg='#f7fafc', bg='green', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar4, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar4.add(mainCol)
label = Label(mainCol, text='股票数据浏览器', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
label = Label(mainCol, text='债券数据浏览器', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
label = Label(mainCol, text='信托数据浏览器', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar4, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar4.add(mainCol)
label = Label(mainCol, text='新三板数据浏览器', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
label = Label(mainCol, text='券商资管数据浏览器', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
label = Label(mainCol, text='保险数据浏览器', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar4, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar4.add(mainCol)
label = Label(mainCol, text='期权数据浏览器', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
label = Label(mainCol, text='私募数据浏览器', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
label = Label(mainCol, text='期货数据浏览器', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar4, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar4.add(mainCol)
label = Label(mainCol, text='券商数据浏览器', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
label = Label(mainCol, text='银行理财数据浏览器', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
label = Label(mainCol, text='板块数据浏览器', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar5, borderwidth=2, bg='green')
mainCol.pack(expand=True, fill='both')
sidebar5.add(mainCol)
label = Label(mainCol, text='行情序列', fg='#f7fafc', bg='green', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar6, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar6.add(mainCol)
label = Label(mainCol, text='沪深股票', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar6, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar6.add(mainCol)
label = Label(mainCol, text='基金', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar6, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar6.add(mainCol)
label = Label(mainCol, text='指数', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar7, borderwidth=2, bg='green')
mainCol.pack(expand=True, fill='both')
sidebar7.add(mainCol)
label = Label(mainCol, text='纵向比较', fg='#f7fafc', bg='green', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar8, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar8.add(mainCol)
label = Label(mainCol, text='财务纵比', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar8, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar8.add(mainCol)
label = Label(mainCol, text='基金比较', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar8, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar8.add(mainCol)
label = Label(mainCol, text='基金公司比较', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

window.mainloop()

# %% [markdown]
# ### 条件选股

# %%
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window= Tk()
window.title("佳期技术大数据库管理系统")

menu_widget = Menu(window)
menu_widget.add_command(label="条件筛选")
menu_widget.add_command(label="数据浏览器")
menu_widget.add_command(label="行情序列")
menu_widget.add_command(label="纵向比较")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar2 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar7 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar8 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar9 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar10 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar11 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar12 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar13 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)
main.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)
sidebar2.add(sidebar6)
sidebar2.add(sidebar7)
sidebar3.add(sidebar8)
sidebar3.add(sidebar9)
sidebar3.add(sidebar10)
sidebar3.add(sidebar11)
sidebar3.add(sidebar12)
sidebar3.add(sidebar13)

mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="条件筛选", fg='#F9F900', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='条件选股', fg='#F9F900', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='股票数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='新三板数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期权数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商资管数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='私募数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="银行理财数据浏览器", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='信托数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='保险数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期货数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='板块数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='行情序列', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='沪深股票', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='指数', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='纵向比较', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="财务纵比", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金比较", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金公司比较", fg='#f7fafc', bg='green')
title.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='待选指标', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
myid=tree.insert("",0,"基本资料",text="基本资料",values=("0"))
myidx1=tree.insert(myid,0,"股本",text="股本",values=("1"))
myid=tree.insert("",1,"股本资料",text="股本资料",values=("2"))
myidx1=tree.insert(myid,0,"总股本",text="总股本",values=("3"))
myidx2=tree.insert(myid,1,"流通A股",text="流通A股",values=("4"))
myidx1=tree.insert(myid,2,"限售A股",text="限售A股",values=("5"))
myidx2=tree.insert(myid,3,"A股合计",text="A股合计",values=("6"))
myidx1=tree.insert(myid,4,"流通B股",text="流通B股",values=("7"))
myidx2=tree.insert(myid,5,"B股合计",text="B股合计",values=("8"))
myidx1=tree.insert(myid,6,"三板合计",text="三板合计",values=("9"))
myidx2=tree.insert(myid,7,"香港上市股",text="香港上市股",values=("10"))
myidx1=tree.insert(myid,8,"海外上市股",text="海外上市股",values=("11"))
myidx2=tree.insert(myid,9,"流通股合计",text="流通股合计",values=("12"))
myidx1=tree.insert(myid,10,"限售股合计",text="限售股合计",values=("13"))
myidx2=tree.insert(myid,11,"非流通股",text="非流通股",values=("14"))
myidx2=tree.insert(myid,12,"优先股",text="优先股",values=("15"))
myid=tree.insert("",2,"股东指标",text="股东指标",values=("2"))
myidx1=tree.insert(myid,0,"股本1",text="股本1",values=("1"))
myid=tree.insert("",3,"行情指标",text="行情指标",values=("2"))
myidx1=tree.insert(myid,0,"股本2",text="股本2",values=("1"))
myid=tree.insert("",4,"估值指标",text="估值指标",values=("2"))
myidx1=tree.insert(myid,0,"股本3",text="股本3",values=("1"))
myid=tree.insert("",5,"风险分析",text="风险分析",values=("2"))
myidx1=tree.insert(myid,0,"股本4",text="股本4",values=("1"))
myid=tree.insert("",6,"盈利预测",text="盈利预测",values=("2"))
myidx1=tree.insert(myid,0,"股本5",text="股本5",values=("1"))
myid=tree.insert("",7,"财务分析",text="财务分析",values=("2"))
myidx1=tree.insert(myid,0,"股本6",text="股本6",values=("1"))
myid=tree.insert("",8,"财务报表",text="财务报表",values=("2"))
myidx1=tree.insert(myid,0,"股本7",text="股本7",values=("1"))
myid=tree.insert("",9,"分红指标",text="分红指标",values=("2"))
myidx1=tree.insert(myid,0,"股本8",text="股本8",values=("1"))
tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='待选范围', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
myid=tree.insert("",0,"市场类",text="市场类",values=("0"))
myidx1=tree.insert(myid,0,"股本",text="股本",values=("1"))
myid=tree.insert("",1,"科创板类",text="科创板类",values=("2"))
myidx1=tree.insert(myid,0,"总股本",text="总股本",values=("3"))
myid=tree.insert("",2,"创业板类",text="创业板类",values=("2"))
myidx1=tree.insert(myid,0,"股本1",text="股本1",values=("1"))
myid=tree.insert("",3,"证监会行业类",text="证监会行业类",values=("2"))
myidx1=tree.insert(myid,0,"股本2",text="股本2",values=("1"))
myid=tree.insert("",4,"申银万国行业类",text="申银万国行业类",values=("2"))
myidx1=tree.insert(myid,0,"股本3",text="股本3",values=("1"))
myid=tree.insert("",5,"中信证券行业类",text="中信证券行业类",values=("2"))
myidx1=tree.insert(myid,0,"股本4",text="股本4",values=("1"))
myid=tree.insert("",6,"中证指数行业类",text="中证指数行业类",values=("2"))
myidx1=tree.insert(myid,0,"股本5",text="股本5",values=("1"))
myid=tree.insert("",7,"国政指数行业类",text="国政指数行业类",values=("2"))
myidx1=tree.insert(myid,0,"股本6",text="股本6",values=("1"))
myid=tree.insert("",8,"地域类",text="地域类",values=("2"))
myidx1=tree.insert(myid,0,"股本7",text="股本7",values=("1"))
myid=tree.insert("",9,"指数成分类",text="指数成分类",values=("2"))
myidx1=tree.insert(myid,0,"股本8",text="股本8",values=("1"))
tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Label(mainCol1, text='条件列表', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
tree = ttk.Treeview(mainCol1, columns=('col1','col2','col3','col4','col5','col6','col7'))
tree.column('col1', width=100, anchor='center')
tree.column('col2', width=100, anchor='center')
tree.column('col3', width=100, anchor='center')
tree.column('col4', width=100, anchor='center')
tree.column('col5', width=100, anchor='center')
tree.column('col6', width=100, anchor='center')
tree.column('col7', width=100, anchor='center')
tree.heading('col1', text='序号')
tree.heading('col2', text='指标')
tree.heading('col3', text='参数')
tree.heading('col4', text='运算符')
tree.heading('col5', text='数值')
tree.heading('col6', text='单位')
tree.heading('col7', text='显示')
tree.insert('',0,values=('#4', 'A股合计','最新','', '', '', '☑'))
tree.insert('',0,values=('#3', '海外上市股','最新','>', '0', '股', '☑'))
tree.insert('',0,values=('#2', '香港上市股','最新','>', '0', '股', '☑'))
tree.insert('',0,values=('#1', 'B股合计','最新','>', '0', '股', '☑'))
tree.pack()

mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='条件表达式：', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#585570')
e1.insert(0, '#1 or #2 or #3')
e1.pack()
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='执行筛选', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='保存方案', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='方案导出', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='方案导入', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='导出到Excel', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='每页', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("20","51","52","53")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='条', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

df1 = pd.read_excel(R"D:\work\佳期投资分析系统\条件选股.xlsx", encoding="GBK")

mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='序号', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in range(20):
    label1 = Label(mainCol1, text=col+1, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='证券代码', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["证券代码"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='证券简称', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["证券简称"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='B股合计最新 股', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["B股合计\n[交易日期] 最新\n[单位] 股"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='香港上市股最新 股', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["香港上市股\n[交易日期] 最新\n[单位] 股"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='海外上市股最新 股', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["海外上市股\n[交易日期] 最新\n[单位] 股"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='A股合计最新 股', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["A股合计\n[交易日期] 最新\n[单位] 股"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')


window.mainloop()

# %% [markdown]
# ### 债券筛选

# %%
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window= Tk()
window.title("佳期技术大数据库管理系统")

menu_widget = Menu(window)
menu_widget.add_command(label="条件筛选")
menu_widget.add_command(label="数据浏览器")
menu_widget.add_command(label="行情序列")
menu_widget.add_command(label="纵向比较")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar2 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar7 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar8 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar9 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar10 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar11 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar12 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar13 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)
main.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)
sidebar2.add(sidebar6)
sidebar2.add(sidebar7)
sidebar3.add(sidebar8)
sidebar3.add(sidebar9)
sidebar3.add(sidebar10)
sidebar3.add(sidebar11)
sidebar3.add(sidebar12)
sidebar3.add(sidebar13)

mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="条件筛选", fg='#F9F900', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='条件选股', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券筛选', fg='#F9F900', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='股票数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='新三板数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期权数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商资管数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='私募数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="银行理财数据浏览器", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='信托数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='保险数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期货数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='板块数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='行情序列', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='沪深股票', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='指数', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='纵向比较', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="财务纵比", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金比较", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金公司比较", fg='#f7fafc', bg='green')
title.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='待选指标', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
myid=tree.insert("",0,"基本资料",text="基本资料",values=("0"))
myidx1=tree.insert(myid,0,"股本",text="股本",values=("1"))
myid=tree.insert("",1,"发行兑付资料",text="发行兑付资料",values=("2"))
myidx1=tree.insert(myid,0,"重要日期",text="重要日期",values=("3"))
myidx11=tree.insert(myidx1,2,"kkz",text="kk",values=("2"))
myidx2=tree.insert(myid,1,"发行资料",text="发行资料",values=("4"))
myidx11=tree.insert(myidx2,2,"kkz1",text="kk",values=("2"))
myidx1=tree.insert(myid,2,"招标发行资料",text="招标发行资料",values=("5"))
myidx11=tree.insert(myidx1,2,"kk4",text="是否发行失败",values=("5"))
myidx1=tree.insert(myid,3,"招投标结果",text="招投标结果",values=("6"))
myidx11=tree.insert(myidx1,0,"是否发行失败",text="最终票面利率",values=("5"))
myidx11=tree.insert(myidx1,1,"最终票面利率",text="是否发行失败",values=("5"))
myidx11=tree.insert(myidx1,2,"应投家数",text="应投家数",values=("5"))
myidx11=tree.insert(myidx1,3,"投标家数",text="投标家数",values=("5"))
myidx11=tree.insert(myidx1,4,"投标笔数",text="投标笔数",values=("5"))
myidx1=tree.insert(myid,4,"中介机构",text="中介机构",values=("7"))
myidx11=tree.insert(myidx1,2,"kk7",text="是否发行失败",values=("5"))
myidx2=tree.insert(myid,5,"发行费用",text="发行费用",values=("8"))
myidx11=tree.insert(myidx2,2,"kk8",text="是否发行失败",values=("5"))
myidx1=tree.insert(myid,6,"兑付资料",text="兑付资料",values=("9"))
myidx11=tree.insert(myidx1,2,"kk9",text="是否发行失败",values=("5"))
myid=tree.insert("",2,"行情指标",text="行情指标",values=("2"))
myidx1=tree.insert(myid,0,"股本1",text="股本1",values=("1"))
myid=tree.insert("",3,"债券估值",text="债券估值",values=("2"))
myidx1=tree.insert(myid,0,"股本2",text="股本2",values=("1"))
myid=tree.insert("",4,"估值指标",text="分析指标",values=("2"))
myidx1=tree.insert(myid,0,"股本3",text="股本3",values=("1"))
myid=tree.insert("",5,"风险分析",text="信用分析指标",values=("2"))
myidx1=tree.insert(myid,0,"股本4",text="股本4",values=("1"))
myid=tree.insert("",6,"盈利预测",text="机构解禁",values=("2"))
myidx1=tree.insert(myid,0,"股本5",text="股本5",values=("1"))
myid=tree.insert("",7,"财务分析",text="持有人指标",values=("2"))
myidx1=tree.insert(myid,0,"股本6",text="股本6",values=("1"))
myid=tree.insert("",8,"标准券折算比例",text="标准券折算比例",values=("2"))
myidx1=tree.insert(myid,0,"股本7",text="股本7",values=("1"))
myid=tree.insert("",9,"分红指标",text="财务分析",values=("2"))
myidx1=tree.insert(myid,0,"股本8",text="股本8",values=("1"))
myid=tree.insert("",10,"财务报表",text="财务报表",values=("2"))
myidx1=tree.insert(myid,0,"股本9",text="股本9",values=("1"))
myid=tree.insert("",11,"报表附注",text="报表附注",values=("2"))
myidx1=tree.insert(myid,0,"股本10",text="股本10",values=("1"))
myid=tree.insert("",12,"利率（回购）基本资料",text="利率（回购）基本资料",values=("2"))
myidx1=tree.insert(myid,0,"股本11",text="股本11",values=("1"))
tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='待选范围', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
myid=tree.insert("",0,"市场类",text="债券市场",values=("0"))
myidx1=tree.insert(myid,0,"股本",text="股本",values=("1"))
myid=tree.insert("",1,"科创板类",text="债券分类（中债）",values=("2"))
myidx1=tree.insert(myid,0,"总股本",text="总股本",values=("3"))
myid=tree.insert("",2,"创业板类",text="债券分类（上清所）",values=("2"))
myidx1=tree.insert(myid,0,"股本1",text="股本1",values=("1"))
myid=tree.insert("",3,"证监会行业类",text="债券分类（监管部门）",values=("2"))
myidx1=tree.insert(myid,0,"股本2",text="股本2",values=("1"))
myid=tree.insert("",4,"申银万国行业类",text="交易所债券分类（按主体）",values=("2"))
myidx1=tree.insert(myid,0,"股本3",text="股本3",values=("1"))
myid=tree.insert("",5,"中信证券行业类",text="概念板块",values=("2"))
myidx1=tree.insert(myid,0,"股本4",text="股本4",values=("1"))
myid=tree.insert("",6,"中证指数行业类",text="计息方式",values=("2"))
myidx1=tree.insert(myid,0,"股本5",text="股本5",values=("1"))
myid=tree.insert("",7,"国政指数行业类",text="含权方式",values=("2"))
myidx1=tree.insert(myid,0,"股本6",text="股本6",values=("1"))
myid=tree.insert("",8,"地域类",text="担保方式",values=("2"))
myidx1=tree.insert(myid,0,"股本7",text="股本7",values=("1"))
myid=tree.insert("",9,"指数成分类",text="剩余期限",values=("2"))
myidx1=tree.insert(myid,0,"股本8",text="股本8",values=("1"))
tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Label(mainCol1, text='条件列表', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
tree = ttk.Treeview(mainCol1, columns=('col1','col2','col3','col4','col5','col6','col7'))
tree.column('col1', width=100, anchor='center')
tree.column('col2', width=100, anchor='center')
tree.column('col3', width=100, anchor='center')
tree.column('col4', width=100, anchor='center')
tree.column('col5', width=100, anchor='center')
tree.column('col6', width=100, anchor='center')
tree.column('col7', width=100, anchor='center')
tree.heading('col1', text='序号')
tree.heading('col2', text='指标')
tree.heading('col3', text='参数')
tree.heading('col4', text='运算符')
tree.heading('col5', text='数值')
tree.heading('col6', text='单位')
tree.heading('col7', text='显示')
tree.insert('',0,values=('#3', '最终票面利率','','', '', '%', '☑'))
tree.insert('',0,values=('#2', '应投家数','','>', '0', '', '☑'))
tree.insert('',0,values=('#1', '是否发行失败','','=', '否', '', '☑'))
tree.pack()

mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='条件表达式：', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#585570')
e1.insert(0, '#1 and #2')
e1.pack()
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='执行筛选', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='保存方案', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='方案导出', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='方案导入', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='导出到Excel', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='每页', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("20","51","52","53")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='条', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

df1 = pd.read_excel(R"D:\work\佳期投资分析系统\债券筛选.xlsx", encoding="GBK")

mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='序号', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in range(20):
    label1 = Label(mainCol1, text=col+1, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='证券代码', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["证券代码"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='证券简称', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["证券简称"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='是否发行失败', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["是否发行失败"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='应投家数', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["应投家数"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='最终票面利率 %', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["最终票面利率\n[单位] %"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

window.mainloop()

# %% [markdown]
# ### 基金筛选

# %%
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window= Tk()
window.title("佳期技术大数据库管理系统")

menu_widget = Menu(window)
menu_widget.add_command(label="条件筛选")
menu_widget.add_command(label="数据浏览器")
menu_widget.add_command(label="行情序列")
menu_widget.add_command(label="纵向比较")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar2 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar7 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar8 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar9 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar10 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar11 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar12 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar13 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)
main.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)
sidebar2.add(sidebar6)
sidebar2.add(sidebar7)
sidebar3.add(sidebar8)
sidebar3.add(sidebar9)
sidebar3.add(sidebar10)
sidebar3.add(sidebar11)
sidebar3.add(sidebar12)
sidebar3.add(sidebar13)

mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="条件筛选", fg='#F9F900', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='条件选股', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金筛选', fg='#F9F900', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='股票数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='新三板数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期权数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商资管数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='私募数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="银行理财数据浏览器", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='信托数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='保险数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期货数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='板块数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='行情序列', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='沪深股票', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='指数', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='纵向比较', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="财务纵比", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金比较", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金公司比较", fg='#f7fafc', bg='green')
title.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='待选指标', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
myid=tree.insert("",0,"基本资料",text="基本资料",values=("0"))
myidx1=tree.insert(myid,0,"股本",text="股本",values=("1"))

myid=tree.insert("",1,"业绩表现",text="业绩表现",values=("2"))
myidx1=tree.insert(myid,0,"股本3",text="股本3",values=("1"))

myid=tree.insert("",2,"行情指标",text="行情指标",values=("2"))
myidx1=tree.insert(myid,0,"股本1",text="股本1",values=("1"))
myid=tree.insert("",3,"债券估值",text="货币市场基金收益",values=("2"))
myidx1=tree.insert(myid,0,"股本2",text="股本2",values=("1"))
myid=tree.insert("",4,"估值指标",text="绩效评估",values=("2"))
myidx1=tree.insert(myid,0,"重要日期",text="基金评级",values=("3"))
myidx11=tree.insert(myidx1,2,"kkz",text="kk",values=("2"))
myidx1=tree.insert(myid,1,"招投标结果",text="风险分析",values=("6"))
myidx11=tree.insert(myidx1,0,"是否发行失败",text="年化收益率",values=("5"))
myidx11=tree.insert(myidx1,1,"最终票面利率",text="平均收益率",values=("5"))
myidx11=tree.insert(myidx1,2,"应投家数",text="最大回撤",values=("5"))
myidx11=tree.insert(myidx1,3,"投标家数",text="相关系数",values=("5"))
myidx11=tree.insert(myidx1,4,"投标笔数",text="可决系数",values=("5"))
myidx11=tree.insert(myidx1,5,"年化波动率",text="年化波动率",values=("5"))
myidx11=tree.insert(myidx1,6,"下行风险",text="下行风险",values=("5"))
myidx11=tree.insert(myidx1,7,"Alpha",text="Alpha",values=("5"))
myidx11=tree.insert(myidx1,8,"beta",text="beta",values=("5"))
myidx11=tree.insert(myidx1,9,"Sharpe（年化）",text="Sharpe（年化）",values=("5"))
myidx11=tree.insert(myidx1,10,"Jensen（年化）",text="Jensen（年化）",values=("5"))
myidx1=tree.insert(myid,4,"中介机构",text="选时选股",values=("7"))
myidx11=tree.insert(myidx1,2,"kk7",text="是否发行失败",values=("5"))
myidx2=tree.insert(myid,5,"发行费用",text="风格分析",values=("8"))
myidx11=tree.insert(myidx2,2,"kk8",text="是否发行失败",values=("5"))
myidx1=tree.insert(myid,6,"兑付资料",text="绝对收益",values=("9"))
myidx11=tree.insert(myidx1,2,"kk9",text="是否发行失败",values=("5"))
myid=tree.insert("",5,"风险分析",text="基金分红",values=("2"))
myidx1=tree.insert(myid,0,"股本4",text="股本4",values=("1"))
myid=tree.insert("",6,"盈利预测",text="基金规模",values=("2"))
myidx1=tree.insert(myid,0,"股本5",text="股本5",values=("1"))
myid=tree.insert("",7,"财务分析",text="持有人结构",values=("2"))
myidx1=tree.insert(myid,0,"股本6",text="股本6",values=("1"))
myid=tree.insert("",8,"标准券折算比例",text="投资组合",values=("2"))
myidx1=tree.insert(myid,0,"股本7",text="股本7",values=("1"))
myid=tree.insert("",9,"分红指标",text="财务指标",values=("2"))
myidx1=tree.insert(myid,0,"股本8",text="股本8",values=("1"))
myid=tree.insert("",10,"财务报表",text="财务报表",values=("2"))
myidx1=tree.insert(myid,0,"股本9",text="股本9",values=("1"))
tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='待选范围', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
myid=tree.insert("",0,"市场类",text="中国公募产品",values=("0"))
myidx1=tree.insert(myid,0,"股本",text="股本",values=("1"))
myid=tree.insert("",1,"科创板类",text="中国非公募产品",values=("2"))
myidx1=tree.insert(myid,0,"总股本",text="总股本",values=("3"))
myid=tree.insert("",2,"创业板类",text="RQFII基金",values=("2"))
myidx1=tree.insert(myid,0,"股本1",text="股本1",values=("1"))
myid=tree.insert("",3,"证监会行业类",text="香港公募基金",values=("2"))
myidx1=tree.insert(myid,0,"股本2",text="股本2",values=("1"))
myid=tree.insert("",4,"申银万国行业类",text="美国公募基金",values=("2"))
myidx1=tree.insert(myid,0,"股本3",text="股本3",values=("1"))
myid=tree.insert("",5,"中信证券行业类",text="我的自选基金",values=("2"))
myidx1=tree.insert(myid,0,"股本4",text="股本4",values=("1"))
tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Label(mainCol1, text='条件列表', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
tree = ttk.Treeview(mainCol1, columns=('col1','col2','col3','col4','col5','col6','col7'))
tree.column('col1', width=100, anchor='center')
tree.column('col2', width=100, anchor='center')
tree.column('col3', width=100, anchor='center')
tree.column('col4', width=100, anchor='center')
tree.column('col5', width=100, anchor='center')
tree.column('col6', width=100, anchor='center')
tree.column('col7', width=100, anchor='center')
tree.heading('col1', text='序号')
tree.heading('col2', text='指标')
tree.heading('col3', text='参数')
tree.heading('col4', text='运算符')
tree.heading('col5', text='数值')
tree.heading('col6', text='单位')
tree.heading('col7', text='显示')
tree.insert('',0,values=('#3', 'Sharpe(年化)','截止日52周前;最新收盘日;周;普通收益率;一年定存利率(税前)','', '', '', '☑'))
tree.insert('',0,values=('#2', '上海证券3年评级(夏普比率)','2020;1月','>', '0', '', '☑'))
tree.insert('',0,values=('#1', '年涨跌幅','最新收盘日','>', '0', '%', '☑'))
tree.pack()

mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='条件表达式：', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#585570')
e1.insert(0, '#1 and #2')
e1.pack()
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='执行筛选', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='保存方案', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='方案导出', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='方案导入', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Button(mainCol1, text='导出到Excel', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='每页', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("20","51","52","53")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='条', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

df1 = pd.read_excel(R"D:\work\佳期投资分析系统\基金筛选.xlsx", encoding="GBK")

mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='序号', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in range(20):
    label1 = Label(mainCol1, text=col+1, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='证券代码', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["证券代码"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='证券简称', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["证券简称"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='年涨跌幅 %', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["年涨跌幅\n[交易日期] 最新收盘日\n[单位] %"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='上海证券3年评级(夏普比率)', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["上海证券3年评级(夏普比率)\n[年度] 2020\n[月份] 1月"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='Sharpe(年化)', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["Sharpe(年化)\n[起始交易日期] 截止日52周前\n[截止交易日期] 最新收盘日\n[计算周期] 周\n[收益率计算方法] 普通收益率\n[无风险收益率] 一年定存利率（税前）"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

window.mainloop()

# %% [markdown]
# ### 股票数据浏览器-查看时序图

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker

window= Tk()
window.title("佳期技术大数据库管理系统")

menu_widget = Menu(window)
menu_widget.add_command(label="条件筛选")
menu_widget.add_command(label="数据浏览器")
menu_widget.add_command(label="行情序列")
menu_widget.add_command(label="纵向比较")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar2 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar7 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar8 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar9 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar10 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar11 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar12 = PanedWindow(sidebar11, orient="horizontal", bg='#FFFFE1')
sidebar13 = PanedWindow(sidebar11, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)
main.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)
sidebar2.add(sidebar6)
sidebar2.add(sidebar7)
sidebar3.add(sidebar8)
sidebar3.add(sidebar9)
sidebar3.add(sidebar10)
sidebar3.add(sidebar11)
sidebar11.add(sidebar12)
sidebar11.add(sidebar13)

mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="条件筛选", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='条件选股', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='数据浏览器', fg='#F9F900', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='股票数据浏览器', fg='#F9F900', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='新三板数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期权数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商资管数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='私募数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="银行理财数据浏览器", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='信托数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='保险数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期货数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='板块数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='行情序列', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='沪深股票', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='指数', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='纵向比较', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="财务纵比", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金比较", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金公司比较", fg='#f7fafc', bg='green')
title.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='待选指标', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
kk=tree.insert("",0,"沪深股票指标",text="沪深股票指标",values=("0"))
myid=tree.insert(kk,0,"基本资料",text="基本资料",values=("0"))
myidx1=tree.insert(myid,0,"股本56",text="股本指标",values=("1"))

myidx=tree.insert(kk,1,"股本指标",text="股本指标",values=("0"))
myidx11=tree.insert(myidx,1,"最终票面利率",text="流通A股",values=("5"))
myidx11=tree.insert(myidx,2,"应投家数",text="限售A股",values=("5"))
myidx11=tree.insert(myidx,3,"投标家数",text="A股合计",values=("5"))
myidx11=tree.insert(myidx,4,"投标笔数",text="流通B股",values=("5"))
myidx11=tree.insert(myidx,5,"年化波动率",text="限售B股",values=("5"))
myidx11=tree.insert(myidx,6,"下行风险",text="B股合计",values=("5"))
myidx11=tree.insert(myidx,7,"Alpha",text="三板合计",values=("5"))
myidx11=tree.insert(myidx,8,"beta",text="香港上市股",values=("5"))
myidx11=tree.insert(myidx,9,"Sharpe（年化）",text="海外上市股",values=("5"))
myidx11=tree.insert(myidx,10,"Jensen（年化）",text="流通股合计",values=("5"))
myidx11=tree.insert(myidx,11,"Jensen（年化1）",text="限售股合计",values=("5"))
myidx1=tree.insert(myid,4,"中介机构",text="占总股本百分比",values=("7"))
myidx11=tree.insert(myidx1,2,"kk7",text="是否发行失败",values=("5"))
myidx2=tree.insert(myid,5,"发行费用",text="限售股份明细",values=("8"))
myidx11=tree.insert(myidx2,2,"kk8",text="是否发行失败",values=("5"))
myidx1=tree.insert(myid,6,"兑付资料",text="解禁股本",values=("9"))
myidx11=tree.insert(myidx1,2,"kk9",text="是否发行失败",values=("5"))

myid=tree.insert(kk,2,"业绩表现",text="股东指标",values=("2"))
myidx1=tree.insert(myid,0,"股本333",text="股本3",values=("1"))
myid=tree.insert(kk,3,"行情指标",text="行情指标",values=("2"))
myidx1=tree.insert(myid,0,"股本1",text="股本1",values=("1"))
myid=tree.insert(kk,4,"债券估值",text="估值指标",values=("2"))
myidx1=tree.insert(myid,0,"股本2",text="股本2",values=("1"))
myid=tree.insert(kk,5,"估值指标",text="风险分析",values=("2"))
myidx1=tree.insert(myid,0,"股本3",text="股本3",values=("1"))
myid=tree.insert(kk,6,"风险分析",text="盈利预测",values=("2"))
myidx1=tree.insert(myid,0,"股本4",text="股本4",values=("1"))
myid=tree.insert(kk,7,"盈利预测",text="财务分析",values=("2"))
myidx1=tree.insert(myid,0,"股本5",text="股本5",values=("1"))
myid=tree.insert(kk,8,"财务分析",text="财务报表",values=("2"))
myidx1=tree.insert(myid,0,"股本6",text="股本6",values=("1"))
myid=tree.insert(kk,9,"标准券折算比例",text="首发(IPO)指标",values=("2"))
myidx1=tree.insert(myid,0,"股本7",text="股本7",values=("1"))

kk=tree.insert("",1,"沪深股票指标1",text="全球股票指标",values=("0"))
myid=tree.insert(kk,0,"基本资料1",text="基本资料",values=("0"))

kk=tree.insert("",2,"沪深股票指标2",text="台股全部指标",values=("0"))
myid=tree.insert(kk,0,"基本资料2",text="基本资料",values=("0"))

tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='待选范围', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
myid=tree.insert("",0,"市场类",text="沪深股票",values=("0"))
myidx1=tree.insert(myid,0,"股本",text="股本",values=("1"))
myid=tree.insert("",1,"科创板类",text="香港股票",values=("2"))
myidx1=tree.insert(myid,0,"总股本",text="总股本",values=("3"))
myid=tree.insert("",2,"创业板类",text="台湾股票",values=("2"))
myidx1=tree.insert(myid,0,"股本1",text="股本1",values=("1"))
myid=tree.insert("",3,"证监会行业类",text="全球股票",values=("2"))
myidx1=tree.insert(myid,0,"股本2",text="股本2",values=("1"))
myid=tree.insert("",4,"申银万国行业类",text="金融机构",values=("2"))
myidx1=tree.insert(myid,0,"股本3",text="股本3",values=("1"))
myid=tree.insert("",5,"中信证券行业类",text="我的自选股",values=("2"))
myidx1=tree.insert(myid,0,"股本4",text="股本4",values=("1"))
tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='提取数据', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='导出数据', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='整体统计', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='分组统计', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='查看时序图', fg='#f7fafc', bg='green')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

df1 = pd.read_excel(R"D:\work\佳期投资分析系统\股票数据浏览器.xlsx", encoding="GBK")

mainCol1 = Frame(sidebar9, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='序号', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in range(20):
    label1 = Label(mainCol1, text=col+1, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='证券代码', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["证券代码"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='证券简称', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["证券简称"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='A股合计\n[交易日期] 最新\n[单位] 股', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["A股合计\r\n[交易日期] 最新\r\n[单位] 股"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='流通A股\n[交易日期] 最新\n[单位] 股', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["流通A股\r\n[交易日期] 最新\r\n[单位] 股"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='限售A股\n[交易日期] 最新\n[单位] 股', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["限售A股\r\n[交易日期] 最新\r\n[单位] 股"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')


    
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='起始日期：', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("2019/ 6/29","亚太")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='截止日期：', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("2020/ 6/29","中国")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='周期：', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("日","中国")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol = Frame(sidebar12, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar12.add(mainCol)

fig, ax = plt.subplots(figsize=(10, 8))
df1 = pd.read_excel(r"D:\work\佳期投资分析系统\平安银行.xlsx")
ax.plot(df1["日期"], df1["平安银行"], label='平安银行')
ax.xaxis.set_major_formatter(mdate.DateFormatter('%Y/%m'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.legend()

ax.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)

plt.subplots_adjust(hspace=0.1)
    
canvas = FigureCanvasTkAgg(fig, master=mainCol)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()


mainCol = Frame(sidebar13, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar13.add(mainCol)
C1 = Checkbutton(sidebar13, text = "总股本[交易日期] 最新[单位] 股", bg='#FFFFE1')
C2 = Checkbutton(sidebar13, text = "流通A股[交易日期] 最新[单位] 股", bg='#FFFFE1')
C3 = Checkbutton(sidebar13, text = "限售A股[交易日期] 最新[单位] 股", bg='#FFFFE1')
C4 = Checkbutton(sidebar13, text = "A股合计[交易日期] 最新[单位] 股", bg='#FFFFE1')
C1.pack()
C2.pack()
C3.pack()
C4.pack()

window.mainloop()
# Out:
# C:\Users\win\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### 板块数据浏览器

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker

window= Tk()
window.title("佳期技术大数据库管理系统")

menu_widget = Menu(window)
menu_widget.add_command(label="条件筛选")
menu_widget.add_command(label="数据浏览器")
menu_widget.add_command(label="行情序列")
menu_widget.add_command(label="纵向比较")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar2 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar7 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar8 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar9 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar10 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar11 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)
main.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)
sidebar2.add(sidebar6)
sidebar2.add(sidebar7)
sidebar3.add(sidebar8)
sidebar3.add(sidebar9)
sidebar3.add(sidebar10)
sidebar3.add(sidebar11)


mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="条件筛选", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='条件选股', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='数据浏览器', fg='#F9F900', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='股票数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='新三板数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期权数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商资管数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='私募数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="银行理财数据浏览器", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='信托数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='保险数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期货数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='板块数据浏览器', fg='#F9F900', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='行情序列', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='沪深股票', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='指数', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='纵向比较', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="财务纵比", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金比较", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金公司比较", fg='#f7fafc', bg='green')
title.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='待选指标', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
myid=tree.insert("",0,"基本资料",text="基本资料",values=("0"))
myidx1=tree.insert(myid,0,"股本56",text="股本指标",values=("1"))
myid=tree.insert("",1,"股本指标",text="股本指标",values=("0"))
myidx1=tree.insert(myid,0,"股本33",text="股本3",values=("1"))
myid=tree.insert("",2,"业绩表现",text="机构持股",values=("2"))
myidx1=tree.insert(myid,0,"股本333",text="股本3",values=("1"))
myid=tree.insert("",3,"行情指标",text="薪酬指标",values=("2"))
myidx1=tree.insert(myid,0,"股本1",text="股本1",values=("1"))
myidx=tree.insert("",4,"债券估值",text="行情指标",values=("2"))
myidx11=tree.insert(myidx,1,"最终票面利率",text="收盘价（算术平均）",values=("5"))
myidx11=tree.insert(myidx,2,"应投家数",text="收盘价（总股本加权平均）",values=("5"))
myidx11=tree.insert(myidx,3,"投标家数",text="收盘价（流通股本加权平均）",values=("5"))
myidx11=tree.insert(myidx,4,"投标笔数",text="成交量（平均）",values=("5"))
myidx11=tree.insert(myidx,5,"年化波动率",text="成交量（合计）",values=("5"))
myidx11=tree.insert(myidx,6,"下行风险",text="成分区间涨跌幅",values=("5"))
myidx11=tree.insert(myidx,7,"Alpha",text="成分区间成交量",values=("5"))
myidx11=tree.insert(myidx,8,"beta",text="涨停家数",values=("5"))
myidx11=tree.insert(myidx,9,"Sharpe（年化）",text="跌停家数",values=("5"))
myidx11=tree.insert(myidx,10,"Jensen（年化）",text="上涨家数",values=("5"))
myidx11=tree.insert(myidx,11,"Jensen（年化1）",text="下跌家数",values=("5"))
myidx11=tree.insert(myidx,12,"Jensen（年化2）",text="本周涨跌幅",values=("5"))
myidx11=tree.insert(myidx,13,"Jensen（年化3）",text="上周涨跌幅",values=("5"))
myid=tree.insert("",5,"估值指标",text="融资融券",values=("2"))
myidx1=tree.insert(myid,0,"股本3",text="股本3",values=("1"))
myid=tree.insert("",6,"风险分析",text="资金流向",values=("2"))
myidx1=tree.insert(myid,0,"股本4",text="股本4",values=("1"))
myid=tree.insert("",7,"盈利预测",text="估值指标",values=("2"))
myidx1=tree.insert(myid,0,"股本5",text="股本5",values=("1"))
myid=tree.insert("",8,"财务分析",text="财务报表",values=("2"))
myidx1=tree.insert(myid,0,"股本6",text="股本6",values=("1"))
myid=tree.insert("",9,"标准券折算比例",text="风险指标",values=("2"))
myidx1=tree.insert(myid,0,"股本7",text="股本7",values=("1"))

tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='待选范围', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
myid=tree.insert("",0,"市场类",text="市场类",values=("0"))
myidx1=tree.insert(myid,0,"股本",text="股本",values=("1"))
myid=tree.insert("",1,"科创板类",text="证监会行业类",values=("2"))
myidx1=tree.insert(myid,0,"总股本",text="总股本",values=("3"))
myid=tree.insert("",2,"创业板类",text="申万行业类",values=("2"))
myidx1=tree.insert(myid,0,"股本1",text="股本1",values=("1"))
myid=tree.insert("",3,"证监会行业类",text="中信证券行业分类",values=("2"))
myidx1=tree.insert(myid,0,"股本2",text="股本2",values=("1"))
myid=tree.insert("",4,"申银万国行业类",text="申万行业类",values=("2"))
myidx1=tree.insert(myid,0,"股本3",text="股本3",values=("1"))
myid=tree.insert("",5,"中信证券行业类",text="概念类",values=("2"))
myidx1=tree.insert(myid,0,"股本4",text="股本4",values=("1"))
myid=tree.insert("",6,"中信证券行业类1",text="地域类",values=("2"))
myidx1=tree.insert(myid,0,"股本5",text="股本4",values=("1"))
myid=tree.insert("",7,"中信证券行业类2",text="指数成分",values=("2"))
myidx1=tree.insert(myid,0,"股本6",text="股本4",values=("1"))

tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='提取数据', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='导出数据', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='整体统计', fg='#f7fafc', bg='green')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='分组统计', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='查看时序图', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

df1 = pd.read_excel(r"D:\work\佳期投资分析系统\板块数据浏览器.xls", encoding="GBK")

mainCol1 = Frame(sidebar9, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='序号', fg='#585570', bg='#FFFFE1', height=4, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in range(20):
    label1 = Label(mainCol1, text=col+1, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='板块名称', fg='#585570', bg='#FFFFE1', height=4, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["板块名称"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='成份区间涨跌幅(流通市值加权平均)\n[起始交易日期]本年初\n[截止交易日期]2020-06-29\n[单位]%', fg='#585570', bg='#FFFFE1', height=4, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["成份区间涨跌幅(流通市值加权平均)\r\n[起始交易日期]本年初\r\n[截止交易日期]2020-06-29\r\n[单位]%"].values[:20]:
    label1 = Label(mainCol1, text=round(col,2), fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='涨停家数\n[交易日期]2020-06-29', fg='#585570', bg='#FFFFE1', height=4, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["涨停家数\r\n[交易日期]2020-06-29"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='跌停家数\n[交易日期]2020-06-29', fg='#585570', bg='#FFFFE1', height=4, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["跌停家数\r\n[交易日期]2020-06-29"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='本周涨跌幅\n[单位]%', fg='#585570', bg='#FFFFE1', height=4, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["本周涨跌幅\r\n[单位]%"].values[:20]:
    label1 = Label(mainCol1, text=round(col,2), fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='上周涨跌幅\n[单位]%', fg='#585570', bg='#FFFFE1', height=4, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["上周涨跌幅\r\n[单位]%"].values[:20]:
    label1 = Label(mainCol1, text=round(col,2), fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

    
mainCol = Frame(sidebar10, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar10.add(mainCol)
C1 = Checkbutton(mainCol, text = "总和", bg='#FFFFE1')
C2 = Checkbutton(mainCol, text = "计数", bg='#FFFFE1')
C1.pack()
C2.pack()
mainCol = Frame(sidebar10, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar10.add(mainCol)
C3 = Checkbutton(mainCol, text = "算数平均", bg='#FFFFE1')
C4 = Checkbutton(mainCol, text = "中位数", bg='#FFFFE1')
C3.pack()
C4.pack()
mainCol = Frame(sidebar10, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar10.add(mainCol)
C5 = Checkbutton(mainCol, text = "加权平均（从下拉框中选择加权因子）", bg='#FFFFE1')
C5.pack()
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol,textvariable=comvalue) #初始化
comboxlist["values"]=("1.收盘价（流通股本加权平均）","中国")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol = Frame(sidebar10, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar10.add(mainCol)
C1 = Checkbutton(mainCol, text = "最大", bg='#FFFFE1')
C2 = Checkbutton(mainCol, text = "最小", bg='#FFFFE1')
C1.pack()
C2.pack()
mainCol = Frame(sidebar10, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar10.add(mainCol)
C1 = Checkbutton(mainCol, text = "标准差", bg='#FFFFE1')
C2 = Checkbutton(mainCol, text = "总体标准差", bg='#FFFFE1')
C1.pack()
C2.pack()
mainCol = Frame(sidebar10, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar10.add(mainCol)
C1 = Checkbutton(mainCol, text = "方差", bg='#FFFFE1')
C2 = Checkbutton(mainCol, text = "总体方差", bg='#FFFFE1')
C1.pack()
C2.pack()
mainCol = Frame(sidebar10, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar10.add(mainCol)
C1 = Label(mainCol, text = "", bg='#FFFFE1')
C1.pack()

mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
for col in df1["板块名称"].values[-11:]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
for col in df1["成份区间涨跌幅(流通市值加权平均)\r\n[起始交易日期]本年初\r\n[截止交易日期]2020-06-29\r\n[单位]%"].values[-11:]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
for col in df1["涨停家数\r\n[交易日期]2020-06-29"].values[-11:]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
for col in df1["跌停家数\r\n[交易日期]2020-06-29"].values[-11:]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
for col in df1["本周涨跌幅\r\n[单位]%"].values[-11:]:
    label1 = Label(mainCol1, text=round(col,2), fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
for col in df1["上周涨跌幅\r\n[单位]%"].values[-11:]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

window.mainloop()

# %% [markdown]
# ### 行情序列

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker

window= Tk()
window.title("佳期技术大数据库管理系统")

menu_widget = Menu(window)
menu_widget.add_command(label="条件筛选")
menu_widget.add_command(label="数据浏览器")
menu_widget.add_command(label="行情序列")
menu_widget.add_command(label="纵向比较")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar00 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar0 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar000 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar2 = PanedWindow(sidebar000, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(sidebar000, orient="vertical", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar000, orient="vertical", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar000, orient="vertical", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar7 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar8 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar9 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar10 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar11 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar12 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar13 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar14 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar15 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar16 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar17 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar18 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar19 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar20 = PanedWindow(sidebar5, orient="horizontal", bg='#FFFFE1')
sidebar21 = PanedWindow(sidebar5, orient="horizontal", bg='#FFFFE1')
sidebar22 = PanedWindow(sidebar5, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar00)
sidebar00.add(sidebar0)
sidebar00.add(sidebar000)
sidebar000.add(sidebar2)
sidebar000.add(sidebar3)
sidebar000.add(sidebar4)
sidebar000.add(sidebar5)
sidebar2.add(sidebar6)
sidebar2.add(sidebar7)
sidebar2.add(sidebar8)
sidebar2.add(sidebar9)
sidebar2.add(sidebar10)
sidebar2.add(sidebar11)
sidebar3.add(sidebar12)
sidebar3.add(sidebar13)
sidebar3.add(sidebar14)
sidebar3.add(sidebar15)
sidebar3.add(sidebar16)
sidebar3.add(sidebar17)
sidebar3.add(sidebar18)
sidebar3.add(sidebar19)
sidebar5.add(sidebar20)
sidebar5.add(sidebar21)
sidebar5.add(sidebar22)

mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
label1 = Label(mainCol1, text='证券类型：', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("沪深股票","中国")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="条件筛选", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='条件选股', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='股票数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='新三板数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期权数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商资管数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='私募数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="银行理财数据浏览器", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='信托数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='保险数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期货数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='板块数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='行情序列', fg='#F9F900', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='沪深股票', fg='#F9F900', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='指数', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='纵向比较', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="财务纵比", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金比较", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金公司比较", fg='#f7fafc', bg='green')
title.pack(fill='x')

mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='范围', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
vsb = ttk.Scrollbar(mainCol1, orient="vertical", command=tree.yview)
vsb.pack(side='right', fill='y')
myidx=tree.insert("",0,"基本资料",text="市场类",values=("0"))
myidx11=tree.insert(myidx,1,"最终票面利率1",text="全部A股",values=("5"))
myidx11=tree.insert(myidx,2,"应投家数",text="上证A股",values=("5"))
myidx11=tree.insert(myidx,3,"投标家数",text="上证主板A股",values=("5"))
myidx11=tree.insert(myidx,4,"投标笔数",text="科创板",values=("5"))
myidx11=tree.insert(myidx,5,"年化波动率",text="深证A股",values=("5"))
myidx11=tree.insert(myidx,6,"下行风险",text="深证主板A股",values=("5"))
myidx11=tree.insert(myidx,7,"Alpha",text="中小企业板",values=("5"))
myidx11=tree.insert(myidx,8,"beta",text="创业板",values=("5"))
myidx11=tree.insert(myidx,9,"Sharpe（年化）",text="沪股通",values=("5"))
myidx11=tree.insert(myidx,10,"Jensen（年化）",text="深股通",values=("5"))
myidx11=tree.insert(myidx,11,"Jensen（年化1）",text="陆股通（含沪深两市）",values=("5"))
myid=tree.insert("",1,"股本指标",text="科创板类",values=("0"))
myidx1=tree.insert(myid,0,"股本33",text="股本3",values=("1"))
myid=tree.insert("",2,"业绩表现",text="创业板类",values=("2"))
myidx1=tree.insert(myid,0,"股本333",text="股本3",values=("1"))
myid=tree.insert("",3,"行情指标",text="证监会行业类",values=("2"))
myidx1=tree.insert(myid,0,"股本1",text="股本1",values=("1"))
myidx=tree.insert("",4,"债券估值",text="申银万国行业类",values=("2"))
myidx11=tree.insert(myidx,1,"最终票面利率",text="收盘价（算术平均）",values=("5"))
myid=tree.insert("",5,"估值指标",text="中信证券行业类",values=("2"))
myidx1=tree.insert(myid,0,"股本3",text="股本3",values=("1"))
myid=tree.insert("",6,"风险分析",text="中证指数行业类",values=("2"))
myidx1=tree.insert(myid,0,"股本4",text="股本4",values=("1"))
myid=tree.insert("",7,"盈利预测",text="地域类",values=("2"))
myidx1=tree.insert(myid,0,"股本5",text="股本5",values=("1"))
myid=tree.insert("",8,"财务分析",text="证监会辖区类",values=("2"))
myidx1=tree.insert(myid,0,"股本6",text="股本6",values=("1"))
tree.configure(yscrollcommand=vsb.set)
tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Label(mainCol1, text='选择指标', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol = Frame(sidebar9, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar9.add(mainCol)
C1 = Checkbutton(mainCol, text = "开盘价", bg='#FFFFE1')
C2 = Checkbutton(mainCol, text = "最高价", bg='#FFFFE1')
C3 = Checkbutton(mainCol, text = "涨跌", bg='#FFFFE1')
C4 = Checkbutton(mainCol, text = "前收盘价", bg='#FFFFE1')
C1.pack()
C2.pack()
C3.pack()
C4.pack()
mainCol = Frame(sidebar9, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar9.add(mainCol)
C1 = Checkbutton(mainCol, text = "收盘价", bg='#FFFFE1')
C2 = Checkbutton(mainCol, text = "最低价", bg='#FFFFE1')
C3 = Checkbutton(mainCol, text = "涨跌幅", bg='#FFFFE1')
C4 = Checkbutton(mainCol, text = "均价", bg='#FFFFE1')
C1.pack()
C2.pack()
C3.pack()
C4.pack()
mainCol = Frame(sidebar9, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar9.add(mainCol)
C1 = Label(mainCol, text = "", bg='#FFFFE1')
C1.pack()

mainCol = Frame(sidebar10, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar10.add(mainCol)
C5 = Label(mainCol, text = "复权方式", bg='#FFFFE1')
C5.pack()

mainCol = Frame(sidebar10, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar10.add(mainCol)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol,textvariable=comvalue) #初始化
comboxlist["values"]=("前复权","中国")
comboxlist.current(0)
comboxlist.pack(fill='x')

mainCol = Frame(sidebar11, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar11.add(mainCol)
C1 = Checkbutton(mainCol, text = "成交量", bg='#FFFFE1')
C2 = Checkbutton(mainCol, text = "成交金额", bg='#FFFFE1')
C3 = Checkbutton(mainCol, text = "换手率", bg='#FFFFE1')
C4 = Checkbutton(mainCol, text = "市盈率", bg='#FFFFE1')
C5 = Checkbutton(mainCol, text = "市净率", bg='#FFFFE1')
C6 = Checkbutton(mainCol, text = "市销率", bg='#FFFFE1')
C7 = Checkbutton(mainCol, text = "总市值", bg='#FFFFE1')
C1.pack()
C2.pack()
C3.pack()
C4.pack()
C5.pack()
C6.pack()
C7.pack()
mainCol = Frame(sidebar11, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar11.add(mainCol)
C1 = Checkbutton(mainCol, text = "A股流通市值", bg='#FFFFE1')
C2 = Checkbutton(mainCol, text = "B股流通市值", bg='#FFFFE1')
C3 = Checkbutton(mainCol, text = "总股本", bg='#FFFFE1')
C4 = Checkbutton(mainCol, text = "A股流通股本", bg='#FFFFE1')
C5 = Checkbutton(mainCol, text = "B股流通股本", bg='#FFFFE1')
C6 = Checkbutton(mainCol, text = "市现率", bg='#FFFFE1')
C1.pack()
C2.pack()
C3.pack()
C4.pack()
C5.pack()
C6.pack()
mainCol = Frame(sidebar11, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar11.add(mainCol)
C1 = Label(mainCol, text = "", bg='#FFFFE1')
C1.pack()

mainCol1 = Frame(sidebar12, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='待选产品列表', fg='#f7fafc', bg='green')
label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='总数[3874]', fg='red', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar13, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar13.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
vsb = ttk.Scrollbar(mainCol1, orient="vertical", command=tree.yview)
vsb.pack(side='right', fill='y')
myidx=tree.insert("",0,"基本资料",text="000001.SZ[平安银行]",values=("0"))
myid=tree.insert("",1,"股本指标",text="000002.SZ[万科A]",values=("0"))
myid=tree.insert("",2,"业绩表现",text="000004.SZ[国农科技]",values=("2"))
myid=tree.insert("",3,"行情指标",text="000005.SZ[世纪星源]",values=("2"))
myidx=tree.insert("",4,"债券估值",text="000006.SZ[深振业A]",values=("2"))
myid=tree.insert("",5,"估值指标",text="000007.SZ[全新好]",values=("2"))
myid=tree.insert("",6,"风险分析",text="000008.SZ[神州高铁]",values=("2"))
myid=tree.insert("",7,"盈利预测",text="000009.SZ[中国宝安]",values=("2"))
myid=tree.insert("",8,"财务分析",text="000010.SZ[*ST美丽]",values=("2"))
myidx=tree.insert("",9,"债券估值1",text="000011.SZ[深物业A]",values=("2"))
myid=tree.insert("",10,"估值指标1",text="000012.SZ[南玻A]",values=("2"))
myid=tree.insert("",11,"风险分析1",text="000014.SZ[沙河股份]",values=("2"))
myid=tree.insert("",12,"盈利预测1",text="000016.SZ[深康佳A]",values=("2"))
myid=tree.insert("",13,"财务分析1",text="000017.SZ[*ST中华A]",values=("2"))
myid=tree.insert("",14,"风险分析2",text="000019.SZ[深粮控股]",values=("2"))
myid=tree.insert("",15,"盈利预测2",text="000020.SZ[深华发A]",values=("2"))
myid=tree.insert("",16,"财务分析2",text="000021.SZ[*深科技]",values=("2"))
tree.configure(yscrollcommand=vsb.set)
tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar14, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar14.add(mainCol1)
label1 = Label(mainCol1, text='选择时间', fg='#f7fafc', bg='green')
label1.pack(fill='x')

v = tk.IntVar()
v.set(1)
mainCol = Frame(sidebar15, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar15.add(mainCol)
label1 = Label(mainCol, text='开始日期', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')


mainCol = Frame(sidebar15, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar15.add(mainCol)
r1 = tk.Radiobutton(mainCol, text='上市日', bg='#FFFFE1',value=2)
r1.pack(fill='x')  
r1 = tk.Radiobutton(mainCol, text='可选日', bg='#FFFFE1',value=2)
r1.pack(fill='x') 


mainCol = Frame(sidebar15, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar15.add(mainCol)
label1 = Label(mainCol, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol,textvariable=comvalue) #初始化
comboxlist["values"]=("2017/11/ 1","中国")
comboxlist.current(0)
comboxlist.pack(fill='x')

v = tk.IntVar()
v.set(1)
mainCol = Frame(sidebar16, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar16.add(mainCol)
label1 = Label(mainCol, text='结束日期', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol = Frame(sidebar16, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar16.add(mainCol)
r1 = tk.Radiobutton(mainCol, text='最新 ', bg='#FFFFE1',value=2)
r1.pack(fill='x')  
r1 = tk.Radiobutton(mainCol, text='可选日', bg='#FFFFE1',value=2)
r1.pack(fill='x') 


mainCol = Frame(sidebar16, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar16.add(mainCol)
label1 = Label(mainCol, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol,textvariable=comvalue) #初始化
comboxlist["values"]=("2018/10/31","中国")
comboxlist.current(0)
comboxlist.pack(fill='x')

mainCol1 = Frame(sidebar17, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar17.add(mainCol1)
label1 = Label(mainCol1, text='选择格式', fg='#f7fafc', bg='green')
label1.pack(fill='x')

v = tk.IntVar()
v.set(1)
mainCol = Frame(sidebar18, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar18.add(mainCol)
label1 = Label(mainCol, text='时间格式', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol = Frame(sidebar18, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar18.add(mainCol)
r1 = tk.Radiobutton(mainCol, text='YYYY-MM-DD', bg='#FFFFE1',value=0)
r1.pack(fill='x')  

v = tk.IntVar()
v.set(1)
mainCol = Frame(sidebar19, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar19.add(mainCol)
label1 = Label(mainCol, text='文件格式', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol = Frame(sidebar19, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar19.add(mainCol)
r1 = tk.Radiobutton(mainCol, text='EXCEL', bg='#FFFFE1',value=2)
r1.pack(fill='x')  
mainCol = Frame(sidebar19, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar19.add(mainCol)
r1 = tk.Radiobutton(mainCol, text='DBF', bg='#FFFFE1',value=2)
r1.pack(fill='x')  
mainCol = Frame(sidebar19, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar19.add(mainCol)
r1 = tk.Radiobutton(mainCol, text='CSV', bg='#FFFFE1',value=2)
r1.pack(fill='x')  

mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
title = Button(mainCol1, text=">>", fg='#585570', bg='#FFFFE1')
title.pack(fill='x')
title = Button(mainCol1, text="<", fg='#585570', bg='#FFFFE1')
title.pack(fill='x')
label1 = Label(mainCol1, text='', fg='#f7fafc', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text='', fg='#f7fafc', bg='#FFFFE1')
label1.pack(fill='x')
title = Button(mainCol1, text="<<", fg='#585570', bg='#FFFFE1')
title.pack(fill='x')
title = Button(mainCol1, text="<", fg='#585570', bg='#FFFFE1')
title.pack(fill='x')

mainCol1 = Frame(sidebar20, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar20.add(mainCol1)
label1 = Label(mainCol1, text='已选产品列表', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar22, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar22.add(mainCol1)
title = Button(mainCol1, text="导出数据", fg='#585570', bg='#FFFFE1')
title.pack(fill='x')

mainCol1 = Frame(sidebar22, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar22.add(mainCol1)
title = Button(mainCol1, text="停止导出", fg='#585570', bg='#FFFFE1')
title.pack(fill='x')

window.mainloop()

# %% [markdown]
# ### 财务纵比

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker

window= Tk()
window.title("佳期技术大数据库管理系统")

menu_widget = Menu(window)
menu_widget.add_command(label="条件筛选")
menu_widget.add_command(label="数据浏览器")
menu_widget.add_command(label="行情序列")
menu_widget.add_command(label="纵向比较")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar00 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar0 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar000 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar2 = PanedWindow(sidebar000, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(sidebar000, orient="vertical", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar7 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar8 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar9 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar10 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar11 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar12 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar13 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar14 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar15 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar00)
sidebar00.add(sidebar0)
sidebar00.add(sidebar000)
sidebar000.add(sidebar2)
sidebar000.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)
sidebar2.add(sidebar6)
sidebar2.add(sidebar7)
sidebar2.add(sidebar8)
sidebar2.add(sidebar9)
sidebar3.add(sidebar10)
sidebar3.add(sidebar11)
sidebar3.add(sidebar12)
sidebar3.add(sidebar13)
sidebar3.add(sidebar14)
sidebar3.add(sidebar15)

mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
label1 = Button(mainCol1, text='提取数据', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
label1 = Button(mainCol1, text='数据导出', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="条件筛选", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='条件选股', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='股票数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='新三板数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期权数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商资管数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='私募数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="银行理财数据浏览器", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='信托数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='保险数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期货数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='板块数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='行情序列', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='沪深股票', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='指数', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='纵向比较', fg='#F9F900', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="财务纵比", fg='#F9F900', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金比较", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金公司比较", fg='#f7fafc', bg='green')
title.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='待选指标', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
vsb = ttk.Scrollbar(mainCol1, orient="vertical", command=tree.yview)
vsb.pack(side='right', fill='y')
myid=tree.insert("",0,"基本资料",text="股本指标",values=("0"))
myidx1=tree.insert(myid,0,"股本56",text="股本指标",values=("1"))
myidx=tree.insert("",1,"股本指标",text="财务分析",values=("0"))
myidx11=tree.insert(myidx,1,"最终票面利率",text="每股指标",values=("5"))
myidx111=tree.insert(myidx11,9,"Sharpe（年化）",text="跌停家数",values=("5"))
myidx11=tree.insert(myidx,2,"应投家数",text="盈利能力",values=("5"))
myidx111=tree.insert(myidx11,0,"Jensen（年化）1",text="净资产收益率",values=("5"))
myidx111=tree.insert(myidx11,1,"Jensen（年化）2",text="总资产报酬率",values=("5"))
myidx111=tree.insert(myidx11,2,"Jensen（年化）3",text="净利润/营业收入",values=("5"))
myidx111=tree.insert(myidx11,3,"Jensen（年化）4",text="息税前利润/营业总收入",values=("5"))
myidx111=tree.insert(myidx11,4,"Jensen（年化）5",text="销售净利润",values=("5"))
myidx111=tree.insert(myidx11,5,"Jensen（年化）6",text="总资产净利润",values=("5"))
myidx111=tree.insert(myidx11,6,"Jensen（年化）7",text="营业利润/营业总收入",values=("5"))
myidx111=tree.insert(myidx11,7,"Jensen（年化）8",text="营业总成本/营业总收入",values=("5"))
myidx111=tree.insert(myidx11,8,"Jensen（年化）9",text="管理费用/营业总收入",values=("5"))
myidx111=tree.insert(myidx11,9,"Jensen（年化）10",text="销售费用/营业总收入",values=("5"))
myidx11=tree.insert(myidx,3,"投标家数",text="收益质量",values=("5"))
myidx111=tree.insert(myidx11,10,"Jensen（年化）",text="上涨家数",values=("5"))
myidx11=tree.insert(myidx,4,"投标笔数",text="资本结构",values=("5"))
myidx111=tree.insert(myidx11,11,"Jensen（年化1）",text="下跌家数",values=("5"))
myidx11=tree.insert(myidx,5,"年化波动率",text="偿债能力",values=("5"))
myidx111=tree.insert(myidx11,12,"Jensen（年化2）",text="本周涨跌幅",values=("5"))
myidx11=tree.insert(myidx,6,"下行风险",text="营运能力",values=("5"))
myidx111=tree.insert(myidx11,13,"Jensen（年化3）",text="上周涨跌幅",values=("5"))
myidx11=tree.insert(myidx,7,"Alpha",text="现金流量",values=("5"))
myidx111=tree.insert(myidx11,13,"Jensen（年化4）",text="上周涨跌幅",values=("5"))
myidx11=tree.insert(myidx,8,"beta",text="成长能力",values=("5"))
myidx111=tree.insert(myidx11,13,"Jensen（年化5）",text="上周涨跌幅",values=("5"))
myid=tree.insert("",2,"业绩表现",text="财务报表（新准则）",values=("2"))
myidx1=tree.insert(myid,0,"股本333",text="股本3",values=("1"))
myid=tree.insert("",3,"行情指标",text="财务报表（旧报表，截至2006年）",values=("2"))
myidx1=tree.insert(myid,0,"股本1",text="股本1",values=("1"))
myidx=tree.insert("",4,"债券估值",text="报表附注",values=("2"))
myidx11=tree.insert(myidx,1,"最终票面利率1",text="收盘价（算术平均）",values=("5"))
tree.configure(yscrollcommand=vsb.set)
tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Button(mainCol1, text='搜索指标', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Button(mainCol1, text='增加指标', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
label1 = Label(mainCol1, text='股票列表', fg='#f7fafc', bg='green')
label1.pack(fill='x')
mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
C1 = Checkbutton(mainCol1, text = "多股票同列", bg='#FFFFE1')
C1.pack()

mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
vsb = ttk.Scrollbar(mainCol1, orient="vertical", command=tree.yview)
vsb.pack(side='right', fill='y')
myidx=tree.insert("",0,"基本资料",text="000001.SZ[平安银行]",values=("0"))
myid=tree.insert("",1,"盈利预测1",text="000016.SZ[深康佳A]",values=("2"))
myid=tree.insert("",2,"财务分析2",text="000031.SZ[大悦城]",values=("2"))
tree.configure(yscrollcommand=vsb.set)
tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Button(mainCol1, text='选择股票', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Button(mainCol1, text='删除', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Button(mainCol1, text='清空', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='时间范围', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar11, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
r1 = tk.Radiobutton(mainCol1, text='全部', bg='#FFFFE1',value=2)
r1.pack(fill='x')  
r1 = tk.Radiobutton(mainCol1, text='自定义', bg='#FFFFE1',value=2)
r1.pack(fill='x') 
mainCol = Frame(sidebar11, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar11.add(mainCol)
label1 = Label(mainCol, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol,textvariable=comvalue) #初始化
comboxlist["values"]=("2018","中国")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol = Frame(sidebar11, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar11.add(mainCol)
label1 = Label(mainCol, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol, text='到', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol = Frame(sidebar11, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar11.add(mainCol)
label1 = Label(mainCol, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol,textvariable=comvalue) #初始化
comboxlist["values"]=("2019","中国")
comboxlist.current(0)
comboxlist.pack(fill='x')

mainCol1 = Frame(sidebar12, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='报告期', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol = Frame(sidebar13, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar13.add(mainCol)
C1 = Checkbutton(mainCol, text = "0331", bg='#FFFFE1')
C1.pack()
mainCol = Frame(sidebar13, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar13.add(mainCol)
C1 = Checkbutton(mainCol, text = "0630", bg='#FFFFE1')
C1.pack()
mainCol = Frame(sidebar13, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar13.add(mainCol)
C1 = Checkbutton(mainCol, text = "0930", bg='#FFFFE1')
C1.pack()
mainCol = Frame(sidebar13, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar13.add(mainCol)
C1 = Checkbutton(mainCol, text = "1231", bg='#FFFFE1')
C1.pack()

mainCol1 = Frame(sidebar14, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar14.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
mainCol1 = Frame(sidebar14, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar14.add(mainCol1)
label1 = Label(mainCol1, text='2018-12-31', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
mainCol1 = Frame(sidebar14, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar14.add(mainCol1)
label1 = Label(mainCol1, text='2019-12-31', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='序号', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='指标名称', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='净利润收益率(%)', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='净利润/营业总收入(%)', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='息税前利润/营业总收入(%)', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='平安银行', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='10.74', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='21.26', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='深康佳A', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='5.51', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.45', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.12', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='大悦城', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='19.17', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='14.20', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='27.52', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='平安银行', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='10.20', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20.44', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='深康佳A', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.62', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='0.61', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.24', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='大悦城', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='17.44', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='10.97', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='22.21', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

window.mainloop()

# %% [markdown]
# ### 基金比较

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker

window= Tk()
window.title("佳期技术大数据库管理系统")

menu_widget = Menu(window)
menu_widget.add_command(label="条件筛选")
menu_widget.add_command(label="数据浏览器")
menu_widget.add_command(label="行情序列")
menu_widget.add_command(label="纵向比较")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar2 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar7 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar8 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar9 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar10 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar11 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar12 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar13 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar14 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar15 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)
main.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)
sidebar2.add(sidebar6)
sidebar2.add(sidebar7)
sidebar2.add(sidebar8)
sidebar3.add(sidebar9)
sidebar3.add(sidebar10)
sidebar3.add(sidebar11)
sidebar3.add(sidebar12)
sidebar3.add(sidebar13)
sidebar3.add(sidebar14)
sidebar3.add(sidebar15)

mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="条件筛选", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='条件选股', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='股票数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='新三板数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期权数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商资管数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='私募数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="银行理财数据浏览器", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='信托数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='保险数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期货数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='板块数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='行情序列', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='沪深股票', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='指数', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='纵向比较', fg='#F9F900', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="财务纵比", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金比较", fg='#F9F900', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金公司比较", fg='#f7fafc', bg='green')
title.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='待选指标', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
C1 = Checkbutton(mainCol1, text = "基金资料", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "规模对比", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "今年业绩表现", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "本月业绩表现", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "短期回报对比图", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "净值走势图表", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "年化回报图表", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "阿尔法对比图", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "回撤", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "资产配置图", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "行业配置对比", bg='#FFFFE1')
C1.pack()

mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='选择基准', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text='截止日期', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text='选择基金', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#585570')
e1.insert(0, '沪深300')
e1.pack()
e1 = tk.Entry(mainCol1, fg='#585570')
e1.insert(0, '2020-06-30')
e1.pack()
e1 = tk.Entry(mainCol1, fg='#585570')
e1.insert(0, '')
e1.pack()

mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
vsb = ttk.Scrollbar(mainCol1, orient="vertical", command=tree.yview)
vsb.pack(side='right', fill='y')
myidx=tree.insert("",0,"基本资料",text="519029.OF[华夏平稳增长]",values=("0"))
myid=tree.insert("",1,"盈利预测1",text="485005.OF[工银瑞信增强收益B]",values=("2"))
myid=tree.insert("",2,"财务分析2",text="110029.OF[易方达科讯]",values=("2"))
tree.configure(yscrollcommand=vsb.set)
tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='删除', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='清空', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Button(mainCol1, text='提取数据', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Button(mainCol1, text='导出PDF', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Button(mainCol1, text='导出Word', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='基金资料', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='基金名称', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='华夏平稳增长', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='工银瑞信增强收益B', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='易方达科讯', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='基金成立日', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2006-08-09', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2007-05-11', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2007-12-18', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='基金类型', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='灵活配置型', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='混合债券型一级', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='偏股混合型', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='基金规模(亿)', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='12.99', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.70', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='42.20', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='最新单位净值', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='2.2990', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.1096', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='1.5916', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='基金经理', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='彭海伟', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='杜海涛,张略钊', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='陈皓,刘健维', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='申购赎回状态', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='开放申购|开放赎回', fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar12, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='规模', fg='#f7fafc', bg='green')
label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#f7fafc', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar12, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='规模变动', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol = Frame(sidebar13, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar13.add(mainCol)

from matplotlib.ticker import FuncFormatter
fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(121)
ax1.bar(np.arange(1)-1, [12.99], label='华夏平稳增长')
ax1.bar(np.arange(1), [2.7], label='工银瑞信增强收益B')
ax1.bar(np.arange(1)+1, [42.20], label='易方达科讯')
ax1.set_ylabel('基金规模（亿）', fontsize=12)
ax1.legend()

ax1.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax1.spines['bottom'].set_color(axisColor)
ax1.spines['left'].set_color(axisColor)
ax1.tick_params(axis='x', colors=axisColor)
ax1.tick_params(axis='y', colors=axisColor)
ax1.yaxis.label.set_color(axisColor)
ax1.xaxis.label.set_color(axisColor)
ax1.title.set_color(axisColor)

ax2 = fig.add_subplot(122)
df1 = pd.read_excel(r"D:\work\佳期投资分析系统\规模变动.xlsx")
ax2.plot(df1["时间"], df1['华夏平稳增长'], label='华夏平稳增长')
ax2.plot(df1["时间"], df1["工银瑞信增强收益B"], label='工银瑞信增强收益B')
ax2.plot(df1["时间"], df1["易方达科讯"], label='易方达科讯')
ax2.set_ylabel('基金规模（亿）', fontsize=12)
ax2.legend()

ax2.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
ax2isColor = '#585570'
ax2.spines['bottom'].set_color(axisColor)
ax2.spines['left'].set_color(axisColor)
ax2.tick_params(axis='x', colors=axisColor)
ax2.tick_params(axis='y', colors=axisColor)
ax2.yaxis.label.set_color(axisColor)
ax2.xaxis.label.set_color(axisColor)
ax2.title.set_color(axisColor)

plt.subplots_adjust(hspace=0.1)
    
canvas = FigureCanvasTkAgg(fig, master=mainCol)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()

mainCol1 = Frame(sidebar14, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar14.add(mainCol1)
label1 = Label(mainCol1, text='今年业绩表现', fg='#f7fafc', bg='green')
label1.pack(fill='x')

df1 = pd.read_excel(r"D:\work\佳期投资分析系统\今年业绩表现.xlsx")
mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='基金名称', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["基金名称"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='基金类型', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["基金类型"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='回报（%）', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["回报（%）"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')  
mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='超额回报', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["超额回报"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x') 
mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='信息比率', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["信息比率"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x') 
mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='Sharpe', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["Sharpe"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x') 
mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='标准差', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["标准差"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x') 
mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='Alpha', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["Alpha"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x') 
mainCol1 = Frame(sidebar15, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='Beta', fg='#585570', bg='#FFFFE1', height=3, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["Beta"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x') 
    
window.mainloop()

# %% [markdown]
# ### 基金比较2

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker
from matplotlib.ticker import FuncFormatter

window= Tk()
window.title("佳期技术大数据库管理系统")

menu_widget = Menu(window)
menu_widget.add_command(label="条件筛选")
menu_widget.add_command(label="数据浏览器")
menu_widget.add_command(label="行情序列")
menu_widget.add_command(label="纵向比较")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar2 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar7 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar8 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar9 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar10 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar11 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar12 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar13 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar14 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')


main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)
main.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)
sidebar2.add(sidebar6)
sidebar2.add(sidebar7)
sidebar2.add(sidebar8)
sidebar3.add(sidebar9)
sidebar3.add(sidebar10)
sidebar3.add(sidebar11)
sidebar3.add(sidebar12)
sidebar3.add(sidebar13)
sidebar3.add(sidebar14)


mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="条件筛选", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='条件选股', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='股票数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='新三板数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期权数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商资管数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='私募数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="银行理财数据浏览器", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='信托数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='保险数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期货数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='板块数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='行情序列', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='沪深股票', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='指数', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='纵向比较', fg='#F9F900', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="财务纵比", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金比较", fg='#F9F900', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金公司比较", fg='#f7fafc', bg='green')
title.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='待选指标', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
C1 = Checkbutton(mainCol1, text = "基金资料", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "规模对比", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "今年业绩表现", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "本月业绩表现", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "短期回报对比图", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "净值走势图表", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "年化回报图表", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "阿尔法对比图", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "回撤", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "资产配置图", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "行业配置对比", bg='#FFFFE1')
C1.pack()

mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='选择基准', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text='截止日期', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text='选择基金', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#585570')
e1.insert(0, '沪深300')
e1.pack()
e1 = tk.Entry(mainCol1, fg='#585570')
e1.insert(0, '2020-06-30')
e1.pack()
e1 = tk.Entry(mainCol1, fg='#585570')
e1.insert(0, '')
e1.pack()

mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
vsb = ttk.Scrollbar(mainCol1, orient="vertical", command=tree.yview)
vsb.pack(side='right', fill='y')
myidx=tree.insert("",0,"基本资料",text="519029.OF[华夏平稳增长]",values=("0"))
myid=tree.insert("",1,"盈利预测1",text="485005.OF[工银瑞信增强收益B]",values=("2"))
myid=tree.insert("",2,"财务分析2",text="110029.OF[易方达科讯]",values=("2"))
tree.configure(yscrollcommand=vsb.set)
tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='删除', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='清空', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Button(mainCol1, text='提取数据', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Button(mainCol1, text='导出PDF', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Button(mainCol1, text='导出Word', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='今年以来回报', fg='#f7fafc', bg='green')
label1.pack(fill='x')
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#f7fafc', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='本月以来回报', fg='#f7fafc', bg='green')
label1.pack(fill='x')



mainCol = Frame(sidebar11, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar11.add(mainCol)

fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(121)
ax1.bar(np.arange(1)-1, [24.34], label='华夏平稳增长')
ax1.bar(np.arange(1), [-0.14], label='工银瑞信增强收益B')
ax1.bar(np.arange(1)+1, [34.37], label='易方达科讯')
formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
ax1.yaxis.set_major_formatter(formatter)
ax1.legend()

ax1.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax1.spines['bottom'].set_color(axisColor)
ax1.spines['left'].set_color(axisColor)
ax1.tick_params(axis='x', colors=axisColor)
ax1.tick_params(axis='y', colors=axisColor)
ax1.yaxis.label.set_color(axisColor)
ax1.xaxis.label.set_color(axisColor)
ax1.title.set_color(axisColor)

ax2 = fig.add_subplot(122)
ax2.bar(np.arange(1)-1, [8.75], label='华夏平稳增长')
ax2.bar(np.arange(1), [0.23], label='工银瑞信增强收益B')
ax2.bar(np.arange(1)+1, [14.03], label='易方达科讯')
formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
ax2.yaxis.set_major_formatter(formatter)
ax2.legend()

ax2.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
ax2isColor = '#585570'
ax2.spines['bottom'].set_color(axisColor)
ax2.spines['left'].set_color(axisColor)
ax2.tick_params(axis='x', colors=axisColor)
ax2.tick_params(axis='y', colors=axisColor)
ax2.yaxis.label.set_color(axisColor)
ax2.xaxis.label.set_color(axisColor)
ax2.title.set_color(axisColor)

plt.subplots_adjust(hspace=0.1)
    
canvas = FigureCanvasTkAgg(fig, master=mainCol)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()

mainCol1 = Frame(sidebar12, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='年化回报', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol = Frame(sidebar13, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar13.add(mainCol)

df1 = pd.read_excel(r"D:\work\佳期投资分析系统\年化回报.xlsx")
fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(111)
width = 0.35
ax1.bar(np.arange(7)-width/2, df1["华夏平稳增长"], width/2, label='华夏平稳增长')
ax1.bar(np.arange(7), df1["工银瑞信增强收益B"], width/2, label='工银瑞信增强收益B')
ax1.bar(np.arange(7)+width/2, df1["易方达科讯"], width/2, label='易方达科讯')
ax1.bar(np.arange(7)+width, df1["沪深300"], width/2, label='沪深300')
formatter = FuncFormatter(lambda y, pos: "%d%%" % (y))
ax1.yaxis.set_major_formatter(formatter)
ax1.set_xticklabels(('0', 'YTD','3月','6月', '一年', '两年', '三年', '五年'))
ax1.legend()

ax1.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax1.spines['bottom'].set_color(axisColor)
ax1.spines['left'].set_color(axisColor)
ax1.tick_params(axis='x', colors=axisColor)
ax1.tick_params(axis='y', colors=axisColor)
ax1.yaxis.label.set_color(axisColor)
ax1.xaxis.label.set_color(axisColor)
ax1.title.set_color(axisColor)

plt.subplots_adjust(hspace=0.1)
    
canvas = FigureCanvasTkAgg(fig, master=mainCol)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()
    
window.mainloop()

# %% [markdown]
# ### 基金公司比较

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker
from matplotlib.ticker import FuncFormatter

window= Tk()
window.title("佳期技术大数据库管理系统")

menu_widget = Menu(window)
menu_widget.add_command(label="条件筛选")
menu_widget.add_command(label="数据浏览器")
menu_widget.add_command(label="行情序列")
menu_widget.add_command(label="纵向比较")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar2 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar7 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar8 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar9 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar10 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar11 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar12 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar13 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar14 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar15 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')
sidebar16 = PanedWindow(sidebar3, orient="horizontal", bg='#FFFFE1')


main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)
main.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)
sidebar2.add(sidebar6)
sidebar2.add(sidebar7)
sidebar2.add(sidebar8)
sidebar3.add(sidebar9)
sidebar3.add(sidebar10)
sidebar3.add(sidebar11)
sidebar3.add(sidebar12)
sidebar3.add(sidebar13)
sidebar3.add(sidebar14)
sidebar3.add(sidebar15)
sidebar3.add(sidebar16)

mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="条件筛选", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='条件选股', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金筛选', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='股票数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='新三板数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期权数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='债券数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='券商资管数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='私募数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="银行理财数据浏览器", fg='#f7fafc', bg='green')
title.pack(fill='x')
label1 = Label(mainCol1, text='信托数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='保险数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='期货数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='板块数据浏览器', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='行情序列', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='沪深股票', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='基金', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Label(mainCol1, text='指数', fg='#f7fafc', bg='green')
label1.pack(fill='x')
label1 = Button(mainCol1, text='纵向比较', fg='#F9F900', bg='green')
label1.pack(fill='x')
title = Label(mainCol1, text="财务纵比", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金比较", fg='#f7fafc', bg='green')
title.pack(fill='x')
title = Label(mainCol1, text="基金公司比较", fg='#F9F900', bg='green')
title.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='待选指标', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
C1 = Checkbutton(mainCol1, text = "基本资料及股东", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "管理规模对比", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "产品结构", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "代表基金对比", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "基金经理", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "财务比较", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "费用比较", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "资产配置", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "行业分布", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "风格分布", bg='#FFFFE1')
C1.pack()
C1 = Checkbutton(mainCol1, text = "重仓持股", bg='#FFFFE1')
C1.pack()

mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='选择基准', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text='截止日期', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text='选择基金', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#585570')
e1.insert(0, '沪深300')
e1.pack()
e1 = tk.Entry(mainCol1, fg='#585570')
e1.insert(0, '2020-06-30')
e1.pack()
e1 = tk.Entry(mainCol1, fg='#585570')
e1.insert(0, '')
e1.pack()

mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
tree = ttk.Treeview(mainCol1, show = "tree")
vsb = ttk.Scrollbar(mainCol1, orient="vertical", command=tree.yview)
vsb.pack(side='right', fill='y')
myidx=tree.insert("",0,"基本资料",text="博时基金",values=("0"))
myid=tree.insert("",1,"盈利预测1",text="华夏基金",values=("2"))
myid=tree.insert("",2,"财务分析2",text="汇添富基金",values=("2"))
myid=tree.insert("",3,"财务分析1",text="易方达基金",values=("2"))
tree.configure(yscrollcommand=vsb.set)
tree.pack(expand = True, fill = tk.BOTH)

mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='删除', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text='清空', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Button(mainCol1, text='提取数据', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Button(mainCol1, text='导出PDF', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Button(mainCol1, text='导出Word', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar10, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='基本资料', fg='#f7fafc', bg='green')
label1.pack(fill='x')

df1 = pd.read_excel(r"D:\work\佳期投资分析系统\基本资料.xlsx")
mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='基金公司名称', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["基金公司名称"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='成立日', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["成立日"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='机构派系', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["机构派系"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='城市', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["城市"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x') 
mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='总经理', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["总经理"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')  
mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='产品数量', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["产品数量"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')  
mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='最新管理规模(亿)', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["最新管理规模(亿)"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')  
mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='管理规模排名', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["管理规模排名"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')  
mainCol1 = Frame(sidebar11, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar11.add(mainCol1)
label1 = Label(mainCol1, text='获奖数量', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["获奖数量"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')  

mainCol1 = Frame(sidebar12, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar12.add(mainCol1)
label1 = Label(mainCol1, text='前5大股东明细', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol1 = Frame(sidebar13, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar13.add(mainCol1)
label1 = Label(mainCol1, text='博时基金', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
mainCol1 = Frame(sidebar13, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar13.add(mainCol1)
label1 = Label(mainCol1, text='华夏基金', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
mainCol1 = Frame(sidebar13, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar13.add(mainCol1)
label1 = Label(mainCol1, text='汇添富基金', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
mainCol1 = Frame(sidebar13, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar13.add(mainCol1)
label1 = Label(mainCol1, text='易方达基金', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')

df1 = pd.read_excel(r"D:\work\佳期投资分析系统\前5大股东明细.xlsx")
mainCol1 = Frame(sidebar14, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar14.add(mainCol1)
label1 = Label(mainCol1, text='股东名称', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["股东名称1"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar14, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar14.add(mainCol1)
label1 = Label(mainCol1, text='持股比例(%)', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["持股比例(%)1"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar14, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar14.add(mainCol1)
label1 = Label(mainCol1, text='股东名称', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["股东名称2"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar14, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar14.add(mainCol1)
label1 = Label(mainCol1, text='持股比例(%)', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["持股比例(%)2"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x') 
mainCol1 = Frame(sidebar14, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar14.add(mainCol1)
label1 = Label(mainCol1, text='股东名称', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["股东名称3"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')  
mainCol1 = Frame(sidebar14, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar14.add(mainCol1)
label1 = Label(mainCol1, text='持股比例(%)', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["持股比例(%)3"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')  
mainCol1 = Frame(sidebar14, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar14.add(mainCol1)
label1 = Label(mainCol1, text='股东名称', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["股东名称4"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')  
mainCol1 = Frame(sidebar14, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar14.add(mainCol1)
label1 = Label(mainCol1, text='持股比例(%)', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["持股比例(%)4"]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')  

mainCol1 = Frame(sidebar15, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='管理规模对比', fg='#f7fafc', bg='green')
label1.pack(fill='x')
mainCol1 = Frame(sidebar15, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar15.add(mainCol1)
label1 = Label(mainCol1, text='新发产品规模（近1年）', fg='#f7fafc', bg='green')
label1.pack(fill='x')

mainCol = Frame(sidebar16, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar16.add(mainCol)

fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(121)
ax1.bar(np.arange(1)-1, [7054.99], label='博时基金')
ax1.bar(np.arange(1), [6635.74], label='华夏基金')
ax1.bar(np.arange(1)+1, [6031.82], label='汇添富基金')
ax1.bar(np.arange(1)+2, [8844.70], label='易方达基金')
ax1.set_ylabel('管理规模（亿）', fontsize=12)
ax1.legend()

ax1.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax1.spines['bottom'].set_color(axisColor)
ax1.spines['left'].set_color(axisColor)
ax1.tick_params(axis='x', colors=axisColor)
ax1.tick_params(axis='y', colors=axisColor)
ax1.yaxis.label.set_color(axisColor)
ax1.xaxis.label.set_color(axisColor)
ax1.title.set_color(axisColor)

ax2 = fig.add_subplot(122)
ax2.bar(np.arange(1)-1, [423.15], label='博时基金')
ax2.bar(np.arange(1), [435.04], label='华夏基金')
ax2.bar(np.arange(1)+1, [455.98], label='汇添富基金')
ax2.bar(np.arange(1)+2, [782.51], label='易方达基金')
ax2.set_ylabel('新发基金规模（亿）', fontsize=12)
ax2.legend()

ax2.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
ax2isColor = '#585570'
ax2.spines['bottom'].set_color(axisColor)
ax2.spines['left'].set_color(axisColor)
ax2.tick_params(axis='x', colors=axisColor)
ax2.tick_params(axis='y', colors=axisColor)
ax2.yaxis.label.set_color(axisColor)
ax2.xaxis.label.set_color(axisColor)
ax2.title.set_color(axisColor)

plt.subplots_adjust(hspace=0.1)
    
canvas = FigureCanvasTkAgg(fig, master=mainCol)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()


window.mainloop()
