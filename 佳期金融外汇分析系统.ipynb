# %%
import os
import glob
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from mpl_finance import candlestick2_ohlc
import matplotlib.dates as mdates
import tkinter as tk
# %matplotlib inline

pd.set_option('max_rows', 300)
pd.set_option('max_columns', 150)
plt.rcParams['font.sans-serif']=['KaiTi']
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# #### Login

# %%
import tkinter as tk
from tkinter import ttk
import tkinter.font as tkFont



window = tk.Tk()
window.title("佳期技术外汇分析系统")
# menu_widget.entryconfig(0, bg='#a1dbcd')

# the main window is divided into left and right sections,
# and the sidebar is divided into a top and bottom section.
pw = tk.PanedWindow(orient="vertical", background="#FFFFE1")
sidebar = tk.PanedWindow(pw, orient="horizontal", background="#99CC00")
main = tk.Frame(pw, width=400, height=400, borderwidth=2, background="#FFFFE1")
sidebar_frame = tk.Frame(sidebar, width=400, height=120, background="#99CC00", borderwidth=1)

# add the paned window to the window
pw.pack(fill="both", expand=True)

# add the sidebar and main area to the main paned window
pw.add(sidebar)
pw.add(main)

# add the top and bottom to the sidebar

startX = 40
startY = 0

sidebar.add(sidebar_frame)
title = tk.Label(sidebar_frame, text='用户登录', fg='#f7fafc', bg='#99CC00')
title.place(x=startX-5, y=startY)
title.config(font=('System', 18))

label = tk.Label(main, text='账户', fg='#3d4240', bg="#FFFFE1")
label.place(x=startX-2, y=startY)
entry = tk.Entry(main)
entry.place(x=startX, y=startY+20, width=240)
entry.config(fg='#d1d1d1')
entry.insert(0, '填写您的佳期技术账号')
label = tk.Label(main, text='密码', fg='#3d4240', bg="#FFFFE1")
label.place(x=startX-2, y=startY+50)
entry = tk.Entry(main)
entry.place(x=startX, y=startY+70, width=240)
entry.config(fg='#d1d1d1')
entry.insert(0, '请输入密码')
button = tk.Button(main, text='登录', fg='#3d4240', relief=tk.GROOVE)
button.place(x=startX+260, y = startY+15)
button = tk.Button(main, text='找回密码', fg='#3d4240', relief=tk.GROOVE)
button.place(x=startX+260, y = startY+65)
check = tk.Checkbutton(main, text="记住密码", fg='#3d4240', relief=tk.GROOVE)
check.place(x=startX, y = startY+100)

window.mainloop()

# %% [markdown]
# #### 主界面

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window= Tk()
window.title("佳期技术外汇分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="外汇资讯")
menu_widget.add_command(label="人民币行情")
menu_widget.add_command(label="国际外汇")
window.config(menu=menu_widget)

main = PanedWindow(orient="vertical", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="horizontal", bg='#FFFFE1', relief=RAISED)
sidebar2 = PanedWindow(main, orient="horizontal", bg='#FFFFE1')
sidebar3 = PanedWindow(main, orient="horizontal", bg='#FFFFE1', relief=RAISED)
sidebar4 = PanedWindow(main, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(main, orient="horizontal", bg='#FFFFE1', relief=RAISED)
sidebar6 = PanedWindow(main, orient="horizontal", bg='#FFFFE1')

main.add(sidebar1)
main.add(sidebar2)
main.add(sidebar3)
main.add(sidebar4)
main.add(sidebar5)
main.add(sidebar6)


main.pack(fill='both', expand=True)

mainCol = Frame(sidebar1, borderwidth=2, bg='#99CC00')
mainCol.pack(expand=True, fill='both')
sidebar1.add(mainCol)
label = Label(mainCol, text='外汇资讯', fg='#f7fafc', bg='#99CC00', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar2, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar2.add(mainCol)
label = Label(mainCol, text='汇市资讯', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar2, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar2.add(mainCol)
label = Label(mainCol, text='央行动态', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar2, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar2.add(mainCol)
label = Label(mainCol, text='全球经济日历', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar2, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar2.add(mainCol)
label = Label(mainCol, text='中国宏观预测', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')


mainCol = Frame(sidebar3, borderwidth=2, bg='#99CC00')
mainCol.pack(expand=True, fill='both')
sidebar3.add(mainCol)
label = Label(mainCol, text='人民币行情', fg='#f7fafc', bg='#99CC00', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar4, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar4.add(mainCol)
label = Label(mainCol, text='人民币综合屏', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
label = Label(mainCol, text='人民币中间价', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar4, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar4.add(mainCol)
label = Label(mainCol, text='人民币询价', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
label = Label(mainCol, text='美元兑人民币远期', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar4, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar4.add(mainCol)
label = Label(mainCol, text='人民币竞价', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
label = Label(mainCol, text='美元兑人民币掉期', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar5, borderwidth=2, bg='#99CC00')
mainCol.pack(expand=True, fill='both')
sidebar5.add(mainCol)
label = Label(mainCol, text='国际外汇', fg='#f7fafc', bg='#99CC00', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

mainCol = Frame(sidebar6, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar6.add(mainCol)
label = Label(mainCol, text='外汇概览', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar6, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar6.add(mainCol)
label = Label(mainCol, text='交叉汇率', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar6, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar6.add(mainCol)
label = Label(mainCol, text='外汇牌价', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')
mainCol = Frame(sidebar6, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar6.add(mainCol)
label = Label(mainCol, text='各国利率', fg='#3d596b', bg='#FFFFE1', anchor='w')
label.config(font=("System", 4))
label.pack(fill='x')

window.mainloop()

# %% [markdown]
# #### 外汇资讯

# %%
import tkinter as tk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from tkinter import *
from tkinter import ttk

window= tk.Tk()
window.title("佳期技术外汇分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="外汇资讯")
menu_widget.add_command(label="人民币行情")
menu_widget.add_command(label="国际外汇")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar2 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar1)
main.add(sidebar2)
sidebar2.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)
sidebar2.add(sidebar6)

mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
title = Button(mainCol1, text="汇市资讯", fg='#f7fafc', bg='#99CC00')
title.pack(fill='x')
label1 = Label(mainCol1, text='高层动态', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='人民币', fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='港币', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='新台币', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='美元', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='欧元', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='日元', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='英镑', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='瑞郎', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='澳元', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='加元', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
title = Button(mainCol1, text="央行动态", fg='#585570', bg='#99CC00')
title.pack(fill='x')
label1 = Label(mainCol1, text='中国央行', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='美联储', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='欧洲央行', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='日本央行', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='英国央行', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='加拿大央行', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='澳纽联储', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='瑞士央行', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='全球央行', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
title = Button(mainCol1, text="全球经济日历", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="中国宏观预测", fg='#585570', bg='#99CC00')
title.pack(fill='x')

mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='标题检索', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '请输入关键字')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='来源', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
e1 = tk.Entry(mainCol1, fg='#d1d1d1')
e1.insert(0, '请输入资讯来源')
e1.pack()
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="搜索", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="重置", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#99CC00', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text="人民币", fg='#f7fafc', bg='#99CC00', anchor='w')
label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Button(mainCol1, text='导出Excel', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Button(mainCol1, text='刷新', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='每页', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("20","51","52","53")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='条', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='字体大小：', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("小","大")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')


df1 = pd.read_excel(R"D:\work\佳期投资分析系统\人民币_财经资讯.xls", encoding="GBK")

mainCol1 = Frame(sidebar6, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='序号', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["序号"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w', relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
        
mainCol1 = Frame(sidebar6, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='时间', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["时间"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar6, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='标题', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["标题"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar6, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='来源', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["来源"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar6, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='作者', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["作者"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
    
window.mainloop()

# %% [markdown]
# #### 全球经济日历

# %%
import calendar 
from tkinter import *
window= tk.Tk()
window.title("佳期技术外汇分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="外汇资讯")
menu_widget.add_command(label="人民币行情")
menu_widget.add_command(label="国际外汇")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar0 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar6 = PanedWindow(main, orient="horizontal", bg='#C8C8C8')
sidebar7 = PanedWindow(main, orient="horizontal", bg='#FFFFE1')
sidebar2 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')


main.pack(fill='both', expand=True)
main.add(sidebar0)
main.add(sidebar1)
main.add(sidebar2)
sidebar2.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)
sidebar1.add(sidebar6)
sidebar1.add(sidebar7)

mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
title = Button(mainCol1, text="汇市资讯", fg='#585570', bg='#99CC00')
title.pack(fill='x')
label1 = Label(mainCol1, text='高层动态', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='人民币', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='港币', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='新台币', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='美元', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='欧元', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='日元', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='英镑', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='瑞郎', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='澳元', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='加元', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
title = Button(mainCol1, text="央行动态", fg='#585570', bg='#99CC00')
title.pack(fill='x')
label1 = Label(mainCol1, text='中国央行', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='美联储', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='欧洲央行', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='日本央行', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='英国央行', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='加拿大央行', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='澳纽联储', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='瑞士央行', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
label1 = Label(mainCol1, text='全球央行', fg='#585570', bg='#99CC00')
label1.pack(fill='x')
title = Button(mainCol1, text="全球经济日历", fg='#f7fafc', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="中国宏观预测", fg='#585570', bg='#99CC00')
title.pack(fill='x')

label = Label(sidebar6,text=str(2020)+"年", bg='#C8C8C8')
label.grid(row=0,column=2)
label = Label(sidebar6,text=str(6)+"月", bg='#C8C8C8')
label.grid(row=0,column=4)

labels = [['一','二','三','四','五','六','日']]
MonthCal = calendar.monthcalendar(2020, 6)
for r in range(7):
    for c in range(7):            
        label = Label(sidebar6,
                          width =5,
                          padx=5,
                          pady=5,
                          text=' ')        
        label.grid(row=r+1,column=c)
for i in range(len(MonthCal)):
    labels.append(MonthCal[i])
for r in range(len(MonthCal)+1):
    for c in range(7):
        if labels[r][c] == 0:
            labels[r][c] = ' '
        label = Label(sidebar6,          
                      padx=5,
                      pady=5,
                      text=str(labels[r][c]))        
        label.grid(row=r+1,column=c)
label = Label(sidebar6,          
                      padx=5,
                      pady=5,
                      text=str(labels[3][4]), bg='#99CC00')        
label.grid(row=3+1,column=4)

button1 = Button(sidebar6, text='前月')
button1.grid(row=len(MonthCal)+2, column=0)
button2 = Button(sidebar6, text='下月')
button2.grid(row=len(MonthCal)+2, column=6)        
        
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='区域：', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("全部","亚太")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='国家及地区：', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("全部","中国")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="确定", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="重要数据", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="经济数据", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="重要会议", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')


df1 = pd.read_excel(r"D:\work\佳期投资分析系统\2020-06-19_全球经济日历.xls", encoding="GBK")

mainCol1 = Frame(sidebar5, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='日期', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["日期"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='提醒', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["提醒"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='国家及地区', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["国家及地区"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='事件', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["事件"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar5, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='报告期', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["报告期"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
    
mainCol1 = Frame(sidebar5, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='公布值', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["公布值"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='预测值', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["预测值"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='前值', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["前值"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='重要性', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["重要性"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='red', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='查看', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='查看全部历史', fg='#585570', bg='#FFFFE1', anchor='w',relief="raised")
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='查看全部历史', fg='#585570', bg='#FFFFE1', anchor='w',relief="raised")
label1.config(font=("System", 4))
label1.pack(fill='x')

window.mainloop()

# %% [markdown]
# #### 人民币综合屏

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker

window= tk.Tk()
window.title("佳期技术外汇分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="外汇资讯")
menu_widget.add_command(label="人民币行情")
menu_widget.add_command(label="国际外汇")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar0 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar2 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar7 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar8 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar9 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar0)
main.add(sidebar1)
main.add(sidebar2)
sidebar2.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)
sidebar2.add(sidebar6)
sidebar2.add(sidebar7)
sidebar2.add(sidebar8)
sidebar2.add(sidebar9)


mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
title = Button(mainCol1, text="人民币综合屏", fg='#f7fafc', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="相关品种", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="询价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="远期", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="掉期", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="HIBOR", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="LIBOR", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币询价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="USDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="SGDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="NZDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="JPYCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="HKDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="GBPCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="EURCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="CNYKRW", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="CNYRUB", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币竞价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币中间价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币外汇远掉", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元兑人民币远期", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元兑人民币掉期", fg='#585570', bg='#99CC00')
title.pack(fill='x')


mainCol = Frame(sidebar1, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar1.add(mainCol)

fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot(211)
df1 = pd.read_excel(r"D:\work\佳期投资分析系统\temp.xlsx")
df1.columns = df1.iloc[0, :]
df1 = df1.iloc[1:, :]
ax1.plot(df1["时间"], df1["价差"], label='价差 USDCNY-USDCNH')
ax1.xaxis.set_major_formatter(mdate.DateFormatter('%H:%M'))
ax1.xaxis.set_major_locator(mdates.HourLocator())
ax1.legend()
ax1.set_title('价差分析')

ax1.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax1.spines['bottom'].set_color(axisColor)
ax1.spines['left'].set_color(axisColor)
ax1.tick_params(axis='x', colors=axisColor)
ax1.tick_params(axis='y', colors=axisColor)
ax1.yaxis.label.set_color(axisColor)
ax1.xaxis.label.set_color(axisColor)
ax1.title.set_color(axisColor)

ax2 = fig.add_subplot(212)
ax2.plot(df1["时间"], df1["美元兑人民币(CFETS)"], label='USDCNY 美元兑人民币询价')
ax2.xaxis.set_major_formatter(mdate.DateFormatter('%H:%M'))
ax2.xaxis.set_major_locator(mdates.HourLocator())
ax2.plot(df1["时间"], df1["美元兑离岸人民币"], label='USDCNH 美元兑离岸人民币')
ax2.xaxis.set_major_formatter(mdate.DateFormatter('%H:%M'))
ax2.xaxis.set_major_locator(mdates.HourLocator())
ax2.legend()

ax2.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
ax2isColor = '#585570'
ax2.spines['bottom'].set_color(axisColor)
ax2.spines['left'].set_color(axisColor)
ax2.tick_params(axis='x', colors=axisColor)
ax2.tick_params(axis='y', colors=axisColor)
ax2.yaxis.label.set_color(axisColor)
ax2.xaxis.label.set_color(axisColor)
ax2.title.set_color(axisColor)

plt.subplots_adjust(hspace=0.1)
    
canvas = FigureCanvasTkAgg(fig, master=mainCol)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()

mainCol1 = Frame(sidebar3, bg='#99CC00', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text="USDCNY", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#99CC00', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text="7.0744/7.0751", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text="最高", fg='#585570', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')
label1 = Label(mainCol1, text="前收", fg='#585570', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text="7.0918", fg='red', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0812", fg='#585570', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text="最低", fg='#585570', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')
label1 = Label(mainCol1, text="开盘", fg='#585570', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text="7.0720", fg='green', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0880", fg='red', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')


mainCol1 = Frame(sidebar5, bg='#99CC00', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text="USDCNH", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar5, bg='#99CC00', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text="7.0714/7.0726", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')

mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text="最高", fg='#585570', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')
label1 = Label(mainCol1, text="前收", fg='#585570', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text="7.0836", fg='red', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0824", fg='#585570', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text="最低", fg='#585570', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')
label1 = Label(mainCol1, text="开盘", fg='#585570', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text="7.0674", fg='green', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0817", fg='red', bg='#FFFFE1', anchor='w')
label1.pack(fill='x')

mainCol1 = Frame(sidebar7, bg='#99CC00', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
label1 = Label(mainCol1, text="中间价", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar7, bg='#99CC00', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
label1 = Label(mainCol1, text="7.09130", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')

mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text="人民币资讯", bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="【外汇局王春英：5月份我国外汇市场延续平稳运行", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="态势】外汇局新闻发言人王春英表示，5月份我国外", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="汇市场延续平稳运行态势，外汇供求保持基本平衡；", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="市场主体外汇交易理性有序，主要渠道跨境资金流动", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="总体稳定。当前，境外疫情和世界经济形势更趋严峻", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="复杂，外部环境不确定性因素增多，但我国坚持以改", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="革开放为动力推动高质量发展，外汇市场运行的韧性", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="进一步增强，人民币资产展现出较强的吸引力。      ", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

label1 = Label(mainCol1, text="", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
sidebar9.add(mainCol1)

label1 = Label(mainCol1, text="【前5月制造业新增贷款1.4万亿元】银保监会政策", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="研究局一级巡视员叶燕斐6月19日介绍称，今年前5", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="个月，制造业新增贷款1.4万亿元，同比增长10.1%", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="为2014年以来最快增速。制造业新增贷款占境内新", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="增贷款的11.3%，比年初提高6.7个百分点。       ", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')


window.mainloop()
# Out:
# C:\Users\win\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### 人民币中间价

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker

window= tk.Tk()
window.title("佳期技术外汇分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="外汇资讯")
menu_widget.add_command(label="人民币行情")
menu_widget.add_command(label="国际外汇")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar0 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar00 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar1 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar2 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar3 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar0)
main.add(sidebar00)
sidebar00.add(sidebar1)
sidebar00.add(sidebar2)
sidebar00.add(sidebar3)
sidebar00.add(sidebar4)

mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
title = Button(mainCol1, text="人民币综合屏", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="相关品种", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="询价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="远期", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="掉期", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="HIBOR", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="LIBOR", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币询价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="USDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="SGDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="NZDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="JPYCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="HKDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="GBPCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="EURCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="CNYKRW", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="CNYRUB", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币竞价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币中间价", fg='#f7fafc', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币外汇远掉", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元兑人民币远期", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元兑人民币掉期", fg='#585570', bg='#99CC00')
title.pack(fill='x')

mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="报价列表", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="多股同列", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="综合排名", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

df1 = pd.read_excel(r"D:\work\佳期投资分析系统\人民币中间价.xlsx")
mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='代码', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["代码"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='名称', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["名称"].values[:20]:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='现价', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
col_list = ['green', 'green', 'green', '#585570', 'red', 'red', 'green', 'red', 'green', 'red', '#585570',
           'red', '#585570', 'red', '#585570', 'red', 'red', 'green', 'green', 'red', 'green', 'green',
            'green', 'red']
for col in range(len(df1["现价"]))[:20]:
    label1 = Label(mainCol1, text=df1["现价"].values[col], fg=col_list[col], bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='涨跌', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
col_list = ['green', 'green', 'green', '#585570', 'red', 'red', 'green', 'red', 'green', 'red', '#585570',
           'red', '#585570', 'red', '#585570', 'red', 'red', 'green', 'green', 'red', 'green', 'green',
            'green', 'red']
for col in range(len(df1["现价"]))[:20]:
    label1 = Label(mainCol1, text=df1["涨跌"].values[col], fg=col_list[col], bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='涨跌幅', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
col_list = ['green', 'green', 'green', '#585570', 'red', 'red', 'green', 'red', 'green', 'red', '#585570',
           'red', '#585570', 'red', '#585570', 'red', 'red', 'green', 'green', 'red', 'green', 'green',
            'green', 'red']
for col in range(len(df1["现价"]))[:20]:
    label1 = Label(mainCol1, text='%.2f%%'%(100 *df1["涨跌幅"].values[col]), fg=col_list[col], bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='最低', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
col_list = ['green', 'green', 'green', '#585570', 'red', 'red', 'green', 'red', 'green', 'red', '#585570',
           'red', '#585570', 'red', '#585570', 'red', 'red', 'green', 'green', 'red', 'green', 'green',
            'green', 'red']
for col in range(len(df1["现价"]))[:20]:
    label1 = Label(mainCol1, text=df1["最低"].values[col], fg=col_list[col], bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='最高', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
col_list = ['green', 'green', 'green', '#585570', 'red', 'red', 'green', 'red', 'green', 'red', '#585570',
           'red', '#585570', 'red', '#585570', 'red', 'red', 'green', 'green', 'red', 'green', 'green',
            'green', 'red']
for col in range(len(df1["现价"]))[:20]:
    label1 = Label(mainCol1, text=df1["最高"].values[col], fg=col_list[col], bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='10日涨跌幅', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
col_list = ['green', 'green', 'red', 'red', 'red', 'red', 'green', 'red', 'red', 'red', 'red',
           'red', '#585570', 'red', 'green', 'red', 'red', 'green', 'green', 'green', 'red', 'green',
            'red', 'green']
for col in range(len(df1["现价"]))[:20]:
    label1 = Label(mainCol1, text='%.2f%%'%(100 *df1["10日涨跌幅"].values[col]), fg=col_list[col], bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='20日涨跌幅', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
col_list = ['red', 'red', 'red', 'red', 'green', 'green', 'green', 'green', 'green', 'green', 'green',
           'green', 'green', 'green', 'green', 'red', 'green', 'red', 'red', 'red', 'red', 'red',
            'red', 'green']
for col in range(len(df1["现价"]))[:20]:
    label1 = Label(mainCol1, text= '%.2f%%'%(100 *df1["20日涨跌幅"].values[col]), fg=col_list[col], bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')



mainCol1 = Frame(sidebar3, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='2020/06/19', fg='#585570', bg='#FFFFE1', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='澳元中间价', fg='#585570', bg='#FFFFE1', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='收', fg='#585570', bg='#FFFFE1', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='4.8624', fg='green', bg='#FFFFE1', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='幅', fg='#585570', bg='#FFFFE1', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')   
mainCol1 = Frame(sidebar3, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='-0.28%(-0.0137)', fg='green', bg='#FFFFE1', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')   

    
mainCol = Frame(sidebar4, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar4.add(mainCol)

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)
df1 = pd.read_excel(r"D:\work\佳期投资分析系统\澳元中间价.xlsx")
ax.plot(df1["日期"], df1["收盘价(元)"], label='澳元中间价收盘价')
ax.xaxis.set_major_formatter(mdate.DateFormatter('%Y.%m'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.legend()

ax.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)

plt.subplots_adjust(hspace=0.1)
    
canvas = FigureCanvasTkAgg(fig, master=mainCol)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()



window.mainloop()

# %% [markdown]
# #### 人民币外汇远掉

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker

window= tk.Tk()
window.title("佳期技术外汇分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="外汇资讯")
menu_widget.add_command(label="人民币行情")
menu_widget.add_command(label="国际外汇")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar0 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar1, orient="horizontal", bg='#99CC00')
sidebar7 = PanedWindow(sidebar1, orient="horizontal", bg='#FFFFE1',relief="ridge")
sidebar8 = PanedWindow(sidebar1, orient="horizontal", bg='#FFFFE1')
sidebar9 = PanedWindow(sidebar1, orient="horizontal", bg='#FFFFE1')
sidebar2 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(sidebar2, orient="horizontal", bg='#99CC00')
sidebar4 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1',relief="ridge")
sidebar5 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar10 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar0)
main.add(sidebar1)
main.add(sidebar2)
sidebar2.add(sidebar3)
sidebar2.add(sidebar4)
sidebar2.add(sidebar5)
sidebar2.add(sidebar10)
sidebar1.add(sidebar6)
sidebar1.add(sidebar7)
sidebar1.add(sidebar8)
sidebar1.add(sidebar9)

mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
title = Button(mainCol1, text="人民币综合屏", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="相关品种", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="询价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="远期", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="掉期", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="HIBOR", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="LIBOR", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币询价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="USDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="SGDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="NZDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="JPYCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="HKDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="GBPCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="EURCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="CNYKRW", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="CNYRUB", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币竞价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币中间价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币外汇远掉", fg='#f7fafc', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元兑人民币远期", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元兑人民币掉期", fg='#585570', bg='#99CC00')
title.pack(fill='x')


mainCol1 = Frame(sidebar6, bg='#99CC00', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text="", fg='#f7fafc', bg='#99CC00', anchor='w')
label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#99CC00', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text="掉期", fg='#f7fafc', bg='#99CC00', anchor='w')
label1.pack(fill='x')


mainCol1 = Frame(sidebar7, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
label1 = Label(mainCol1, text='到期日', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/06/23', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/06/22', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/06/23', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/06/24', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/06/30', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/07/07', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/07/14', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/07/23', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/08/24', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/09/23', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')


mainCol1 = Frame(sidebar7, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
label1 = Label(mainCol1, text='名称', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNY', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNYONS', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNYTNS', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNYSNS', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNYSWS', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNY2WS', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNY3WS', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNY1MS', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNY2MS', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNY3MS', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar7, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
label1 = Label(mainCol1, text='买价', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0749', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='11.5000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3.8500', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3.6600', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='27.5000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='65.0000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='88.0000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='116.5000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='207.0000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='299.0000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar7, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
label1 = Label(mainCol1, text='卖价', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0776', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='12.5000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3.8500', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3.6900', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='27.5000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='67.0000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='90.0000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='116.5000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='207.5000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='299.0000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar7, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
label1 = Label(mainCol1, text='报价时间', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:12', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar7, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
label1 = Label(mainCol1, text='成交价', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0749', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='13.0000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3.8500', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='3.7500', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='27.5000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='65.5000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='88.0000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='117.0000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='203.0000', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='289.5000', fg='red', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')























mainCol1 = Frame(sidebar3, bg='#99CC00', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text="", fg='#f7fafc', bg='#99CC00', anchor='w')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#99CC00', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text="远期（远期价格由掉期计算得出）", fg='#f7fafc', bg='#99CC00', anchor='w')
label1.pack(fill='x')


mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='到期日', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/06/23', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/06/22', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/06/23', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/06/24', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/06/30', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/07/07', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/07/14', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/07/23', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/08/24', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20/09/23', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')


mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='名称', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNY', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNYONF', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNYTNF', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNYSNF', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNYSWF', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNY2WF', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNY3WF', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNY1MF', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNY2MF', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='USDCNY3MF', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='买价', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0749', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0733', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0745', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0753', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0777', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0814', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0837', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0866', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0956', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.1048', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='卖价', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0776', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0761', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0772', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0780', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0804', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0843', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0866', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0893', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0984', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.1075', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='报价时间', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='成交价', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0749', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0732', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0745', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0753', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0777', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0815', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0837', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0866', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.0952', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='7.1039', fg='green', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')




mainCol1 = Frame(sidebar8, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Label(mainCol1, text='2020/06/19', fg='#585570', bg='#FFFFE1', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Label(mainCol1, text='美元兑人民币一周远期', fg='#585570', bg='#FFFFE1', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Label(mainCol1, text='日线', fg='red', bg='#FFFFE1', height=1, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x') 

    
mainCol = Frame(sidebar9, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar9.add(mainCol)

fig, ax = plt.subplots(figsize=(10, 8))
df1 = pd.read_excel(r"D:\work\佳期投资分析系统\人民币远期.xlsx")
ax.plot(df1["日期"], df1["收盘价(元)"], label='USDCNYSWF.IB')
ax.xaxis.set_major_formatter(mdate.DateFormatter('%Y.%m'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.legend()

ax.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)

plt.subplots_adjust(hspace=0.1)
    
canvas = FigureCanvasTkAgg(fig, master=mainCol)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()



mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Button(mainCol1, text="汇市新闻", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Button(mainCol1, text="央行动态", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Button(mainCol1, text="滚动新闻", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Button(mainCol1, text="更多新闻", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')


mainCol1 = Frame(sidebar10, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:13', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:06', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='20:04', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='19:48', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='19:45', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='18:45', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='18:45', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='18:30', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='18:30', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar10, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='新浪', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='金十数据', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='英为财情', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='和讯', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='和讯', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='中金在线', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='中金在线', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='中金在线', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='金十数据', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='中证网', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

mainCol1 = Frame(sidebar10, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar10.add(mainCol1)
label1 = Label(mainCol1, text='欧盟领导人结束峰会，未能就复苏计划达成共识', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='【行情】欧元兑美元短线波动不大，现报1.1203', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='今日财经市场5件大事', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='俄罗斯央行行长：复苏的时间将比预期更长', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='英镑兑美元创6月1日以来低位', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='OANDA（安达）：今夜美元兑日元、欧元兑美元的走势预测', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='领峰环球：外汇评论 美指或持续反弹 汇市多品种面临方向抉择', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='铸博皇御环球金融：汇市直击 美国经济复苏之路任重道远', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='18:30俄罗斯至6月19日央行利率决定重要程度', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')
label1 = Label(mainCol1, text='俄罗斯央行降息至4.5%，符合市场预期', fg='#585570', bg='#FFFFE1', anchor='w')
label1.config(font=("System", 4))
label1.pack(fill='x')

window.mainloop()

# %% [markdown]
# #### 美元对人民币 F5

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker

window= tk.Tk()
window.title("佳期技术外汇分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="外汇资讯")
menu_widget.add_command(label="人民币行情")
menu_widget.add_command(label="国际外汇")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar0 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar1 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar3 = PanedWindow(sidebar1, orient="horizontal", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar1, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar1, orient="horizontal", bg='#FFFFE1',relief="ridge")
sidebar2 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar7 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar8 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')
sidebar9 = PanedWindow(sidebar2, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar0)
main.add(sidebar1)
main.add(sidebar2)
sidebar2.add(sidebar6)
sidebar2.add(sidebar7)
sidebar2.add(sidebar8)
sidebar2.add(sidebar9)
sidebar1.add(sidebar3)
sidebar1.add(sidebar4)
sidebar1.add(sidebar5)

mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
title = Button(mainCol1, text="人民币综合屏", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="相关品种", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="询价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="远期", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="掉期", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="HIBOR", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="LIBOR", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币询价", fg='#f7fafc', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="USDCNY", fg='#f7fafc', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="SGDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="NZDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="JPYCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="HKDCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="GBPCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="EURCNY", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="CNYKRW", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="CNYRUB", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币竞价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币中间价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="人民币外汇远掉", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元兑人民币远期", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元兑人民币掉期", fg='#585570', bg='#99CC00')
title.pack(fill='x')

mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="分时图", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="K线图", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="TICK", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text="成交明细", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="分时", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="多日", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="1分", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="5分", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="15分", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="30分", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="60分", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="4小时", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="日", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="周", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="月", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Button(mainCol1, text="更多", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol = Frame(sidebar5, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar5.add(mainCol)

fig, ax = plt.subplots(figsize=(10, 8))
df1 = pd.read_excel(r"D:\work\佳期投资分析系统\F5.xlsx")
ax.plot(df1["日期"], df1["收盘价(元)"], label='USDCNY.IB [美元兑人民币(CFETS)] 日线')
ax.xaxis.set_major_formatter(mdate.DateFormatter('%Y.%m'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.set_xlim(df1["日期"].min())
ax.legend()

ax.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)

plt.subplots_adjust(hspace=0.1)
    
canvas = FigureCanvasTkAgg(fig, master=mainCol)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()


mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text="USDCNY", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="美元兑人民币(CFETS)", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text="7.08040", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.07990 7.08020", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
label1 = Label(mainCol1, text="最高", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="最低", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="涨跌PIP", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="涨跌%", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
label1 = Label(mainCol1, text="7.0817", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0764", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="24.0", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.03%", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
label1 = Label(mainCol1, text="中间价", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="开盘价", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="收盘", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="末笔", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar7, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar7.add(mainCol1)
label1 = Label(mainCol1, text="7.0865", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0810", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.0000", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="-", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text="成交明细", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text="外汇新闻", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Button(mainCol1, text="财经直播", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar8, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar8.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="时间", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="10:06:59", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="10:07:54", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="10:08:54", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="10:09:55", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="10:10:59", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="10:11:55", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="10:12:59", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="10:14:57", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="10:15:59", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="10:16:50", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="10:17:59", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="10:18:41", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="10:19:40", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="价格", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0806", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0800", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0806", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0814", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0813", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0814", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0811", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0806", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0805", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0810", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0805", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0796", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0804", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar9, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar9.add(mainCol1)
label1 = Label(mainCol1, text="涨跌PIP", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="26.0000", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="20.0000", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="26.0000", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="34.0000", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="33.0000", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="34.0000", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="31.0000", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="26.0000", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="25.0000", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="30.0000", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="25.0000", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="16.0000", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="24.0000", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

window.mainloop()

# %% [markdown]
# #### 外汇概览

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker

window= tk.Tk()
window.title("佳期技术外汇分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="外汇资讯")
menu_widget.add_command(label="人民币行情")
menu_widget.add_command(label="国际外汇")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar0 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar00 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar1 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar2 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar3 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar0)
main.add(sidebar00)
sidebar00.add(sidebar1)
sidebar00.add(sidebar2)
sidebar00.add(sidebar3)

mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
title = Button(mainCol1, text="外汇概览", fg='#f7fafc', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元离岸人民币", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="100日元人民币混合", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="欧元人民币混合", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="港币人民币混合", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元指数", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="欧元兑美元", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="英镑兑美元", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元兑日元", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="交叉汇率", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="外汇牌价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="工商银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="农业银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="中国银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="建设银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="交通银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="招商银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="各国利率", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美国", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="日本", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="欧元区", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="英国", fg='#585570', bg='#99CC00')
title.pack(fill='x')


mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="查看最新", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="全球时间", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="北京06月22日 10:57:24", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="伦敦06月22日 03:57:24", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="纽约06月21日 22:57:24", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="悉尼06月22日 12:57:24", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')


mainCol = Frame(sidebar3, borderwidth=2, bg='#FFFFE1')
mainCol.pack(expand=True, fill='both')
sidebar3.add(mainCol)

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(241)
df1 = pd.read_excel(r"D:\work\佳期投资分析系统\美国离岸人民币.xlsx")
ax.plot(df1["时间"], df1["价格"], label='美元离岸人民币')
ax.xaxis.set_major_formatter(mdate.DateFormatter('%H:%M'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.set_xlim(df1["时间"].min())
ax.legend()

ax.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)

ax = fig.add_subplot(242)
df1 = pd.read_excel(r"D:\work\佳期投资分析系统\100日元人民币混合.xlsx")
ax.plot(df1["时间"], df1["价格"], label='100日元人民币混合')
ax.xaxis.set_major_formatter(mdate.DateFormatter('%H:%M'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.set_xlim(df1["时间"].min())
ax.legend()

ax.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)
    
ax = fig.add_subplot(243)
df1 = pd.read_excel(r"D:\work\佳期投资分析系统\欧元人民币混合.xlsx")
ax.plot(df1["时间"], df1["价格"], label='欧元人民币混合')
ax.xaxis.set_major_formatter(mdate.DateFormatter('%H:%M'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.set_xlim(df1["时间"].min())
ax.legend()

ax.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)

ax = fig.add_subplot(244)
df1 = pd.read_excel(r"D:\work\佳期投资分析系统\港币人民币混合.xlsx")
ax.plot(df1["时间"], df1["价格"], label='港币人民币混合')
ax.xaxis.set_major_formatter(mdate.DateFormatter('%H:%M'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.set_xlim(df1["时间"].min())
ax.legend()

ax.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)

ax = fig.add_subplot(245)
df1 = pd.read_excel(r"D:\work\佳期投资分析系统\美元指数.xlsx")
ax.plot(df1["时间"], df1["价格"], label='美元指数')
ax.xaxis.set_major_formatter(mdate.DateFormatter('%H:%M'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.set_xlim(df1["时间"].min())
ax.legend()

ax.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)

ax = fig.add_subplot(246)
df1 = pd.read_excel(r"D:\work\佳期投资分析系统\欧元兑美元.xlsx")
ax.plot(df1["时间"], df1["价格"], label='欧元兑美元')
ax.xaxis.set_major_formatter(mdate.DateFormatter('%H:%M'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.set_xlim(df1["时间"].min())
ax.legend()

ax.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)
    
ax = fig.add_subplot(247)
df1 = pd.read_excel(r"D:\work\佳期投资分析系统\英镑兑美元.xlsx")
ax.plot(df1["时间"], df1["价格"], label='英镑兑美元')
ax.xaxis.set_major_formatter(mdate.DateFormatter('%H:%M'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.set_xlim(df1["时间"].min())
ax.legend()

ax.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)

ax = fig.add_subplot(248)
df1 = pd.read_excel(r"D:\work\佳期投资分析系统\美元兑日元.xlsx")
ax.plot(df1["时间"], df1["价格"], label='美元兑日元')
ax.xaxis.set_major_formatter(mdate.DateFormatter('%H:%M'))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.set_xlim(df1["时间"].min())
ax.legend()

ax.set_facecolor('#FFFFE1')
fig.patch.set_facecolor('#FFFFE1')
axisColor = '#585570'
ax.spines['bottom'].set_color(axisColor)
ax.spines['left'].set_color(axisColor)
ax.tick_params(axis='x', colors=axisColor)
ax.tick_params(axis='y', colors=axisColor)
ax.yaxis.label.set_color(axisColor)
ax.xaxis.label.set_color(axisColor)
ax.title.set_color(axisColor)

plt.subplots_adjust(hspace=0.1)
    
canvas = FigureCanvasTkAgg(fig, master=mainCol)
canvas.get_tk_widget().pack(fill='x')
canvas.draw()

window.mainloop()

# %% [markdown]
# #### 交叉汇率

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker
from tkinter import ttk

window= tk.Tk()
window.title("佳期技术外汇分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="外汇资讯")
menu_widget.add_command(label="人民币行情")
menu_widget.add_command(label="国际外汇")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar0 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar00 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar1 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar2 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1', relief='solid')
sidebar3 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1', relief='solid')

main.pack(fill='both', expand=True)
main.add(sidebar0)
main.add(sidebar00)
sidebar00.add(sidebar1)
sidebar00.add(sidebar2)
sidebar00.add(sidebar3)

mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
title = Button(mainCol1, text="外汇概览", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元离岸人民币", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="100日元人民币混合", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="欧元人民币混合", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="港币人民币混合", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元指数", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="欧元兑美元", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="英镑兑美元", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元兑日元", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="交叉汇率", fg='#f7fafc', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="外汇牌价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="工商银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="农业银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="中国银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="建设银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="交通银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="招商银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="各国利率", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美国", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="日本", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="欧元区", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="英国", fg='#585570', bg='#99CC00')
title.pack(fill='x')

mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="卖价", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="买价", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="中间价", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="基准/计价", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="USD", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="EUR", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="100JPY", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="GBP", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="CAD", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="AUD", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="NZD", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="CHF", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="HKD", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="CNH", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="CNY", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="USD", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text=" ", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.1189", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.9358", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.2368", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.7359", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.6853", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.6421", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.0510", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1290", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1414", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1413", fg='green', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="EUR", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.8937", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text=" ", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.8364", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.1054", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.6577", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.6125", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.5739", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.9393", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1153", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1264", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1263", fg='green', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="JPY", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="106.8600", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="119.5657", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text=" ", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="132.1644", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="78.6371", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="73.2312", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="68.6148", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="112.3069", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="13.7886", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="15.1075", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="15.0962", fg='green', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="GBP", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.8085", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.9047", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.7566", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text=" ", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.5950", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.5541", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.5192", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.8498", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1043", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1143", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1142", fg='green', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="CAD", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.3598", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.5205", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.2717", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.6807", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text=" ", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.9313", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.8725", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.4282", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1753", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1921", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1920", fg='green', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="AUD", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.4592", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.6327", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.3655", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.8048", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.0738", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text=" ", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.9370", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.5336", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1883", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.2063", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.2061", fg='green', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="NZD", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.5574", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.7426", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.4574", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.9262", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.1461", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.0673", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text=" ", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.6368", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.2010", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.2202", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.2200", fg='green', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="CHF", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.9515", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.0646", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.8904", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.1768", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.7002", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.6521", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.6110", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text=" ", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1228", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1345", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.1344", fg='green', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="HKD", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.7499", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="8.6714", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.2524", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="9.5851", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="5.7031", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="5.3310", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="4.9762", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="8.1449", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text=" ", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.0957", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.0948", fg='green', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="CNH", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0733", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.9143", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="6.6192", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="8.7483", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="5.2052", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="4.8473", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="4.5418", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.4338", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.9127", fg='green', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text=" ", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.9993", fg='green', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="CNY", fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.0786", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.9202", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="6.6242", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="8.7548", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="5.2091", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="4.8510", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="4.5452", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="7.4394", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="0.9134", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text="1.0007", fg='red', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text=" ", fg='red', bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='基准货币', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text='买价', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("USD","EUR")
comboxlist.current(0)
comboxlist.pack(fill='x')
label1 = Label(mainCol1, text='0.9047', fg='green', bg='#FFFFE1')
label1.pack(fill='x')


mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='非基准货币', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
label1 = Label(mainCol1, text='卖价', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("GBP","EUR")
comboxlist.current(0)
comboxlist.pack(fill='x')
label1 = Label(mainCol1, text='0.9046', fg='green', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Button(mainCol1, text='>', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar3.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

window.mainloop()

# %% [markdown]
# #### 外汇牌价

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker
from tkinter import ttk

window= tk.Tk()
window.title("佳期技术外汇分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="外汇资讯")
menu_widget.add_command(label="人民币行情")
menu_widget.add_command(label="国际外汇")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar0 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar00 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar1 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar2 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar0)
main.add(sidebar00)
sidebar00.add(sidebar1)
sidebar00.add(sidebar2)

mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
title = Button(mainCol1, text="外汇概览", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元离岸人民币", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="100日元人民币混合", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="欧元人民币混合", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="港币人民币混合", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元指数", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="欧元兑美元", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="英镑兑美元", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元兑日元", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="交叉汇率", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="外汇牌价", fg='#f7fafc', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="工商银行报价", fg='#f7fafc', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="农业银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="中国银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="建设银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="交通银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="招商银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="各国利率", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美国", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="日本", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="欧元区", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="英国", fg='#585570', bg='#99CC00')
title.pack(fill='x')


mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="工商银行报价", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="农业银行报价", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="中国银行报价", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="建设银行报价", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="交通银行报价", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="招商银行报价", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')

df1 = pd.read_excel(r"D:\work\佳期投资分析系统\外汇牌价.xlsx")
mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='序号', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["序号"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='代码', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["代码"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='名称', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["名称"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='现汇买入价', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["现汇买入价"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='现钞买入价', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["现钞买入价"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='现汇卖出价', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["现汇卖出价"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='现钞卖出价', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["现钞卖出价"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='更新时间', fg='#585570', bg='#FFFFE1', height=1, anchor='w',relief="ridge")
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["更新时间"].astype(str).values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w',relief="ridge")
    label1.config(font=("System", 4))
    label1.pack(fill='x')

window.mainloop()

# %% [markdown]
# #### 各国利率

# %%
import calendar 
from tkinter import *
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdate
import matplotlib.ticker as ticker
from tkinter import ttk

window= tk.Tk()
window.title("佳期技术外汇分析系统")

menu_widget = Menu(window)
menu_widget.add_command(label="外汇资讯")
menu_widget.add_command(label="人民币行情")
menu_widget.add_command(label="国际外汇")
window.config(menu=menu_widget)

main = PanedWindow(orient="horizontal", bg='#FFFFE1')
sidebar0 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar00 = PanedWindow(main, orient="vertical", bg='#FFFFE1')
sidebar1 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar2 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar3 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar4 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar5 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')
sidebar6 = PanedWindow(sidebar00, orient="horizontal", bg='#FFFFE1')

main.pack(fill='both', expand=True)
main.add(sidebar0)
main.add(sidebar00)
sidebar00.add(sidebar1)
sidebar00.add(sidebar2)
sidebar00.add(sidebar3)
sidebar00.add(sidebar4)
sidebar00.add(sidebar5)
sidebar00.add(sidebar6)

mainCol1 = Frame(sidebar0, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar0.add(mainCol1)
title = Button(mainCol1, text="外汇概览", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元离岸人民币", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="100日元人民币混合", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="欧元人民币混合", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="港币人民币混合", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元指数", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="欧元兑美元", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="英镑兑美元", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美元兑日元", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="交叉汇率", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="外汇牌价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="工商银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="农业银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="中国银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="建设银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="交通银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="招商银行报价", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Button(mainCol1, text="各国利率", fg='#f7fafc', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="美国", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="日本", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="欧元区", fg='#585570', bg='#99CC00')
title.pack(fill='x')
title = Label(mainCol1, text="英国", fg='#585570', bg='#99CC00')
title.pack(fill='x')

mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="提取数据", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="导出到Excel", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Button(mainCol1, text="数据筛选", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar1, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar1.add(mainCol1)
label1 = Label(mainCol1, text="", bg='#FFFFE1')
label1.pack(fill='x')

mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='开始时间', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("2020/6/15","2020/6/22")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text='结束时间', fg='#585570', bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
comvalue=tk.StringVar()
comboxlist=ttk.Combobox(mainCol1,textvariable=comvalue) #初始化
comboxlist["values"]=("2020/6/22","2020/6/15")
comboxlist.current(0)
comboxlist.pack(fill='x')
mainCol1 = Frame(sidebar2, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar2.add(mainCol1)
label1 = Label(mainCol1, text="", bg='#FFFFE1')
label1.pack(fill='x')

# mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
# mainCol1.pack(expand=True, fill='both')
# sidebar3.add(mainCol1)
# label1 = Label(mainCol1, text="美国", bg='#FFFFE1')
# label1.config(font=("System", 6))
# label1.pack(fill='x')
# mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
# mainCol1.pack(expand=True, fill='both')
# sidebar3.add(mainCol1)
# label1 = Label(mainCol1, text="日本", bg='#FFFFE1')
# label1.config(font=("System", 6))
# label1.pack(fill='x')
# mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
# mainCol1.pack(expand=True, fill='both')
# sidebar3.add(mainCol1)
# label1 = Label(mainCol1, text="欧元区", bg='#FFFFE1')
# label1.config(font=("System", 6))
# label1.pack(fill='x')
# mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
# mainCol1.pack(expand=True, fill='both')
# sidebar3.add(mainCol1)
# label1 = Label(mainCol1, text="英国", bg='#FFFFE1')
# label1.config(font=("System", 6))
# label1.pack(fill='x')
# mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
# mainCol1.pack(expand=True, fill='both')
# sidebar3.add(mainCol1)
# label1 = Label(mainCol1, text="加拿大", bg='#FFFFE1')
# label1.config(font=("System", 6))
# label1.pack(fill='x')
# mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
# mainCol1.pack(expand=True, fill='both')
# sidebar3.add(mainCol1)
# label1 = Label(mainCol1, text="澳大利亚", bg='#FFFFE1')
# label1.config(font=("System", 6))
# label1.pack(fill='x')
# mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
# mainCol1.pack(expand=True, fill='both')
# sidebar3.add(mainCol1)
# label1 = Label(mainCol1, text="新西兰", bg='#FFFFE1')
# label1.config(font=("System", 6))
# label1.pack(fill='x')
# mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
# mainCol1.pack(expand=True, fill='both')
# sidebar3.add(mainCol1)
# label1 = Label(mainCol1, text="瑞士", bg='#FFFFE1')
# label1.config(font=("System", 6))
# label1.pack(fill='x')
# mainCol1 = Frame(sidebar3, bg='#FFFFE1', borderwidth=2)
# mainCol1.pack(expand=True, fill='both')
# sidebar3.add(mainCol1)
# label1 = Label(mainCol1, text="瑞典", bg='#FFFFE1')
# label1.config(font=("System", 6))
# label1.pack(fill='x')

df1 = pd.read_excel(r"D:\work\佳期投资分析系统\全球主要国家利率.xls")
df1.columns = df1.iloc[0, :]
df1 = df1.iloc[1:, :]
mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='时间', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["时间"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='美国', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='联邦基金\n目标利率', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["联邦基金目标利率"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='贴现利率', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["贴现利率"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='日本', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='隔夜拆借利率', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["隔夜拆借利率"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='贴现率', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["贴现率"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='欧元区', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='再融资利率', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["再融资利率"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='英国', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='再回购利率', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["再回购利率1"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='加拿大', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='隔夜目标利率', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["隔夜目标利率"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='澳大利亚', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='隔夜利率', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["隔夜利率"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='新西兰', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='基准利率', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["基准利率"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='瑞士', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='目标利率', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["目标利率"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='三个月LIBOR\n目标利率', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["三个月LIBOR目标利率"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar4, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar4.add(mainCol1)
label1 = Label(mainCol1, text='瑞典', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
label1 = Label(mainCol1, text='再回购利率', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["再回购利率2"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')

mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Button(mainCol1, text="最新数据", fg='#f7fafc', bg='#99CC00')
label1.pack(fill='x')
mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Button(mainCol1, text="自定义", bg='#FFFFE1')
label1.pack(fill='x')
mainCol1 = Frame(sidebar5, bg='#FFFFE1', borderwidth=2)
mainCol1.pack(expand=True, fill='both')
sidebar5.add(mainCol1)
label1 = Label(mainCol1, text="", bg='#FFFFE1')
label1.pack(fill='x')

df1 = pd.read_excel(r"D:\work\佳期投资分析系统\全球主要国家利率-最新数据.xls")
mainCol1 = Frame(sidebar6, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='国家', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["国家"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='利率', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["利率"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='日期', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["日期"].astype(str).values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='利率排名', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["利率排名"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='当期', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["当期"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='上期', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["上期"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')
mainCol1 = Frame(sidebar6, bg='#FFFFE1')
mainCol1.pack(expand=True, fill='both')
sidebar6.add(mainCol1)
label1 = Label(mainCol1, text='利率变动', fg='#585570', bg='#FFFFE1', height=2, anchor='w')
label1.config(font=("System", 6))
label1.pack(fill='x')
for col in df1["利率变动"].values:
    label1 = Label(mainCol1, text=col, fg='#585570', bg='#FFFFE1', anchor='w')
    label1.config(font=("System", 4))
    label1.pack(fill='x')


window.mainloop()
