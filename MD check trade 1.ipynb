# %%
import pandas as pd
import random
import numpy as np

# Trade = pd.read_csv('E:\\compare\\zs_88_01_20200214_premdgw_and_sipui\\Logs\\mdTradeLog_20200214_0904.csv',
#                        encoding="utf-8")
# Order = pd.read_csv('E:\\compare\\zs_88_01_20200214_premdgw_and_sipui\\Logs\\mdOrderLog_20200214_0904.csv',
#                        encoding="utf-8")
TradeLog1 = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\check\20200324\5242\mdTradeLog_20200324_0909.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
                                                 "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
                                                 "OfferApplSeqNum"]]
OrderLog1 = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\check\20200324\5242\mdOrderLog_20200324_0909.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
                                                 "OrderQty"]]
TradeLog = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\rawData\logs_20200324_zs_92_01_day_data\mdTradeLog_20200324_0836.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
                                                 "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
                                                 "OfferApplSeqNum"]]
OrderLog = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\rawData\logs_20200324_zs_92_01_day_data\mdOrderLog_20200324_0836.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
                                                 "OrderQty"]]
# TradeLog1 = TradeLog1[TradeLog1["mdSource"] == 21].loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
#                                                  "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
#                                                  "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
#                                                  "OfferApplSeqNum"]]
# OrderLog1 = OrderLog1[OrderLog1["mdSource"] == 21].loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
#                                                  "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
#                                                  "OrderQty"]]

# TradeLog = TradeLog1[TradeLog1["mdSource"] == 21].loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
#                                                  "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
#                                                  "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
#                                                  "OfferApplSeqNum"]]
# OrderLog = OrderLog1[OrderLog1["mdSource"] == 21].loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
#                                                  "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
#                                                  "OrderQty"]]
# TradeLog1 = TradeLog1[TradeLog1["mdSource"] == 24].loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
#                                                  "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
#                                                  "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
#                                                  "OfferApplSeqNum"]]
# OrderLog1 = OrderLog1[OrderLog1["mdSource"] == 24].loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
#                                                  "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
#                                                  "OrderQty"]]

# %%
import pandas as pd
import random
import numpy as np

Trade = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\check\20200317\full_20200317_zs_52_02_day_tdf_and_premdgw\mdlog\mdTradeLog_20200317_1216.csv',
                    encoding="utf-8")
TradeLog1 = Trade[Trade["mdSource"] == 21].loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
                                                 "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
                                                 "OfferApplSeqNum"]]
TradeLog = Trade[Trade["mdSource"] == 24].loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
                                                 "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
                                                 "OfferApplSeqNum"]]
del Trade
Order = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\check\20200317\full_20200317_zs_52_02_day_tdf_and_premdgw\mdlog\mdOrderLog_20200317_1216.csv',
                    encoding="utf-8")
OrderLog1 = Order[Order["mdSource"] == 21].loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
                                                 "OrderQty"]]
OrderLog = Order[Order["mdSource"] == 24].loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
                                                 "OrderQty"]]
del Order

# %%
stocks = OrderLog1["SecurityID"].unique()
l1 = stocks[:1000]
l2 = stocks[1000:]
OrderLogSZ = OrderLog[OrderLog["SecurityID"].isin(l1)]
OrderLogSZ1 = OrderLog1[OrderLog1["SecurityID"].isin(l1)]
del OrderLog
del OrderLog1
TradeLogSZ = TradeLog[TradeLog["SecurityID"].isin(l1)]
TradeLogSZ1 = TradeLog1[TradeLog1["SecurityID"].isin(l1)]
del TradeLog
del TradeLog1
OrderLogSZ["OrderType"] = OrderLogSZ["OrderType"].apply(lambda x: str(x))
OrderLogSZ1["OrderType"] = OrderLogSZ1["OrderType"].apply(lambda x: str(x))

# %%
# OrderLogSZ = OrderLogSZ[OrderLogSZ["TransactTime"] >= 103000000]
# OrderLogSZ1 = OrderLogSZ1[OrderLogSZ1["TransactTime"] >= 103000000]
# TradeLogSZ = TradeLogSZ[TradeLogSZ["TransactTime"] >= 103000000]
# TradeLogSZ1 = TradeLogSZ1[TradeLogSZ1["TransactTime"] >= 103000000]

# %%
# columns = ["TransactTime", "ApplSeqNum", "ExecType", "TradeBSFlag", "TradePrice", "TradeQty",
#            "TradeMoney", "BidApplSeqNum", "OfferApplSeqNum"]
# TradeLogSZ1 = TradeLogSZ1.groupby("SecurityID")[TradeLogSZ1.columns[~TradeLogSZ1.columns.isin(["SecurityID"])].values].apply(
#     lambda x: x[~x.duplicated(columns, keep="first")]).reset_index()
# TradeLogSZ1 = TradeLogSZ1.drop("level_1", axis=1)
# columns = ["TransactTime", "ApplSeqNum","Side",'OrderType', 'Price', 'OrderQty']
# OrderLogSZ1 = OrderLogSZ1.groupby("SecurityID")[OrderLogSZ1.columns[~OrderLogSZ1.columns.isin(["SecurityID"])].values].apply(
#     lambda x: x[~x.duplicated(columns, keep="first")]).reset_index()
# OrderLogSZ1 = OrderLogSZ1.drop("level_1", axis=1)

# %%
import pandas as pd
import random
import numpy as np
import pickle

F1 = open("F:\\data\\20200324\\baseline\\order2.pkl", 'rb')
OrderLogSZ = pickle.load(F1)
F2 = open("F:\\data\\20200324\\zt_88_02\\order2.pkl", 'rb')
OrderLogSZ1 = pickle.load(F2)
F3 = open("F:\\data\\20200324\\baseline\\trade2.pkl", 'rb')
TradeLogSZ = pickle.load(F3)
F4 = open("F:\\data\\20200324\\zt_88_02\\trade2.pkl", 'rb')
TradeLogSZ1 = pickle.load(F4)
OrderLogSZ["OrderType"] = OrderLogSZ["OrderType"].apply(lambda x: str(x))
OrderLogSZ1["OrderType"] = OrderLogSZ1["OrderType"].apply(lambda x: str(x))
sl = list(set(OrderLogSZ["SecurityID"].unique()) & set(OrderLogSZ1['SecurityID'].unique()))
OrderLogSZ = OrderLogSZ[OrderLogSZ["SecurityID"].isin(sl)]
OrderLogSZ1 = OrderLogSZ1[OrderLogSZ1["SecurityID"].isin(sl)]
sl = list(set(TradeLogSZ["SecurityID"].unique()) & set(TradeLogSZ1['SecurityID'].unique()))
TradeLogSZ = TradeLogSZ[TradeLogSZ["SecurityID"].isin(sl)]
TradeLogSZ1 = TradeLogSZ1[TradeLogSZ1["SecurityID"].isin(sl)]
print(len(OrderLogSZ["SecurityID"].unique()))
print(len(OrderLogSZ1["SecurityID"].unique()))
print(len(TradeLogSZ["SecurityID"].unique()))
print(len(TradeLogSZ1["SecurityID"].unique()))
# Out:
# 1319
# 1319
# 1319
# 1319

# %% [markdown]
# ### Completeness check - tradelog

# %%
# columns = ["TransactTime", "ApplSeqNum","Side",'OrderType', 'Price', 'OrderQty', "SecurityID"]
TradeLogSZ["ExecType"] = TradeLogSZ["ExecType"].apply(lambda x: str(x))
TradeLogSZ1["ExecType"] = TradeLogSZ1["ExecType"].apply(lambda x: str(x))

columns = ["TransactTime","ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag","TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum","OfferApplSeqNum"]
# columns = ["TransactTime","ApplSeqNum", "SecurityID", "ExecType", "TradePrice", "TradeQty", "BidApplSeqNum","OfferApplSeqNum"]
# TradeLogSZ = TradeLogSZ[TradeLogSZ["TransactTime"] >= 130000000]
# TradeLogSZ1 = TradeLogSZ1[TradeLogSZ1["TransactTime"] >= 130000000]
re = pd.merge(TradeLogSZ, TradeLogSZ1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
n1 = re["sequenceNo_x"].count()
n2 = re["sequenceNo_y"].count()
len1 = len(re)
print(n1)
print(n2)
print(len1)
if len1 == n2:
    print((n2-n1)/n1)
print((n1-n2)/n1)
# Out:
# 15913059
# 15913059
# 15913059
# 0.0
# 0.0

# %%
re = re[~re["sequenceNo_x"].isnull()]
diff = re["clockAtArrival_y"] - re["clockAtArrival_x"]
print(np.median(diff[diff < 0]))
print(np.median(diff[diff > 0]))
print(sum(diff > 0)/len(diff))
# Out:
# -19275.0
# nan
# C:\Users\win\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\win\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 0.0

# %%
re[re["sequenceNo_y"].isnull()]
# Out:
#         clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 525     1585012505828942        638809         2      91502020       71512
# 102462  1585013407268394       2564249         2      93001810      403734
# 102463  1585013407268439       2564256         2      93001810      403741
#
#         SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 525         300323        4           N           0     20800           0
# 102462        2286        F           N       79000      1300   102700000
# 102463      300063        F           N       41200     11000   453200000
#
#         BidApplSeqNum  OfferApplSeqNum  clockAtArrival_y  sequenceNo_y  \
# 525             70726                0               NaN           NaN
# 102462         403733           396267               NaN           NaN
# 102463         403740           159375               NaN           NaN
#
#         exchId_y
# 525          NaN
# 102462       NaN
# 102463       NaN

# %%
re[re["clockAtArrival_y"] - re["clockAtArrival_x"] < 0]
# Out:
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 14613067      1.584428e+15    82170588.0       2.0     145625290    22768107
# 14613068      1.584428e+15    82170591.0       2.0     145625290    22768109
# 14613069      1.584428e+15    82170594.0       2.0     145625290    23342297
# 14613070      1.584428e+15    82170596.0       2.0     145625290    23342299
# 14613071      1.584428e+15    82170601.0       2.0     145625300    23342301
# 14613072      1.584428e+15    82170602.0       2.0     145625300    23342302
# 14613073      1.584428e+15    82170603.0       2.0     145625300    23342303
# 14613074      1.584428e+15    82170604.0       2.0     145625300    23342304
# 14613075      1.584428e+15    82170606.0       2.0     145625300    23342307
# 14613076      1.584428e+15    82170607.0       2.0     145625300    23342308
#
#           SecurityID ExecType TradeBSFlag_x  TradePrice  TradeQty  \
# ...

# %%
TradeLogSZ1["Flag"] = np.where(TradeLogSZ1["ExecType"] == "4", np.nan, np.where(
    TradeLogSZ1["BidApplSeqNum"] > TradeLogSZ1["OfferApplSeqNum"], "B", "S"))
TradeLogSZ1[TradeLogSZ1["ExecType"] == "F"][TradeLogSZ1[TradeLogSZ1["ExecType"] == "F"]["TradeBSFlag"] != TradeLogSZ1[TradeLogSZ1["ExecType"] == "F"]["Flag"]]
# Out:
# Empty DataFrame
# Columns: [clockAtArrival, sequenceNo, exchId, TransactTime, ApplSeqNum, SecurityID, ExecType, TradeBSFlag, TradePrice, TradeQty, TradeMoney, BidApplSeqNum, OfferApplSeqNum, Flag]
# Index: []

# %%
display(TradeLogSZ[(TradeLogSZ["SecurityID"] == 300323) & (TradeLogSZ["ApplSeqNum"]== 71512)])
display(TradeLogSZ1[(TradeLogSZ1["SecurityID"] == 300323) & (TradeLogSZ1["ApplSeqNum"] == 71512)])
# Out:
#         clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 1945  1585012505828942      638809       2      91502020       71512
#
#       SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 1945      300323        4           N           0     20800           0
#
#       BidApplSeqNum  OfferApplSeqNum
# 1945          70726                0
# Empty DataFrame
# Columns: [clockAtArrival, sequenceNo, exchId, TransactTime, ApplSeqNum, SecurityID, ExecType, TradeBSFlag, TradePrice, TradeQty, TradeMoney, BidApplSeqNum, OfferApplSeqNum]
# Index: []

# %%
TradeLogSZ1["TradeBSFlag"].unique()
# Out:
# array(['N', 'S', 'B'], dtype=object)

# %% [markdown]
# ### Completeness check - orderlog

# %%
columns = ["TransactTime", "ApplSeqNum","Side",'OrderType', 'Price', 'OrderQty', "SecurityID"]
# OrderLogSZ = OrderLogSZ[OrderLogSZ["TransactTime"] >= 130000000]
# OrderLogSZ1 = OrderLogSZ1[OrderLogSZ1["TransactTime"] >= 130000000]
ree = pd.merge(OrderLogSZ, OrderLogSZ1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
n1 = ree["sequenceNo_x"].count()
n2 = ree["sequenceNo_y"].count()
len1 = len(ree)
print(n1)
print(n2)
print(len1)
if len1 == n2:
    print((n2-n1)/n1)
print((n1-n2)/n1)
# Out:
# 17544728
# 17544753
# 17544753
# 1.4249294716908693e-06
# -1.4249294716908693e-06

# %%
display(len(ree[ree["sequenceNo_x"].isnull()]))
ree[ree["sequenceNo_x"].isnull()]
# Out:
# 25
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 17544728               NaN           NaN       NaN     145959930    19612903
# 17544729               NaN           NaN       NaN     145959930    19612904
# 17544730               NaN           NaN       NaN     145959940    20437161
# 17544731               NaN           NaN       NaN     145959940    20437162
# 17544732               NaN           NaN       NaN     145959940    19612906
# 17544733               NaN           NaN       NaN     145959950    20437165
# 17544734               NaN           NaN       NaN     145959950    21293795
# 17544735               NaN           NaN       NaN     145959950    19612907
# 17544736               NaN           NaN       NaN     145959960    19612909
# 17544737               NaN           NaN       NaN     145959960    19612911
# 17544738               NaN           NaN       NaN     145959960    21293799
# ...

# %%
ree = ree[~ree["sequenceNo_x"].isnull()]
diff = ree["clockAtArrival_y"] - ree["clockAtArrival_x"]
print(np.median(diff[diff < 0]))
print(np.median(diff[diff > 0]))
print(sum(diff > 0)/len(diff))
# Out:
# -18952.0
# nan
# 0.0

# %%
ree[ree["clockAtArrival_y"] - ree["clockAtArrival_x"] < 0]
# Out:
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 15332922      1.584428e+15    82170587.0       2.0     145625290    22768106
# 15332923      1.584428e+15    82170589.0       2.0     145625290    23342294
# 15332924      1.584428e+15    82170590.0       2.0     145625290    22768108
# 15332925      1.584428e+15    82170592.0       2.0     145625290    23342295
# 15332926      1.584428e+15    82170593.0       2.0     145625290    23342296
# 15332927      1.584428e+15    82170595.0       2.0     145625290    23342298
# 15332928      1.584428e+15    82170597.0       2.0     145625300    22768110
# 15332929      1.584428e+15    82170598.0       2.0     145625300    22768111
# 15332930      1.584428e+15    82170599.0       2.0     145625300    22768112
# 15332931      1.584428e+15    82170600.0       2.0     145625300    23342300
# 15332932      1.584428e+15    82170605.0       2.0     145625300    23342306
# ...

# %%
display(OrderLogSZ1[(OrderLogSZ1["SecurityID"] == 300272) & (OrderLogSZ1["ApplSeqNum"] == 69408)])
display(OrderLogSZ[(OrderLogSZ["SecurityID"] == 300272) & (OrderLogSZ["ApplSeqNum"] == 69408)])
# Out:
# Empty DataFrame
# Columns: [clockAtArrival, sequenceNo, exchId, TransactTime, ApplSeqNum, SecurityID, Side, OrderType, Price, OrderQty]
# Index: []
#           clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 286176  1585012505828963      638823       2      91502020       69408
#
#         SecurityID  Side OrderType  Price  OrderQty
# 286176      300272     1         2  40000       200

# %%
OrderLogSZ1[(OrderLogSZ1["SecurityID"] == 2069)].head()
# Out:
#         clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 863   1583889302270136      555237       2      91501900       76159
# 1116  1583889302472293      583931       2      91502090       83159
# 1274  1583889302643791      610828       2      91502330       89848
# 1370  1583889302769057      628281       2      91502500       93901
# 1854  1583889303176095      686332       2      91503060      107596
#
#       SecurityID  Side OrderType  Price  OrderQty
# 863         2069   NaN       nan    NaN       NaN
# 1116        2069   NaN       nan    NaN       NaN
# 1274        2069   NaN       nan    NaN       NaN
# 1370        2069   NaN       nan    NaN       NaN
# 1854        2069   NaN       nan    NaN       NaN

# %%
TradeLogSZ1["tradeseq"] = TradeLogSZ1.index.values
OrderLogSZ1["orderseq"] = OrderLogSZ1.index.values
SZ = pd.concat([TradeLogSZ, OrderLogSZ]).sort_values(by=["sequenceNo", "clockAtArrival"])
SZ1 = pd.concat([TradeLogSZ1, OrderLogSZ1]).sort_values(by=["sequenceNo", "clockAtArrival"])
del TradeLogSZ
# del TradeLogSZ1
del OrderLogSZ
# del OrderLogSZ1

print(len(SZ["SecurityID"].unique()))
print(len(SZ1["SecurityID"].unique()))
# Out:
# C:\Users\win\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\win\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.
# 1319
# 1319

# %%
ree = ree[~np.isnan(ree["sequenceNo_x"])]
ree = ree[~np.isnan(ree["sequenceNo_y"])]
re = pd.concat([re, ree]).sort_values(by=["sequenceNo_x"])
del ree
# re["innerSeq"] = re.sort_values(by=["sequenceNo_y", "clockAtArrival_y"]).reset_index(drop=True).index.values
# display(re.head())
# Out:
# C:\Users\win\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
SZ1[SZ1["sequenceNo"].duplicated(keep=False)]
# Out:
#           ApplSeqNum  BidApplSeqNum ExecType  OfferApplSeqNum  OrderQty  \
# 2288444       772177            NaN      NaN              NaN     500.0
# 2288446       772180            NaN      NaN              NaN    1000.0
# 13636316     5012068      4999929.0        F        5012066.0       NaN
# 13636318     5012070      5002859.0        F        5012066.0       NaN
# 13636317     5012069      5000155.0        F        5012066.0       NaN
# 11752955     4994567            NaN      NaN              NaN     200.0
# 25265878    12509539            NaN      NaN              NaN    5000.0
# 25265879    11307012            NaN      NaN              NaN     200.0
# 47087777    22487490            NaN      NaN              NaN    4200.0
# 47087778    23372810            NaN      NaN              NaN     400.0
#
#          OrderType     Price  SecurityID  Side TradeBSFlag   TradeMoney  \
# 2288444          2   92000.0         961   2.0         NaN          NaN
# ...

# %% [markdown]
# ### Completeness check - trade + order

# %%
SZ1["ExecType"] = SZ1["ExecType"].apply(lambda x: str(x))
SZ["ExecType"] = SZ["ExecType"].apply(lambda x: str(x))
# columns = ["TransactTime", "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag", "TradePrice", "TradeQty",
#            "TradeMoney", "BidApplSeqNum", "OfferApplSeqNum", "Side", "OrderType", "Price", "OrderQty"]
columns = ["TransactTime", "ApplSeqNum", "SecurityID", "ExecType", "TradePrice", "TradeQty", 
          "BidApplSeqNum", "OfferApplSeqNum", "Side", "OrderType", "Price", "OrderQty"]
re = pd.merge(SZ, SZ1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
n1 = re["sequenceNo_x"].count()
n2 = re["sequenceNo_y"].count()
len1 = len(re)
print(n1)
print(n2)
print(len1)
if len1 == n2:
    print((n2-n1)/n1)
print((n1-n2)/n1)
# Out:
# 39222250
# 39222250
# 39222250
# 0.0
# 0.0

# %%
# 1.1 find difference
re[np.isnan(re["sequenceNo_y"])]
# Out:
#           ApplSeqNum  BidApplSeqNum ExecType  OfferApplSeqNum  OrderQty  \
# 74701          95190            NaN      nan              NaN     200.0
# 74759         102068            NaN      nan              NaN     100.0
# 74760         102069            NaN      nan              NaN     500.0
# 80849         110641            NaN      nan              NaN    7800.0
# 80850         110642            NaN      nan              NaN    8400.0
# ...              ...            ...      ...              ...       ...
# 19329538    23952125            NaN      nan              NaN    1000.0
# 19329539    23952126     23952125.0        F       23943069.0       NaN
# 21547835    27768266            NaN      nan              NaN    1000.0
# 21547836    27768267            NaN      nan              NaN     400.0
# 21548941    27769743            NaN      nan              NaN    5000.0
#
#          OrderType     Price  SecurityID  Side TradeBSFlag   TradeMoney  \
# ...

# %%
SZ1[(SZ1["SecurityID"] == 300059) & (SZ1["TransactTime"] == 91503150)]
# Out:
#         ApplSeqNum  BidApplSeqNum ExecType  OfferApplSeqNum  OrderQty  \
# 376503       95631            NaN      nan              NaN     300.0
# 376504       95632            NaN      nan              NaN     100.0
# 376518       95633            NaN      nan              NaN     200.0
# 376568       95646            NaN      nan              NaN     200.0
# 376581       95648            NaN      nan              NaN     200.0
# 376628       95659            NaN      nan              NaN     200.0
# 376771       95664            NaN      nan              NaN     200.0
# 376776       95669            NaN      nan              NaN     200.0
# 376783       95676            NaN      nan              NaN     200.0
# 376838       95731            NaN      nan              NaN     100.0
# 376840       95733            NaN      nan              NaN     100.0
# 376841       95734            NaN      nan              NaN     100.0
#
# ...

# %%
SZ[(SZ["SecurityID"] == 300059) & (SZ["TransactTime"] == 91503150)]
# Out:
#         ApplSeqNum  BidApplSeqNum ExecType  OfferApplSeqNum  OrderQty  \
# 381796       95631            NaN      nan              NaN     300.0
# 381797       95632            NaN      nan              NaN     100.0
# 381804       95633            NaN      nan              NaN     200.0
# 381821       95637            NaN      nan              NaN     200.0
# 381961       95646            NaN      nan              NaN     200.0
# 382010       95648            NaN      nan              NaN     200.0
# 382060       95659            NaN      nan              NaN     200.0
# 382314       95664            NaN      nan              NaN     200.0
# 382323       95669            NaN      nan              NaN     200.0
# 382332       95676            NaN      nan              NaN     200.0
# 382627       95731            NaN      nan              NaN     100.0
# 382629       95733            NaN      nan              NaN     100.0
# ...

# %%
OrderLog1[(OrderLog1["SecurityID"] == 78) & (OrderLog1["TransactTime"] <= 91500730)]
# Out:
#           clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 5422    1579482960375162       26937       2      91500000         633
# 5487    1579482960375236       27002       2      91500010         700
# 5573    1579482960375278       27089       2      91500020         799
# 6692    1579482960385932       28208       2      91500020        1097
# 6698    1579482960385934       28214       2      91500020        1103
# ...                  ...         ...     ...           ...         ...
# 126401  1579482961214305      149494       2      91500700       34943
# 127636  1579482961225292      150729       2      91500700       35206
# 127902  1579482961225514      150997       2      91500700       35343
# 127945  1579482961225537      151040       2      91500700       35388
# 129641  1579482961236419      152737       2      91500710       35742
#
#         SecurityID  Side OrderType  Price  OrderQty
# 5422            78     1         2  40300    796900
# ...

# %%
OrderLog[(OrderLog["SecurityID"] == 78) & (OrderLog["TransactTime"] <= 91500730)]
# Out:
#           clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 5487    1579482911202417      290628       2      91500000         633
# 5553    1579482911202740      290694       2      91500010         700
# 5641    1579482911203166      290783       2      91500020         799
# 6762    1579482911212002      291904       2      91500020        1097
# 6768    1579482911212009      291910       2      91500020        1103
# ...                  ...         ...     ...           ...         ...
# 136128  1579482912063425      424360       2      91500710       35742
# 136461  1579482912065292      424699       2      91500710       35944
# 138249  1579482912076728      426494       2      91500720       36262
# 138258  1579482912076782      426503       2      91500720       36271
# 138262  1579482912076796      426507       2      91500720       36275
#
#         SecurityID  Side OrderType  Price  OrderQty
# 5487            78     1         2  40300    796900
# ...

# %%
TradeLog[TradeLog["SecurityID"] == 78].head(10)
# Out:
#         clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 226   1579482912065310      424705       2      91500710       35950
# 240   1579482912084739      427859       2      91500720       36521
# 292   1579482912234192      450817       2      91500850       42526
# 2027  1579482915086947      706103       2      91503950      106070
# 2337  1579482916306796      738626       2      91505170      114238
# 3051  1579482928250477      776630       2      91517110      121494
# 3417  1579482939509548      782421       2      91528370      122380
# 3892  1579482954302080      790040       2      91543160      123584
# 3995  1579482957155520      791909       2      91546010      123814
# 4056  1579482958849996      792577       2      91547710      123929
#
#       SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 226           78        4           N           0      4000           0
# ...

# %%
OrderLog1[OrderLog1["SecurityID"] == 300752].head(20)
# Out:
#           clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 16687   1579482960456392       38220       2      91500100        5115
# 19293   1579482960476507       40828       2      91500110        5623
# 26066   1579482960521407       47615       2      91500160        7457
# 33688   1579482960579002       55245       2      91500190        9524
# 33692   1579482960579005       55249       2      91500190        9528
# 40086   1579482960623623       61656       2      91500210       11216
# 40087   1579482960623625       61657       2      91500210       11217
# 48653   1579482960679980       70230       2      91500270       13808
# 48661   1579482960679984       70238       2      91500270       13816
# 48662   1579482960679985       70239       2      91500270       13817
# 58657   1579482960752235       80265       2      91500320       16521
# 69733   1579482960829397       91819       2      91500410       19822
# ...

# %%
OrderLog[OrderLog["SecurityID"] == 300752].head(20)
# Out:
#           clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 18247   1579482911292037      303408       2      91500100        5115
# 19910   1579482911303172      305072       2      91500110        5623
# 26516   1579482911349560      311689       2      91500160        7457
# 27314   1579482911357545      312490       2      91500160        7552
# 27333   1579482911357791      312509       2      91500160        7554
# 34889   1579482911405493      320075       2      91500190        9524
# 34893   1579482911405496      320079       2      91500190        9528
# 41610   1579482911449680      326809       2      91500210       11216
# 41611   1579482911449682      326810       2      91500210       11217
# 50936   1579482911509254      336147       2      91500270       13808
# 50944   1579482911509277      336155       2      91500270       13816
# 50945   1579482911509277      336156       2      91500270       13817
# ...

# %%
# 2. ordering within stocks 
columns = ["TransactTime", "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag", "TradePrice", "TradeQty",
           "TradeMoney", "BidApplSeqNum", "OfferApplSeqNum", "Side", "OrderType", "Price", "OrderQty"]
# columns = ["TransactTime", "ApplSeqNum", "SecurityID", "ExecType", "TradePrice", "TradeQty",
#            "BidApplSeqNum", "OfferApplSeqNum", "Side", "OrderType", "Price", "OrderQty"]
stocks = SZ["SecurityID"].unique()
m = 0
diff = []
# SZ1 = SZ1.reset_index().iloc[:, 1:]
# SZ1["innerSeq"] = SZ1.index.values
for i in stocks:
    re1 = pd.merge(SZ[SZ["SecurityID"] == i], SZ1[SZ1["SecurityID"] == i], left_on=columns, right_on=columns, how="inner")
    if (sorted(re1["sequenceNo_y"]) != re1["sequenceNo_y"]).any() == False:
        m = m + 1
    else:
        diff.append(i)
if m == len(stocks):
    print("SZE Trade + Order Data have same ordering within stocks")
print(m)
print(diff)
# Out:
# SZE Trade + Order Data have same ordering within stocks
# 1319
# []

# %%
# SZ1 = SZ1.reset_index().iloc[:, 1:]
# SZ1["innerSeq_y"] = SZ1.index.values
# SZ2 = SZ2.reset_index().iloc[:, 1:]
# SZ2["innerSeq_x"] = SZ2.index.values
# columns = ["TransactTime", "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag", "TradePrice", "TradeQty","TradeMoney",
#            "BidApplSeqNum", "OfferApplSeqNum", "Side", "OrderType", "Price", "OrderQty"]
# SZ1 = SZ1.reset_index(drop=True)
# SZ1["innerSeq"] = SZ1.index.values
for i in [300615, 2286, 596, 300680]:
    re1 = pd.merge(SZ[SZ["SecurityID"] == i], SZ1[SZ1["SecurityID"] == i], left_on=columns, right_on=columns, how="inner")
#     display(re1[sorted(re1["innerSeq"]) != re1["innerSeq"]].loc[:,["ApplSeqNum", "ExecType", "SecurityID", "clockAtArrival_y", 
#                                                                 "TradePrice", "TradeQty", "TradeMoney_y"]])
    display(re1[sorted(re1["sequenceNo_y"]) != re1["sequenceNo_y"]])
# Out:
#      ApplSeqNum  BidApplSeqNum ExecType  OfferApplSeqNum  OrderQty OrderType  \
# 425      403687       403686.0        F         326458.0       NaN       NaN
# 426      403688       403686.0        F         355271.0       NaN       NaN
# 427      403689       403686.0        F         373661.0       NaN       NaN
# 428      403690       403686.0        F         380788.0       NaN       NaN
# 429      403691       403686.0        F         156893.0       NaN       NaN
# 430      403865            NaN      NaN              NaN    5000.0         2
# 431      404130            NaN      NaN              NaN     100.0         2
#
#         Price  SecurityID  Side TradeBSFlag  ...  TradeQty  TransactTime  \
# 425       NaN      300615   NaN           N  ...    1000.0      93001810
# 426       NaN      300615   NaN           N  ...     500.0      93001810
# 427       NaN      300615   NaN           N  ...     100.0      93001810
# ...

# %%
TradeLogSZ1[TradeLogSZ1["sequenceNo"] >= 38223259]
# Out:
#             clockAtArrival  sequenceNo  exchId  TransactTime  ApplSeqNum  \
# 13773595  1583791767305963    38223260       2     130000090    16183672
# 13773596  1583791767305963    38223261       2     130000090    16183673
# 13773597  1583791767305963    38223262       2     130000090    16183674
# 13773598  1583791767305963    38223263       2     130000090    16183675
# 13773599  1583791767305963    38223262       2     130000090    16183676
# ...                    ...         ...     ...           ...         ...
# 44466740  1583798969486229   121124744       2     150000000    27544830
# 44466741  1583798969486229   121124745       2     150000000    27544831
# 44466742  1583798969486229   121124746       2     150000000    27544832
# 44466743  1583798969486229   121124747       2     150000000    27544833
# 44466744  1583798969486229   121124748       2     150000000    27544834
#
#           SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# ...

# %%
re1 = pd.merge(SZ[SZ["SecurityID"] == 2614], SZ1[SZ1["SecurityID"] == 2614], left_on=columns, right_on=columns, how="inner")
display(re1[sorted(re1["sequenceNo_y"]) != re1["sequenceNo_y"]])
# Out:
#        ApplSeqNum  BidApplSeqNum ExecType  OfferApplSeqNum  OrderQty  \
# 42798     5012069      5000155.0        F        5012066.0       NaN
# 42799     5012070      5002859.0        F        5012066.0       NaN
#
#       OrderType  Price  SecurityID  Side TradeBSFlag_x  ...  TransactTime  \
# 42798       NaN    NaN        2614   NaN             N  ...      94446050
# 42799       NaN    NaN        2614   NaN             N  ...      94446050
#
#        clockAtArrival_x  exchId_x  sequenceNo_x  TradeBSFlag_y  TradeMoney_y  \
# 42798  1583718286541651         2      28713300              S   546400000.0
# 42799  1583718286541652         2      28713301              S   136600000.0
#
#        clockAtArrival_y exchId_y  sequenceNo_y  innerSeq
# 42798  1583693652713825        2      33654980   8462384
# 42799  1583693652713825        2      33654979   8462383
#
# [2 rows x 23 columns]

# %%
re1[re1["sequenceNo_y"] == 33654979]
# Out:
#        ApplSeqNum  BidApplSeqNum ExecType  OfferApplSeqNum  OrderQty  \
# 42797     5012068      4999929.0        F        5012066.0       NaN
# 42799     5012070      5002859.0        F        5012066.0       NaN
#
#       OrderType  Price  SecurityID  Side TradeBSFlag_x  ...  TransactTime  \
# 42797       NaN    NaN        2614   NaN             N  ...      94446050
# 42799       NaN    NaN        2614   NaN             N  ...      94446050
#
#        clockAtArrival_x  exchId_x  sequenceNo_x  TradeBSFlag_y  TradeMoney_y  \
# 42797  1583718286541648         2      28713299              S    27320000.0
# 42799  1583718286541652         2      28713301              S   136600000.0
#
#        clockAtArrival_y exchId_y  sequenceNo_y  innerSeq
# 42797  1583693652713825        2      33654979   8462382
# 42799  1583693652713825        2      33654979   8462383
#
# [2 rows x 23 columns]

# %%
data[data["sequenceNo_x"]>=516160].loc[:,["ApplSeqNum", "TransactTime", "sequenceNo_x", "sequenceNo_y", "SecurityID"]]
# Out:
#        ApplSeqNum  TransactTime  sequenceNo_x  sequenceNo_y  SecurityID
# 0          153755      91944850       2940315        616762        2137
# 1          153814      91945270       2940582        617004        2137
# 2          154026      91946640       2942144        617761        2137
# 3          154097      91947160       2943220        618028        2137
# 4          154154      91947540       2943529        618225        2137
# ...           ...           ...           ...           ...         ...
# 64906    16426826     150000000     130284133      69880970        2137
# 64907    16426827     150000000     130284134      69880971        2137
# 64908    16426828     150000000     130284135      69880972        2137
# 64909    16426829     150000000     130284136      69880973        2137
# 64910    16426830     150000000     130284137      69880974        2137
#
# [64911 rows x 5 columns]

# %%
# 3. ordering among stocks
if (sorted(re["sequenceNo_y"]) != re["sequenceNo_y"]).any():
    display(re[sorted(re["sequenceNo_y"]) != re["sequenceNo_y"]])
    print("SZE Trade + Order Data don't have same ordering among stocks")
print(len(re))
print(len(re[sorted(re["sequenceNo_y"]) != re["sequenceNo_y"]]))
print(sum(sorted(re["sequenceNo_y"]) != re["sequenceNo_y"]))
# Out:
#           ApplSeqNum  BidApplSeqNum ExecType  OfferApplSeqNum  OrderQty  \
# 8           11932345            NaN      NaN              NaN   80100.0
# 168         11261173     11261028.0        F        8029450.0       NaN
# 169         11261174     11261028.0        F        8481234.0       NaN
# 170         11261175     11261028.0        F        9107972.0       NaN
# 171         11261176     11261028.0        F        9140161.0       NaN
# ...              ...            ...      ...              ...       ...
# 11442295    21358567     21285573.0        F       21213760.0       NaN
# 11442296    21358568     21287883.0        F       21213760.0       NaN
# 11442297    21358569     21290955.0        F       21213760.0       NaN
# 11442298    21358570     21293244.0        F       21213760.0       NaN
# 11442299    21358571     21293244.0        F       21216360.0       NaN
#
#          OrderType     Price  SecurityID  Side TradeBSFlag   TradeMoney  \
# ...

# %%
# 4. speed check
diff = re["clockAtArrival_y"] - re["clockAtArrival_x"]
print(np.median(diff[diff < 0]))
print(np.median(diff[diff > 0]))
print(sum(diff < 0)/len(diff))
# Out:
# -1228.0
# 570.0
# 0.9999998859935689
