# %%
import pandas as pd
import random
import numpy as np
import glob
import os
import pickle

startDate = "20200429"
endDate = "20200506"
readPath = r'\\192.168.10.30\Kevin_zhenyu\rawData\***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([os.path.basename(i).split('_')[1] for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs >= startDate) & (dateLs <= endDate)]
opath = []
tpath = []
for i in dataPathLs:
    opath.append(glob.glob(os.path.join(i, "mdOrderLog_***")))
    tpath.append(glob.glob(os.path.join(i, "mdTradeLog_***")))
opath1 = opath[::2]
opath2 = opath[1::2]
tpath1 = tpath[::2]
tpath2 = tpath[1::2]
print(opath1)
print(opath2)
print(tpath1)
print(tpath2)
F1 = open("\\\\192.168.10.30\\Kevin_zhenyu\\index\\weight_table_CSI1000.pkl", 'rb')
df1 = pickle.load(F1)


for i in range(len(opath1)):
    print(tpath2[i][0])
    TradeLog = pd.read_csv(tpath2[i][0], encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
                                                 "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
                                                 "OfferApplSeqNum"]]
    OrderLog = pd.read_csv(opath2[i][0], encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
                                                 "OrderQty"]]
    print(tpath1[i][0])
    TradeLog1 = pd.read_csv(tpath1[i][0], encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
                                                 "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
                                                 "OfferApplSeqNum"]]
    OrderLog1 = pd.read_csv(opath1[i][0], encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
                                                 "OrderQty"]]
    stocks = OrderLog1["SecurityID"].unique()
    
    d_ate = os.path.basename(tpath1[i][0]).split('_')[1]
    d_ate = d_ate[:4] + '-' + d_ate[4:6] + '-' + d_ate[6:]
    ID_list = df1[df1["date"] == d_ate]["ID"]
    len1 = ID_list[ID_list.str[:2] == "SH"].shape[0]
    len2 = ID_list[ID_list.str[:2] == "SZ"].shape[0]
    print(len1)
    print(len2)
    ID_list = ID_list.str[2:].astype(int)
    
    l1 = stocks[:1000]
    OrderLogSZ = OrderLog[OrderLog["SecurityID"].isin(l1)]
    OrderLogSZ1 = OrderLog1[OrderLog1["SecurityID"].isin(l1)]
    del OrderLog
    del OrderLog1
    OrderLogSZ["idx"] = np.where(OrderLogSZ["SecurityID"].isin(ID_list.values), 1, 0)
    OrderLogSZ1["idx"] = np.where(OrderLogSZ1["SecurityID"].isin(ID_list.values), 1, 0)
    print(len(OrderLogSZ["SecurityID"].unique()))
    print(len(OrderLogSZ1["SecurityID"].unique()))
    TradeLogSZ = TradeLog[TradeLog["SecurityID"].isin(l1)]
    TradeLogSZ1 = TradeLog1[TradeLog1["SecurityID"].isin(l1)]
    TradeLogSZ["idx"] = np.where(TradeLogSZ["SecurityID"].isin(ID_list.values), 1, 0)
    TradeLogSZ1["idx"] = np.where(TradeLogSZ1["SecurityID"].isin(ID_list.values), 1, 0)
    print(len(TradeLogSZ["SecurityID"].unique()))
    print(len(TradeLogSZ1["SecurityID"].unique()))
    del TradeLog
    del TradeLog1
    OrderLogSZ["OrderType"] = OrderLogSZ["OrderType"].apply(lambda x: str(x))
    OrderLogSZ1["OrderType"] = OrderLogSZ1["OrderType"].apply(lambda x: str(x))
    
    # TradeLog check
    TradeLogSZ["ExecType"] = TradeLogSZ["ExecType"].apply(lambda x: str(x))
    TradeLogSZ1["ExecType"] = TradeLogSZ1["ExecType"].apply(lambda x: str(x))
    columns = ["TransactTime","ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag","TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum","OfferApplSeqNum"]
    re = pd.merge(TradeLogSZ, TradeLogSZ1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
    n1 = re["sequenceNo_x"].count()
    n2 = re["sequenceNo_y"].count()
    len1 = len(re)
    display(os.path.basename(os.path.basename(tpath2[i][0]).split("_")[1] + "_TradeLog Check_first 1000:"))
    print(n1)
    print(n2)
    print(len1)
    if len1 == n2:
            print((n2-n1)/n1)
    print((n1-n2)/n1)
    display(re[re["sequenceNo_y"].isnull()])
    display(re[re["sequenceNo_y"].isnull()]["SecurityID"].unique())
    display(re[re["sequenceNo_y"].isnull()]["TransactTime"].unique())
    display(re[(re["sequenceNo_y"].isnull()) & (re["idx_x"] == 1)])
    display(re[(re["sequenceNo_y"].isnull()) & (re["idx_x"] == 1)]["SecurityID"].unique())
    display(re[(re["sequenceNo_y"].isnull()) & (re["idx_x"] == 1)]["TransactTime"].unique())
    display(re[(re["sequenceNo_y"].isnull()) & (re["idx_x"] == 0)])
    display(re[(re["sequenceNo_y"].isnull()) & (re["idx_x"] == 0)]["SecurityID"].unique())
    display(re[(re["sequenceNo_y"].isnull()) & (re["idx_x"] == 0)]["TransactTime"].unique())
    
    display(re[re["sequenceNo_x"].isnull()])
    
    # OrderLog check    
    columns = ["TransactTime", "ApplSeqNum","Side",'OrderType', 'Price', 'OrderQty', "SecurityID"]
    ree = pd.merge(OrderLogSZ, OrderLogSZ1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
    n1 = ree["sequenceNo_x"].count()
    n2 = ree["sequenceNo_y"].count()
    len1 = len(ree)
    display(os.path.basename(os.path.basename(tpath2[i][0]).split("_")[1] + "_OrderLog Check_first 1000:"))
    print(n1)
    print(n2)
    print(len1)
    if len1 == n2:
            print((n2-n1)/n1)
    print((n1-n2)/n1)
    display(ree[np.isnan(ree["sequenceNo_y"])])
    display(ree[ree["sequenceNo_y"].isnull()]["SecurityID"].unique())
    display(ree[ree["sequenceNo_y"].isnull()]["TransactTime"].unique())
    display(ree[(np.isnan(ree["sequenceNo_y"])) & (ree["idx_x"] == 1)])
    display(ree[(np.isnan(ree["sequenceNo_y"])) & (ree["idx_x"] == 1)]["SecurityID"].unique())
    display(ree[(np.isnan(ree["sequenceNo_y"])) & (ree["idx_x"] == 1)]["TransactTime"].unique())
    display(ree[(np.isnan(ree["sequenceNo_y"])) & (ree["idx_x"] == 0)])
    display(ree[(np.isnan(ree["sequenceNo_y"])) & (ree["idx_x"] == 0)]["SecurityID"].unique())
    display(ree[(np.isnan(ree["sequenceNo_y"])) & (ree["idx_x"] == 0)]["TransactTime"].unique())
    
    display(ree[np.isnan(ree["sequenceNo_x"])])

    
#     # among stocks ordering check
#     TradeLogSZ1["tradeseq"] = TradeLogSZ1.index.values
#     OrderLogSZ1["orderseq"] = OrderLogSZ1.index.values
#     SZ = pd.concat([TradeLogSZ, OrderLogSZ]).sort_values(by=["sequenceNo", "clockAtArrival"])
#     SZ1 = pd.concat([TradeLogSZ1, OrderLogSZ1]).sort_values(by=["sequenceNo", "clockAtArrival"])
#     del TradeLogSZ
#     del TradeLogSZ1
#     del OrderLogSZ
#     del OrderLogSZ1
#     print(len(SZ["SecurityID"].unique()))
#     print(len(SZ1["SecurityID"].unique()))
    
#     # within stocks ordering check
#     columns = ["TransactTime", "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag", "TradePrice", "TradeQty",
#            "TradeMoney", "BidApplSeqNum", "OfferApplSeqNum", "Side", "OrderType", "Price", "OrderQty"]
#     stocks = SZ["SecurityID"].unique()
#     m = 0
#     diff = []
#     for i1 in stocks:
#         re1 = pd.merge(SZ[SZ["SecurityID"] == i1], SZ1[SZ1["SecurityID"] == i1], left_on=columns, right_on=columns, how="inner")
#         if (sorted(re1["sequenceNo_y"]) != re1["sequenceNo_y"]).any() == False:
#             m = m + 1
#         else:
#             diff.append(i1)
#     display(os.path.basename(os.path.basename(tpath2[i][0]).split("_")[1] + "_Ordering within stocks_first 1000:"))
#     if m == len(stocks):
#         print("SZE Trade + Order Data have same ordering within stocks")
#     print(m)
#     print(diff)
#     if len(diff)!=0:
#         for i1 in diff:
#             re1 = pd.merge(SZ[SZ["SecurityID"] == i1], SZ1[SZ1["SecurityID"] == i1], left_on=columns, right_on=columns, how="inner")
#             display(re1[sorted(re1["sequenceNo_y"]) != re1["sequenceNo_y"]])
#     del re1
#     del SZ
#     del SZ1
    
            
    print(tpath2[i][0])        
    TradeLog = pd.read_csv(tpath2[i][0], encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
                                                 "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
                                                 "OfferApplSeqNum"]]
    OrderLog = pd.read_csv(opath2[i][0], encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
                                                 "OrderQty"]]
    print(tpath1[i][0])
    TradeLog1 = pd.read_csv(tpath1[i][0], encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag",
                                                 "TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum",
                                                 "OfferApplSeqNum"]]
    OrderLog1 = pd.read_csv(opath1[i][0], encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "exchId", "TransactTime",
                                                 "ApplSeqNum", "SecurityID", "Side", "OrderType", "Price",
                                                 "OrderQty"]]
    stocks = OrderLog1["SecurityID"].unique()
    l1 = stocks[1000:]
    OrderLogSZ = OrderLog[OrderLog["SecurityID"].isin(l1)]
    OrderLogSZ1 = OrderLog1[OrderLog1["SecurityID"].isin(l1)]
    OrderLogSZ["idx"] = np.where(OrderLogSZ["SecurityID"].isin(ID_list.values), 1, 0)
    OrderLogSZ1["idx"] = np.where(OrderLogSZ1["SecurityID"].isin(ID_list.values), 1, 0)
    print(len(OrderLogSZ["SecurityID"].unique()))
    print(len(OrderLogSZ1["SecurityID"].unique()))
    del OrderLog
    del OrderLog1
    TradeLogSZ = TradeLog[TradeLog["SecurityID"].isin(l1)]
    TradeLogSZ1 = TradeLog1[TradeLog1["SecurityID"].isin(l1)]
    TradeLogSZ["idx"] = np.where(TradeLogSZ["SecurityID"].isin(ID_list.values), 1, 0)
    TradeLogSZ1["idx"] = np.where(TradeLogSZ1["SecurityID"].isin(ID_list.values), 1, 0)
    print(len(TradeLogSZ["SecurityID"].unique()))
    print(len(TradeLogSZ1["SecurityID"].unique()))
    del TradeLog
    del TradeLog1
    OrderLogSZ["OrderType"] = OrderLogSZ["OrderType"].apply(lambda x: str(x))
    OrderLogSZ1["OrderType"] = OrderLogSZ1["OrderType"].apply(lambda x: str(x))
    
    # TradeLog check
    TradeLogSZ["ExecType"] = TradeLogSZ["ExecType"].apply(lambda x: str(x))
    TradeLogSZ1["ExecType"] = TradeLogSZ1["ExecType"].apply(lambda x: str(x))
    columns = ["TransactTime","ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag","TradePrice", "TradeQty", "TradeMoney", "BidApplSeqNum","OfferApplSeqNum"]
    re = pd.merge(TradeLogSZ, TradeLogSZ1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
    n1 = re["sequenceNo_x"].count()
    n2 = re["sequenceNo_y"].count()
    len1 = len(re)
    display(os.path.basename(os.path.basename(tpath2[i][0]).split("_")[1] + "_TradeLog Check_second 1000:"))
    print(n1)
    print(n2)
    print(len1)
    if len1 == n2:
            print((n2-n1)/n1)
    print((n1-n2)/n1)
    display(re[re["sequenceNo_y"].isnull()])
    display(re[re["sequenceNo_y"].isnull()]["SecurityID"].unique())
    display(re[re["sequenceNo_y"].isnull()]["TransactTime"].unique())
    display(re[(re["sequenceNo_y"].isnull()) & (re["idx_x"] == 1)])
    display(re[(re["sequenceNo_y"].isnull()) & (re["idx_x"] == 1)]["SecurityID"].unique())
    display(re[(re["sequenceNo_y"].isnull()) & (re["idx_x"] == 1)]["TransactTime"].unique())
    display(re[(re["sequenceNo_y"].isnull()) & (re["idx_x"] == 0)])
    display(re[(re["sequenceNo_y"].isnull()) & (re["idx_x"] == 0)]["SecurityID"].unique())
    display(re[(re["sequenceNo_y"].isnull()) & (re["idx_x"] == 0)]["TransactTime"].unique())
    
    display(re[re["sequenceNo_x"].isnull()])
    
    # OrderLog check    
    columns = ["TransactTime", "ApplSeqNum","Side",'OrderType', 'Price', 'OrderQty', "SecurityID"]
    ree = pd.merge(OrderLogSZ, OrderLogSZ1, left_on=columns, right_on=columns, how="outer", validate='one_to_one')
    n1 = ree["sequenceNo_x"].count()
    n2 = ree["sequenceNo_y"].count()
    len1 = len(ree)
    display(os.path.basename(os.path.basename(tpath2[i][0]).split("_")[1] + "_OrderLog Check_second 1000:"))
    print(n1)
    print(n2)
    print(len1)
    if len1 == n2:
            print((n2-n1)/n1)
    print((n1-n2)/n1)
    display(ree[np.isnan(ree["sequenceNo_y"])])
    display(ree[ree["sequenceNo_y"].isnull()]["SecurityID"].unique())
    display(ree[ree["sequenceNo_y"].isnull()]["TransactTime"].unique())
    display(ree[(np.isnan(ree["sequenceNo_y"])) & (ree["idx_x"] == 1)])
    display(ree[(np.isnan(ree["sequenceNo_y"])) & (ree["idx_x"] == 1)]["SecurityID"].unique())
    display(ree[(np.isnan(ree["sequenceNo_y"])) & (ree["idx_x"] == 1)]["TransactTime"].unique())
    display(ree[(np.isnan(ree["sequenceNo_y"])) & (ree["idx_x"] == 0)])
    display(ree[(np.isnan(ree["sequenceNo_y"])) & (ree["idx_x"] == 0)]["SecurityID"].unique())
    display(ree[(np.isnan(ree["sequenceNo_y"])) & (ree["idx_x"] == 0)]["TransactTime"].unique())
    
    display(ree[np.isnan(ree["sequenceNo_x"])])
    
#     # among stocks ordering check
#     TradeLogSZ1["tradeseq"] = TradeLogSZ1.index.values
#     OrderLogSZ1["orderseq"] = OrderLogSZ1.index.values
#     SZ = pd.concat([TradeLogSZ, OrderLogSZ]).sort_values(by=["sequenceNo", "clockAtArrival"])
#     SZ1 = pd.concat([TradeLogSZ1, OrderLogSZ1]).sort_values(by=["sequenceNo", "clockAtArrival"])
#     del TradeLogSZ
#     del TradeLogSZ1
#     del OrderLogSZ
#     del OrderLogSZ1
#     print(len(SZ["SecurityID"].unique()))
#     print(len(SZ1["SecurityID"].unique()))
    
#     # within stocks ordering check
#     columns = ["TransactTime", "ApplSeqNum", "SecurityID", "ExecType", "TradeBSFlag", "TradePrice", "TradeQty",
#            "TradeMoney", "BidApplSeqNum", "OfferApplSeqNum", "Side", "OrderType", "Price", "OrderQty"]
#     stocks = SZ["SecurityID"].unique()
#     m = 0
#     diff = []
#     for i1 in stocks:
#         re1 = pd.merge(SZ[SZ["SecurityID"] == i1], SZ1[SZ1["SecurityID"] == i1], left_on=columns, right_on=columns, how="inner")
#         if (sorted(re1["sequenceNo_y"]) != re1["sequenceNo_y"]).any() == False:
#             m = m + 1
#         else:
#             diff.append(i1)
#     display(os.path.basename(os.path.basename(tpath2[i][0]).split("_")[1] + "_Ordering within stocks_second 1000:"))
#     if m == len(stocks):
#         print("SZE Trade + Order Data have same ordering within stocks")
#     print(m)
#     print(diff)
#     if len(diff)!=0:
#         for i1 in diff:
#             re1 = pd.merge(SZ[SZ["SecurityID"] == i1], SZ1[SZ1["SecurityID"] == i1], left_on=columns, right_on=columns, how="inner")
#             display(re1[sorted(re1["sequenceNo_y"]) != re1["sequenceNo_y"]])
#     del re1
#     del SZ
#     del SZ1
# Out:
# [['\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_20200429_zs_92_01_day_data\\mdOrderLog_20200429_0851.csv'], ['\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_20200430_zs_92_01_day_data\\mdOrderLog_20200430_0847.csv'], ['\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_20200506_zs_92_01_day_data\\mdOrderLog_20200506_0833.csv']]
# [['\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_20200429_zt_96_04_day_96data\\mdOrderLog_20200429_0853.csv'], ['\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_20200430_zt_96_04_day_96data\\mdOrderLog_20200430_0848.csv'], ['\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_20200506_zt_96_04_day_96data\\mdOrderLog_20200506_0835.csv']]
# [['\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_20200429_zs_92_01_day_data\\mdTradeLog_20200429_0851.csv'], ['\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_20200430_zs_92_01_day_data\\mdTradeLog_20200430_0847.csv'], ['\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_20200506_zs_92_01_day_data\\mdTradeLog_20200506_0833.csv']]
# [['\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_20200429_zt_96_04_day_96data\\mdTradeLog_20200429_0853.csv'], ['\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_20200430_zt_96_04_day_96data\\mdTradeLog_20200430_0848.csv'], ['\\\\192.168.10.30\\Kevin_zhenyu\\rawData\\logs_20200506_zt_96_04_day_96data\\mdTradeLog_20200506_0835.csv']]
# \\192.168.10.30\Kevin_zhenyu\rawData\logs_20200429_zt_96_04_day_96data\mdTradeLog_20200429_0853.csv
# C:\Users\win\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# \\192.168.10.30\Kevin_zhenyu\rawData\logs_20200429_zs_92_01_day_data\mdTradeLog_20200429_0851.csv
# 360
# 640
# 1000
# 1000
# C:\Users\win\Anaconda3\lib\site-packages\ipykernel_launcher.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\win\Anaconda3\lib\site-packages\ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1000
# 1000
# '20200429_TradeLog Check_first 1000:'
# 17786235
# 17786233
# 17786235
# 1.1244650708820613e-07
#       clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 1311  1588122902417442        625295         2      91503490       91036
# 1316  1588122902417975        625464         2      91503490       92698
#
#       SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 1311        2204        4           N           0     12200           0
# 1316         636        4           N           0       900           0
#
#       BidApplSeqNum  OfferApplSeqNum  idx_x  clockAtArrival_y  sequenceNo_y  \
# 1311              0            75149      1               NaN           NaN
# 1316          47320                0      0               NaN           NaN
#
#       exchId_y  idx_y
# 1311       NaN    NaN
# 1316       NaN    NaN
# array([2204,  636], dtype=int64)
# array([91503490], dtype=int64)
#       clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 1311  1588122902417442        625295         2      91503490       91036
#
#       SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 1311        2204        4           N           0     12200           0
#
#       BidApplSeqNum  OfferApplSeqNum  idx_x  clockAtArrival_y  sequenceNo_y  \
# 1311              0            75149      1               NaN           NaN
#
#       exchId_y  idx_y
# 1311       NaN    NaN
# array([2204], dtype=int64)
# array([91503490], dtype=int64)
#       clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 1316  1588122902417975        625464         2      91503490       92698
#
#       SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 1316         636        4           N           0       900           0
#
#       BidApplSeqNum  OfferApplSeqNum  idx_x  clockAtArrival_y  sequenceNo_y  \
# 1316          47320                0      0               NaN           NaN
#
#       exchId_y  idx_y
# 1316       NaN    NaN
# array([636], dtype=int64)
# array([91503490], dtype=int64)
# Empty DataFrame
# Columns: [clockAtArrival_x, sequenceNo_x, exchId_x, TransactTime, ApplSeqNum, SecurityID, ExecType, TradeBSFlag, TradePrice, TradeQty, TradeMoney, BidApplSeqNum, OfferApplSeqNum, idx_x, clockAtArrival_y, sequenceNo_y, exchId_y, idx_y]
# Index: []
# '20200429_OrderLog Check_first 1000:'
# 20017793
# 20017414
# 20017793
# 1.8933156117659924e-05
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 231964    1588122902401601        623751         2      91503460       92307
# 231965    1588122902401601        623752         2      91503460       92308
# 231966    1588122902401603        623753         2      91503460       92309
# 231967    1588122902401684        623754         2      91503460       92310
# 231968    1588122902401686        623755         2      91503460       92311
# ...                    ...           ...       ...           ...         ...
# 20017788  1588143598625697     118534459         2     145959980    15463431
# 20017789  1588143598630884     118534460         2     145959980    15463432
# 20017790  1588143598630889     118534463         2     145959990    15463433
# 20017791  1588143598634927     118534472         2     145959990    15463434
# 20017792  1588143598634929     118534473         2     145959990    14853323
#
#           SecurityID  Side OrderType   Price  OrderQty  idx_x  \
# 231964            89     1         2   71100       400      0
# 231965          2195     2         2   30600      6000      0
# 231966          2573     2         2   54900       100      0
# 231967        300054     2         2  114600      2000      1
# 231968          2756     2         2  167300      1000      1
# ...              ...   ...       ...     ...       ...    ...
# 20017788          48     2         2  260000       700      0
# 20017789          48     2         2  260000       700      0
# 20017790          48     2         2  260000      2180      0
# 20017791      300026     1         2   56600     10000      0
# 20017792        2727     2         2  268900       200      1
#
#           clockAtArrival_y  sequenceNo_y  exchId_y  idx_y
# 231964                 NaN           NaN       NaN    NaN
# 231965                 NaN           NaN       NaN    NaN
# 231966                 NaN           NaN       NaN    NaN
# 231967                 NaN           NaN       NaN    NaN
# 231968                 NaN           NaN       NaN    NaN
# ...                    ...           ...       ...    ...
# 20017788               NaN           NaN       NaN    NaN
# 20017789               NaN           NaN       NaN    NaN
# 20017790               NaN           NaN       NaN    NaN
# 20017791               NaN           NaN       NaN    NaN
# 20017792               NaN           NaN       NaN    NaN
#
# [379 rows x 15 columns]
# array([    89,   2195,   2573, 300054,   2756,   2470,    751, 300091,
#          2838,   2600,   2589,    338,   2714,    890,    661,    977,
#        300606,   2371,   2481,   2030,   2946,   2241,   2090,    639,
#            61,     90,   2075,     78,   2847, 300207, 300341, 300213,
#           876,   2280,    822, 300021,   2435, 300339,   2048,   2419,
#          2812,   2326,   2673, 300364,    413,   2185,   2590,   2596,
#        300116, 300185, 300653,   2492,    683, 300342,    717, 300676,
#           100,    518,   2079,   2236,   2340,   2110,   2233,   2045,
#           610,    908, 300429, 300735,   2321,   2975, 300444, 300822,
#        300803,   2299, 300311,    931,     36, 300748,   2161,   2936,
#          2156, 300684,   2463, 300200, 300085,   2487, 300001,   2832,
#        300768,   2505,   2204,   2503,   2194,    564,    600,   2049,
#           700,    625, 300773,   2555,   2486,   2243,   2103,    609,
#          2508,   2239, 300107,   2603,    650,   2035,   2355,    636,
#        300026,   2958,   2276,   2547,   2498, 300184,    158,    938,
#          2817, 300688,   2636,   2097,   2416,   2074, 300041,    408,
#        300825,    498,    937,   2411,   2620, 300640,   2823,    586,
#        300821,   2751,   2737, 300236,   2256, 300231,    576, 300329,
#           815, 300482,    760,    652,   2002,   2402, 300746,    533,
#          2807,    920,   2770, 300623,   2384,    791, 300390,   2584,
#           778,    961,   2466,   2183,   2036,    750, 300065,     19,
#        300579,    807,    903,   2025,    967,    563, 300153,   2405,
#           733,   2157,   2292, 300303,   2022,    595,     63,   2414,
#          2128,   2635,    540,   2480,      1,   2152,   2662,   2177,
#           725,   2238, 300249,   2981,   2493, 300136,   2839,      2,
#          2138,   2028,   2273,    776,   2020,   2424,   2328,    703,
#           401,   2585,     60,   2058,   2610,   2225,   2332,     48,
#          2945,   2793,     42, 300666, 300576,   2727], dtype=int64)
# array([ 91503460,  91503470,  91503480,  91503490,  91503500,  91503540,
#        145959940, 145959950, 145959960, 145959970, 145959980, 145959990],
#       dtype=int64)
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 231967    1588122902401684        623754         2      91503460       92310
# 231968    1588122902401686        623755         2      91503460       92311
# 231970    1588122902401688        623758         2      91503460       92314
# 231971    1588122902401689        623759         2      91503460       92315
# 231973    1588122902401696        623764         2      91503460       92317
# ...                    ...           ...       ...           ...         ...
# 234293    1588122902432994        628379         2      91503540      106105
# 234294    1588122902432995        628380         2      91503540      106106
# 20017765  1588143598583861     118534389         2     145959940    17191842
# 20017776  1588143598606293     118534415         2     145959960    14853319
# 20017792  1588143598634929     118534473         2     145959990    14853323
#
#           SecurityID  Side OrderType   Price  OrderQty  idx_x  \
# 231967        300054     2         2  114600      2000      1
# 231968          2756     2         2  167300      1000      1
# 231970           751     2         2   27800     10400      1
# 231971        300091     2         2   37000     10000      1
# 231973        300054     2         2  121700      5000      1
# ...              ...   ...       ...     ...       ...    ...
# 234293          2610     2         2   16500      2000      1
# 234294           903     1         2   45900      1300      1
# 20017765        2332     2         2  135300       200      1
# 20017776      300666     1         2  507700       500      1
# 20017792        2727     2         2  268900       200      1
#
#           clockAtArrival_y  sequenceNo_y  exchId_y  idx_y
# 231967                 NaN           NaN       NaN    NaN
# 231968                 NaN           NaN       NaN    NaN
# 231970                 NaN           NaN       NaN    NaN
# 231971                 NaN           NaN       NaN    NaN
# 231973                 NaN           NaN       NaN    NaN
# ...                    ...           ...       ...    ...
# 234293                 NaN           NaN       NaN    NaN
# 234294                 NaN           NaN       NaN    NaN
# 20017765               NaN           NaN       NaN    NaN
# 20017776               NaN           NaN       NaN    NaN
# 20017792               NaN           NaN       NaN    NaN
#
# [109 rows x 15 columns]
# array([300054,   2756,    751, 300091,   2481,    639, 300213,    822,
#        300021,   2435, 300339,   2326, 300364,   2185,   2590,   2596,
#        300185,    683, 300676,   2079, 300429, 300735, 300311,    931,
#            36, 300748,   2156, 300684, 300085,   2832, 300768,   2204,
#        300773,   2243,   2239, 300107,    650,   2035,   2355,   2276,
#          2547,   2498, 300184,   2636,   2097,    498,   2751,   2737,
#        300236,   2256,    576,    815, 300482,    652,   2402, 300623,
#           791,   2036, 300065,     19,    903,   2025,   2405,    733,
#          2292, 300303,   2022,    540,   2662,   2138,   2020,   2585,
#          2610,   2332, 300666,   2727], dtype=int64)
# array([ 91503460,  91503480,  91503490,  91503500,  91503540, 145959940,
#        145959960, 145959990], dtype=int64)
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 231964    1588122902401601        623751         2      91503460       92307
# 231965    1588122902401601        623752         2      91503460       92308
# 231966    1588122902401603        623753         2      91503460       92309
# 231969    1588122902401686        623756         2      91503460       92312
# 231972    1588122902401695        623763         2      91503460       92316
# ...                    ...           ...       ...           ...         ...
# 20017787  1588143598625696     118534458         2     145959980    15463430
# 20017788  1588143598625697     118534459         2     145959980    15463431
# 20017789  1588143598630884     118534460         2     145959980    15463432
# 20017790  1588143598630889     118534463         2     145959990    15463433
# 20017791  1588143598634927     118534472         2     145959990    15463434
#
#           SecurityID  Side OrderType   Price  OrderQty  idx_x  \
# 231964            89     1         2   71100       400      0
# 231965          2195     2         2   30600      6000      0
# 231966          2573     2         2   54900       100      0
# 231969          2470     2         2   26500     43700      0
# 231972          2838     1         2  310000      1800      0
# ...              ...   ...       ...     ...       ...    ...
# 20017787          48     2         2  260000       700      0
# 20017788          48     2         2  260000       700      0
# 20017789          48     2         2  260000       700      0
# 20017790          48     2         2  260000      2180      0
# 20017791      300026     1         2   56600     10000      0
#
#           clockAtArrival_y  sequenceNo_y  exchId_y  idx_y
# 231964                 NaN           NaN       NaN    NaN
# 231965                 NaN           NaN       NaN    NaN
# 231966                 NaN           NaN       NaN    NaN
# 231969                 NaN           NaN       NaN    NaN
# 231972                 NaN           NaN       NaN    NaN
# ...                    ...           ...       ...    ...
# 20017787               NaN           NaN       NaN    NaN
# 20017788               NaN           NaN       NaN    NaN
# 20017789               NaN           NaN       NaN    NaN
# 20017790               NaN           NaN       NaN    NaN
# 20017791               NaN           NaN       NaN    NaN
#
# [270 rows x 15 columns]
# array([    89,   2195,   2573,   2470,   2838,   2600,   2589,    338,
#          2714,    890,    661,    977, 300606,   2371,   2030,   2946,
#          2241,   2090,     61,     90,   2075,     78,   2847, 300207,
#        300341,    876,   2280,   2048,   2419,   2812,   2673,    413,
#        300116, 300653,   2492, 300342,    717,    100,    518,   2236,
#          2340,   2110,   2233,   2045,    610,    908,   2321,   2975,
#        300444, 300822, 300803,   2299,   2161,   2936,   2463, 300200,
#          2487, 300001,   2505,   2503,   2194,    564,    600,   2049,
#           700,    625,   2555,   2486,   2103,    609,   2508,   2603,
#           636, 300026,   2958,    158,    938,   2817, 300688,   2416,
#          2074, 300041,    408, 300825,    937,   2411,   2620, 300640,
#          2823,    586, 300821, 300231, 300329,    760,   2002, 300746,
#           533,   2807,    920,   2770,   2384, 300390,   2584,    778,
#           961,   2466,   2183,    750, 300579,    807,    967,    563,
#        300153,   2157,    595,     63,   2414,   2128,   2635,   2480,
#             1,   2152,   2177,    725,   2238, 300249,   2981,   2493,
#        300136,   2839,      2,   2028,   2273,    776,   2424,   2328,
#           703,    401,     60,   2058,   2225,     48,   2945,   2793,
#            42, 300576], dtype=int64)
# array([ 91503460,  91503470,  91503480,  91503490,  91503500,  91503540,
#        145959940, 145959950, 145959960, 145959970, 145959980, 145959990],
#       dtype=int64)
# Empty DataFrame
# Columns: [clockAtArrival_x, sequenceNo_x, exchId_x, TransactTime, ApplSeqNum, SecurityID, Side, OrderType, Price, OrderQty, idx_x, clockAtArrival_y, sequenceNo_y, exchId_y, idx_y]
# Index: []
# \\192.168.10.30\Kevin_zhenyu\rawData\logs_20200429_zt_96_04_day_96data\mdTradeLog_20200429_0853.csv
# \\192.168.10.30\Kevin_zhenyu\rawData\logs_20200429_zs_92_01_day_data\mdTradeLog_20200429_0851.csv
# C:\Users\win\Anaconda3\lib\site-packages\ipykernel_launcher.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\win\Anaconda3\lib\site-packages\ipykernel_launcher.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1191
# 1191
# C:\Users\win\Anaconda3\lib\site-packages\ipykernel_launcher.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\win\Anaconda3\lib\site-packages\ipykernel_launcher.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1191
# 1191
# '20200429_TradeLog Check_second 1000:'
# 12097166
# 12097165
# 12097166
# 8.266398923516466e-08
#      clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 817  1588122902416461        625131         2      91503480      106952
#
#      SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 817        2644        4           N           0      3000           0
#
#      BidApplSeqNum  OfferApplSeqNum  idx_x  clockAtArrival_y  sequenceNo_y  \
# 817              0           106884      0               NaN           NaN
#
#      exchId_y  idx_y
# 817       NaN    NaN
# array([2644], dtype=int64)
# array([91503480], dtype=int64)
# Empty DataFrame
# Columns: [clockAtArrival_x, sequenceNo_x, exchId_x, TransactTime, ApplSeqNum, SecurityID, ExecType, TradeBSFlag, TradePrice, TradeQty, TradeMoney, BidApplSeqNum, OfferApplSeqNum, idx_x, clockAtArrival_y, sequenceNo_y, exchId_y, idx_y]
# Index: []
# array([], dtype=int64)
# array([], dtype=int64)
#      clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 817  1588122902416461        625131         2      91503480      106952
#
#      SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 817        2644        4           N           0      3000           0
#
#      BidApplSeqNum  OfferApplSeqNum  idx_x  clockAtArrival_y  sequenceNo_y  \
# 817              0           106884      0               NaN           NaN
#
#      exchId_y  idx_y
# 817       NaN    NaN
# array([2644], dtype=int64)
# array([91503480], dtype=int64)
# Empty DataFrame
# Columns: [clockAtArrival_x, sequenceNo_x, exchId_x, TransactTime, ApplSeqNum, SecurityID, ExecType, TradeBSFlag, TradePrice, TradeQty, TradeMoney, BidApplSeqNum, OfferApplSeqNum, idx_x, clockAtArrival_y, sequenceNo_y, exchId_y, idx_y]
# Index: []
# '20200429_OrderLog Check_second 1000:'
# 13722613
# 13722397
# 13722613
# 1.574044243614536e-05
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 153693    1588122902401687        623757         2      91503460       92313
# 153698    1588122902401702        623771         2      91503460       92323
# 153700    1588122902401824        623789         2      91503460       92327
# 153701    1588122902401826        623790         2      91503460       92328
# 153703    1588122902401946        623806         2      91503460       90707
# ...                    ...           ...       ...           ...         ...
# 13722608  1588143598622859     118534444         2     145959980    16081780
# 13722609  1588143598622867     118534452         2     145959980    16081781
# 13722610  1588143598625695     118534457         2     145959980    17191850
# 13722611  1588143598630888     118534462         2     145959980    14853322
# 13722612  1588143598630892     118534467         2     145959990    16081782
#
#           SecurityID  Side OrderType    Price  OrderQty  idx_x  \
# 153693        300235     2         2   149000      2000      0
# 153698        300419     2         2    58000      3400      0
# 153700        300336     1         2    39100      1000      1
# 153701          2821     1         2  1826900       100      0
# 153703           779     1         2   100000       200      0
# ...              ...   ...       ...      ...       ...    ...
# 13722608         519     1         2    81800      2000      0
# 13722609      300786     1         2   459200       200      0
# 13722610      300192     2         2   179200       500      0
# 13722611         910     1         2   113200      2000      1
# 13722612        2949     1         2   154200      2000      0
#
#           clockAtArrival_y  sequenceNo_y  exchId_y  idx_y
# 153693                 NaN           NaN       NaN    NaN
# 153698                 NaN           NaN       NaN    NaN
# 153700                 NaN           NaN       NaN    NaN
# 153701                 NaN           NaN       NaN    NaN
# 153703                 NaN           NaN       NaN    NaN
# ...                    ...           ...       ...    ...
# 13722608               NaN           NaN       NaN    NaN
# 13722609               NaN           NaN       NaN    NaN
# 13722610               NaN           NaN       NaN    NaN
# 13722611               NaN           NaN       NaN    NaN
# 13722612               NaN           NaN       NaN    NaN
#
# [216 rows x 15 columns]
# array([300235, 300419, 300336,   2821,    779,   2642,   2669,   2150,
#        300820, 300592,   2932,   2952,    628, 300247, 300102,   2725,
#          2554,   2112,   2877,   2448,   2869,    802, 300607,   2124,
#          2021,   2127, 300661,   2415,   2252,    157, 300325,    816,
#          2385,    425,   2607,   2433, 300497, 300418, 300698, 300778,
#        300239,   2148, 300771,   2429,   2247, 300223,    617, 300181,
#        300324, 300731,   2873,    886,    651,   1965,   2608,   2400,
#          2625,   2860,   2126,   2617,    918,   2172,   2389, 300498,
#        300765, 300114,    875,   2745,    560,   2859,   2386,   2677,
#        300710, 300613,   2890,   2594,   2575,   2513,   2682,    726,
#          2475,   2515, 300456,   2663, 300284,   2297, 300425,   2082,
#          2766,   2087,    972, 300595, 300823,    915,   2015,   2612,
#          2457,   2057,   2145,   2930,    400,    666,   2559, 300520,
#          2537,   2919,   2456,    735,   2155,   2506, 300738,    978,
#        300816, 300597,   2065,   2797,   2741,    691,    587, 300003,
#          2728,   2760,    673,   2848,   2454,   2623, 300362,   2029,
#        300686,   2887,   2971,    589,    897, 300115,   2027, 300450,
#          2842, 300030,    803,   2782,    568, 300655,    519, 300786,
#        300192,    910,   2949], dtype=int64)
# array([ 91503460,  91503470,  91503480,  91503490,  91503500,  91503540,
#        145959940, 145959950, 145959960, 145959970, 145959980, 145959990],
#       dtype=int64)
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 153700    1588122902401824        623789         2      91503460       92327
# 153839    1588122902410868        624555         2      91503480       92538
# 153959    1588122902415271        624979         2      91503480       90979
# 153984    1588122902415404        625020         2      91503480       92630
# 154001    1588122902416317        625084         2      91503480      106923
# ...                    ...           ...       ...           ...         ...
# 154952    1588122902431714        628312         2      91503540      107603
# 13722600  1588143598615851     118534429         2     145959970    16081774
# 13722604  1588143598621933     118534439         2     145959980    16081776
# 13722605  1588143598621933     118534440         2     145959980    16081777
# 13722611  1588143598630888     118534462         2     145959980    14853322
#
#           SecurityID  Side OrderType   Price  OrderQty  idx_x  \
# 153700        300336     1         2   39100      1000      1
# 153839        300102     2         2   44300     10000      1
# 153959           802     1         2   64700       100      1
# 153984        300607     2         2  631100       500      1
# 154001          2124     2         2  138600      1600      1
# ...              ...   ...       ...     ...       ...    ...
# 154952          2029     1         2   48700      2200      1
# 13722600      300450     1         2  348200       300      1
# 13722604         726     2         2   84200       600      1
# 13722605        2782     2         2  109500       500      1
# 13722611         910     1         2  113200      2000      1
#
#           clockAtArrival_y  sequenceNo_y  exchId_y  idx_y
# 153700                 NaN           NaN       NaN    NaN
# 153839                 NaN           NaN       NaN    NaN
# 153959                 NaN           NaN       NaN    NaN
# 153984                 NaN           NaN       NaN    NaN
# 154001                 NaN           NaN       NaN    NaN
# ...                    ...           ...       ...    ...
# 154952                 NaN           NaN       NaN    NaN
# 13722600               NaN           NaN       NaN    NaN
# 13722604               NaN           NaN       NaN    NaN
# 13722605               NaN           NaN       NaN    NaN
# 13722611               NaN           NaN       NaN    NaN
#
# [64 rows x 15 columns]
# array([300336, 300102,    802, 300607,   2124, 300661,   2433, 300497,
#          2148, 300771,   2429, 300223,   2400,   2126,   2617,    918,
#          2389, 300765, 300114,    875,    560,   2859,   2677, 300613,
#           726,   2515, 300456,   2663, 300284, 300595,    915,   2145,
#          2930,    666, 300520,   2537,    735,   2741,   2029, 300450,
#          2782,    910], dtype=int64)
# array([ 91503460,  91503480,  91503490,  91503500,  91503540, 145959970,
#        145959980], dtype=int64)
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 153693    1588122902401687        623757         2      91503460       92313
# 153698    1588122902401702        623771         2      91503460       92323
# 153701    1588122902401826        623790         2      91503460       92328
# 153703    1588122902401946        623806         2      91503460       90707
# 153704    1588122902401948        623809         2      91503460       90710
# ...                    ...           ...       ...           ...         ...
# 13722607  1588143598621936     118534443         2     145959980    16081779
# 13722608  1588143598622859     118534444         2     145959980    16081780
# 13722609  1588143598622867     118534452         2     145959980    16081781
# 13722610  1588143598625695     118534457         2     145959980    17191850
# 13722612  1588143598630892     118534467         2     145959990    16081782
#
#           SecurityID  Side OrderType    Price  OrderQty  idx_x  \
# 153693        300235     2         2   149000      2000      0
# 153698        300419     2         2    58000      3400      0
# 153701          2821     1         2  1826900       100      0
# 153703           779     1         2   100000       200      0
# 153704          2642     2         2    56000       400      0
# ...              ...   ...       ...      ...       ...    ...
# 13722607      300655     2         2   298300       200      0
# 13722608         519     1         2    81800      2000      0
# 13722609      300786     1         2   459200       200      0
# 13722610      300192     2         2   179200       500      0
# 13722612        2949     1         2   154200      2000      0
#
#           clockAtArrival_y  sequenceNo_y  exchId_y  idx_y
# 153693                 NaN           NaN       NaN    NaN
# 153698                 NaN           NaN       NaN    NaN
# 153701                 NaN           NaN       NaN    NaN
# 153703                 NaN           NaN       NaN    NaN
# 153704                 NaN           NaN       NaN    NaN
# ...                    ...           ...       ...    ...
# 13722607               NaN           NaN       NaN    NaN
# 13722608               NaN           NaN       NaN    NaN
# 13722609               NaN           NaN       NaN    NaN
# 13722610               NaN           NaN       NaN    NaN
# 13722612               NaN           NaN       NaN    NaN
#
# [152 rows x 15 columns]
# array([300235, 300419,   2821,    779,   2642,   2669,   2150, 300820,
#        300592,   2932,   2952,    628, 300247,   2725,   2554,   2112,
#          2877,   2448,   2869,   2021,   2127,   2415,   2252,    157,
#        300325,    816,   2385,    425,   2607, 300418, 300698, 300778,
#        300239,   2247,    617, 300181, 300324, 300731,   2873,    886,
#           651,   1965,   2608,   2625,   2860,   2172, 300498,   2745,
#          2386, 300710,   2890,   2594,   2575,   2513,   2682,   2475,
#          2297, 300425,   2082,   2766,   2087,    972, 300823,   2015,
#          2612,   2457,   2057,    400,   2559,   2919,   2456,   2155,
#          2506, 300738,    978, 300816, 300597,   2065,   2797,    691,
#           587, 300003,   2728,   2760,    673,   2848,   2454,   2623,
#        300362, 300686,   2887,   2971,    589,    897, 300115,   2027,
#          2842, 300030,    803,    568, 300655,    519, 300786, 300192,
#          2949], dtype=int64)
# array([ 91503460,  91503470,  91503480,  91503490,  91503500,  91503540,
#        145959940, 145959950, 145959960, 145959970, 145959980, 145959990],
#       dtype=int64)
# Empty DataFrame
# Columns: [clockAtArrival_x, sequenceNo_x, exchId_x, TransactTime, ApplSeqNum, SecurityID, Side, OrderType, Price, OrderQty, idx_x, clockAtArrival_y, sequenceNo_y, exchId_y, idx_y]
# Index: []
# \\192.168.10.30\Kevin_zhenyu\rawData\logs_20200430_zt_96_04_day_96data\mdTradeLog_20200430_0848.csv
# C:\Users\win\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# \\192.168.10.30\Kevin_zhenyu\rawData\logs_20200430_zs_92_01_day_data\mdTradeLog_20200430_0847.csv
# 360
# 640
# 1000
# 1000
# 1000
# 1000
# '20200430_TradeLog Check_first 1000:'
# 22493268
# 22493250
# 22493268
# 8.002394316379461e-07
#       clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 1669  1588209302511532        676938         2      91503480      100252
# 1689  1588209302533533        680991         2      91503570       94068
# 1690  1588209302542898        681210         2      91503560      106907
# 1691  1588209302542899        681211         2      91503560      106908
# 1692  1588209302545084        681614         2      91503570      101219
# 1704  1588209302548580        682349         2      91503580       94250
# 1783  1588209302621117        691473         2      91503730       95844
# 1791  1588209302625910        692355         2      91503740      109173
# 1838  1588209302646743        694751         2      91503790      109690
# 1839  1588209302646760        694756         2      91503790      103751
# 1840  1588209302646778        694762         2      91503790      103755
# 1841  1588209302646779        694763         2      91503790      103756
# 1843  1588209302647466        694905         2      91503790      109711
# 1846  1588209302647678        694984         2      91503790      109727
# 1847  1588209302647689        694995         2      91503790       96497
# 1849  1588209302647723        695025         2      91503790       96503
# 1850  1588209302647823        695048         2      91503790      103801
# 1851  1588209302647855        695057         2      91503790      103809
#
#       SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 1669      300363        4           N           0       300           0
# 1689        2562        4           N           0       600           0
# 1690        2201        4           N           0      6700           0
# 1691         957        4           N           0      4700           0
# 1692        2700        4           N           0     16900           0
# 1704         505        4           N           0      1000           0
# 1783      300116        4           N           0      5700           0
# 1791        2121        4           N           0     30000           0
# 1838         564        4           N           0      2500           0
# 1839        2504        4           N           0       300           0
# 1840         876        4           N           0       500           0
# 1841        2920        4           N           0       100           0
# 1843      300325        4           N           0     76100           0
# 1846           9        4           N           0      8900           0
# 1847      300026        4           N           0      6600           0
# 1849         100        4           N           0      2500           0
# 1850        2329        4           N           0       300           0
# 1851         536        4           N           0       300           0
#
#       BidApplSeqNum  OfferApplSeqNum  idx_x  clockAtArrival_y  sequenceNo_y  \
# 1669          22261                0      1               NaN           NaN
# 1689              0            32976      1               NaN           NaN
# 1690         106710                0      0               NaN           NaN
# 1691          93260                0      1               NaN           NaN
# 1692              0            24078      0               NaN           NaN
# 1704          94244                0      0               NaN           NaN
# 1783              0            17414      0               NaN           NaN
# 1791              0             4879      1               NaN           NaN
# 1838              0            51441      0               NaN           NaN
# 1839              0            47712      0               NaN           NaN
# 1840         103752                0      0               NaN           NaN
# 1841         103744                0      0               NaN           NaN
# 1843              0            46988      0               NaN           NaN
# 1846         109722                0      0               NaN           NaN
# 1847              0            96490      0               NaN           NaN
# 1849          96499                0      0               NaN           NaN
# 1850              0           100053      0               NaN           NaN
# 1851              0           103806      0               NaN           NaN
#
#       exchId_y  idx_y
# 1669       NaN    NaN
# 1689       NaN    NaN
# 1690       NaN    NaN
# 1691       NaN    NaN
# 1692       NaN    NaN
# 1704       NaN    NaN
# 1783       NaN    NaN
# 1791       NaN    NaN
# 1838       NaN    NaN
# 1839       NaN    NaN
# 1840       NaN    NaN
# 1841       NaN    NaN
# 1843       NaN    NaN
# 1846       NaN    NaN
# 1847       NaN    NaN
# 1849       NaN    NaN
# 1850       NaN    NaN
# 1851       NaN    NaN
# array([300363,   2562,   2201,    957,   2700,    505, 300116,   2121,
#           564,   2504,    876,   2920, 300325,      9, 300026,    100,
#          2329,    536], dtype=int64)
# array([91503480, 91503570, 91503560, 91503580, 91503730, 91503740,
#        91503790], dtype=int64)
#       clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 1669  1588209302511532        676938         2      91503480      100252
# 1689  1588209302533533        680991         2      91503570       94068
# 1691  1588209302542899        681211         2      91503560      106908
# 1791  1588209302625910        692355         2      91503740      109173
#
#       SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 1669      300363        4           N           0       300           0
# 1689        2562        4           N           0       600           0
# 1691         957        4           N           0      4700           0
# 1791        2121        4           N           0     30000           0
#
#       BidApplSeqNum  OfferApplSeqNum  idx_x  clockAtArrival_y  sequenceNo_y  \
# 1669          22261                0      1               NaN           NaN
# 1689              0            32976      1               NaN           NaN
# 1691          93260                0      1               NaN           NaN
# 1791              0             4879      1               NaN           NaN
#
#       exchId_y  idx_y
# 1669       NaN    NaN
# 1689       NaN    NaN
# 1691       NaN    NaN
# 1791       NaN    NaN
# array([300363,   2562,    957,   2121], dtype=int64)
# array([91503480, 91503570, 91503560, 91503740], dtype=int64)
#       clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 1690  1588209302542898        681210         2      91503560      106907
# 1692  1588209302545084        681614         2      91503570      101219
# 1704  1588209302548580        682349         2      91503580       94250
# 1783  1588209302621117        691473         2      91503730       95844
# 1838  1588209302646743        694751         2      91503790      109690
# 1839  1588209302646760        694756         2      91503790      103751
# 1840  1588209302646778        694762         2      91503790      103755
# 1841  1588209302646779        694763         2      91503790      103756
# 1843  1588209302647466        694905         2      91503790      109711
# 1846  1588209302647678        694984         2      91503790      109727
# 1847  1588209302647689        694995         2      91503790       96497
# 1849  1588209302647723        695025         2      91503790       96503
# 1850  1588209302647823        695048         2      91503790      103801
# 1851  1588209302647855        695057         2      91503790      103809
#
#       SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 1690        2201        4           N           0      6700           0
# 1692        2700        4           N           0     16900           0
# 1704         505        4           N           0      1000           0
# 1783      300116        4           N           0      5700           0
# 1838         564        4           N           0      2500           0
# 1839        2504        4           N           0       300           0
# 1840         876        4           N           0       500           0
# 1841        2920        4           N           0       100           0
# 1843      300325        4           N           0     76100           0
# 1846           9        4           N           0      8900           0
# 1847      300026        4           N           0      6600           0
# 1849         100        4           N           0      2500           0
# 1850        2329        4           N           0       300           0
# 1851         536        4           N           0       300           0
#
#       BidApplSeqNum  OfferApplSeqNum  idx_x  clockAtArrival_y  sequenceNo_y  \
# 1690         106710                0      0               NaN           NaN
# 1692              0            24078      0               NaN           NaN
# 1704          94244                0      0               NaN           NaN
# 1783              0            17414      0               NaN           NaN
# 1838              0            51441      0               NaN           NaN
# 1839              0            47712      0               NaN           NaN
# 1840         103752                0      0               NaN           NaN
# 1841         103744                0      0               NaN           NaN
# 1843              0            46988      0               NaN           NaN
# 1846         109722                0      0               NaN           NaN
# 1847              0            96490      0               NaN           NaN
# 1849          96499                0      0               NaN           NaN
# 1850              0           100053      0               NaN           NaN
# 1851              0           103806      0               NaN           NaN
#
#       exchId_y  idx_y
# 1690       NaN    NaN
# 1692       NaN    NaN
# 1704       NaN    NaN
# 1783       NaN    NaN
# 1838       NaN    NaN
# 1839       NaN    NaN
# 1840       NaN    NaN
# 1841       NaN    NaN
# 1843       NaN    NaN
# 1846       NaN    NaN
# 1847       NaN    NaN
# 1849       NaN    NaN
# 1850       NaN    NaN
# 1851       NaN    NaN
# array([  2201,   2700,    505, 300116,    564,   2504,    876,   2920,
#        300325,      9, 300026,    100,   2329,    536], dtype=int64)
# array([91503560, 91503570, 91503580, 91503730, 91503790], dtype=int64)
# Empty DataFrame
# Columns: [clockAtArrival_x, sequenceNo_x, exchId_x, TransactTime, ApplSeqNum, SecurityID, ExecType, TradeBSFlag, TradePrice, TradeQty, TradeMoney, BidApplSeqNum, OfferApplSeqNum, idx_x, clockAtArrival_y, sequenceNo_y, exchId_y, idx_y]
# Index: []
# '20200430_OrderLog Check_first 1000:'
# 25178054
# 25176736
# 25178054
# 5.234717504379012e-05
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 265150    1588209302486365        674971         2      91503450       99827
# 265152    1588209302486462        674977         2      91503450       99829
# 265263    1588209302489358        675166         2      91503450       99859
# 265269    1588209302489388        675174         2      91503450       99861
# 265271    1588209302489411        675176         2      91503450       99862
# ...                    ...           ...       ...           ...         ...
# 25178049  1588229999242044     131620841         2     145959960    18134156
# 25178050  1588229999242046     131620842         2     145959960    17126054
# 25178051  1588229999242264     131620845         2     145959970    18988745
# 25178052  1588229999242266     131620846         2     145959970    18988746
# 25178053  1588229999248407     131620847         2     145959970    18420072
#
#           SecurityID  Side OrderType   Price  OrderQty  idx_x  \
# 265150        300716     2         2   87900      1100      0
# 265152          2505     1         2   24000      4300      0
# 265263          2509     2         2    9300      6000      0
# 265269        300151     1         2   96500     40000      0
# 265271           767     2         2   22800      2200      0
# ...              ...   ...       ...     ...       ...    ...
# 25178049      300781     2         2  289100      1400      0
# 25178050        2846     2         2  169800       100      0
# 25178051        2551     2         2   73300       300      0
# 25178052        2551     2         2   73300      1800      0
# 25178053         413     1         2   27500       100      0
#
#           clockAtArrival_y  sequenceNo_y  exchId_y  idx_y
# 265150                 NaN           NaN       NaN    NaN
# 265152                 NaN           NaN       NaN    NaN
# 265263                 NaN           NaN       NaN    NaN
# 265269                 NaN           NaN       NaN    NaN
# 265271                 NaN           NaN       NaN    NaN
# ...                    ...           ...       ...    ...
# 25178049               NaN           NaN       NaN    NaN
# 25178050               NaN           NaN       NaN    NaN
# 25178051               NaN           NaN       NaN    NaN
# 25178052               NaN           NaN       NaN    NaN
# 25178053               NaN           NaN       NaN    NaN
#
# [1318 rows x 15 columns]
# array([300716,   2505,   2509, 300151,    767,   2330,   2223,   2575,
#           890,   2185,    401,    721,   2498,   2304,    620,   2230,
#          2429,   2436,   2273,   2465, 300750, 300793,    540,   2120,
#          2194, 300401,   2127, 300325,   2838,   2050,   2266,   2102,
#          2714,   2456, 300292,   2702,   2638, 300255,   2049,   2183,
#           713, 300003,    166, 300059, 300046,   2078,    636,   2206,
#        300017,   2007,    597,   2236,   2415,   2721,    656,   2002,
#           488,   2600,   2195,    776, 300267,   2594, 300027,    895,
#          2013,   2030,   2241,   2582,    976,   2614, 300205, 300070,
#           650,   2281,   2041,    710,   2892, 300260,   2256,   2401,
#          2751,   2177,    882,   2176,   2841, 300433, 300042,    876,
#           552, 300014,    858,     17,   2662,   2556,     36,   2471,
#           848,   2948,   2716,   2463, 300538, 300676, 300136,     58,
#          2610,   2373,   2503,     78, 300761,   2152,   2567,   2557,
#        300783,   2460,   2908,   2437,    592,   2615,    673,   2326,
#          2636,    839,    735, 300078,    413,    564,   2099,   2969,
#          2075,    623,   2228,   2258,    536,   2555,    795,    609,
#        300781,    338,   2131, 300189, 300363,   2154,    629,   2603,
#          2797, 300466, 300124, 300511,    651,    516,   2249, 300071,
#          2817,     50,   2351, 300333, 300450,    709, 300156,    639,
#          2280,    789,   2012,   2458,    793,   2297,   2430,   2788,
#          2204,    525,    989,   2668,   2513,    998,    519,   2596,
#        300273, 300058,   2255, 300558,   2521, 300410,    901,   2277,
#           778, 300448, 300115, 300790,   2027,    725, 300746, 300366,
#          2560,   2405,   2775,   2221,      2, 300760, 300383,    831,
#          2384,   2022,   2980,    997,   2475,    963, 300345,   2581,
#        300178,    739,     35,   2396,    727,     34, 300040,   2945,
#           100,   2966,   2031,    662,     27, 300397,   2264,   2585,
#        300634,   2329, 300732,   2276, 300088,   2217,   2124,    726,
#          2106,   2589, 300578, 300158,    810,   2305,   2161, 300485,
#            63,    822,   2981,    600,   2444,    697,   2269,    301,
#          2208,    528,   2174, 300459, 300274,    537,    768,   2020,
#          3816,    333, 300817,    610,    878,   2036,    811,   2308,
#          2029, 300012,   2546,    807,   2936,   2202,   2129,   2060,
#           931,   2074,   2551,   2515,   2822,   2087,   2606,   2352,
#        300560,   2484,    687,    628,   1872,    938, 300398,   2385,
#        300144,    830,    900, 300498, 300440,   2835,   2508, 300026,
#          2426,      8,   2517,    573, 300105,    682,   2432,   2486,
#           158,   2062,    425,   2270, 300352,   2086,    930,   2107,
# ...
# Index: []
# array([], dtype=int64)
# array([], dtype=int64)
# Empty DataFrame
# Columns: [clockAtArrival_x, sequenceNo_x, exchId_x, TransactTime, ApplSeqNum, SecurityID, ExecType, TradeBSFlag, TradePrice, TradeQty, TradeMoney, BidApplSeqNum, OfferApplSeqNum, idx_x, clockAtArrival_y, sequenceNo_y, exchId_y, idx_y]
# Index: []
# array([], dtype=int64)
# array([], dtype=int64)
# Empty DataFrame
# Columns: [clockAtArrival_x, sequenceNo_x, exchId_x, TransactTime, ApplSeqNum, SecurityID, ExecType, TradeBSFlag, TradePrice, TradeQty, TradeMoney, BidApplSeqNum, OfferApplSeqNum, idx_x, clockAtArrival_y, sequenceNo_y, exchId_y, idx_y]
# Index: []
# array([], dtype=int64)
# array([], dtype=int64)
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 12029038               NaN           NaN       NaN     143937440    17205039
# 12029039               NaN           NaN       NaN     143937440    17205040
# 12029040               NaN           NaN       NaN     143937440    17094295
# 12029041               NaN           NaN       NaN     143937440    17094296
# 12029042               NaN           NaN       NaN     143937450    16093544
# ...                    ...           ...       ...           ...         ...
# 12029661               NaN           NaN       NaN     143938460    17095271
# 12029662               NaN           NaN       NaN     143938460    17095272
# 12029663               NaN           NaN       NaN     143938460    17206052
# 12029664               NaN           NaN       NaN     143938460    17095277
# 12029665               NaN           NaN       NaN     143938460    17206056
#
#           SecurityID ExecType TradeBSFlag  TradePrice  TradeQty  TradeMoney  \
# 12029038      300690        F           N      241000       100    24100000
# 12029039      300690        F           N      241000       100    24100000
# 12029040          55        F           N       43500       400    17400000
# 12029041          55        F           N       43500      1700    73950000
# 12029042        2324        F           N      133300       100    13330000
# ...              ...      ...         ...         ...       ...         ...
# 12029661        2928        F           N      137800       400    55120000
# 12029662        2928        F           N      137800      3700   509860000
# 12029663        2970        4           N           0       300           0
# 12029664      300697        4           N           0      7100           0
# 12029665         158        F           N       94500       100     9450000
#
#           BidApplSeqNum  OfferApplSeqNum  idx_x  clockAtArrival_y  \
# 12029038       17179096         17205038    NaN  1588747191867450
# 12029039       17179981         17205038    NaN  1588747191867451
# 12029040       17094294         17064392    NaN  1588747191868813
# 12029041       17094294         17079817    NaN  1588747191868814
# 12029042       16093543         15606347    NaN  1588747191868912
# ...                 ...              ...    ...               ...
# 12029661       17095269         15627955    NaN  1588747192884456
# 12029662       17095269         15974780    NaN  1588747192884483
# 12029663              0         10542176    NaN  1588747192887225
# 12029664       17043459                0    NaN  1588747192887982
# 12029665       17195743         17206055    NaN  1588747192890217
#
#           sequenceNo_y  exchId_y  idx_y
# 12029038     108711892         2      0
# 12029039     108711893         2      0
# 12029040     108711903         2      1
# 12029041     108711904         2      1
# 12029042     108711906         2      0
# ...                ...       ...    ...
# 12029661     108717393         2      1
# 12029662     108717394         2      1
# 12029663     108717721         2      0
# 12029664     108717724         2      0
# 12029665     108717741         2      0
#
# [628 rows x 18 columns]
# '20200506_OrderLog Check_second 1000:'
# 13447820
# 13448475
# 13448495
# -4.8706779240055265e-05
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 13447800      1.588748e+15   130009678.0       2.0     145959950    18741385
# 13447801      1.588748e+15   130009680.0       2.0     145959950    18741386
# 13447802      1.588748e+15   130009683.0       2.0     145959960    18946463
# 13447803      1.588748e+15   130009687.0       2.0     145959960    17647744
# 13447804      1.588748e+15   130009693.0       2.0     145959960    18946464
# 13447805      1.588748e+15   130009696.0       2.0     145959960    18741387
# 13447806      1.588748e+15   130009697.0       2.0     145959960    18946465
# 13447807      1.588748e+15   130009703.0       2.0     145959970    18946466
# 13447808      1.588748e+15   130009704.0       2.0     145959970    18741391
# 13447809      1.588748e+15   130009707.0       2.0     145959970    18946467
# 13447810      1.588748e+15   130009709.0       2.0     145959970    18946469
# 13447811      1.588748e+15   130009713.0       2.0     145959970    18946470
# 13447812      1.588748e+15   130009716.0       2.0     145959970    18741393
# 13447813      1.588748e+15   130009718.0       2.0     145959970    18946471
# 13447814      1.588748e+15   130009720.0       2.0     145959970    17647748
# 13447815      1.588748e+15   130009722.0       2.0     145959980    17647750
# 13447816      1.588748e+15   130009731.0       2.0     145959980    17647751
# 13447817      1.588748e+15   130009732.0       2.0     145959980    18263407
# 13447818      1.588748e+15   130009733.0       2.0     145959980    17647752
# 13447819      1.588748e+15   130009740.0       2.0     145959980    18946476
#
#           SecurityID  Side OrderType   Price  OrderQty  idx_x  \
# 13447800         636     1         2  214100       500    0.0
# 13447801      300332     1         2   48400      2000    1.0
# 13447802      300075     1         2  129400       200    1.0
# 13447803      300265     2         2  120400      1000    0.0
# 13447804      300672     2         2  486500       700    0.0
# 13447805        2747     1         2  105700      1100    1.0
# 13447806      300192     1         2  174800       100    0.0
# 13447807      300683     1         2  485100       300    0.0
# 13447808        2300     1         2   75300      1000    0.0
# 13447809      300275     2         2  118300       800    0.0
# 13447810      300014     2         2  696100       500    0.0
# 13447811        2232     1         2   95800      1200    1.0
# 13447812      300119     1         2  189700       700    0.0
# 13447813          32     1         2  179000       200    0.0
# 13447814        2956     1         2  582100       100    0.0
# 13447815      300221     1         2   47800      1000    0.0
# 13447816      300626     1         2   99800      1000    0.0
# 13447817      300173     2         2   55500      1000    0.0
# 13447818         565     2         2   46800      1600    0.0
# 13447819        2761     2         2   94800       500    0.0
#
#           clockAtArrival_y  sequenceNo_y  exchId_y  idx_y
# 13447800               NaN           NaN       NaN    NaN
# 13447801               NaN           NaN       NaN    NaN
# 13447802               NaN           NaN       NaN    NaN
# 13447803               NaN           NaN       NaN    NaN
# 13447804               NaN           NaN       NaN    NaN
# 13447805               NaN           NaN       NaN    NaN
# 13447806               NaN           NaN       NaN    NaN
# 13447807               NaN           NaN       NaN    NaN
# 13447808               NaN           NaN       NaN    NaN
# 13447809               NaN           NaN       NaN    NaN
# 13447810               NaN           NaN       NaN    NaN
# 13447811               NaN           NaN       NaN    NaN
# 13447812               NaN           NaN       NaN    NaN
# 13447813               NaN           NaN       NaN    NaN
# 13447814               NaN           NaN       NaN    NaN
# 13447815               NaN           NaN       NaN    NaN
# 13447816               NaN           NaN       NaN    NaN
# 13447817               NaN           NaN       NaN    NaN
# 13447818               NaN           NaN       NaN    NaN
# 13447819               NaN           NaN       NaN    NaN
# array([   636, 300332, 300075, 300265, 300672,   2747, 300192, 300683,
#          2300, 300275, 300014,   2232, 300119,     32,   2956, 300221,
#        300626, 300173,    565,   2761], dtype=int64)
# array([145959950, 145959960, 145959970, 145959980], dtype=int64)
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 13447801      1.588748e+15   130009680.0       2.0     145959950    18741386
# 13447802      1.588748e+15   130009683.0       2.0     145959960    18946463
# 13447805      1.588748e+15   130009696.0       2.0     145959960    18741387
# 13447811      1.588748e+15   130009713.0       2.0     145959970    18946470
#
#           SecurityID  Side OrderType   Price  OrderQty  idx_x  \
# 13447801      300332     1         2   48400      2000    1.0
# 13447802      300075     1         2  129400       200    1.0
# 13447805        2747     1         2  105700      1100    1.0
# 13447811        2232     1         2   95800      1200    1.0
#
#           clockAtArrival_y  sequenceNo_y  exchId_y  idx_y
# 13447801               NaN           NaN       NaN    NaN
# 13447802               NaN           NaN       NaN    NaN
# 13447805               NaN           NaN       NaN    NaN
# 13447811               NaN           NaN       NaN    NaN
# array([300332, 300075,   2747,   2232], dtype=int64)
# array([145959950, 145959960, 145959970], dtype=int64)
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 13447800      1.588748e+15   130009678.0       2.0     145959950    18741385
# 13447803      1.588748e+15   130009687.0       2.0     145959960    17647744
# 13447804      1.588748e+15   130009693.0       2.0     145959960    18946464
# 13447806      1.588748e+15   130009697.0       2.0     145959960    18946465
# 13447807      1.588748e+15   130009703.0       2.0     145959970    18946466
# 13447808      1.588748e+15   130009704.0       2.0     145959970    18741391
# 13447809      1.588748e+15   130009707.0       2.0     145959970    18946467
# 13447810      1.588748e+15   130009709.0       2.0     145959970    18946469
# 13447812      1.588748e+15   130009716.0       2.0     145959970    18741393
# 13447813      1.588748e+15   130009718.0       2.0     145959970    18946471
# 13447814      1.588748e+15   130009720.0       2.0     145959970    17647748
# 13447815      1.588748e+15   130009722.0       2.0     145959980    17647750
# 13447816      1.588748e+15   130009731.0       2.0     145959980    17647751
# 13447817      1.588748e+15   130009732.0       2.0     145959980    18263407
# 13447818      1.588748e+15   130009733.0       2.0     145959980    17647752
# 13447819      1.588748e+15   130009740.0       2.0     145959980    18946476
#
#           SecurityID  Side OrderType   Price  OrderQty  idx_x  \
# 13447800         636     1         2  214100       500    0.0
# 13447803      300265     2         2  120400      1000    0.0
# 13447804      300672     2         2  486500       700    0.0
# 13447806      300192     1         2  174800       100    0.0
# 13447807      300683     1         2  485100       300    0.0
# 13447808        2300     1         2   75300      1000    0.0
# 13447809      300275     2         2  118300       800    0.0
# 13447810      300014     2         2  696100       500    0.0
# 13447812      300119     1         2  189700       700    0.0
# 13447813          32     1         2  179000       200    0.0
# 13447814        2956     1         2  582100       100    0.0
# 13447815      300221     1         2   47800      1000    0.0
# 13447816      300626     1         2   99800      1000    0.0
# 13447817      300173     2         2   55500      1000    0.0
# 13447818         565     2         2   46800      1600    0.0
# 13447819        2761     2         2   94800       500    0.0
#
#           clockAtArrival_y  sequenceNo_y  exchId_y  idx_y
# 13447800               NaN           NaN       NaN    NaN
# 13447803               NaN           NaN       NaN    NaN
# 13447804               NaN           NaN       NaN    NaN
# 13447806               NaN           NaN       NaN    NaN
# 13447807               NaN           NaN       NaN    NaN
# 13447808               NaN           NaN       NaN    NaN
# 13447809               NaN           NaN       NaN    NaN
# 13447810               NaN           NaN       NaN    NaN
# 13447812               NaN           NaN       NaN    NaN
# 13447813               NaN           NaN       NaN    NaN
# 13447814               NaN           NaN       NaN    NaN
# 13447815               NaN           NaN       NaN    NaN
# 13447816               NaN           NaN       NaN    NaN
# 13447817               NaN           NaN       NaN    NaN
# 13447818               NaN           NaN       NaN    NaN
# 13447819               NaN           NaN       NaN    NaN
# array([   636, 300265, 300672, 300192, 300683,   2300, 300275, 300014,
#        300119,     32,   2956, 300221, 300626, 300173,    565,   2761],
#       dtype=int64)
# array([145959950, 145959960, 145959970, 145959980], dtype=int64)
#           clockAtArrival_x  sequenceNo_x  exchId_x  TransactTime  ApplSeqNum  \
# 13447820               NaN           NaN       NaN     143937440    17205038
# 13447821               NaN           NaN       NaN     143937440    17094294
# 13447822               NaN           NaN       NaN     143937450    16093543
# 13447823               NaN           NaN       NaN     143937450    17205042
# 13447824               NaN           NaN       NaN     143937450    17205044
# ...                    ...           ...       ...           ...         ...
# 13448490               NaN           NaN       NaN     143938460    17095269
# 13448491               NaN           NaN       NaN     143938460    16094465
# 13448492               NaN           NaN       NaN     143938460    17206054
# 13448493               NaN           NaN       NaN     143938460    17206055
# 13448494               NaN           NaN       NaN     143938470    17095281
#
#           SecurityID  Side OrderType   Price  OrderQty  idx_x  \
# 13447820      300690     2         2  241000       200    NaN
# 13447821          55     1         2   43500      5000    NaN
# 13447822        2324     1         2  133300       100    NaN
# 13447823        2334     2         2   44500       100    NaN
# 13447824        2368     2         2  403800       100    NaN
# ...              ...   ...       ...     ...       ...    ...
# 13448490        2928     1         2  137800      5600    NaN
# 13448491      300688     2         2  283800      2000    NaN
# 13448492      300652     1         2  191200       100    NaN
# 13448493         158     2         2   94500       100    NaN
# 13448494      300540     2         2  126000       300    NaN
#
#           clockAtArrival_y  sequenceNo_y  exchId_y  idx_y
# 13447820      1.588747e+15   108711891.0       2.0    0.0
# 13447821      1.588747e+15   108711902.0       2.0    1.0
# 13447822      1.588747e+15   108711905.0       2.0    0.0
# 13447823      1.588747e+15   108711911.0       2.0    0.0
# 13447824      1.588747e+15   108711914.0       2.0    0.0
# ...                    ...           ...       ...    ...
# 13448490      1.588747e+15   108717391.0       2.0    1.0
# 13448491      1.588747e+15   108717725.0       2.0    0.0
# 13448492      1.588747e+15   108717737.0       2.0    0.0
# 13448493      1.588747e+15   108717740.0       2.0    0.0
# 13448494      1.588747e+15   108717742.0       2.0    0.0
#
# [675 rows x 15 columns]
