# %%
import pandas as pd
import random
import numpy as np
import glob
import os
from unrar import rarfile
import py7zr
import pickle
import datetime
import time
pd.set_option("max_columns", 200)


year = "2019"
startDate = '20191001'
endDate = '20191231'
bad = []
less = []
l = []
readPath = 'K:\\data\\' + year + '\\***\\***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([os.path.basename(i).split('_')[0] for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs >= startDate) & (dateLs <= endDate)]
date_list = pd.read_csv("G:\\trading_days.csv")
for data in dataPathLs:
    if len(np.array(glob.glob(data + '\\SH\\***'))) == 0:
        if int(os.path.basename(data)) not in date_list["Date"].values:
            continue
        else:
            print(os.path.basename(data) + " less data!!!!!!!!!!!!!!!!!")
            less.append(data)
            continue
    
    startTm = datetime.datetime.now()
    date = os.path.basename(data)
    exe_path = 'G:\\7z1900-extra\\7za.exe'
    rar_path = data + '\\SH\\snapshot.7z'
    path = 'E:\\KR\\' + year + '\\SH'
    path1 = path + '\\' + date
    os.mkdir(path1)
    un_path = path1
    cmd = '{} x {} -o{} -aos -r'.format(exe_path, rar_path, un_path)
    os.system(cmd)

    date = os.path.basename(data)
    exe_path = 'G:\\7z1900-extra\\7za.exe'
    rar_path = data + '\\SZ\\snapshot.7z'
    path = 'E:\\KR\\' + year + '\\SZ'
    path1 = path + '\\' + date
    un_path = path1
    cmd = '{} x {} -o{} -aos -r'.format(exe_path, rar_path, un_path)
    os.system(cmd)
    
    date = os.path.basename(data)
    exe_path = 'G:\\7z1900-extra\\7za.exe'
    rar_path = data + '\\SZ\\order.7z'
    path = 'E:\\KR\\' + year + '\\SZ'
    path1 = path + '\\' + date
    un_path = path1
    cmd = '{} x {} -o{} -aos -r'.format(exe_path, rar_path, un_path)
    os.system(cmd)
    
    date = os.path.basename(data)
    exe_path = 'G:\\7z1900-extra\\7za.exe'
    rar_path = data + '\\SZ\\tick.7z'
    path = 'E:\\KR\\' + year + '\\SZ'
    path1 = path + '\\' + date
    un_path = path1
    cmd = '{} x {} -o{} -aos -r'.format(exe_path, rar_path, un_path)
    os.system(cmd)
    
    l.append(data)
    print(datetime.datetime.now() - startTm)
    print(date + 'finished')
    
print(len(dataPathLs))
print(len(np.array(glob.glob('G:\\KR\\' + year + '\\SZ\\***'))))
print(len(np.array(glob.glob('G:\\KR\\' + year + '\\SH\\***'))))
print(bad)
print(less)
# Out:
# 0:05:39.782358
# 20191008finished
# 0:05:51.142606
# 20191009finished
# 0:05:24.431284
# 20191010finished
# 0:04:39.700922
# 20191011finished
# 0:04:45.631439
# 20191014finished
# 0:04:42.051959
# 20191015finished
# 0:04:42.158570
# 20191016finished
# 0:04:28.107245
# 20191017finished
# 0:04:53.743419
# 20191018finished
# 0:04:54.481961
# 20191021finished
# 0:04:19.494407
# 20191022finished
# 0:04:21.842801
# 20191023finished
# 0:04:44.468119
# 20191024finished
# 0:04:43.713624
# 20191025finished
# 0:00:02.290006
# 20191027finished
# 0:05:02.168144
# 20191028finished
# 0:04:45.186972
# 20191029finished
# 0:05:17.586511
# 20191030finished
# 0:04:48.601657
# 20191031finished
# 0:04:48.192619
# 20191101finished
# 0:04:43.047382
# 20191104finished
# 0:04:35.494209
# 20191105finished
# 0:04:44.712690
# 20191106finished
# 0:04:29.735245
# 20191107finished
# 0:04:22.249158
# 20191108finished
# 0:04:29.035787
# 20191111finished
# 0:04:39.967557
# 20191112finished
# 0:04:20.662697
# 20191113finished
# 0:04:26.095829
# 20191114finished
# 0:04:40.304273
# 20191115finished
# 0:04:47.992546
# 20191118finished
# 0:04:42.834255
# 20191119finished
# 0:04:20.795166
# 20191120finished
# 0:05:50.816767
# 20191121finished
# 0:06:15.151396
# 20191122finished
# 0:06:36.466903
# 20191125finished
# 0:05:36.222903
# 20191126finished
# 0:06:21.394857
# 20191127finished
# 0:05:57.743298
# 20191128finished
# 0:05:54.336712
# 20191129finished
# 0:00:02.466461
# 20191130finished
# 0:11:13.700271
# 20191202finished
# 0:11:12.869199
# 20191203finished
# 0:10:53.691298
# 20191204finished
# 0:07:58.373073
# 20191205finished
# 0:07:03.346466
# 20191206finished
# 0:08:30.261340
# 20191209finished
# 0:09:42.760215
# 20191210finished
# 0:10:00.517058
# 20191211finished
# 0:10:03.074736
# 20191212finished
# 0:05:46.706990
# 20191213finished
# 0:11:12.812485
# 20191216finished
# 0:13:08.672930
# 20191217finished
# 0:12:44.703351
# 20191218finished
# 0:12:24.343670
# 20191219finished
# 0:12:23.903590
# 20191220finished
# 0:12:15.965652
# 20191223finished
# 0:11:57.661979
# 20191224finished
# 0:11:49.182223
# 20191225finished
# 0:10:56.442085
# 20191226finished
# 0:11:44.494894
# 20191227finished
# 0:11:28.888740
# 20191230finished
# 0:05:23.110315
# 20191231finished
# 63
# 144
# 145
# []
# []
