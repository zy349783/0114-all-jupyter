# %% [markdown]
# ## 1. cffex lv2

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import pickle
from matplotlib import pyplot as plt
import statsmodels.api as sm
from matplotlib.ticker import Formatter
import collections
from decimal import Decimal, getcontext, ROUND_HALF_UP
pd.set_option('max_columns', 200)

data1 = pd.read_csv(r'F:\data\20200812\fn_34_01_mdLog_fut2_20200812_0856\mdLog_fut2_20200812_0856.csv')
data2 = pd.read_csv(r'F:\data\20200812\fn_40_01_mdLog_fut2_20200812_0901\mdLog_fut2_20200812_0901.csv')
data1 = data1.rename(columns={"secName":"secid", "genTime":"exchangeTime"})
data2 = data2.rename(columns={"secName":"secid", "genTime":"exchangeTime"})
data2 = data2[data2['secid'].isin(['IC2009', 'IF2009', 'IH2009', 'IC2012', 'IF2012', 'IH2012',
       'IC2008', 'IF2008', 'IH2008', 'IC2103', 'IF2103', 'IH2103'])]
data1 = data1[data1['secid'].isin(['IC2009', 'IF2009', 'IH2009', 'IC2012', 'IF2012', 'IH2012',
       'IC2008', 'IF2008', 'IH2008', 'IC2103', 'IF2103', 'IH2103'])]

# %%
data1[data1['secid'] == 'IC2103'].head(10)
# Out:
#                   ms             clock    clockAtArrival  eventId  threadId  \
# 0    09:28:23.937087  1597195703938468  1597195703938365        7     13611
# 21   09:28:23.938087  1597195703939677  1597195703939649       28     13611
# 28   09:28:23.939087  1597195703940941  1597195703940902       35     13611
# 57   09:28:23.942087  1597195703943214  1597195703943185       64     13611
# 84   09:29:24.354083  1597195764355779  1597195764355729       97     13611
# 85   09:29:24.354083  1597195764355798  1597195764355760       98     13611
# 122  09:29:24.356083  1597195764357381  1597195764357357      135     13611
# 127  09:29:24.357083  1597195764358140  1597195764358112      140     13611
# 160  09:29:24.852083  1597195764853751  1597195764853709      181     13611
# 163  09:29:24.853083  1597195764854240  1597195764854200      184     13611
#
#       secid  isFaster  lastPrice  volume   buyP5   buyP4   buyP3   buyP2  \
# ...

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import pickle
from matplotlib import pyplot as plt
import statsmodels.api as sm
from matplotlib.ticker import Formatter
import collections
from decimal import Decimal, getcontext, ROUND_HALF_UP
pd.set_option('max_columns', 200)

d1 = pd.read_csv(r'\\192.168.10.28\DataTeamShared\20200722\indigo\mdl2BestAndDeepLog_20200722_0810.csv')
d2 = pd.read_csv(r'\\192.168.10.28\DataTeamShared\20200722\indigo\mdl2BestAndDeepLog_20200722_1303.csv')
dd1 = pd.read_csv(r'\\192.168.10.28\DataTeamShared\20200722\indigo\mdLog_20200722_0810.csv')
dd2 = pd.read_csv(r'\\192.168.10.28\DataTeamShared\20200722\indigo\mdLog_20200722_1303.csv')
corrections = {1088: 'IF2007',    
               1089: 'IF2008', 
               1090: 'IF2009', 
               1093: 'IF2012', 
               3363: 'IH2007',    
               3364: 'IH2008', 
               3365: 'IH2009', 
               3368: 'IH2012', 
               3463: 'IC2007',    
               3464: 'IC2008', 
               3465: 'IC2009', 
               3468: 'IC2012',  
               6263: 'XC2007',    
               6264: 'XC2008', 
               6265: 'XC2009', 
               6268: 'XC2012'}
d1 = pd.concat([d1, d2])
dd1 = pd.concat([dd1, dd2])
d1.secid = d1.secid.map(corrections)
dd1.secid = dd1.secid.map(corrections)
d1 = d1[d1['secid'].isin(['IC2009', 'IF2009', 'IH2009', 'IC2012', 'IF2012', 'IH2012',
       'IC2008', 'IF2008', 'IH2008'])]
dd1 = dd1[dd1['secid'].isin(['IC2009', 'IF2009', 'IH2009', 'IC2012', 'IF2012', 'IH2012',
       'IC2008', 'IF2008', 'IH2008'])]
d1 = d1[~d1['lastPrice'].isnull()]
display(d1.shape[0])
data1 = pd.merge(d1, dd1.drop_duplicates(['secid', 'clockAtArrival', 'exchangeTime'])[['secid', 'clockAtArrival', 'exchangeTime']], on=['secid', 'clockAtArrival'], how='left')
display(data1.shape[0])
display(data1[data1['exchangeTime'].isnull()])

data2 = pd.read_csv(r'\\192.168.10.28\DataTeamShared\20200722\mdLog_20200722_0909_fn3402_day\mdLog_fut2_20200722_0909.csv')
data2 = data2.rename(columns={"secName":"secid", "genTime":"exchangeTime"})
data2 = data2[data2['secid'].isin(['IC2009', 'IF2009', 'IH2009', 'IC2012', 'IF2012', 'IH2012',
       'IC2008', 'IF2008', 'IH2008'])]
# Out:
# 221896
# 221896
# Empty DataFrame
# Columns: [ms, clock, clockAtArrival, eventId, threadId, secid, isFaster, lastPrice, volume, buyP5, buyP4, buyP3, buyP2, buyP1, sellP1, sellP2, sellP3, sellP4, sellP5, buyQ5, buyQ4, buyQ3, buyQ2, buyQ1, sellQ1, sellQ2, sellQ3, sellQ4, sellQ5, genTime, oi, suspension, buyQI5, buyQI4, buyQI3, buyQI2, buyQI1, sellQI1, sellQI2, sellQI3, sellQI4, sellQI5, tick, turnover, temp, buyP10, buyP9, buyP8, buyP7, buyP6, sellP6, sellP7, sellP8, sellP9, sellP10, buyQ10, buyQ9, buyQ8, buyQ7, buyQ6, sellQ6, sellQ7, sellQ8, sellQ9, sellQ10, Unnamed: 65, exchangeTime]
# Index: []

# %%
pd.set_option('max_rows', 200)
data1.dtypes
# Out:
# ms                 object
# clock               int64
# clockAtArrival      int64
# eventId             int64
# threadId            int64
# secid              object
# isFaster            int64
# lastPrice         float64
# volume              int64
# buyP5              object
# buyP4              object
# buyP3             float64
# buyP2             float64
# buyP1             float64
# sellP1            float64
# sellP2            float64
# sellP3            float64
# sellP4             object
# sellP5             object
# buyQ5               int64
# buyQ4               int64
# buyQ3               int64
# buyQ2               int64
# buyQ1               int64
# sellQ1              int64
# sellQ2              int64
# sellQ3              int64
# sellQ4              int64
# sellQ5              int64
# exchangeTime       object
# oi                  int64
# sequenceNo          int64
# buyQI5            float64
# buyQI4            float64
# buyQI3            float64
# ...

# %%
data1.groupby('secid')['exchangeTime'].max()
# Out:
# secid
# IC2008      11:30:00|0
# IC2009    11:29:59|500
# IC2012      11:30:00|0
# IC2103      11:30:00|0
# IF2008      11:30:00|0
# IF2009    11:29:59|500
# IF2012      11:30:00|0
# IF2103      11:30:00|0
# IH2008      11:30:00|0
# IH2009    11:29:59|500
# IH2012    11:29:59|500
# IH2103    11:29:59|500
# Name: exchangeTime, dtype: object

# %%
data2.groupby('secid')['exchangeTime'].max()
# Out:
# secid
# IC2008      11:30:00|0
# IC2009    11:29:59|500
# IC2012      11:30:00|0
# IC2103      11:30:00|0
# IF2008      11:30:00|0
# IF2009    11:29:59|500
# IF2012      11:30:00|0
# IF2103      11:30:00|0
# IH2008      11:30:00|0
# IH2009    11:29:59|500
# IH2012    11:29:59|500
# IH2103    11:29:59|500
# Name: exchangeTime, dtype: object

# %%
columns = ["secid", "lastPrice", "volume", "buyP5", "buyP4", "buyP3", "buyP2", "buyP1", "sellP1", "sellP2",
           "sellP3", "sellP4", "sellP5", "buyQ5", "buyQ4", "buyQ3", "buyQ2", "buyQ1", "sellQ1", "sellQ2", "sellQ3",
           "sellQ4", "sellQ5", 'turnover', 'exchangeTime']
for cols in ['sellP4', 'sellP5', "buyP5", "buyP4"]:
    data2[cols] = data2[cols].astype(float)
    data1[cols] = data1[cols].astype(float)
# data2 = data2[data2['volume'] > 0]
# data11 = data1[(data1['exchangeTime'] <= '11:29:57|700') | (data1['exchangeTime'] >= '13:07:26|200')]
# data21 = data2[(data2['exchangeTime'] <= '11:29:57|700') | (data2['exchangeTime'] >= '13:07:26|200')]
data11 = data1.drop_duplicates(subset=columns, keep="first").reset_index()
data21 = data2.drop_duplicates(subset=columns, keep="first").reset_index()
test = pd.merge(data11, data21, left_on=columns, right_on=columns, how="outer")
n1 = test["clock_x"].count()
n2 = test["clock_y"].count()
len1 = len(test)
print(n1)
print(n2)
print(len1)
# Out:
# 150384
# 150424
# 150424

# %%
test[test['clock_x'].isnull()]
# Out:
#         index_x ms_x  clock_x  clockAtArrival_x  eventId_x  threadId_x  \
# 150384      NaN  NaN      NaN               NaN        NaN         NaN
# 150385      NaN  NaN      NaN               NaN        NaN         NaN
# 150386      NaN  NaN      NaN               NaN        NaN         NaN
# 150387      NaN  NaN      NaN               NaN        NaN         NaN
# 150388      NaN  NaN      NaN               NaN        NaN         NaN
# 150389      NaN  NaN      NaN               NaN        NaN         NaN
# 150390      NaN  NaN      NaN               NaN        NaN         NaN
# 150391      NaN  NaN      NaN               NaN        NaN         NaN
# 150392      NaN  NaN      NaN               NaN        NaN         NaN
# 150393      NaN  NaN      NaN               NaN        NaN         NaN
# 150394      NaN  NaN      NaN               NaN        NaN         NaN
# 150395      NaN  NaN      NaN               NaN        NaN         NaN
# ...

# %%
test[test['clock_x'].isnull()]['exchangeTime'].unique()
# Out:
# array(['09:34:00|500', '10:35:21|500', '10:40:38|0', '10:55:43|0',
#        '10:58:38|500', '11:00:28|500', '11:01:18|500', '11:05:39|500'],
#       dtype=object)

# %%
data1[(data1['secid'] == 'IH2008') & (data1['exchangeTime'] >= '10:58:38')].head(10)
# Out:
#                      ms             clock    clockAtArrival  eventId  \
# 685266  10:58:01.836667  1597201081837398  1597201081837367   856788
# 685283  10:58:01.836667  1597201081837847  1597201081837830   856805
# 685290  10:58:01.837667  1597201081838098  1597201081838075   856812
# 685316  10:58:02.840667  1597201082841528  1597201082841503   856867
# 685338  10:58:02.841667  1597201082842443  1597201082842425   856889
# 685345  10:58:02.842667  1597201082843093  1597201082843066   856896
# 685370  10:58:03.338667  1597201083339442  1597201083339411   856936
# 685390  10:58:03.339667  1597201083340203  1597201083340185   856957
# 685398  10:58:03.339667  1597201083340377  1597201083340357   856965
# 685405  10:58:03.340667  1597201083341161  1597201083341142   856972
#
#         threadId   secid  isFaster  lastPrice  volume   buyP5   buyP4   buyP3  \
# 685266     13611  IH2008         1     3233.4   22100  3232.4  3232.6  3232.8
# ...

# %%
data1[(data1['secid'] == 'IC2012') & (data1['exchangeTime'] >= '09:32:33|200')].head(10)[['clockAtArrival', 'secid', 'lastPrice', 'volume', 'buyP1', 'buyQ1', 'sellP1', 'sellQ1', 'exchangeTime']]
# Out:
#       clockAtArrival   secid  lastPrice  volume   buyP1  buyQ1  sellP1  \
# 2751    1.595382e+15  IC2012     6215.2   540.0  6214.8    1.0  6217.4
# 2759    1.595382e+15  IC2012     6217.4   541.0  6216.8    1.0  6219.2
# 2768    1.595382e+15  IC2012     6220.0   549.0  6218.8    1.0  6220.0
# 2777    1.595382e+15  IC2012     6220.0   551.0  6218.8    1.0  6219.8
# 2794    1.595382e+15  IC2012     6218.8   552.0  6217.4    1.0  6218.4
# 2803    1.595382e+15  IC2012     6217.4   554.0  6216.2    1.0  6218.4
# 2812    1.595382e+15  IC2012     6217.8   555.0  6217.4    1.0  6218.2
# 2821    1.595382e+15  IC2012     6216.2   556.0  6215.0    3.0  6217.4
# 2829    1.595382e+15  IC2012     6215.0   558.0  6215.0    2.0  6217.2
# 2837    1.595382e+15  IC2012     6215.0   560.0  6214.0    1.0  6215.0
#
#       sellQ1  exchangeTime
# 2751     1.0  09:32:33|200
# 2759     3.0  09:32:34|200
# 2768     3.0  09:32:34|700
# 2777     3.0  09:32:35|200
# 2794     1.0  09:32:36|200
# ...

# %%
data2[(data2['secid'] == 'IC2012') & (data2['exchangeTime'] >= '09:32:33|200')].head(18)[['clockAtArrival', 'secid', 'lastPrice', 'volume', 'buyP1', 'buyQ1', 'sellP1', 'sellQ1', 'exchangeTime']]
# Out:
#          clockAtArrival   secid  lastPrice  volume   buyP1  buyQ1  sellP1  \
# 21976  1595381561792251  IC2012     6215.2     540  6214.8      1  6217.4
# 21978  1595381561792286  IC2012     6215.2     540  6214.8      1  6217.4
# 21980  1595381561792503  IC2012     6215.2     540  6214.8      1  6217.4
# 21982  1595381561792552  IC2012     6215.2     540  6214.8      1  6217.4
# 22036  1595381562292577  IC2012     6217.4     541  6216.8      1  6219.2
# 22039  1595381562292618  IC2012     6217.4     541  6216.8      1  6219.2
# 22040  1595381562292634  IC2012     6217.4     541  6216.8      1  6219.2
# 22043  1595381562292652  IC2012     6217.4     541  6216.8      1  6219.2
# 22104  1595381562794474  IC2012     6220.0     546  6218.4      1  6220.0
# 22106  1595381562794535  IC2012     6220.0     546  6218.4      1  6220.0
# 22110  1595381562794599  IC2012     6220.0     546  6218.4      1  6220.0
# 22113  1595381562794629  IC2012     6220.0     546  6218.4      1  6220.0
# ...

# %%
d1 = pd.read_csv(r'\\192.168.10.28\DataTeamShared\20200722\indigo\mdl2BestAndDeepLog_20200722_0810.csv')
dd1 = pd.read_csv(r'\\192.168.10.28\DataTeamShared\20200722\indigo\mdLog_20200722_0810.csv')
corrections = {1088: 'IF2007',    
               1089: 'IF2008', 
               1090: 'IF2009', 
               1093: 'IF2012', 
               3363: 'IH2007',    
               3364: 'IH2008', 
               3365: 'IH2009', 
               3368: 'IH2012', 
               3463: 'IC2007',    
               3464: 'IC2008', 
               3465: 'IC2009', 
               3468: 'IC2012',  
               6263: 'XC2007',    
               6264: 'XC2008', 
               6265: 'XC2009', 
               6268: 'XC2012'}
d1.secid = d1.secid.map(corrections)
dd1.secid = dd1.secid.map(corrections)

# %%
dd1[(dd1['clockAtArrival'] ==1595381526035073.0) & (dd1['secid'] == 'IC2012')][['clockAtArrival', 'secid', 'lastPrice', 'volume', 'exchangeTime']]
# Out:
#          clockAtArrival   secid  lastPrice  volume  exchangeTime
# 14460  1595381526035073  IC2012     6220.0   546.0  09:32:34|200

# %%
d1[(d1['clockAtArrival'] == 1595381526035073) & (d1['secid'] == 'IC2012')][['clockAtArrival', 'secid', 'lastPrice', 'volume', 'buyP1', 'buyQ1', 'sellP1', 'sellQ1']]
# Out:
#         clockAtArrival   secid  lastPrice  volume   buyP1  buyQ1  sellP1  \
# 4789  1595381526035073  IC2012     6217.4     541  6216.8    1.0  6219.2
#
#       sellQ1
# 4789     3.0

# %%
test[test['clock_y'].isnull()]
# Out:
#          index_x                          ms_x       clock_x  \
# 113914  118267.0  2020-July-22 13:06:58.029844  1.595394e+15
# 113925  118279.0  2020-July-22 13:06:58.533590  1.595394e+15
#
#         clockAtArrival_x  eventId_x  threadId_x   secid  isFaster_x  \
# 113914      1.595394e+15     8514.0      1536.0  IF2012         1.0
# 113925      1.595394e+15     8583.0      1536.0  IF2009         1.0
#
#         lastPrice   volume   buyP5   buyP4   buyP3   buyP2   buyP1  sellP1  \
# 113914     4678.4   7374.0  4677.0  4678.0  4678.2  4678.4  4678.6  4680.0
# 113925     4714.0  20801.0  4712.0  4712.2  4712.8  4713.0  4714.0  4716.0
#
#         sellP2  sellP3  sellP4  sellP5  buyQ5  buyQ4  buyQ3  buyQ2  buyQ1  \
# 113914  4684.2  4684.4  4684.8  4685.2    1.0    4.0    1.0    1.0    1.0
# 113925  4716.2  4718.4  4719.6  4719.8    3.0    2.0    1.0    2.0    1.0
#
#         sellQ1  sellQ2  sellQ3  sellQ4  sellQ5  genTime  oi_x  suspension_x  \
# ...
