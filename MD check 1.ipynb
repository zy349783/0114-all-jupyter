# %%
import pandas as pd
import numpy as np

logSZ = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\rawData\logs_20200324_zs_92_01_day_data\mdLog_SZ_20200324_0836.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
                                              "exchange", "time", "cum_volume", "cum_amount", "close",
                                              "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
                                              "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
                                              "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
                                              "ask4q", "ask5q", "openPrice"]]
logSZ1 = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\check\20200324\full_20200324_zt_88_02_day_8843.tar\mdLog_SZ_20200324_0838.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
                                              "exchange", "time", "cum_volume", "cum_amount", "close",
                                              "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
                                              "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
                                              "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
                                              "ask4q", "ask5q", "openPrice"]]
# logSZ2 = pd.read_csv('E:\\compare\\temp 8865\\mdLog_SZ_20200120_0834.csv',
#                      encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
#                                                "exchange", "time", "cum_volume", "cum_amount", "close",
#                                                "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
#                                                "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
#                                                "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
#                                                "ask4q", "ask5q", "openPrice"]]
# logSZ3 = pd.read_csv('E:\\compare\\native 88\\mdLog_SZ_20200115_0835.csv',
#                      encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
#                                                "exchange", "time", "cum_volume", "cum_amount", "close",
#                                                "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
#                                                "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
#                                                "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
#                                                "ask4q", "ask5q", "openPrice"]]
# 1. data format
# 1.1 in general
print("original data source type: ")
print(logSZ["source"].unique())
print("new data source type: ")
print(logSZ1["source"].unique())
print(logSZ["time"].unique())
print(logSZ1["time"].unique())
# Out:
# original data source type:
# [4 3]
# new data source type:
# [11 12]
# ['08:36:36.000' '08:37:36.000' '08:38:36.000' ... '15:15:03.000'
#  '15:16:03.000' '15:17:03.000']
# ['08:38:36' '08:38:33' '08:39:33' ... '15:32:48' '15:33:00' '15:33:03']

# %%
logSZ2 = logSZ1[logSZ1["source"] == 24]
logSZ1 = logSZ1[logSZ1["source"].isin([20, 21])]
print(logSZ["time"].unique())
print(logSZ1["time"].unique())
print(logSZ2["time"].unique())
# Out:
# ['08:32:51.000' '08:32:54.000' '08:33:51.000' ... '15:16:03.000'
#  '15:17:03.000' '15:18:03.000']
# ['08:25:51' '08:43:15' '08:25:54' ... '14:59:51' '14:59:54' '15:00:03']
# ['09:12:51.000' '09:12:54.000' '09:13:51.000' ... '15:19:03.000'
#  '15:20:03.000' '15:21:03.000']

# %%
import pandas as pd
import numpy as np
post = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\check\20200317\full_20200316_zt_52_01_day_5274\full_20200316_zt_52_01_day_5274.tar.gz\mdLog_SZ_20200316_0912.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
                                              "exchange", "time", "cum_volume", "cum_amount", "close",
                                              "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
                                              "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
                                              "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
                                              "ask4q", "ask5q", "openPrice"]]
pre = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\check\20200317\full_20200316_zt_52_01_day_5271\mdLog_SZ_20200316_0909.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
                                              "exchange", "time", "cum_volume", "cum_amount", "close",
                                              "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
                                              "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
                                              "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
                                              "ask4q", "ask5q", "openPrice"]]
tdf = pd.read_csv(r'\\192.168.10.30\Kevin_zhenyu\check\20200317\full_20200316_zt_52_01_day_sidetdf\mdLog_SZ_20200316_0909.csv',
                    encoding="utf-8").loc[:, ["clockAtArrival", "sequenceNo", "source", "StockID",
                                              "exchange", "time", "cum_volume", "cum_amount", "close",
                                              "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q",
                                              "bid2q", "bid3q", "bid4q", "bid5q", "ask1p", "ask2p",
                                              "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
                                              "ask4q", "ask5q", "openPrice"]]



print("post data source type: ")
print(post["source"].unique())
print("pre data source type: ")
print(pre["source"].unique())
print("tdf data source type: ")
print(tdf["source"].unique())

print(post["time"].unique())
print(pre["time"].unique())
print(tdf["time"].unique())

# %%
display(post[(post["StockID"] == 1) & (post["time"] >= 134500000) & (post["time"] <= 135000000)])
display(pre[(pre["StockID"] == 1) & (pre["time"] >= 134500000) & (pre["time"] <= 135000000)])
display(tdf[(tdf["StockID"] == 1) & (tdf["time"] >= 134500000) & (tdf["time"] <= 135000000)])

# %%
# logSZ1["time"] = logSZ1["time"].apply(lambda x: int((x.replace(':', "")).replace(".", "")))
logSZ["time"] = logSZ["time"].apply(lambda x: int((x.replace(':', "")).replace(".", "")))
logSZ1["time"] = logSZ1["time"].apply(lambda x: int((x.replace(':', "")).ljust(9, "0")))
# logSZ2["time"] = logSZ2["time"].apply(lambda x: int((x.replace(':', "")).replace(".", "")))

# %%
logSZ[(logSZ["StockID"] == 1) & (logSZ["time"] >= 134500000) & (logSZ["time"] <= 135000000)]
# Out:
#             clockAtArrival  sequenceNo  source  StockID exchange       time  \
# 11492295  1585028704342257    92761823       4        1       SZ  134500000
# 11492347  1585028704360597    92762268       3        1       SZ  134500000
# 11495549  1585028707364595    92783636       4        1       SZ  134503000
# 11495605  1585028707391778    92783801       3        1       SZ  134503000
# 11498914  1585028710343427    92805784       4        1       SZ  134506000
# ...                    ...         ...     ...      ...      ...        ...
# 11827152  1585028998360870    95086148       3        1       SZ  134954000
# 11830340  1585029001343244    95108002       4        1       SZ  134957000
# 11830367  1585029001348000    95108057       3        1       SZ  134957000
# 11833661  1585029004342946    95135238       4        1       SZ  135000000
# 11833712  1585029004358352    95135811       3        1       SZ  135000000
#
# ...

# %%
logSZ1[(logSZ1["StockID"] == 1) & (logSZ1["time"] >= 134500000) & (logSZ1["time"] <= 135000000)]
# Out:
#             clockAtArrival  sequenceNo  source  StockID exchange       time  \
# 17465513  1585028661501409   140228679      12        1       SZ  134500000
# 17465578  1585028661515034   140228830      11        1       SZ  134500000
# 17479659  1585028664539972   140271982      12        1       SZ  134503000
# 17479687  1585028664550014   140272153      11        1       SZ  134503000
# 17483785  1585028667504363   140305751      12        1       SZ  134506000
# ...                    ...         ...     ...      ...      ...        ...
# 17928467  1585028955515649   143723173      11        1       SZ  134954000
# 17932424  1585028958500033   143755758      12        1       SZ  134957000
# 17932471  1585028958516107   143755928      11        1       SZ  134957000
# 17936497  1585028961496859   143795433      12        1       SZ  135000000
# 17936532  1585028961508715   143795551      11        1       SZ  135000000
#
# ...

# %%
# check if they start from same time first!!!!!!!!!!!!
# if not, then cut the time of new database to make it match
print(max(logSZ[logSZ["source"] == 4].groupby("StockID")["time"].first()))
print(max(logSZ1[logSZ1["source"] == 24].groupby("StockID")["time"].first()))
# Out:
# 83648000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-63b300b1b5b6> in <module>
#       2 # if not, then cut the time of new database to make it match
#       3 print(max(logSZ[logSZ["source"] == 4].groupby("StockID")["time"].first()))
# ----> 4 print(max(logSZ1[logSZ1["source"] == 24].groupby("StockID")["time"].first()))
#
# ValueError: max() arg is an empty sequence

# %%
# 2. lv1 data compare
# 2.1 drop duplicates
data1 = logSZ[(logSZ["cum_volume"] > 0) & (logSZ["time"] < 145700000) & (logSZ["source"] == 3)]
data2 = logSZ1[(logSZ1["cum_volume"] > 0) & (logSZ1["time"] < 145700000) & (logSZ1["source"] == 11)]
# data1 = logSZ[(logSZ["time"] >= 103000000) & (logSZ["time"] < 145700000) & (logSZ["source"] == 3)]
# data2 = logSZ1[(logSZ1["time"] >= 103000000) & (logSZ1["time"] < 145700000) & (logSZ1["source"] == 20)]
columns = ["StockID", "cum_volume", "close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q", "bid2q",
           "bid3q", "bid4q", "bid5q", "ask1p", "ask2p", "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
           "ask4q", "ask5q", "openPrice"]
data1_1 = data1.drop_duplicates(subset=columns, keep="first").reset_index()
data2_1 = data2.drop_duplicates(subset=columns, keep="first").reset_index()
n1 = len(data1_1["StockID"].unique())
n2 = len(data2_1["StockID"].unique())
print(n1)
print(n2)
# Out:
# 2192
# 3234

# %%
# 2.2 merge and compare
columns = ["StockID", "cum_volume", "close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q", "bid2q",
           "bid3q", "bid4q", "bid5q", "ask1p", "ask2p", "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
           "ask4q", "ask5q", "openPrice"]
data2_1 = data2_1[data2_1["StockID"].isin(data1_1["StockID"].unique())]
test = pd.merge(data1_1, data2_1, left_on=columns, right_on=columns, how="outer")
n1 = test["sequenceNo_x"].count()
n2 = test["sequenceNo_y"].count()
len1 = len(test)
print(n1)
print(n2)
print(len1)
if len1 == n2:
    print((n2-n1)/n1)
# Out:
# 7567454
# 7567454
# 7567454
# 0.0

# %%
test[test["sequenceNo_y"].isnull()]
# Out:
#          StockID  clockAtArrival_x  sequenceNo_x  source_x exchange_x  \
# 440329       585  1583807401267171      62376299         3         SZ
# 1176232      972  1583807458401858      63074163         3         SZ
# 1834662     2207  1583807410519970      62502718         3         SZ
#
#             time_x  cum_volume  cum_amount_x  close  bid1p  ...   ask3q  \
# 440329   103000000     3860001    6574107.69   1.70   1.69  ...   72700
# 1176232  103057000     1666900    5417908.00   3.24   3.23  ...  166600
# 1834662  103009000      784901    4305435.47   5.47   5.47  ...   32000
#
#          ask4q  ask5q  openPrice  clockAtArrival_y  sequenceNo_y  source_y  \
# 440329   64000  62200       1.70               NaN           NaN       NaN
# 1176232  54000  99700       3.25               NaN           NaN       NaN
# 1834662   3000   4500       5.52               NaN           NaN       NaN
#
#          exchange_y  time_y  cum_amount_y
# 440329          NaN     NaN           NaN
# ...

# %%
logSZ1[(logSZ1["StockID"] == 2207) & (logSZ1["cum_volume"] == 784901) & (logSZ1["source"]==20)]
# Out:
#           clockAtArrival  sequenceNo  source  StockID exchange       time  \
# 6303    1583782708695366       60586      20     2207       SZ  102854000
# 17222   1583782716681518      141267      20     2207       SZ  102909000
# 102409  1583782791683028     1043516      20     2207       SZ  103024000
#
#         cum_volume  cum_amount  close  bid1p  ...  ask2p  ask3p  ask4p  ask5p  \
# 6303        784901   4305435.0   5.47   5.47  ...   5.49    5.5   5.51   5.52
# 17222       784901   4305435.0   5.47   5.47  ...   5.49    5.5   5.51   5.52
# 102409      784901   4305435.0   5.47   5.47  ...   5.49    5.5   5.51   5.52
#
#         ask1q  ask2q  ask3q  ask4q  ask5q  openPrice
# 6303    35100  29600  32000   3000   4500       5.52
# 17222   35100  29600  32000   3000   4500       5.52
# 102409  28200  29600  32000   3000   4500       5.52
#
# [3 rows x 30 columns]

# %%
# speed check
# test1 = test[~np.isnan(test["sequenceNo_x"])]
diff = test["clockAtArrival_y"] - test["clockAtArrival_x"]
print(np.median(diff[diff < 0]))
print(np.median(diff[diff > 0]))
print(sum(diff > 0)/len(diff))
print(sum(diff>0))
# Out:
# C:\Users\win\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\win\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# nan
# 15142704.0
# 1.0
# 7631903

# %%
# 2.3 find difference
test[np.isnan(test["sequenceNo_x"])]
# Out:
#          StockID  clockAtArrival_x  sequenceNo_x  source_x exchange_x  time_x  \
# 5743140       10               NaN           NaN       NaN        NaN     NaN
# 5743141       89               NaN           NaN       NaN        NaN     NaN
# 5743142      151               NaN           NaN       NaN        NaN     NaN
# 5743143      409               NaN           NaN       NaN        NaN     NaN
# 5743144      525               NaN           NaN       NaN        NaN     NaN
# 5743145      551               NaN           NaN       NaN        NaN     NaN
# 5743146      582               NaN           NaN       NaN        NaN     NaN
# 5743147      597               NaN           NaN       NaN        NaN     NaN
# 5743148      720               NaN           NaN       NaN        NaN     NaN
# 5743149      792               NaN           NaN       NaN        NaN     NaN
# 5743150      815               NaN           NaN       NaN        NaN     NaN
# ...

# %%
logSZ[(logSZ["StockID"] == 10) & (logSZ["time"] >= 100530000)]
# Out:
#             clockAtArrival  sequenceNo  source  StockID exchange       time  \
# 541095    1579054001160736    32283142      12       10       SZ  100545000
# 545658    1579054004172336    32320779      12       10       SZ  100548000
# 545732    1579054004189259    32321014      11       10       SZ  100548000
# 577441    1579054019196549    32520385      12       10       SZ  100603000
# 577626    1579054019233712    32521027      11       10       SZ  100603000
# ...                    ...         ...     ...      ...      ...        ...
# 18725259  1579072079620522   126956798      11       10       SZ  150703000
# 18740543  1579072139497900   126989290      12       10       SZ  150803000
# 18741049  1579072139607714   126989844      11       10       SZ  150803000
# 18756444  1579072199518414   127021108      12       10       SZ  150903000
# 18756886  1579072199609060   127021576      11       10       SZ  150903000
#
# ...

# %%
data2_1[(data2_1["StockID"] == 10) & (data2_1["time"] >= 100545000)]
# Out:
#        StockID    clockAtArrival  sequenceNo  source exchange       time  \
# 23541       10  1579054001155409    42856868      24       SZ  100545000
# 23542       10  1579054004157147    42905330      24       SZ  100548000
# 23543       10  1579054019194853    43144157      24       SZ  100603000
# 23544       10  1579054022146164    43192470      24       SZ  100606000
# 23545       10  1579054025157873    43238694      24       SZ  100609000
# ...        ...               ...         ...     ...      ...        ...
# 24354       10  1579071410328788   138457959      24       SZ  145554000
# 24355       10  1579071419367412   138584541      24       SZ  145603000
# 24356       10  1579071431340825   138758281      24       SZ  145615000
# 24357       10  1579071443340163   138931682      24       SZ  145627000
# 24358       10  1579071458339892   139139428      24       SZ  145642000
#
#        cum_volume  cum_amount  close  bid1p  ...  ask2p  ask3p  ask4p  ask5p  \
# ...

# %%
# 3. lv2 data compare
# 3.1 drop duplicates
data1 = logSZ[(logSZ["cum_volume"] > 0) & (logSZ["time"] < 145700000) & (logSZ["source"] == 4)]
data2 = logSZ1[(logSZ1["cum_volume"] > 0) & (logSZ1["time"] < 145700000) & (logSZ1["source"] == 12)]
# data1 = logSZ[(logSZ["time"] >= 130000000) & (logSZ["time"] < 145700000) & (logSZ["source"] == 4)]
# data2 = logSZ1[(logSZ1["time"] >= 130000000) & (logSZ1["time"] < 145700000) & (logSZ1["source"] == 24)]

columns = ["StockID", "cum_volume", "close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q", "bid2q",
           "bid3q", "bid4q", "bid5q", "ask1p", "ask2p", "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
           "ask4q", "ask5q", "openPrice"]
data1_1 = data1.drop_duplicates(subset=columns, keep="first").reset_index()
data2_1 = data2.drop_duplicates(subset=columns, keep="first").reset_index()
n1 = len(data1_1["StockID"].unique())
n2 = len(data2_1["StockID"].unique())
print(n1)
print(n2)
# Out:
# 2192
# 2883

# %%
# 3.2 merge and compare
columns = ["StockID", "cum_volume", "close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q", "bid2q",
           "bid3q", "bid4q", "bid5q", "ask1p", "ask2p", "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
           "ask4q", "ask5q", "openPrice"]
data2_1 = data2_1[data2_1["StockID"].isin(data1_1["StockID"].unique())]
test = pd.merge(data1_1, data2_1, left_on=columns, right_on=columns, how="outer")
n1 = test["sequenceNo_x"].count()
n2 = test["sequenceNo_y"].count()
len1 = len(test)
print(n1)
print(n2)
print(len1)
if len1 == n2:
    print((n2-n1)/n1)
# Out:
# 7567454
# 7567454
# 7567454
# 0.0

# %%
test[np.isnan(test["sequenceNo_y"])]
# Out:
#          StockID  clockAtArrival_x  sequenceNo_x  source_x exchange_x  \
# 1834698     2207  1583807410470069      62501221         4         SZ
#
#             time_x  cum_volume  cum_amount_x  close  bid1p  ...  ask3q  ask4q  \
# 1834698  103009000      784901    4305435.47   5.47   5.47  ...  32000   3000
#
#          ask5q  openPrice  clockAtArrival_y  sequenceNo_y  source_y  \
# 1834698   4500       5.52               NaN           NaN       NaN
#
#          exchange_y  time_y  cum_amount_y
# 1834698         NaN     NaN           NaN
#
# [1 rows x 36 columns]

# %%
logSZ1[(logSZ1["StockID"] == 2207) & (logSZ1["cum_volume"] == 784901) & (logSZ1["source"]==21)]
# Out:
#           clockAtArrival  sequenceNo  source  StockID exchange       time  \
# 660     1583782707933038        2758      21     2207       SZ  102854000
# 16862   1583782716616763      140305      21     2207       SZ  102909000
# 102105  1583782791628449     1042815      21     2207       SZ  103024000
#
#         cum_volume  cum_amount  close  bid1p  ...  ask2p  ask3p  ask4p  ask5p  \
# 660         784901   4305435.0   5.47   5.47  ...   5.49    5.5   5.51   5.52
# 16862       784901   4305435.0   5.47   5.47  ...   5.49    5.5   5.51   5.52
# 102105      784901   4305435.0   5.47   5.47  ...   5.49    5.5   5.51   5.52
#
#         ask1q  ask2q  ask3q  ask4q  ask5q  openPrice
# 660     35100  29600  32000   3000   4500       5.52
# 16862   35100  29600  32000   3000   4500       5.52
# 102105  28200  29600  32000   3000   4500       5.52
#
# [3 rows x 30 columns]

# %%
logSZ[(logSZ["StockID"] == 300194) & (logSZ["cum_volume"] == 63084040) & (logSZ["source"] == 4)].loc[:, ["bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q", "bid2q",
           "bid3q", "bid4q", "bid5q", "ask1p", "ask2p", "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
           "ask4q", "ask5q"]]
# Out:
#           bid1p  bid2p  bid3p  bid4p  bid5p  bid1q   bid2q   bid3q   bid4q  \
# 16979904    6.1   6.09   6.08   6.07   6.06   3800  224954  137275  193500
#
#            bid5q  ask1p  ask2p  ask3p  ask4p  ask5p   ask1q  ask2q   ask3q  \
# 16979904  220000   6.11   6.12   6.13   6.14   6.15  174800  95400  147100
#
#            ask4q   ask5q
# 16979904  113900  253600

# %%
logSZ1[(logSZ1["StockID"] == 300194) & (logSZ1["cum_volume"] == 63084040) & (logSZ1["source"] == 24)]
# Out:
#            clockAtArrival  sequenceNo  source  StockID exchange       time  \
# 8459676  1583218061175293   109813214      24   300194       SZ  144754000
# 8461414  1583218064153330   109830464      24   300194       SZ  144757000
#
#          cum_volume   cum_amount  close  bid1p  ...  ask2p  ask3p  ask4p  \
# 8459676    63084040  384088435.2    6.1    6.1  ...   6.12   6.13   6.14
# 8461414    63084040  384088435.2    6.1    6.1  ...   6.12   6.13   6.14
#
#          ask5p   ask1q   ask2q   ask3q   ask4q   ask5q  openPrice
# 8459676   6.15  174800   95400  147100  113900  253600       5.85
# 8461414   6.15  176800  115400  147100  113900  253600       5.85
#
# [2 rows x 30 columns]

# %%
# compare speed with another source
print(logSZ2["source"].unique())
print(logSZ2["time"].unique())
print(logSZ3["source"].unique())
print(logSZ3["time"].unique())
logSZ2["time"] = logSZ2["time"].apply(lambda x: int((x.replace(':', "")).ljust(9, "0")))
logSZ3["time"] = logSZ3["time"].apply(lambda x: int((x.replace(':', "")).ljust(9, "0")))
# Out:
# [11 12]
# ['08:32:24' '08:33:24' '08:34:24' ... '15:11:30' '15:11:33' '15:11:36']
# [11 12]
# ['08:34:33' '08:35:33' '08:36:33' ... '15:09:24' '15:09:27' '15:09:30']

# %%
data1 = logSZ3[(logSZ3["cum_volume"] > 0) & (logSZ3["time"] < 145700000) & (logSZ3["source"] == 12)]
data2 = logSZ1[(logSZ1["cum_volume"] > 0) & (logSZ1["time"] < 145700000) & (logSZ1["source"] == 24)]
# data1 = logSZ[(logSZ["time"] >= 100536000) & (logSZ["time"] < 145700000) & (logSZ["source"] == 4)]
# data2 = logSZ1[(logSZ1["time"] >= 100536000) & (logSZ1["time"] < 145700000) & (logSZ1["source"] == 24)]
columns = ["cum_volume", "close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q", "bid2q",
           "bid3q", "bid4q", "bid5q", "ask1p", "ask2p", "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
           "ask4q", "ask5q", "openPrice"]
data1_1 = data1.groupby("StockID")[data1.columns[~data1.columns.isin(["StockID"])].values].apply(
    lambda x: x[~x.duplicated(columns, keep="first")]).reset_index()
data2_1 = data2.groupby("StockID")[data2.columns[~data2.columns.isin(["StockID"])].values].apply(
    lambda x: x[~x.duplicated(columns, keep="first")]).reset_index()
data1_1 = data1_1.drop("level_1", axis=1)
data2_1 = data2_1.drop("level_1", axis=1)
n1 = len(data1_1["StockID"].unique())
n2 = len(data2_1["StockID"].unique())
print(n1)
print(n2)
# Out:
# 2837
# 2863

# %%
columns = ["StockID", "cum_volume", "close", "bid1p", "bid2p", "bid3p", "bid4p", "bid5p", "bid1q", "bid2q",
           "bid3q", "bid4q", "bid5q", "ask1p", "ask2p", "ask3p", "ask4p", "ask5p", "ask1q", "ask2q", "ask3q",
           "ask4q", "ask5q", "openPrice"]
# data1_1 = data1_1[data1_1["StockID"].isin(data2_1["StockID"].unique())]
data2_1 = data2_1[data2_1["StockID"].isin(data1_1["StockID"].unique())]
test = pd.merge(data1_1, data2_1, left_on=columns, right_on=columns, how="outer")
n1 = test["sequenceNo_x"].count()
n2 = test["sequenceNo_y"].count()
len1 = len(test)
print(n1)
print(n2)
print(len1)
if len1 == n2:
    print((n2-n1)/n1)
# Out:
# 6483939
# 7565659
# 14049598

# %%
test[np.isnan(test["sequenceNo_y"])]
# Out:
#          StockID  clockAtArrival_x  sequenceNo_x  source_x exchange_x  \
# 0              1      1.579054e+15    31434386.0      12.0         SZ
# 1              1      1.579054e+15    31472090.0      12.0         SZ
# 2              1      1.579054e+15    31507072.0      12.0         SZ
# 3              1      1.579054e+15    31543611.0      12.0         SZ
# 4              1      1.579054e+15    31579255.0      12.0         SZ
# ...          ...               ...           ...       ...        ...
# 6483934   300813      1.579071e+15   125096907.0      12.0         SZ
# 6483935   300813      1.579071e+15   125206411.0      12.0         SZ
# 6483936   300813      1.579071e+15   125242946.0      12.0         SZ
# 6483937   300813      1.579071e+15   125344949.0      12.0         SZ
# 6483938   300813      1.579071e+15   125377274.0      12.0         SZ
#
#               time_x  cum_volume  cum_amount_x  close  bid1p  ...   ask3q  \
# ...

# %%
data2_1[(data2_1["StockID"] == 1) & (data2_1["cum_amount"]>= 3.521993e+08)]
# Out:
#       StockID    clockAtArrival  sequenceNo  source exchange       time  \
# 982         1  1579486803858813    42555354      12       SZ  101903000
# 983         1  1579486806840473    42581378      12       SZ  101906000
# 984         1  1579486809829163    42605717      12       SZ  101909000
# 985         1  1579486812839714    42631207      12       SZ  101912000
# 986         1  1579486815828798    42655379      12       SZ  101915000
# ...       ...               ...         ...     ...      ...        ...
# 4737        1  1579503466018338   129247648      12       SZ  145645000
# 4738        1  1579503469040767   129281655      12       SZ  145648000
# 4739        1  1579503472053961   129315173      12       SZ  145651000
# 4740        1  1579503475030750   129349276      12       SZ  145654000
# 4741        1  1579503477996819   129381367      12       SZ  145657000
#
#       cum_volume    cum_amount  close  bid1p  ...  ask2p  ask3p  ask4p  ask5p  \
# ...

# %%
data1_1[(data1_1["StockID"] == 1) & (data1_1["time"]>= 100439000)]
# Out:
#       StockID    clockAtArrival  sequenceNo  source exchange       time  \
# 0           1  1579053935149100    31434386      12       SZ  100439000
# 1           1  1579053938159105    31472090      12       SZ  100442000
# 2           1  1579053941159413    31507072      12       SZ  100445000
# 3           1  1579053944157977    31543611      12       SZ  100448000
# 4           1  1579053947158338    31579255      12       SZ  100451000
# ...       ...               ...         ...     ...      ...        ...
# 4042        1  1579071461342808   125228326      12       SZ  145645000
# 4043        1  1579071464334050   125264487      12       SZ  145648000
# 4044        1  1579071467379470   125298927      12       SZ  145651000
# 4045        1  1579071470372141   125332779      12       SZ  145654000
# 4046        1  1579071473323044   125365863      12       SZ  145657000
#
#       cum_volume    cum_amount  close  bid1p  ...  ask2p  ask3p  ask4p  ask5p  \
# ...

# %%
# 3.3 speed check
diff = test["clockAtArrival_y"] - test["clockAtArrival_x"]
print(np.median(diff[diff < 0]))
print(np.median(diff[diff > 0]))
print(sum(diff > 0)/len(diff))
print(sum(diff < 0)/len(diff))
# Out:
# -31909.0
# nan
# C:\Users\win\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\win\Anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 0.0
# 1.0

# %%
test[test["clockAtArrival_y"] - test["clockAtArrival_x"] < 0]
# Out:
#          StockID  clockAtArrival_x  sequenceNo_x  source_x exchange_x  \
# 3125136   300506  1584428185306773      82170513        24         SZ
# 3139988   300516  1584428185306776      82170514        24         SZ
# 3150162   300525  1584428185306777      82170515        24         SZ
# 3163038   300534  1584428185306778      82170516        24         SZ
# 3168930   300538  1584428185306779      82170517        24         SZ
# 3171006   300540  1584428185306780      82170518        24         SZ
# 3174216   300542  1584428185306819      82170521        24         SZ
# 3180539   300547  1584428185306861      82170529        24         SZ
# 3182618   300548  1584428185306862      82170530        24         SZ
# 3185677   300551  1584428185306863      82170531        24         SZ
# 3189668   300554  1584428185306820      82170522        24         SZ
# 3192934   300556  1584428185306780      82170519        24         SZ
# ...

# %%
data2[data2["StockID"] == 1]["time"].unique()
# Out:
# array([113000000, 130000000, 130003000, ..., 145651000, 145654000,
#        145657000], dtype=int64)

# %%
data2[(data2["time"] >= 130000000) & (data2["StockID"] == 1)]
# Out:
#             clockAtArrival  sequenceNo  source  StockID exchange       time  \
# 96686     1584421200492151      221098      21        1       SZ  130000000
# 96687     1584421200492162      221099      21        1       SZ  130000000
# 103642    1584421203714242     1015703      21        1       SZ  130003000
# 111400    1584421206596310     1642715      21        1       SZ  130006000
# 117822    1584421209564859     1802976      21        1       SZ  130009000
# ...                    ...         ...     ...      ...      ...        ...
# 11133513  1584428205519966    82538079      21        1       SZ  145645000
# 11139161  1584428208554970    82590597      21        1       SZ  145648000
# 11144496  1584428211524680    82640690      21        1       SZ  145651000
# 11149981  1584428214534446    82690218      21        1       SZ  145654000
# 11155402  1584428217506098    82740916      21        1       SZ  145657000
#
# ...
